# %%
import openai
from openai import AzureOpenAI, AsyncAzureOpenAI
from tqdm.notebook import tqdm
import os
from dotenv import load_dotenv, find_dotenv
import requests
import base64

GPT_3_5_TURBO = "gpt-3.5-turbo"
GPT_4_TURBO_PREVIEW = "gpt-4-turbo-preview"
GPT_4 = 'gpt-4'
GPT_4o = 'gpt-4o'

def get_openai_api_key():
    _ = load_dotenv(find_dotenv())

    return os.getenv("OPENAI_API_KEY")

OPENAI_API_KEY = get_openai_api_key()
azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),  
    api_version="2024-07-01-preview",
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
)

# %%
source_lang = 'English'
secondary_lang = 'Russian'
target_lang = 'Finnish'

# %%
import json


EVAL_FOLDER = '../../data/russian-english/cards/eval_results/ru_eng_'
def get_ru_finn_eval_results_from_file(file_name):
    data = []
    file_path = EVAL_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

EVAL_FOLDER = '../../data/english-finnish/cards/eval_results/eng_finn_'
def get_eng_finn_eval_results_from_file(file_name):
    data = []
    file_path = EVAL_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

RU_ENG_OUTPUT_FOLDER = '../../data/russian-english/cards/test_cards/ru_eng_'
def get_ru_eng_cards_from_file(file_name):
    data = []
    file_path = OUTPUT_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data


RU_FINN_FOLDER_WITH_JSON = '../../data/russian-finnish/cards/curated_platform_cards/'
def get_ru_finn_cards_from_file(file_name):
    data = []
    file_path = RU_FINN_FOLDER_WITH_JSON + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    res = []
    for card in data:
        if 'isMarkedDeleted' not in card.keys():
            res.append(card)
    return res


ENG_FINN_OUTPUT_FOLDER = '../../data/english-finnish/cards/test_cards/eng_finn_'
def get_eng_finn_cards_from_file(file_name):
    data = []
    file_path = ENG_FINN_OUTPUT_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data


OUTPUT_FOLDER = '../../data/english-finnish/cards/test_cards/eng_finn_'
def write_cards_to_file(file_name, cards):
    file_path = OUTPUT_FOLDER + file_name
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(cards, f, ensure_ascii=False, indent=2)
        
        
EVAL_FOLDER = '../../data/english-finnish/cards/eval_results/eng_finn_'
def write_eval_results_to_file(file_name, results):
    file_path = EVAL_FOLDER + file_name
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

# %%
def generate_phrase_card(source_card, secondary_card, card_id, source_lang, target_lang, secondary_lang, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()

    system_prompt = f'''You are a multilingual assistant who is proficient in {source_lang}, {secondary_lang} and {target_lang}.'''

    user_prompt = f"""
    Translate the given {source_lang} word or phrase: '{source_word}' into clear and natural {target_lang}, reflecting its meaning and context as the primary focus. Use the {secondary_lang} equivalent: '{secondary_word}' as a supportive reference to help clarify or refine the exact context if needed. The goal is to create a {target_lang} translation that is accurate, fluent, and authentic to native speakers, avoiding overly complex or literal phrasing.

    Please provide the {target_lang} translation of the word or phrase and nothing else.

    Important formatting rules:
    1. Ensure punctuation consistency with the source language:
        - If the source word or phrase ends with a period, the translation should also end with a period unless there is another example in brackets
    2. Maintain consistent capitalization rules between source and target languages:
        - If the source word or phrase ends starts with lower case letter, the translation should also start with lower case letter
    3. Return the translation without any external quotation marks:
        - Do not wrap the result in quotes
    4. Return only the translation without any additions
    """

    response = client.chat.completions.create(
        model=model,
        messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
        ]
    )

    tr_word = response.choices[0].message.content.strip()

    card = {}
    card["word"] = tr_word
    card["sentence"] = ""
    card["id"] = card_id

    return card

# %%
def generate_full_card(source_card, secondary_card, card_id, source_lang, target_lang, secondary_lang, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()

    system_prompt = f'''You are a multilingual assistant who is proficient in {source_lang}, {secondary_lang} and {target_lang}.'''

    user_prompt = f"""
    **Translate the given {source_lang} word or phrase along with its {secondary_lang} translation into {target_lang}, and then translate the provided {source_lang} sentence, incorporating the {target_lang} translation of the word or phrase. Use synonyms or related terms where necessary to convey the intended meaning and maintain naturalness in {target_lang}.**  

    Given word or phrase ({source_lang}): '{source_word}'  
    Given word or phrase ({secondary_lang}): '{secondary_word}'  

    Given sentence ({source_lang}): '{source_sentence}'  
    Given sentence ({secondary_lang}): '{secondary_sentence}'  

    ### Response structure:  

    Respond in JSON format with the following structure:
    {{
        "translatedWord": "Translated word in {target_lang}",
        "translatedSentence": "Translated sentence in {target_lang}"
    }}
    ```

    Important formatting rules:
    1. Ensure punctuation consistency with the source language:
        - If the source word or phrase ends with a period, the translation should also end with a period unless there is another example in brackets
    2. Maintain consistent capitalization rules between source and target languages:
        - If the source word or phrase ends starts with lower case letter, the translation should also start with lower case letter
    3. Return the translation without any external quotation marks:
        - Do not wrap the result in quotes
    """

    response = client.chat.completions.create(
        model=model,
        response_format={ "type": "json_object" },
        messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
        ]
    )
    
    response_dict = json.loads(response.choices[0].message.content.strip())
    tr_word = response_dict['translatedWord']
    tr_sentence = response_dict['translatedSentence']

    card = {}
    card["word"] = tr_word.strip()
    card["sentence"] = tr_sentence.strip()
    card["id"] = card_id

    return card

# %%
def eval_phrase_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()
    target_word, target_sentence, _ = target_card.items()

    system_prompt = f'''You are a multilingual assistant who is proficient in {source_lang}, {secondary_lang} and {target_lang}.'''

    user_prompt = f"""
    **As an AI model, your task is to evaluate the correctness and naturalness of {target_lang} translations for given {source_lang} and {secondary_lang} words or phrases. Check if the {target_lang} translation accurately conveys the meaning and context of the {source_lang} and {secondary_lang} versions, and whether it sounds natural to a native speaker. Your evaluation does not need to suggest the best possible translation, only confirm that it is good enough and identify any issues if present.**  

    When suggesting corrections, provide only the final corrected {target_lang} translation. If no correction is needed, set `suggestedFix` to `null`.  

    Here are the words or phrases:  
    - Word or Phrase in {source_lang}: {source_word}  
    - Word or Phrase in {secondary_lang}: {secondary_word}  
    - Word or Phrase in {target_lang}: {target_word}  

    Respond in JSON format using the following structure:
    {{
      "translationAccuracy": {{
        "isCorrect": true/false,
        "explanation": "Detailed explanation if there is an issue or why it's correct",
        "suggestedFix": "Suggested correction if there is an issue or null if no correction is needed"
      }}
    }}
    """

    response = client.chat.completions.create(
      model=model,
      response_format={ "type": "json_object" },
      messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
      ]
    )

    res = json.loads(response.choices[0].message.content.strip())
    res['id'] = card_id

    return res

# %%
def eval_full_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()
    target_word, target_sentence, _ = target_card.items()

    system_prompt = f'''You are a multilingual assistant who is proficient in {source_lang}, {secondary_lang} and {target_lang}.'''

    user_prompt = f"""
    **Evaluate the correctness of a {target_lang} word and sentence based on their translations from {source_lang} and {secondary_lang}. You will receive a word in {source_lang}, {secondary_lang}, and its translation in {target_lang}, as well as a sentence in {source_lang}, {secondary_lang}, and its translation in {target_lang}. Your task is to assess the quality of the {target_lang} sentence, the usage of the {target_lang} word in the sentence, and the accuracy of the translations from {source_lang} and {secondary_lang} to {target_lang}. For each evaluation point, provide a detailed explanation of your judgment and suggest fixes where applicable, either to the {target_lang} word, the {target_lang} sentence, or both.**  

    Please ensure that the {target_lang} sentence is grammatically correct and natural. Suggest a corrected version if necessary. Verify that the {target_lang} sentence contains the {target_lang} word in some form and suggest using synonyms or related terms if the word is missing. Prioritize naturalness and correctness. Ensure that the translations of both the word and sentence from {source_lang} and {secondary_lang} to {target_lang} are accurate and provide corrections if necessary.  

    Respond in JSON format with the following structure:  
    {{
        "sentenceCorrectness": {{
            "isCorrect": true/false,
            "explanation": "Detailed explanation if there is an issue or why it's correct.",
            "suggestedFix": "Suggested corrected sentence if there is an issue, or null if not applicable."
        }},
        "wordUsage": {{
            "isCorrect": true/false,
            "explanation": "Detailed explanation if there is an issue or why it's correct.",
            "suggestedFixSentence": "Suggested corrected sentence if the word usage is incorrect, or null if not applicable.",
            "suggestedFixWord": "Suggested corrected word if the word usage is incorrect, or null if not applicable."
        }},
        "wordTranslationAccuracy": {{
            "isCorrect": true/false,
            "explanation": "Detailed explanation if there is an issue or why it's correct.",
            "suggestedFix": "Suggested correction for translation issues, or null if not applicable."
        }},
        "sentenceTranslationAccuracy": {{
            "isCorrect": true/false,
            "explanation": "Detailed explanation if there is an issue or why it's correct.",
            "suggestedFix": "Suggested correction for translation issues, or null if not applicable."
        }}
    }}

    Here are the provided word and sentence in {source_lang}, {secondary_lang}, and {target_lang}:  

    - Word in {source_lang}: {source_word}  
    - Word in {secondary_lang}: {secondary_word}  
    - Word in {target_lang}: {target_word}  
    - Sentence in {source_lang}: {source_sentence}  
    - Sentence in {secondary_lang}: {secondary_sentence}  
    - Sentence in {target_lang}: {target_sentence}  

    Please adhere to this structure to ensure clear, actionable feedback for each evaluation point.
    """

    response = client.chat.completions.create(
      model=model,
      response_format={ "type": "json_object" },
      messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
      ]
    )

    res = json.loads(response.choices[0].message.content.strip())
    res['id'] = card_id

    return res

# %%
BASE_SYSTEM_PROMPT = f'''You are a multilingual assistant who is proficient in {source_lang}, {secondary_lang} and {target_lang}.'''

# %%
def improve_phrase_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result, system_prompt=BASE_SYSTEM_PROMPT, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()
    target_word, target_sentence, _ = target_card.items()

    _, explanation, suggested_fix = eval_result['translationAccuracy'].values()

    user_prompt = f"""
    **Translate the given {source_lang} word or phrase: '{source_word}' into clear and natural {target_lang}, prioritizing its meaning and how it would sound most authentic and fluent to native speakers. Use the {secondary_lang} equivalent: '{secondary_word}' as a supportive reference if it helps refine the context or meaning. While accuracy is important, favor translations that fit naturally into everyday {target_lang}, even if they are not the most direct equivalents.**  

    Consider the following:  
    - Existing {target_lang} translation: '{target_word}'  
    - Issues identified: '{explanation}'  
    - Suggested improvement: '{suggested_fix}'  

    ### Instructions:  
    Based on the information provided, craft a {target_lang} translation that balances accuracy, naturalness, and context. You may adapt the word or phrase slightly to ensure it resonates well with native speakers and fits its intended use.  

    **Respond with only the final {target_lang} translation without any additional explanations, just word or phrase in {target_lang}.**

    Important formatting rules:
    1. Ensure punctuation consistency with the source language:
        - If the source word or phrase ends with a period, the translation should also end with a period unless there is another example in brackets
    2. Maintain consistent capitalization rules between source and target languages:
        - If the source word or phrase ends starts with lower case letter, the translation should also start with lower case letter
    3. Return the translation without any external quotation marks:
        - Do not wrap the result in quotes
    4. Return only the translation without any additions
    """

    response = client.chat.completions.create(
        model=model,
        messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
        ]
    )
    
    tr_word = response.choices[0].message.content.strip()

    card = {}
    card["word"] = tr_word
    card["sentence"] = ""
    card["id"] = card_id

    return card

# %%
def improve_full_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result, system_prompt=BASE_SYSTEM_PROMPT, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()
    target_word, target_sentence, _ = target_card.items()

    user_prompt = f"""
    **Translate the given {source_lang} word or phrase into {target_lang} and use it within the provided {source_lang} sentence to create a natural and accurate {target_lang} translation. Use the {secondary_lang} word or sentence as additional context if needed. Focus on accurately conveying the meaning of the {source_lang} source while incorporating all feedback and suggestions from the evaluation results.**  

    When choosing the {target_lang} word or phrase, prioritize naturalness and fluency in the sentence over strict accuracy. While the translation should reflect the original meaning, it is acceptable to use a word or phrase that is not the most direct translation but still conveys the intended sense in a way that sounds natural and idiomatic in {target_lang}.  

    ### **Details to guide your translation:**  

    - **Word or phrase in {source_lang}:** '{source_word}'  
    - **Word or phrase in {secondary_lang}:** '{secondary_word}'  
    - **Sentence in {source_lang}:** '{source_sentence}'  
    - **Sentence in {secondary_lang}:** '{secondary_sentence}'  
    - **Existing {target_lang} translation of the word or phrase:** '{target_word}'  
    - **Existing {target_lang} translation of the sentence:** '{target_sentence}'  

    ### **Evaluation Results Summary:**  

    **{target_lang} Sentence Evaluation:**  
    - **Correctness:** {eval_result['sentenceCorrectness']['isCorrect']}  
    - **Explanation:** {eval_result['sentenceCorrectness']['explanation']}  
    - **Suggested Fix (if applicable):** {eval_result['sentenceCorrectness']['suggestedFix']}  

    **Word Usage Evaluation:**  
    - **Correctness:** {eval_result['wordUsage']['isCorrect']}  
    - **Explanation:** {eval_result['wordUsage']['explanation']}  
    - **Suggested Fix for Word (if applicable):** {eval_result['wordUsage']['suggestedFixWord']}  
    - **Suggested Fix for Sentence (if applicable):** {eval_result['wordUsage']['suggestedFixSentence']}  

    **Word Translation Accuracy Evaluation:**  
    - **Correctness:** {eval_result['wordTranslationAccuracy']['isCorrect']}  
    - **Explanation:** {eval_result['wordTranslationAccuracy']['explanation']}  
    - **Suggested Fix (if applicable):** {eval_result['wordTranslationAccuracy']['suggestedFix']}  

    **Sentence Translation Accuracy Evaluation:**  
    - **Correctness:** {eval_result['sentenceTranslationAccuracy']['isCorrect']}  
    - **Explanation:** {eval_result['sentenceTranslationAccuracy']['explanation']}  
    - **Suggested Fix (if applicable):** {eval_result['sentenceTranslationAccuracy']['suggestedFix']}  

    ### **Instructions:**  

    1. **Review the Evaluation Feedback:**  
    - Carefully consider all provided explanations and suggested fixes for the word or phrase, sentence, and overall translation accuracy.  

    2. **Translate the Word or Phrase:**  
    - Choose a translation that balances accuracy with naturalness.  
    - If the word usage is marked incorrect, incorporate the suggested fix or refine it further for better contextual alignment.  

    3. **Translate the {source_lang} Sentence:**  
    - Integrate the translated word or phrase naturally into the sentence.  
    - If the sentence translation is marked incorrect, incorporate the suggested fixes and adjust for fluency and clarity.  

    4. **Address Translation Accuracy Issues:**  
    - If any translation inaccuracies are identified, apply the suggested fixes or clarify the meaning while ensuring the translation sounds natural and idiomatic.  

    5. **Leverage Context:**  
    - Use the {secondary_lang} word or sentence as additional guidance where necessary.  

    6. **Produce a Polished Result:**  
    - Ensure the final translation conveys the intended meaning, aligns naturally with the sentence, and incorporates feedback from the evaluation results.  

    ### **Response structure:**  

    Respond in JSON format with the following structure:  
    {{
        "translatedWord": "Translated word in {target_lang}",
        "translatedSentence": "Translated sentence in {target_lang}"
    }}

    Important formatting rules:
    1. Ensure punctuation consistency with the source language:
        - If the source word or phrase ends with a period, the translation should also end with a period unless there is another example in brackets
    2. Maintain consistent capitalization rules between source and target languages:
        - If the source word or phrase ends starts with lower case letter, the translation should also start with lower case letter
    3. Return the translation without any external quotation marks (do not wrap the result in quotes)
    """

    response = client.chat.completions.create(
        model=model,
        response_format={ "type": "json_object" },
        messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
        ]
    )
    
    response_dict = json.loads(response.choices[0].message.content.strip())
    tr_word = response_dict['translatedWord']
    tr_sentence = response_dict['translatedSentence']

    card = {}
    card["word"] = tr_word.strip()
    card["sentence"] = tr_sentence.strip()
    card["id"] = card_id

    return card

# %%
def is_phrase_card(card):
    return card['sentence'] == ''

# %%
def check_eval(eval_result, is_phrase_card_):
    if is_phrase_card_:
        return eval_result['translationAccuracy']['isCorrect']
    
    w_tr_accuracy = eval_result['wordTranslationAccuracy']['isCorrect']
    s_tr_accuracy = eval_result['sentenceTranslationAccuracy']['isCorrect']
    s_accuracy = eval_result['sentenceCorrectness']['isCorrect']
    w_accuracy = eval_result['wordUsage']['isCorrect']
    
    return all([w_tr_accuracy, s_tr_accuracy, s_accuracy, w_accuracy])

# %%
def regressor(source_card, secondary_card, target_cards, card_id, source_lang, target_lang, secondary_lang, n_models=3, model=GPT_4o):

    source_word, source_sentence, _ = source_card.items()
    secondary_word, secondary_sentence, _ = secondary_card.items()

    target_words = [card['word'] for card in target_cards]
    target_sentences = [card['sentence'] for card in target_cards]

    models_response = ''
    for i in range(n_models):
        models_response += f"""{i + 1}. `Model {i + 1}` Response: {{ "{target_lang}Word": '{target_words[i]}', "{target_lang}Sentence": '{target_sentences[i]}'}}\n"""

    system_prompt = f'''Act as a translation evaluator and synthesizer. Assess model-generated translations for a {source_lang} word/phrase and its sentence, prioritizing accuracy, fluency, and contextual fit. Return the best translations in JSON format with refinements if necessary.'''

    user_prompt = f"""
**Instruction for the Regressor**:  
Evaluate the translations provided by different models for a given {source_lang} word or phrase and its accompanying sentence. Select or synthesize the best {target_lang} translation for the word and sentence based on:
1. **Accuracy**: Ensure the translation reflects the original {source_lang} meaning correctly.
2. **Naturalness**: The {target_lang} translations should be fluid and use appropriate synonyms or phrasing where needed.
3. **Consistency**: The translated sentence should appropriately incorporate the word's translation.

### Input:
Given word or phrase ({source_lang}): '{source_word}'  
Given word or phrase ({secondary_lang}): '{secondary_word}'  

Given sentence ({source_lang}): '{source_sentence}'  
Given sentence ({secondary_lang}): '{secondary_sentence}'  

Responses from models:
{models_response}

---

### Task:
Critically evaluate these responses, identify the best translations, and synthesize a single, high-quality translation. If needed, refine the translations to ensure accuracy and naturalness. Do not simply copy; improve where necessary.

### Response structure:
Respond in JSON format with the following structure:
{{
    "{target_lang}Word": "Best translated word in {target_lang}",
    "{target_lang}Sentence": "Best translated sentence in {target_lang}"
}}

---

### Key Considerations for Evaluation:
- **Accuracy**: Does the translation reflect the original meaning and nuances in {source_lang}?
- **Fluency**: Is the translation grammatically correct and natural in {target_lang}?
- **Contextual Fit**: Does the sentence correctly integrate the translation of the word or phrase?

Important formatting rules:
1. Ensure punctuation consistency with the source language:
    - If the source word or phrase ends with a period, the translation should also end with a period unless there is another example in brackets
2. Maintain consistent capitalization rules between source and target languages:
    - If the source word or phrase ends starts with lower case letter, the translation should also start with lower case letter
3. Return the translation without any external quotation marks (do not wrap the result in quotes)
    """

    response = client.chat.completions.create(
        model=model,
        response_format={ "type": "json_object" },
        messages=[
        {"role": "system", "content": system_prompt.strip()},
        {"role": "user", "content": user_prompt.strip()}
        ]
    )
    
    response_dict = json.loads(response.choices[0].message.content.strip())
    target_word = response_dict[f'{target_lang}Word']
    target_sentence = response_dict[f'{target_lang}Sentence']

    card = {}
    card["word"] = target_word.strip()
    card["sentence"] = target_sentence.strip()
    card["id"] = card_id

    return card

# %%
system_prompts = [
    "Act as a linguistic expert specializing in Russian, Finnish, and English translations. Evaluate the given English word and sentence translations in conjunction with the Russian context. Based on evaluation feedback, refine the word and sentence translations for accuracy, fluency, and naturalness, ensuring idiomatic Finnish usage. Provide the response in JSON format.",
    "Take on the role of a translator focusing on contextual accuracy. Use the provided English and Russian inputs, along with feedback evaluations, to create an Finnish translation that balances precise meaning with natural phrasing. Address inaccuracies and ensure the translation reads fluent?ly and idiomatically. Respond in JSON format.",
    "Serve as a cultural localization specialist. Translate the provided English word and sentence into Finnish, using the Russian context and feedback to enhance naturalness and idiomatic expression. Focus on making the translation contextually relevant and fluent for an Finnish-speaking audience. Provide your output in JSON format."
]

# %%
def meaxture_of_improving_agents(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result, n_models=3):
    is_phrase_card_ = is_phrase_card(source_card)

    target_cards = []
    for s_p in system_prompts:
        improved_eng_finn_card = {}

        if is_phrase_card_:
            improved_eng_finn_card = improve_phrase_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result, system_prompt=s_p)
        else:
            improved_eng_finn_card = improve_full_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result, system_prompt=s_p)

        target_cards.append(improved_eng_finn_card)

    card = regressor(source_card, secondary_card, target_cards, card_id, source_lang, target_lang, secondary_lang, n_models)

    return card

# %%
def card_handler_with_agents(source_card, secondary_card, card_id, source_lang, target_lang, secondary_lang, num_iter=5, num_agents=3):
    is_phrase_card_ = is_phrase_card(source_card)

    target_card = {}

    if is_phrase_card_:
        target_card = generate_phrase_card(source_card, secondary_card, card_id, source_lang, target_lang, secondary_lang)
    else:
        target_card = generate_full_card(source_card, secondary_card, card_id, source_lang, target_lang, secondary_lang)

    eval_result = {}

    if is_phrase_card_:
        eval_result = eval_phrase_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang)
    else:
        eval_result = eval_full_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang)

    for _ in range(num_iter):
        if check_eval(eval_result, is_phrase_card_):
            break
        
        if is_phrase_card_:
            target_card = meaxture_of_improving_agents(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result)
        else:
            target_card = meaxture_of_improving_agents(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang, eval_result)

        if is_phrase_card_:
            eval_result = eval_phrase_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang)
        else:
            eval_result = eval_full_card(source_card, secondary_card, target_card, card_id, source_lang, target_lang, secondary_lang)
    
    return target_card, eval_result

# %%
import logging

logging.basicConfig(
    filename='errors.txt',
    level=logging.ERROR,
    format='%(message)s',
    filemode='a'
)

def generate_source_target_cards_with_eval_results(source_cards, secondary_cards, source_lang, target_lang, secondary_lang):

    source_target_cards = []
    eval_results = []

    for source_card, secondary_card in tqdm(list(zip(source_cards, secondary_cards))):
        card_id = source_card['id']

        while True:
            try:
                target_card, eval_res = card_handler_with_agents(source_card, secondary_card, card_id, source_lang, target_lang, secondary_lang)

                card = {}
                card["wordFirstLang"] = source_card['word']
                card["sentenceFirstLang"] = source_card['sentence']
                card["wordSecondLang"] = target_card['word']
                card["sentenceSecondLang"] = target_card['sentence']
                card["id"] = card_id

                source_target_cards.append(card)
                eval_results.append(eval_res)
                break
            except Exception as e:
                logging.error(str(e))
                pass

    assert len(source_target_cards) == len(eval_results)

    return source_target_cards, eval_results

# %%
def example():
    ru_finn_cards = get_ru_finn_cards_from_file('sm1_new_kap1.json')

    source_cards = [{'word': card["wordSecondLang"], 'sentence': card["sentenceSecondLang"], 'id': card['id']} for card in ru_finn_cards]
    secondary_cards = [{'word': card["wordFirstLang"], 'sentence': card["sentenceFirstLang"], 'id': card['id']} for card in ru_finn_cards]

    source_lang, target_lang, secondary_lang = 'Finnish', 'English', 'Russian'

    source_target_cards, eval_results = generate_source_target_cards_with_eval_results(source_cards, secondary_cards, source_lang, target_lang, secondary_lang)

    res = []
    for card, eval_res in list(zip(source_target_cards, eval_results)):
        res.append(check_eval(eval_res, card['sentenceFirstLang'] == ''))
    
    print(sum(res) / len(res))

# %%
example()
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]

# %%
def get_bad_cards_from_files(file_names):
    bad_ru_finn_cards = []
    bad_eng_finn_cards = []
    for file_name in file_names:
        ru_finn_cards = get_ru_finn_cards_from_file(file_name)
        eng_finn_cards = get_eng_finn_cards_from_file(file_name)

        for eng_finn, ru_finn in list(zip(eng_finn_cards, ru_finn_cards)):
            if eng_finn['wordSecondLang'] != ru_finn['wordSecondLang'] or eng_finn['sentenceSecondLang'] != ru_finn['sentenceSecondLang']:
                bad_eng_finn_cards.append(eng_finn)
                bad_ru_finn_cards.append(ru_finn)

    return bad_ru_finn_cards, bad_eng_finn_cards

# %%
file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
file_names.append('sm2_new_puhekieli.json')
file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])
file_names.extend([f'sm4_kap{i}.json' for i in range(1, 6)])

# %%
bad_ru_finn_cards, bad_eng_finn_cards = get_bad_cards_from_files(file_names)

# %%
source_cards = [{'word': card["wordSecondLang"], 'sentence': card["sentenceSecondLang"], 'id': card['id']} for card in bad_ru_finn_cards]
secondary_cards = [{'word': card["wordFirstLang"], 'sentence': card["sentenceFirstLang"], 'id': card['id']} for card in bad_ru_finn_cards]

source_lang, target_lang, secondary_lang = 'Finnish', 'English', 'Russian'

source_target_cards, eval_results = generate_source_target_cards_with_eval_results(source_cards, secondary_cards, source_lang, target_lang, secondary_lang)
# Out:
#   0%|          | 0/471 [00:00<?, ?it/s]

# %%
results = []

for ru_eng, eval_res in list(zip(source_target_cards, eval_results)):
    results.append(check_eval(eval_res, (ru_eng['sentenceFirstLang'] == '')))

sum(results) / len(results)
# Out:
# 0.8535031847133758

# %%
ids = [card['id'] for card in source_target_cards]

# %%
def check_eval_old(eval_result, is_phrase_card):
    if is_phrase_card:
        return eval_result['translationAccuracy']['isCorrect']
    
    w_tr_accuracy = eval_result['wordTranslationAccuracy']['isCorrect']
    s_tr_accuracy = eval_result['sentenceTranslationAccuracy']['isCorrect']
    s_accuracy = eval_result['englishSentenceCorrectness']['isCorrect']
    w_accuracy = eval_result['wordUsage']['isCorrect']
    
    return all([w_tr_accuracy, s_tr_accuracy, s_accuracy, w_accuracy])

# %%
def check_all_cards_from_files(file_names):
    results = []
    for file_name in file_names:
        eng_finn_cards = get_eng_finn_cards_from_file(file_name)
        eng_finn_eval = get_eng_finn_eval_results_from_file(file_name)

        for eng_finn, eval_res in list(zip(eng_finn_cards, eng_finn_eval)):
            is_phrase_card = (eng_finn['sentenceFirstLang'] == '')

            if eng_finn['id'] in ids:
                for true_eval in eval_results:
                    if true_eval['id'] == eng_finn['id']:
                        results.append(check_eval(true_eval, is_phrase_card))
                        break
            else:
                results.append(check_eval_old(eval_res, is_phrase_card))

    return sum(results) / len(results)

# %%
check_all_cards_from_files(file_names)
# Out:
# 0.9842196623007733

# %%
def swap_cards(card_list):
    new_list = []
    for card in card_list:
        card['wordFirstLang'], card['sentenceFirstLang'], card['wordSecondLang'], card['sentenceSecondLang'] = card['wordSecondLang'], card['sentenceSecondLang'], card['wordFirstLang'], card['sentenceFirstLang']
        new_list.append(card)
    return new_list

# %%
final_cards = swap_cards(source_target_cards)

# %%
def update_eng_finn_cards(file_name):
    new_eng_finn_cards = []
    new_eng_finn_evals = []

    eng_finn_cards = get_eng_finn_cards_from_file(file_name)
    eng_finn_eval = get_eng_finn_eval_results_from_file(file_name)
    
    for eng_finn, eval_res in list(zip(eng_finn_cards, eng_finn_eval)):
        if eng_finn['id'] in ids:
            for card, true_eval in list(zip(final_cards, eval_results)):
                if card['id'] == eng_finn['id']:
                    new_eng_finn_cards.append(card)
                    new_eng_finn_evals.append(true_eval)
                    break
        else:
            new_eng_finn_cards.append(eng_finn)
            new_eng_finn_evals.append(eval_res)
    
    write_cards_to_file(file_name, new_eng_finn_cards)
    write_eval_results_to_file(file_name, new_eng_finn_evals)

# %%
for file_name in file_names:
    update_eng_finn_cards(file_name)

# %%
should_be_empty, _ = get_bad_cards_from_files(file_names)

# %%
should_be_empty
# Out:
# []

# %%
test_cards = []
with open('./test_cards.json', 'r', encoding='utf-8') as file:
    test_cards = json.load(file)
test_cards
# Out:
# [{'id': 6130,
#   'translations': {'ru': {'word': 'турнир',
#     'sentence': 'Турнир проводится в субботу в школьном зале.'},
#    'fi': {'word': 'turnaus',
#     'sentence': 'Turnaus järjestetään lauantaina koulun salissa.'},
#    'en': {'word': 'tournament',
#     'sentence': 'The tournament is held on Saturday in the school hall.'}}},
#  {'id': 6141,
#   'translations': {'ru': {'word': 'матч',
#     'sentence': 'Матч начинается в 18:00.'},
#    'fi': {'word': 'ottelu', 'sentence': 'Ottelu alkaa klo 18.'},
#    'en': {'word': 'match', 'sentence': 'The match starts at 6:00 PM.'}}},
#  {'id': 6182,
#   'translations': {'ru': {'word': 'соревнование',
#     'sentence': 'Соревнование начинается ровно в десять часов.'},
#    'fi': {'word': 'kilpailu (kisa)',
#     'sentence': 'Kisa alkaa tasan kello kymmenen.'},
#    'en': {'word': 'competition',
#     'sentence': "The competition begins precisely at ten o'clock."}}},
#  {'id': 6192,
#   'translations': {'ru': {'word': 'отправление',
#     'sentence': 'Отправление завтра в девять часов.'},
#    'fi': {'word': 'lähtö', 'sentence': 'Lähtö on huomenna kello yhdeksän.'},
#    'en': {'word': 'departure',
#     'sentence': "The departure is tomorrow at nine o'clock."}}},
#  {'id': 6196,
#   'translations': {'ru': {'word': 'поражение',
#     'sentence': 'Команда потерпела горькое поражение во вчерашнем матче.'},
#    'fi': {'word': 'häviö (tappio)',
#     'sentence': 'Joukkue kärsi kirvelevän häviön eilisessä ottelussa.'},
#    'en': {'word': 'defeat',
#     'sentence': "The team suffered a bitter defeat in yesterday's match."}}},
#  {'id': 6197,
#   'translations': {'ru': {'word': 'ничья',
#     'sentence': 'Игра закончилась вничью.'},
#    'fi': {'word': 'tasapeli', 'sentence': 'Peli päättyi tasapeliin.'},
#    'en': {'word': 'draw', 'sentence': 'The game ended in a draw.'}}},
#  {'id': 6258,
#   'translations': {'ru': {'word': 'который',
#     'sentence': 'В который раз ты посещаешь этот музей?'},
#    'fi': {'word': 'monetta',
#     'sentence': 'Monettako kertaa olet käynyt tässä museossa?'},
#    'en': {'word': 'how many times',
#     'sentence': 'How many times have you visited this museum?'}}},
#  {'id': 6286,
#   'translations': {'ru': {'word': 'всё ещё', 'sentence': 'Мы всё ещё друзья?'},
#    'fi': {'word': 'yhä', 'sentence': 'Olemmeko yhä ystäviä?'},
#    'en': {'word': 'still', 'sentence': 'Are we still friends?'}}},
#  {'id': 6298,
#   'translations': {'ru': {'word': 'решать',
#     'sentence': 'Они решают поехать в Италию следующим летом.'},
#    'fi': {'word': 'päättää',
#     'sentence': 'He päättävät matkustaa Italiaan ensi kesänä.'},
#    'en': {'word': 'decide',
#     'sentence': 'They decide to travel to Italy next summer.'}}},
#  {'id': 6309,
#   'translations': {'ru': {'word': 'искатель талантов',
#     'sentence': 'Искатель талантов заметил талант молодого певца.'},
#    'fi': {'word': 'kykyjenetsijä',
#     'sentence': 'Kykyjenetsijä huomasi nuoren laulajan talentin.'},
#    'en': {'word': 'talent scout',
#     'sentence': "The talent scout noticed the young singer's talent."}}},
#  {'id': 6325,
#   'translations': {'ru': {'word': 'посол',
#     'sentence': 'В Германии новый посол Финляндии.'},
#    'fi': {'word': 'suurlähettiläs',
#     'sentence': 'Saksassa on uusi Suomen suurlähettiläs.'},
#    'en': {'word': 'ambassador',
#     'sentence': 'Germany has a new Finnish ambassador.'}}},
#  {'id': 6327,
#   'translations': {'ru': {'word': 'воздвигать, устанавливать',
#     'sentence': 'Они собираются установить палатку на кемпинговой площадке.'},
#    'fi': {'word': 'pystyttää',
#     'sentence': 'He aikovat pystyttää teltan leirintäalueelle.'},
#    'en': {'word': 'to erect, to set up',
#     'sentence': 'They are going to set up a tent at the campsite.'}}},
#  {'id': 6330,
#   'translations': {'ru': {'word': 'двадцать четыре',
#     'sentence': 'Время — два часа и двадцать четыре минуты.'},
#    'fi': {'word': 'kakskyneljä',
#     'sentence': 'Kello on kakskyneljä yli kaksi.'},
#    'en': {'word': 'twenty-four',
#     'sentence': 'The time is twenty-four past two.'}}}]

# %%
def create_cards_list(base_cards, source_key, secondary_key):
    source_cards = []
    secondary_cards = []

    for item in base_cards:
        source_card = item['translations'][source_key]
        source_card['id'] = item['id']

        secondary_card = item['translations'][secondary_key]
        secondary_card['id'] = item['id']

        source_cards.append(source_card)
        secondary_cards.append(secondary_card)
    
    return source_cards, secondary_cards

# %%
test_source_cards, test_secondary_cards = create_cards_list(test_cards, 'en', 'ru')

# %%
test_source_target_cards, test_eval_results = generate_source_target_cards_with_eval_results(test_source_cards, test_secondary_cards, 'Finnish', 'Kazakh', 'English')
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
test_source_target_cards
# Out:
# [{'wordFirstLang': 'turnaus',
#   'sentenceFirstLang': 'Turnaus järjestetään lauantaina koulun salissa.',
#   'wordSecondLang': 'турнир/жарыс',
#   'sentenceSecondLang': 'Турнир сенбі күні мектеп залында өткізіледі.',
#   'id': 6130},
#  {'wordFirstLang': 'ottelu',
#   'sentenceFirstLang': 'Ottelu alkaa klo 18.',
#   'wordSecondLang': 'сөз, матч',
#   'sentenceSecondLang': 'Матч кешкі сағат 6-да басталады.',
#   'id': 6141},
#  {'wordFirstLang': 'kilpailu (kisa)',
#   'sentenceFirstLang': 'Kisa alkaa tasan kello kymmenen.',
#   'wordSecondLang': 'жарыс',
#   'sentenceSecondLang': 'Жарыс дәл сағат онде басталады.',
#   'id': 6182},
#  {'wordFirstLang': 'lähtö',
#   'sentenceFirstLang': 'Lähtö on huomenna kello yhdeksän.',
#   'wordSecondLang': 'кету',
#   'sentenceSecondLang': 'Кету ертең сағат тоғызда.',
#   'id': 6192},
#  {'wordFirstLang': 'häviö (tappio)',
#   'sentenceFirstLang': 'Joukkue kärsi kirvelevän häviön eilisessä ottelussa.',
#   'wordSecondLang': 'жеңіліс',
#   'sentenceSecondLang': 'Команда кеше өткен матчта ащы жеңіліске ұшырады.',
#   'id': 6196},
#  {'wordFirstLang': 'tasapeli',
#   'sentenceFirstLang': 'Peli päättyi tasapeliin.',
#   'wordSecondLang': 'тең нәтиже',
#   'sentenceSecondLang': 'Ойын тең нәтижемен аяқталды.',
#   'id': 6197},
#  {'wordFirstLang': 'monetta',
#   'sentenceFirstLang': 'Monettako kertaa olet käynyt tässä museossa?',
#   'wordSecondLang': 'рет',
#   'sentenceSecondLang': 'Сіз бұл мұражайда қанша рет болдыңыз?',
#   'id': 6258},
#  {'wordFirstLang': 'yhä',
#   'sentenceFirstLang': 'Olemmeko yhä ystäviä?',
#   'wordSecondLang': 'әлі',
#   'sentenceSecondLang': 'Біз әлі де достармыз ба?',
#   'id': 6286},
#  {'wordFirstLang': 'päättää',
#   'sentenceFirstLang': 'He päättävät matkustaa Italiaan ensi kesänä.',
#   'wordSecondLang': 'шешім қабылдау',
#   'sentenceSecondLang': 'Олар келесі жазда Италияға саяхаттауға шешім қабылдады.',
#   'id': 6298},
#  {'wordFirstLang': 'kykyjenetsijä',
#   'sentenceFirstLang': 'Kykyjenetsijä huomasi nuoren laulajan talentin.',
#   'wordSecondLang': 'талант аңшысы',
#   'sentenceSecondLang': 'Талант аңшысы жас әншінің дарынын байқады.',
#   'id': 6309},
#  {'wordFirstLang': 'suurlähettiläs',
#   'sentenceFirstLang': 'Saksassa on uusi Suomen suurlähettiläs.',
#   'wordSecondLang': 'елші',
#   'sentenceSecondLang': 'Германияда Финляндияның жаңа елшісі бар.',
#   'id': 6325},
#  {'wordFirstLang': 'pystyttää',
#   'sentenceFirstLang': 'He aikovat pystyttää teltan leirintäalueelle.',
#   'wordSecondLang': 'тігу',
#   'sentenceSecondLang': 'Олар лагерьде шатыр тігеді.',
#   'id': 6327},
#  {'wordFirstLang': 'kakskyneljä',
#   'sentenceFirstLang': 'Kello on kakskyneljä yli kaksi.',
#   'wordSecondLang': 'жиырма төрт',
#   'sentenceSecondLang': 'Сағат екіден жиырма төрт минут өткенде.',
#   'id': 6330}]

# %%
test_source_target_cards, test_eval_results = generate_source_target_cards_with_eval_results(test_source_cards, test_secondary_cards, 'English', 'Kazakh', 'Russian')
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
test_source_target_cards
# Out:
# [{'wordFirstLang': 'tournament',
#   'sentenceFirstLang': 'The tournament is held on Saturday in the school hall.',
#   'wordSecondLang': 'турнир',
#   'sentenceSecondLang': 'Турнир сенбі күні мектеп залында өтеді.',
#   'id': 6130},
#  {'wordFirstLang': 'match',
#   'sentenceFirstLang': 'The match starts at 6:00 PM.',
#   'wordSecondLang': 'матч',
#   'sentenceSecondLang': 'Матч кешкі сағат 18:00-де басталады.',
#   'id': 6141},
#  {'wordFirstLang': 'competition',
#   'sentenceFirstLang': "The competition begins precisely at ten o'clock.",
#   'wordSecondLang': 'жарыс',
#   'sentenceSecondLang': 'Жарыс дәл сағат онда басталады.',
#   'id': 6182},
#  {'wordFirstLang': 'departure',
#   'sentenceFirstLang': "The departure is tomorrow at nine o'clock.",
#   'wordSecondLang': 'кету',
#   'sentenceSecondLang': 'Кету ертең сағат тоғызда.',
#   'id': 6192},
#  {'wordFirstLang': 'defeat',
#   'sentenceFirstLang': "The team suffered a bitter defeat in yesterday's match.",
#   'wordSecondLang': 'жеңіліс',
#   'sentenceSecondLang': 'Кеше матчта команда ащы жеңіліс тапты.',
#   'id': 6196},
#  {'wordFirstLang': 'draw',
#   'sentenceFirstLang': 'The game ended in a draw.',
#   'wordSecondLang': 'тең ойын',
#   'sentenceSecondLang': 'Ойын тең болып аяқталды.',
#   'id': 6197},
#  {'wordFirstLang': 'how many times',
#   'sentenceFirstLang': 'How many times have you visited this museum?',
#   'wordSecondLang': 'неше рет',
#   'sentenceSecondLang': 'Сен осы мұражайға неше рет келдің?',
#   'id': 6258},
#  {'wordFirstLang': 'still',
#   'sentenceFirstLang': 'Are we still friends?',
#   'wordSecondLang': 'Әлі',
#   'sentenceSecondLang': 'Біз әлі де дос болып жүрміз бе?',
#   'id': 6286},
#  {'wordFirstLang': 'decide',
#   'sentenceFirstLang': 'They decide to travel to Italy next summer.',
#   'wordSecondLang': 'шешу',
#   'sentenceSecondLang': 'Олар келесі жазда Италияға баруды шешеді.',
#   'id': 6298},
#  {'wordFirstLang': 'talent scout',
#   'sentenceFirstLang': "The talent scout noticed the young singer's talent.",
#   'wordSecondLang': 'таланттарды іздеуші',
#   'sentenceSecondLang': 'Таланттарды іздеуші жас әншінің қабілетін байқады.',
#   'id': 6309},
#  {'wordFirstLang': 'ambassador',
#   'sentenceFirstLang': 'Germany has a new Finnish ambassador.',
#   'wordSecondLang': 'елші',
#   'sentenceSecondLang': 'Германияда жаңа фин елшісі бар.',
#   'id': 6325},
#  {'wordFirstLang': 'to erect, to set up',
#   'sentenceFirstLang': 'They are going to set up a tent at the campsite.',
#   'wordSecondLang': 'тігу',
#   'sentenceSecondLang': 'Олар лагерьде шатыр тігуді жоспарлап отыр.',
#   'id': 6327},
#  {'wordFirstLang': 'twenty-four',
#   'sentenceFirstLang': 'The time is twenty-four past two.',
#   'wordSecondLang': 'жиырма төрт',
#   'sentenceSecondLang': 'Қазір сағат екіден жиырма төрт минут өтті.',
#   'id': 6330}]

# %%
nl_source_cards, nl_secondary_cards = create_cards_list(test_cards, 'en', 'fi')

# %%
nl_source_target_cards, nl_eval_results = generate_source_target_cards_with_eval_results(nl_source_cards, nl_secondary_cards, 'English', 'Dutch', 'Finnish')
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
nl_source_target_cards
# Out:
# [{'wordFirstLang': 'tournament',
#   'sentenceFirstLang': 'The tournament is held on Saturday in the school hall.',
#   'wordSecondLang': 'toernooi',
#   'sentenceSecondLang': 'Het toernooi wordt gehouden op zaterdag in de schoolzaal.',
#   'id': 6130},
#  {'wordFirstLang': 'match',
#   'sentenceFirstLang': 'The match starts at 6:00 PM.',
#   'wordSecondLang': 'wedstrijd',
#   'sentenceSecondLang': 'De wedstrijd begint om 18:00 uur.',
#   'id': 6141},
#  {'wordFirstLang': 'competition',
#   'sentenceFirstLang': "The competition begins precisely at ten o'clock.",
#   'wordSecondLang': 'wedstrijd',
#   'sentenceSecondLang': 'De wedstrijd begint precies om tien uur.',
#   'id': 6182},
#  {'wordFirstLang': 'departure',
#   'sentenceFirstLang': "The departure is tomorrow at nine o'clock.",
#   'wordSecondLang': 'vertrek',
#   'sentenceSecondLang': 'Het vertrek is morgen om negen uur.',
#   'id': 6192},
#  {'wordFirstLang': 'defeat',
#   'sentenceFirstLang': "The team suffered a bitter defeat in yesterday's match.",
#   'wordSecondLang': 'nederlaag',
#   'sentenceSecondLang': 'Het team leed een bittere nederlaag in de wedstrijd van gisteren.',
#   'id': 6196},
#  {'wordFirstLang': 'draw',
#   'sentenceFirstLang': 'The game ended in a draw.',
#   'wordSecondLang': 'gelijkspel',
#   'sentenceSecondLang': 'Het spel eindigde in een gelijkspel.',
#   'id': 6197},
#  {'wordFirstLang': 'how many times',
#   'sentenceFirstLang': 'How many times have you visited this museum?',
#   'wordSecondLang': 'hoe vaak',
#   'sentenceSecondLang': 'Hoe vaak heb je dit museum bezocht?',
#   'id': 6258},
#  {'wordFirstLang': 'still',
#   'sentenceFirstLang': 'Are we still friends?',
#   'wordSecondLang': 'nog steeds',
#   'sentenceSecondLang': 'Zijn we nog steeds vrienden?',
#   'id': 6286},
#  {'wordFirstLang': 'decide',
#   'sentenceFirstLang': 'They decide to travel to Italy next summer.',
#   'wordSecondLang': 'beslissen',
#   'sentenceSecondLang': 'Ze beslissen om volgende zomer naar Italië te reizen.',
#   'id': 6298},
#  {'wordFirstLang': 'talent scout',
#   'sentenceFirstLang': "The talent scout noticed the young singer's talent.",
#   'wordSecondLang': 'talentenscout',
#   'sentenceSecondLang': 'De talentenscout merkte het talent van de jonge zanger op.',
#   'id': 6309},
#  {'wordFirstLang': 'ambassador',
#   'sentenceFirstLang': 'Germany has a new Finnish ambassador.',
#   'wordSecondLang': 'ambassadeur',
#   'sentenceSecondLang': 'Duitsland heeft een nieuwe Finse ambassadeur.',
#   'id': 6325},
#  {'wordFirstLang': 'to erect, to set up',
#   'sentenceFirstLang': 'They are going to set up a tent at the campsite.',
#   'wordSecondLang': 'opzetten',
#   'sentenceSecondLang': 'Ze gaan een tent opzetten op de camping.',
#   'id': 6327},
#  {'wordFirstLang': 'twenty-four',
#   'sentenceFirstLang': 'The time is twenty-four past two.',
#   'wordSecondLang': 'vierentwintig',
#   'sentenceSecondLang': 'Het is vierentwintig over twee.',
#   'id': 6330}]

# %%
kz_cards = [{'word': card["wordSecondLang"], 'sentence': card["sentenceSecondLang"]} for card in test_source_target_cards]
nl_cards = [{'word': card["wordSecondLang"], 'sentence': card["sentenceSecondLang"]} for card in nl_source_target_cards]

# %%
for kz, nl, final_set in list(zip(kz_cards, nl_cards, test_cards)):
    final_set['translations']['kz']['id'] = final_set['id']
    final_set['translations']['nl']['id'] = final_set['id']

# %%
test_cards
# Out:
# [{'id': 6130,
#   'translations': {'ru': {'word': 'турнир',
#     'sentence': 'Турнир проводится в субботу в школьном зале.',
#     'id': 6130},
#    'fi': {'word': 'turnaus',
#     'sentence': 'Turnaus järjestetään lauantaina koulun salissa.',
#     'id': 6130},
#    'en': {'word': 'tournament',
#     'sentence': 'The tournament is held on Saturday in the school hall.',
#     'id': 6130},
#    'kz': {'word': 'турнир',
#     'sentence': 'Турнир сенбі күні мектеп залында өтеді.',
#     'id': 6130},
#    'nl': {'word': 'toernooi',
#     'sentence': 'Het toernooi wordt gehouden op zaterdag in de schoolzaal.',
#     'id': 6130}}},
#  {'id': 6141,
#   'translations': {'ru': {'word': 'матч',
#     'sentence': 'Матч начинается в 18:00.',
#     'id': 6141},
#    'fi': {'word': 'ottelu', 'sentence': 'Ottelu alkaa klo 18.', 'id': 6141},
#    'en': {'word': 'match',
#     'sentence': 'The match starts at 6:00 PM.',
#     'id': 6141},
#    'kz': {'word': 'матч',
#     'sentence': 'Матч кешкі сағат 18:00-де басталады.',
#     'id': 6141},
#    'nl': {'word': 'wedstrijd',
#     'sentence': 'De wedstrijd begint om 18:00 uur.',
#     'id': 6141}}},
#  {'id': 6182,
#   'translations': {'ru': {'word': 'соревнование',
#     'sentence': 'Соревнование начинается ровно в десять часов.',
#     'id': 6182},
#    'fi': {'word': 'kilpailu (kisa)',
#     'sentence': 'Kisa alkaa tasan kello kymmenen.',
#     'id': 6182},
#    'en': {'word': 'competition',
#     'sentence': "The competition begins precisely at ten o'clock.",
#     'id': 6182},
#    'kz': {'word': 'жарыс',
#     'sentence': 'Жарыс дәл сағат онда басталады.',
#     'id': 6182},
#    'nl': {'word': 'wedstrijd',
#     'sentence': 'De wedstrijd begint precies om tien uur.',
#     'id': 6182}}},
#  {'id': 6192,
#   'translations': {'ru': {'word': 'отправление',
#     'sentence': 'Отправление завтра в девять часов.',
#     'id': 6192},
#    'fi': {'word': 'lähtö',
#     'sentence': 'Lähtö on huomenna kello yhdeksän.',
#     'id': 6192},
#    'en': {'word': 'departure',
#     'sentence': "The departure is tomorrow at nine o'clock.",
#     'id': 6192},
#    'kz': {'word': 'кету', 'sentence': 'Кету ертең сағат тоғызда.', 'id': 6192},
#    'nl': {'word': 'vertrek',
#     'sentence': 'Het vertrek is morgen om negen uur.',
#     'id': 6192}}},
#  {'id': 6196,
#   'translations': {'ru': {'word': 'поражение',
#     'sentence': 'Команда потерпела горькое поражение во вчерашнем матче.',
#     'id': 6196},
#    'fi': {'word': 'häviö (tappio)',
#     'sentence': 'Joukkue kärsi kirvelevän häviön eilisessä ottelussa.',
#     'id': 6196},
#    'en': {'word': 'defeat',
#     'sentence': "The team suffered a bitter defeat in yesterday's match.",
#     'id': 6196},
#    'kz': {'word': 'жеңіліс',
#     'sentence': 'Кеше матчта команда ащы жеңіліс тапты.',
#     'id': 6196},
#    'nl': {'word': 'nederlaag',
#     'sentence': 'Het team leed een bittere nederlaag in de wedstrijd van gisteren.',
#     'id': 6196}}},
#  {'id': 6197,
#   'translations': {'ru': {'word': 'ничья',
#     'sentence': 'Игра закончилась вничью.',
#     'id': 6197},
#    'fi': {'word': 'tasapeli',
#     'sentence': 'Peli päättyi tasapeliin.',
#     'id': 6197},
#    'en': {'word': 'draw', 'sentence': 'The game ended in a draw.', 'id': 6197},
#    'kz': {'word': 'тең ойын',
#     'sentence': 'Ойын тең болып аяқталды.',
#     'id': 6197},
#    'nl': {'word': 'gelijkspel',
#     'sentence': 'Het spel eindigde in een gelijkspel.',
#     'id': 6197}}},
#  {'id': 6258,
#   'translations': {'ru': {'word': 'который',
#     'sentence': 'В который раз ты посещаешь этот музей?',
#     'id': 6258},
#    'fi': {'word': 'monetta',
#     'sentence': 'Monettako kertaa olet käynyt tässä museossa?',
#     'id': 6258},
#    'en': {'word': 'how many times',
#     'sentence': 'How many times have you visited this museum?',
#     'id': 6258},
#    'kz': {'word': 'неше рет',
#     'sentence': 'Сен осы мұражайға неше рет келдің?',
#     'id': 6258},
#    'nl': {'word': 'hoe vaak',
#     'sentence': 'Hoe vaak heb je dit museum bezocht?',
#     'id': 6258}}},
#  {'id': 6286,
#   'translations': {'ru': {'word': 'всё ещё',
#     'sentence': 'Мы всё ещё друзья?',
#     'id': 6286},
#    'fi': {'word': 'yhä', 'sentence': 'Olemmeko yhä ystäviä?', 'id': 6286},
#    'en': {'word': 'still', 'sentence': 'Are we still friends?', 'id': 6286},
#    'kz': {'word': 'Әлі',
#     'sentence': 'Біз әлі де дос болып жүрміз бе?',
#     'id': 6286},
#    'nl': {'word': 'nog steeds',
#     'sentence': 'Zijn we nog steeds vrienden?',
#     'id': 6286}}},
#  {'id': 6298,
#   'translations': {'ru': {'word': 'решать',
#     'sentence': 'Они решают поехать в Италию следующим летом.',
#     'id': 6298},
#    'fi': {'word': 'päättää',
#     'sentence': 'He päättävät matkustaa Italiaan ensi kesänä.',
#     'id': 6298},
#    'en': {'word': 'decide',
#     'sentence': 'They decide to travel to Italy next summer.',
#     'id': 6298},
#    'kz': {'word': 'шешу',
#     'sentence': 'Олар келесі жазда Италияға баруды шешеді.',
#     'id': 6298},
#    'nl': {'word': 'beslissen',
#     'sentence': 'Ze beslissen om volgende zomer naar Italië te reizen.',
#     'id': 6298}}},
#  {'id': 6309,
#   'translations': {'ru': {'word': 'искатель талантов',
#     'sentence': 'Искатель талантов заметил талант молодого певца.',
#     'id': 6309},
#    'fi': {'word': 'kykyjenetsijä',
#     'sentence': 'Kykyjenetsijä huomasi nuoren laulajan talentin.',
#     'id': 6309},
#    'en': {'word': 'talent scout',
#     'sentence': "The talent scout noticed the young singer's talent.",
#     'id': 6309},
#    'kz': {'word': 'таланттарды іздеуші',
#     'sentence': 'Таланттарды іздеуші жас әншінің қабілетін байқады.',
#     'id': 6309},
#    'nl': {'word': 'talentenscout',
#     'sentence': 'De talentenscout merkte het talent van de jonge zanger op.',
#     'id': 6309}}},
#  {'id': 6325,
#   'translations': {'ru': {'word': 'посол',
#     'sentence': 'В Германии новый посол Финляндии.',
#     'id': 6325},
#    'fi': {'word': 'suurlähettiläs',
#     'sentence': 'Saksassa on uusi Suomen suurlähettiläs.',
#     'id': 6325},
#    'en': {'word': 'ambassador',
#     'sentence': 'Germany has a new Finnish ambassador.',
#     'id': 6325},
#    'kz': {'word': 'елші',
#     'sentence': 'Германияда жаңа фин елшісі бар.',
#     'id': 6325},
#    'nl': {'word': 'ambassadeur',
#     'sentence': 'Duitsland heeft een nieuwe Finse ambassadeur.',
#     'id': 6325}}},
#  {'id': 6327,
#   'translations': {'ru': {'word': 'воздвигать, устанавливать',
#     'sentence': 'Они собираются установить палатку на кемпинговой площадке.',
#     'id': 6327},
#    'fi': {'word': 'pystyttää',
#     'sentence': 'He aikovat pystyttää teltan leirintäalueelle.',
#     'id': 6327},
#    'en': {'word': 'to erect, to set up',
#     'sentence': 'They are going to set up a tent at the campsite.',
#     'id': 6327},
#    'kz': {'word': 'тігу',
#     'sentence': 'Олар лагерьде шатыр тігуді жоспарлап отыр.',
#     'id': 6327},
#    'nl': {'word': 'opzetten',
#     'sentence': 'Ze gaan een tent opzetten op de camping.',
#     'id': 6327}}},
#  {'id': 6330,
#   'translations': {'ru': {'word': 'двадцать четыре',
#     'sentence': 'Время — два часа и двадцать четыре минуты.',
#     'id': 6330},
#    'fi': {'word': 'kakskyneljä',
#     'sentence': 'Kello on kakskyneljä yli kaksi.',
#     'id': 6330},
#    'en': {'word': 'twenty-four',
#     'sentence': 'The time is twenty-four past two.',
#     'id': 6330},
#    'kz': {'word': 'жиырма төрт',
#     'sentence': 'Қазір сағат екіден жиырма төрт минут өтті.',
#     'id': 6330},
#    'nl': {'word': 'vierentwintig',
#     'sentence': 'Het is vierentwintig over twee.',
#     'id': 6330}}}]

# %%
with open('./test_cards.json', 'w', encoding='utf-8') as f:
    json.dump(test_cards, f, ensure_ascii=False, indent=2)

# %%
import os
import json
from pathlib import Path

def get_english_card_ids():
    all_ids = set()
    
    file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
    file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
    file_names.append('sm2_new_puhekieli.json')
    file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])
    file_names.extend([f'sm4_kap{i}.json' for i in range(1, 6)])
    
    for file_name in file_names:
        cards = get_eng_finn_cards_from_file(file_name)
        ids = [card['id'] for card in cards]
        all_ids.update(ids)
    
    return all_ids

def get_russian_card_ids():
    all_ids = set()
    
    file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
    file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
    file_names.append('sm2_new_puhekieli.json')
    file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])
    file_names.extend([f'sm4_kap{i}.json' for i in range(1, 6)])
    
    for file_name in file_names:
        cards = get_ru_finn_cards_from_file(file_name)
        ids = [card['id'] for card in cards]
        all_ids.update(ids)
    
    return all_ids

def print_missing_ids():
    eng_ids = get_english_card_ids()
    rus_ids = get_russian_card_ids()
    
    missing_ids = eng_ids - rus_ids
    
    missing_ids = sorted(list(missing_ids))
    
    print(f"Всего англо-финских карточек: {len(eng_ids)}")
    print(f"Всего русско-финских карточек: {len(rus_ids)}")
    print(f"Отсутствующих карточек: {len(missing_ids)}")
    print("\nСписок отсутствующих ID:")
    for id in missing_ids:
        print(id)

# %%
print_missing_ids()
# Out:
# Всего англо-финских карточек: 6337
# Всего русско-финских карточек: 6337
# Отсутствующих карточек: 0
#
# Список отсутствующих ID:

# %%
def check_ru_fi_case_and_punctuation_consistency():
    file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
    file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
    file_names.append('sm2_new_puhekieli.json')
    file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])
    file_names.extend([f'sm4_kap{i}.json' for i in range(1, 6)])
    
    case_inconsistencies = 0
    dot_inconsistencies = 0
    
    for file_name in file_names:
        cards = get_ru_finn_cards_from_file(file_name)
        
        for card in cards:
            fi_word = card['wordSecondLang']
            ru_word = card['wordFirstLang'] 
            fi_sentence = card['sentenceSecondLang']
            ru_sentence = card['sentenceFirstLang']
            
            try:
                if ru_word[0].isupper() != fi_word[0].isupper():
                    case_inconsistencies += 1
                    print(f"Несогласованность регистра в слове, карточка {card['id']}:")
                    print(f"RU: {ru_word}")
                    print(f"FI: {fi_word}\n")
            except:
                print(f"Warning: {card['id']}:")
                
            if ru_word.endswith('.') != fi_word.endswith('.'):
                dot_inconsistencies += 1
                print(f"Несогласованность точки в слове, карточка {card['id']}:")
                print(f"RU: {ru_word}")
                print(f"FI: {fi_word}\n")
                
            if ru_sentence != '':
                if ru_sentence[0].isupper() != fi_sentence[0].isupper():
                    case_inconsistencies += 1
                    print(f"Несогласованность регистра в предложении, карточка {card['id']}:")
                    print(f"RU: {ru_sentence}")
                    print(f"FI: {fi_sentence}\n")
                
            if ru_sentence.endswith('.') != fi_sentence.endswith('.'):
                dot_inconsistencies += 1
                print(f"Несогласованность точки в предложении, карточка {card['id']}:")
                print(f"RU: {ru_sentence}") 
                print(f"FI: {fi_sentence}\n")
                
    print(f"Несогласованность регистра: {case_inconsistencies} карточек")
    print(f"Несогласованность точки в конце: {dot_inconsistencies} карточек")
    print(f"Всего несогласованностей: {case_inconsistencies + dot_inconsistencies}")

check_ru_fi_case_and_punctuation_consistency()
# Out:
# Несогласованность регистра в слове, карточка 1407:
# RU: +30 градусов. Жарко.
# FI: On +30 astetta. On kuuma.
#
# Несогласованность регистра в слове, карточка 1409:
# RU: +20 градусов. Тепло.
# FI: On +20 astetta. On lämmin.
#
# Несогласованность регистра в слове, карточка 1410:
# RU: +2 градуса. Прохладно.
# FI: On +2 astetta. On viileä.
#
# Несогласованность регистра в слове, карточка 1411:
# RU: -15 градусов. холодно.
# FI: On -15 astetta. On kylmä.
#
# Несогласованность точки в предложении, карточка 1747:
# RU: Она любит его. (Он любит её.)
# FI: Hän rakastaa häntä.
#
# Несогласованность регистра в предложении, карточка 1934:
# RU: 9 часов ровно.
# FI: Kello on tasan yhdeksän.
#
# Несогласованность регистра в слове, карточка 2198:
# RU: в Вантаа
# FI: Vantaalla
#
# Несогласованность регистра в слове, карточка 2199:
# RU: в Тампере
# FI: Tampereella
#
# Несогласованность регистра в слове, карточка 2200:
# RU: в Рованиеми
# FI: Rovaniemellä
#
# Несогласованность регистра в слове, карточка 2201:
# RU: в Иматре
# FI: Imatralla
#
# Несогласованность регистра в слове, карточка 2222:
# RU: в Порвоо
# FI: Porvooseen
#
# Несогласованность точки в предложении, карточка 2237:
# RU: Они стоят 79 евро
# FI: Ne maksavat 79 euroa.
#
# Несогласованность точки в слове, карточка 2413:
# RU: Ого! У тебя был очень длинный день.
# FI: Ohhoh! Sinulla oli tosi pitkä päivä
#
# Несогласованность точки в предложении, карточка 2973:
# RU: Вот за тобой и приехали. (Вот приехал твой перевозчик)
# FI: Nyt tuli sinun kyyti.
#
# Несогласованность точки в слове, карточка 3026:
# RU: Мы в пути неделю.
# FI: Olemme matkalla viikon. (yhden viikon)
#
# Несогласованность точки в слове, карточка 3231:
# RU: Никакой спешки. (Не торопись)
# FI: Ei mitään kiirettä.
#
# Несогласованность регистра в слове, карточка 4203:
# RU: Первомай, Ваппу.
# FI: vappu 1.5.
#
# Несогласованность регистра в предложении, карточка 4423:
# RU: "Вторая ступень образования" в Финляндии означает среднее общее и профессиональное образование.
# FI: Toinen aste tarkoittaa Suomessa lukio- ja ammatillista koulutusta.
#
# Несогласованность регистра в слове, карточка 4626:
# RU: НДС
# FI: arvonlisävero (ALV)
#
# Несогласованность регистра в слове, карточка 4806:
# RU: Эта еда очень вкусная!
# FI: susta
#
# Несогласованность точки в предложении, карточка 4897:
# RU: Каждый житель города является потребителем электроэнергии.
# FI: Jokainen kaupungin asukas on sähkönkuluttaja
#
# Несогласованность точки в предложении, карточка 5050:
# RU: Он съел целый арбуз один
# FI: Hän söi kokonaisen vesimelonin yksin.
#
# Несогласованность точки в предложении, карточка 5059:
# RU: Зритель получил огромное удовольствие от фильма
# FI: Katsoja nautti elokuvasta suuresti.
#
# Несогласованность регистра в слове, карточка 5061:
# RU: XIX век
# FI: 1800-luku
#
# Несогласованность точки в предложении, карточка 5175:
# RU: Мне подойдет до четырех.
# FI: Minulle käy ennen neljää
#
# Несогласованность точки в слове, карточка 5364:
# RU: Мы заканчиваем экскурсию по отелю
# FI: Me päätämme kiertoajelun hotellille.
#
# Несогласованность точки в предложении, карточка 5410:
# RU: Эта старая песня вдруг вспомнилась.
# FI: Tämä vanha laulu muistui yhtäkkiä mieleen
#
# Несогласованность точки в предложении, карточка 5414:
# RU: Раньше мама часто говорила: "Не пускайте мужчин на кухню."
# FI: Ennen äiti usein sanoi, että älkää päästäkö miehiä keittiöön.
#
# Несогласованность точки в предложении, карточка 5428:
# RU: У меня впереди длинный уикенд
# FI: Minulla on pitkä viikonloppu edessäni.
#
# Несогласованность точки в предложении, карточка 5447:
# RU: Поцелуй меня
# FI: Anna pusi minulle.
#
# Несогласованность точки в слове, карточка 5461:
# RU: один час, день, год…
# FI: yhden tunnin, päivän, vuoden...
#
# Несогласованность точки в слове, карточка 5466:
# RU: Я не был(а) на родине год (пять лет).
# FI: En ole käynyt kotimaassani vuoteen (viiteen vuoteen.)
#
# Несогласованность точки в слове, карточка 5467:
# RU: Я не видел(а) свою мать месяц (два месяца).
# FI: En ole nähnyt äitiäni kuukauteen (kahteen kuukauteen.)
#
# Несогласованность точки в предложении, карточка 5520:
# RU: А что если мы сбежали бы вместе от этой скучной ситуации?
# FI: Jospa paettaisiin yhdessä tästä tylsästä tilanteesta.
#
# Несогласованность регистра в слове, карточка 5590:
# RU: УЗИ-снимок
# FI: ultraäänikuva
#
# Несогласованность точки в предложении, карточка 5705:
# RU: Вы сделаете задания вовремя.
# FI: Te paatte tehtävät valmiiksi ajoissa
#
# Несогласованность точки в предложении, карточка 5832:
# RU: Дети быстро вырастают большими
# FI: Lapset kasvavat isommiksi nopeasti.
#
# Несогласованность регистра в слове, карточка 5970:
# RU: В течение 30 дней
# FI: 30 päivän sisällä
#
# Несогласованность точки в предложении, карточка 5990:
# RU: Подними книжный шкаф и поставь его около стены
# FI: Nosta kirjahylly pystyyn seinää vasten.
#
# Несогласованность точки в предложении, карточка 6048:
# RU: Он владелец самой большой парикмахерской в городе.
# FI: Hän on kaupungin isoimman kampamon omistaja
#
# Несогласованность точки в предложении, карточка 6317:
# RU: Чемпионат Финляндии.
# FI: SM - Suomen mestaruus
#
# Несогласованность точки в предложении, карточка 6360:
# RU: Ему двадцатка, и он учится в университете
# FI: Hän on kakskymppinen ja opiskelee yliopistossa.
#
# Несогласованность точки в предложении, карточка 6364:
# RU: Он выиграл тысячу в лоторею
# FI: Hän voitti lotossa tonnin.
#
# Несогласованность регистра в предложении, карточка 6543:
# RU: «Я видел на пляже много мужчин, пакующих чемоданы.»
# FI: Näin rannalla paljon matkalaukkua pakkaavia miehiä.
#
# Несогласованность точки в предложении, карточка 6543:
# RU: «Я видел на пляже много мужчин, пакующих чемоданы.»
# FI: Näin rannalla paljon matkalaukkua pakkaavia miehiä.
#
# Несогласованность точки в слове, карточка 6673:
# RU: Но было бы хорошо...
# FI: Mut oishan se hyvä…
#
# Несогласованность регистра в слове, карточка 6674:
# RU: «Может быть…?»
# FI: Voiskohan…?
#
# Несогласованность регистра в слове, карточка 6675:
# RU: «Может быть, возможно…?»
# FI: Oiskohan mahdollista…?
#
# Warning: 6677:
# Несогласованность точки в слове, карточка 6677:
# RU:
# FI: Joo. Nii-i.
#
# Warning: 6679:
# Несогласованность точки в слове, карточка 6686:
# RU: Может быть, да, но...
# FI: Ehkä joo, mut…
#
# Несогласованность точки в слове, карточка 6687:
# RU: Может быть, но...
# FI: Voi olla, mut…
#
# Несогласованность точки в слове, карточка 6688:
# RU: Может быть, но...
# FI: Saattaa olla, mut…
#
# Warning: 6689:
# Несогласованность точки в слове, карточка 6775:
# RU: Светоотражатель может спасти вашу жизнь.
# FI: Heijastin voi pelastaa henkesi
#
# Несогласованность точки в предложении, карточка 6776:
# RU: Светоотражатель может спасти вашу жизнь.
# FI: Heijastin voi pelastaa henkesi
#
# Несогласованность точки в слове, карточка 6861:
# RU: Немного удивлён.
# FI: Vähän yllättynyt
#
# Несогласованность регистра в слове, карточка 6866:
# RU: «Ай!»
# FI: Ai!
#
# Warning: 6868:
# Warning: 6919:
# Несогласованность точки в слове, карточка 6919:
# RU:
# FI: Koruja valmistuu 5–10 kappaletta päivässä.
#
# Warning: 6921:
# Несогласованность точки в слове, карточка 6921:
# RU:
# FI: Vedenkulutuksemme on vähentynyt huomattavasti viime vuoden aikana.
#
# Warning: 7025:
# Warning: 7035:
# Несогласованность точки в слове, карточка 7080:
# RU: Иногда MA-причастие может относиться к настоящему времени.
# FI: Joskus MA-partisiippi voi viitata nykyhetkeen
#
# Несогласованность регистра в предложении, карточка 7162:
# RU: «Я собираюсь пойти в магазин сегодня.»
# FI: Aion meinata mennä kauppaan tänään.
#
# Несогласованность точки в предложении, карточка 7162:
# RU: «Я собираюсь пойти в магазин сегодня.»
# FI: Aion meinata mennä kauppaan tänään.
#
# Несогласованность точки в слове, карточка 7176:
# RU: Пара думала, что потеряла.
# FI: Pariskunta luuli menettäneensä
#
# Несогласованность точки в предложении, карточка 7179:
# RU: Пара думала, что потеряла.
# FI: Pariskunta luuli menettäneensä
#
# Несогласованность точки в слове, карточка 7254:
# RU: Скандально известная Титта Туртиайнен попалась на вождении в нетрезвом виде – просит прощения у своих поклонников.
# FI: Kohujulkkis Titta Turtiainen kärähti rattijuopumuksesta – pyytää faneiltaan anteeksi
#
# Warning: 7371:
# Несогласованность точки в слове, карточка 7371:
# RU:
# FI: Kun Maija puhuu, täytyy vain olla hiljaa ja kuunnella.
#
# Warning: 7389:
# Несогласованность точки в слове, карточка 7389:
# RU:
# FI: Mä unohdin eilen avaimet ja puhelimen kotiin ja jouduin odottamaan rappukäytävässä puoleenyöhön asti.
#
# Несогласованность регистра в слове, карточка 7398:
# RU: «Тони сказал, что после этого действительно будет помнить брать ключи с собой!»
# FI: Toni sanoi tämän jälkeen todellakin muistavansa ottaa avaimet aina mukaan!
#
# Несогласованность регистра: 23 карточек
# Несогласованность точки в конце: 44 карточек
# Всего несогласованностей: 67

# %%
def check_en_fi_case_and_punctuation_consistency():
    file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
    file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
    file_names.append('sm2_new_puhekieli.json')
    file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])
    file_names.extend([f'sm4_kap{i}.json' for i in range(1, 6)])
    
    case_inconsistencies = 0
    dot_inconsistencies = 0
    
    bad_cards_ids = []
    for file_name in file_names:
        cards = get_eng_finn_cards_from_file(file_name)
        
        for card in cards:
            fi_word = card['wordSecondLang']
            en_word = card['wordFirstLang'] 
            fi_sentence = card['sentenceSecondLang']
            en_sentence = card['sentenceFirstLang']

            bad_card = False
            
            try:
                if en_word[0].isupper() != fi_word[0].isupper():
                    case_inconsistencies += 1
                    bad_card = True
                    print(f"Несогласованность регистра в слове, карточка {card['id']}:")
                    print(f"EN: {en_word}")
                    print(f"FI: {fi_word}\n")
            except:
                bad_card = True
                print(f"Warning: {card['id']}:")
                
            if en_word.endswith('.') != fi_word.endswith('.'):
                dot_inconsistencies += 1
                bad_card = True
                print(f"Несогласованность точки в слове, карточка {card['id']}:")
                print(f"EN: {en_word}")
                print(f"FI: {fi_word}\n")
                
            if en_sentence != '' and fi_sentence != '':
                if en_sentence[0].isupper() != fi_sentence[0].isupper():
                    case_inconsistencies += 1
                    bad_card = True
                    print(f"Несогласованность регистра в предложении, карточка {card['id']}:")
                    print(f"EN: {en_sentence}")
                    print(f"FI: {fi_sentence}\n")
                
            if en_sentence.endswith('.') != fi_sentence.endswith('.'):
                dot_inconsistencies += 1
                bad_card = True
                print(f"Несогласованность точки в предложении, карточка {card['id']}:")
                print(f"EN: {en_sentence}") 
                print(f"FI: {fi_sentence}\n")

            if bad_card:
                bad_cards_ids.append(card['id'])
                
    print(f"Несогласованность регистра: {case_inconsistencies} карточек")
    print(f"Несогласованность точки в конце: {dot_inconsistencies} карточек")
    print(f"Всего несогласованностей: {case_inconsistencies + dot_inconsistencies}")

    return bad_cards_ids

# %%
en_fi_bad_cards_ids = check_en_fi_case_and_punctuation_consistency()
# Out:
# Несогласованность регистра в слове, карточка 1005:
# EN: I
# FI: minä
#
# Несогласованность регистра в слове, карточка 1018:
# EN: Last name
# FI: sukunimi
#
# Несогласованность точки в слове, карточка 1039:
# EN: Yes.
# FI: Joo
#
# Несогласованность регистра в слове, карточка 1042:
# EN: Monday
# FI: maanantai
#
# Несогласованность регистра в слове, карточка 1043:
# EN: Tuesday
# FI: tiistai
#
# Несогласованность регистра в слове, карточка 1044:
# EN: Wednesday
# FI: keskiviikko
#
# Несогласованность регистра в слове, карточка 1045:
# EN: Thursday
# FI: torstai
#
# Несогласованность регистра в слове, карточка 1046:
# EN: Friday
# FI: perjantai
#
# Несогласованность регистра в слове, карточка 1047:
# EN: Saturday
# FI: lauantai
#
# Несогласованность регистра в слове, карточка 1048:
# EN: Sunday
# FI: sunnuntai
#
# Несогласованность регистра в слове, карточка 1049:
# EN: Weekend
# FI: viikonloppu
#
# Несогласованность регистра в слове, карточка 1053:
# EN: On Tuesday
# FI: tiistaina
#
# Несогласованность регистра в слове, карточка 1054:
# EN: On Wednesday
# FI: keskiviikkona
#
# Несогласованность регистра в слове, карточка 1056:
# EN: On Friday
# FI: perjantaina
#
# Несогласованность регистра в слове, карточка 1057:
# EN: On Saturday
# FI: lauantaina
#
# Несогласованность регистра в слове, карточка 1058:
# EN: On Sunday
# FI: sunnuntaina
#
# Несогласованность регистра в слове, карточка 1059:
# EN: The day before yesterday.
# FI: toissapäivänä
#
# Несогласованность точки в слове, карточка 1059:
# EN: The day before yesterday.
# FI: toissapäivänä
#
# Несогласованность регистра в слове, карточка 1060:
# EN: Yesterday
# FI: eilen
#
# Несогласованность регистра в слове, карточка 1061:
# EN: Today
# FI: tänään
#
# Несогласованность регистра в слове, карточка 1062:
# EN: Tomorrow
# FI: huomenna
#
# Несогласованность регистра в слове, карточка 1063:
# EN: The day after tomorrow
# FI: ylihuomenna
#
# Несогласованность регистра в слове, карточка 1064:
# EN: Zero
# FI: nolla
#
# Несогласованность регистра в слове, карточка 1065:
# EN: One
# FI: yksi
#
# Несогласованность регистра в слове, карточка 1066:
# EN: Two
# FI: kaksi
#
# Несогласованность регистра в слове, карточка 1067:
# EN: Three
# FI: kolme
#
# Несогласованность регистра в слове, карточка 1068:
# EN: Twenty-one
# FI: kaksikymmentäyksi
#
# Несогласованность регистра в слове, карточка 1070:
# EN: Two hundred
# FI: kaksisataa
#
# Несогласованность регистра в слове, карточка 1072:
# EN: Four
# FI: neljä
#
# Несогласованность регистра в слове, карточка 1073:
# EN: Five
# FI: viisi
#
# Несогласованность регистра в слове, карточка 1074:
# EN: Six
# FI: kuusi
#
# Несогласованность регистра в слове, карточка 1075:
# EN: Seven
# FI: seitsemän
#
# Несогласованность регистра в слове, карточка 1076:
# EN: Eight
# FI: kahdeksan
#
# Несогласованность регистра в слове, карточка 1077:
# EN: Nine
# FI: yhdeksän
#
# Несогласованность регистра в слове, карточка 1078:
# EN: Ten
# FI: kymmenen
#
# Несогласованность регистра в слове, карточка 1079:
# EN: Eleven
# FI: yksitoista
#
# Несогласованность регистра в слове, карточка 1080:
# EN: Twelve
# FI: kaksitoista
#
# Несогласованность регистра в слове, карточка 1081:
# EN: Thirty
# FI: kolmekymmentä
#
# Несогласованность регистра в слове, карточка 1082:
# EN: Fourteen
# FI: neljätoista
#
# Несогласованность регистра в слове, карточка 1083:
# EN: Fifteen
# FI: viisitoista
#
# Несогласованность регистра в слове, карточка 1084:
# EN: Sixteen
# FI: kuusitoista
#
# Несогласованность регистра в слове, карточка 1085:
# EN: Seventeen
# FI: seitsemäntoista
#
# Несогласованность регистра в слове, карточка 1086:
# EN: Eighteen
# FI: kahdeksantoista
#
# Несогласованность регистра в слове, карточка 1087:
# EN: Nineteen
# FI: yhdeksäntoista
#
# Несогласованность регистра в слове, карточка 1088:
# EN: Twenty
# FI: kaksikymmentä
#
# Несогласованность регистра в слове, карточка 1089:
# EN: Forty
# FI: neljäkymmentä
#
# Несогласованность регистра в слове, карточка 1090:
# EN: Fifty
# FI: viisikymmentä
#
# Несогласованность регистра в слове, карточка 1091:
# EN: Sixty
# FI: kuusikymmentä
#
# Несогласованность регистра в слове, карточка 1092:
# EN: Seventy
# FI: seitsemänkymmentä
#
# Несогласованность регистра в слове, карточка 1093:
# EN: Eighty
# FI: kahdeksankymmentä
#
# Несогласованность регистра в слове, карточка 1094:
# EN: Ninety
# FI: yhdeksänkymmentä
#
# Несогласованность регистра в слове, карточка 1095:
# EN: One hundred and one
# FI: satayksi
#
# Несогласованность регистра в слове, карточка 1096:
# EN: Three hundred
# FI: kolmesataa
#
# Несогласованность регистра в слове, карточка 1097:
# EN: Thousand
# FI: tuhat
#
# Несогласованность регистра в слове, карточка 1098:
# EN: Two thousand
# FI: kaksituhatta
#
# Несогласованность регистра в слове, карточка 1099:
# EN: Five hundred thousand
# FI: viisisataatuhatta
#
# Несогласованность регистра в слове, карточка 1103:
# EN: Finnish language course
# FI: suomen kurssi
#
# Несогласованность регистра в слове, карточка 1112:
# EN: Alright
# FI: okei
#
# Несогласованность регистра в слове, карточка 1113:
# EN: Course day, class
# FI: kurssipäivä
#
# Несогласованность регистра в слове, карточка 1114:
# EN: I am
# FI: minä olen
#
# Несогласованность регистра в слове, карточка 1123:
# EN: I am (informal)
# FI: mä oon
#
# Несогласованность регистра в слове, карточка 1125:
# EN: We are (informal)
# FI: me ollaan
#
# Несогласованность регистра в слове, карточка 1131:
# EN: Physics
# FI: fysiikka
#
# Несогласованность регистра в слове, карточка 1132:
# EN: Biology
# FI: biologia
#
# Несогласованность регистра в слове, карточка 1133:
# EN: Swedish
# FI: ruotsi
#
# Несогласованность регистра в слове, карточка 1134:
# EN: Exercise
# FI: liikunta
#
# Несогласованность регистра в слове, карточка 1140:
# EN: English
# FI: englanti
#
# Несогласованность регистра в слове, карточка 1141:
# EN: French language
# FI: ranska
#
# Несогласованность регистра в слове, карточка 1168:
# EN: Brazilian
# FI: brasilialainen
#
# Несогласованность регистра в слове, карточка 1171:
# EN: Spanish (language)
# FI: espanja
#
# Несогласованность регистра в слове, карточка 1173:
# EN: Portuguese (language)
# FI: portugali
#
# Несогласованность регистра в слове, карточка 1175:
# EN: Of course
# FI: tietysti
#
# Несогласованность регистра в слове, карточка 1188:
# EN: Oh, I see
# FI: ai jaa
#
# Несогласованность регистра в слове, карточка 1189:
# EN: Do you speak
# FI: puhutko
#
# Несогласованность регистра в слове, карточка 1190:
# EN: Do you understand
# FI: ymmärrätkö
#
# Несогласованность точки в слове, карточка 1192:
# EN: Finland is a wonderful country.
# FI: Suomi on ihana maa
#
# Несогласованность точки в слове, карточка 1194:
# EN: Greece is a hot country.
# FI: Kreikka on kuuma maa
#
# Несогласованность точки в слове, карточка 1195:
# EN: Iceland is a beautiful country.
# FI: Islanti on kaunis maa
#
# Несогласованность точки в слове, карточка 1197:
# EN: Russia is a big country.
# FI: Venäjä on iso maa
#
# Несогласованность регистра в слове, карточка 1199:
# EN: Finn
# FI: suomalainen
#
# Несогласованность регистра в слове, карточка 1200:
# EN: Frenchman
# FI: ranskalainen
#
# Несогласованность регистра в слове, карточка 1201:
# EN: Greek
# FI: kreikkalainen
#
# Несогласованность регистра в слове, карточка 1202:
# EN: Icelander
# FI: islantilainen
#
# Несогласованность регистра в слове, карточка 1203:
# EN: Egyptian
# FI: egyptiläinen
#
# Несогласованность регистра в слове, карточка 1204:
# EN: Russian
# FI: venäläinen
#
# Несогласованность регистра в слове, карточка 1205:
# EN: Pakistani
# FI: pakistanilainen
#
# Несогласованность регистра в слове, карточка 1206:
# EN: Finnish
# FI: suomi
#
# Несогласованность регистра в слове, карточка 1207:
# EN: Greek
# FI: kreikka
#
# Несогласованность регистра в слове, карточка 1208:
# EN: Icelandic
# FI: islanti
#
# Несогласованность регистра в слове, карточка 1209:
# EN: Arabic
# FI: arabia
#
# Несогласованность регистра в слове, карточка 1210:
# EN: Russian
# FI: venäjä
#
# Несогласованность регистра в слове, карточка 1211:
# EN: Urdu
# FI: urdu
#
# Несогласованность регистра в слове, карточка 1223:
# EN: North
# FI: pohjoinen
#
# Несогласованность регистра в слове, карточка 1226:
# EN: West
# FI: länsi
#
# Несогласованность регистра в слове, карточка 1264:
# EN: I also
# FI: minäkin
#
# Несогласованность регистра в слове, карточка 1268:
# EN: These
# FI: nämä
#
# Несогласованность регистра в слове, карточка 1270:
# EN: Do you need
# FI: tarvitsetko
#
# Несогласованность регистра в слове, карточка 1272:
# EN: Thanks
# FI: kiitti
#
# Несогласованность регистра в слове, карточка 1274:
# EN: I speak
# FI: minä puhun
#
# Несогласованность регистра в слове, карточка 1280:
# EN: I am speaking
# FI: mä puhun
#
# Несогласованность регистра в слове, карточка 1285:
# EN: Five
# FI: viis
#
# Несогласованность регистра в слове, карточка 1288:
# EN: Eight
# FI: kaheksan
#
# Несогласованность регистра в слове, карточка 1291:
# EN: Twelve
# FI: kakstoist
#
# Несогласованность регистра в слове, карточка 1295:
# EN: Sixteen
# FI: kuustoist
#
# Несогласованность регистра в слове, карточка 1296:
# EN: Seventeen
# FI: seittemäntoist
#
# Несогласованность регистра в слове, карточка 1301:
# EN: Twenty-two
# FI: kakskytkaks
#
# Несогласованность регистра в слове, карточка 1302:
# EN: Twenty-three
# FI: kakskytkolme
#
# Несогласованность регистра в слове, карточка 1303:
# EN: Twenty-four
# FI: kakskytneljä
#
# Несогласованность регистра в слове, карточка 1304:
# EN: Twenty-six
# FI: kakskytkuus
#
# Несогласованность регистра в слове, карточка 1305:
# EN: Twenty-seven
# FI: kakskytseittemän
#
# Несогласованность регистра в слове, карточка 1306:
# EN: Twenty-eight
# FI: kakskytkaheksan
#
# Несогласованность регистра в слове, карточка 1307:
# EN: Twenty-nine
# FI: kakskytyheksän
#
# Несогласованность регистра в слове, карточка 1312:
# EN: Seventy.
# FI: seiskyt
#
# Несогласованность точки в слове, карточка 1312:
# EN: Seventy.
# FI: seiskyt
#
# Несогласованность точки в слове, карточка 1331:
# EN: You understand.
# FI: Te ymmärrätte
#
# Несогласованность регистра в слове, карточка 1335:
# EN: "Don't you speak English?"
# FI: Etkö puhu englantia?
#
# Несогласованность регистра в слове, карточка 1338:
# EN: I
# FI: mä
#
# Несогласованность регистра в слове, карточка 1368:
# EN: Evening
# FI: ilta
#
# Несогласованность регистра в слове, карточка 1374:
# EN: August
# FI: elokuu
#
# Несогласованность регистра в слове, карточка 1389:
# EN: Best regards
# FI: terveisin
#
# Несогласованность регистра в слове, карточка 1428:
# EN: In the morning.
# FI: aamulla
#
# Несогласованность точки в слове, карточка 1428:
# EN: In the morning.
# FI: aamulla
#
# Несогласованность регистра в слове, карточка 1430:
# EN: In the evening.
# FI: illalla
#
# Несогласованность точки в слове, карточка 1430:
# EN: In the evening.
# FI: illalla
#
# Несогласованность регистра в слове, карточка 1431:
# EN: At night
# FI: yöllä
#
# Несогласованность регистра в слове, карточка 1433:
# EN: In the afternoon
# FI: iltapäivällä
#
# Несогласованность регистра в слове, карточка 1434:
# EN: In the early morning
# FI: aamuyöllä
#
# Несогласованность регистра в слове, карточка 1436:
# EN: Winter
# FI: talvi
#
# Несогласованность регистра в слове, карточка 1437:
# EN: Spring
# FI: kevät
#
# Несогласованность регистра в слове, карточка 1438:
# EN: Summer
# FI: kesä
#
# Несогласованность регистра в слове, карточка 1439:
# EN: Autumn
# FI: syksy
#
# Несогласованность регистра в слове, карточка 1440:
# EN: In winter
# FI: talvella
#
# Несогласованность регистра в слове, карточка 1442:
# EN: In the summer
# FI: kesällä
#
# Несогласованность регистра в слове, карточка 1445:
# EN: January - in January
# FI: tammikuu - tammikuussa
#
# Несогласованность регистра в слове, карточка 1446:
# EN: February - in February
# FI: helmikuu - helmikuussa
#
# Несогласованность регистра в слове, карточка 1447:
# EN: March - in March
# FI: maaliskuu - maaliskuussa
#
# Несогласованность регистра в слове, карточка 1448:
# EN: April - in April
# FI: huhtikuu - huhtikuussa
#
# Несогласованность регистра в слове, карточка 1449:
# EN: May - in May
# FI: toukokuu - toukokuussa
#
# Несогласованность регистра в слове, карточка 1450:
# EN: June - in June
# FI: kesäkuu - kesäkuussa
#
# Несогласованность регистра в слове, карточка 1451:
# EN: July - in July
# FI: heinäkuu - heinäkuussa
#
# Несогласованность регистра в слове, карточка 1452:
# EN: August - in August
# FI: elokuu - elokuussa
#
# Несогласованность регистра в слове, карточка 1453:
# EN: September - in September
# FI: syyskuu - syyskuussa
#
# Несогласованность регистра в слове, карточка 1454:
# EN: October - in October
# FI: lokakuu - lokakuussa
#
# Несогласованность регистра в слове, карточка 1455:
# EN: November - in November
# FI: marraskuu - marraskuussa
#
# Несогласованность регистра в слове, карточка 1456:
# EN: December - in December
# FI: joulukuu - joulukuussa
#
# Несогласованность регистра в слове, карточка 1461:
# EN: 'How do you say thank you in Finnish?'
# FI: Mitä спасибо on suomeksi?
#
# Несогласованность регистра в слове, карточка 1468:
# EN: 'The nice teacher's name'
# FI: Kivan opettajan nimi
#
# Несогласованность регистра в слове, карточка 1472:
# EN: Your book
# FI: sinun kirja
#
# Несогласованность регистра в слове, карточка 1498:
# EN: November
# FI: marraskuu
#
# Несогласованность регистра в слове, карточка 1499:
# EN: "Yeah, that's what they say!"
# FI: No joo, niin kuulemma!
#
# Несогласованность регистра в слове, карточка 1507:
# EN: September
# FI: syyskuu
#
# Несогласованность регистра в слове, карточка 1509:
# EN: I need to
# FI: minun täytyy
#
# Несогласованность регистра в слове, карточка 1515:
# EN: "Wow, the weather is awful today! - Yeah, it really is!"
# FI: Uh, onpa kamala ilma tänään! -No niin on!
#
# Несогласованность регистра в слове, карточка 1516:
# EN: "It's wonderful that the sun is shining! - Yeah, and it's really warm!"
# FI: Ihanaa, että aurinko paistaa! -Joo, ja on tosi lämmin!
#
# Несогласованность точки в слове, карточка 1520:
# EN: That won't work
# FI: Se ei käy.
#
# Несогласованность регистра в слове, карточка 1521:
# EN: Well
# FI: no
#
# Несогласованность регистра в слове, карточка 1541:
# EN: His car
# FI: sen auto
#
# Несогласованность регистра в слове, карточка 1575:
# EN: "Pretty soon you'll speak Finnish as well as I do! - Yeah, right!"
# FI: Kohta sinä puhut suomea yhtä hyvin kuin minä! - Niin varmaan!
#
# Несогласованность регистра в слове, карточка 1587:
# EN: I don't have
# FI: minulla ei ole
#
# Несогласованность регистра в слове, карточка 1652:
# EN: Secretary
# FI: sihteeri
#
# Несогласованность регистра в слове, карточка 1681:
# EN: In a common-law marriage
# FI: avoliitossa
#
# Несогласованность регистра в слове, карточка 1695:
# EN: White
# FI: valkoinen
#
# Несогласованность регистра в слове, карточка 1696:
# EN: Red
# FI: punainen
#
# Несогласованность регистра в слове, карточка 1697:
# EN: Blue
# FI: sininen
#
# Несогласованность регистра в слове, карточка 1698:
# EN: Yellow
# FI: keltainen
#
# Несогласованность регистра в слове, карточка 1699:
# EN: Green
# FI: vihreä
#
# Несогласованность регистра в слове, карточка 1701:
# EN: Brown
# FI: ruskea
#
# Несогласованность регистра в слове, карточка 1702:
# EN: Gray
# FI: harmaa
#
# Несогласованность регистра в слове, карточка 1703:
# EN: Orange
# FI: oranssi
#
# Несогласованность регистра в слове, карточка 1716:
# EN: "Do you have this in size L?"
# FI: Onks tästä ällää?
#
# Несогласованность регистра в слове, карточка 1720:
# EN: I don't have a car.
# FI: minulla ei ole autoa
#
# Несогласованность точки в слове, карточка 1720:
# EN: I don't have a car.
# FI: minulla ei ole autoa
#
# Несогласованность точки в слове, карточка 1733:
# EN: Here
# FI: Tässä.
#
# Несогласованность точки в предложении, карточка 1747:
# EN: She loves him. (He loves her.)
# FI: Hän rakastaa häntä.
#
# Несогласованность регистра в слове, карточка 1770:
# EN: I have a car.
# FI: minulla on auto
#
# Несогласованность точки в слове, карточка 1770:
# EN: I have a car.
# FI: minulla on auto
#
# Несогласованность регистра в слове, карточка 1777:
# EN: 'That makes 97.50 €.'
# FI: Tää tekee 97,50 €.
#
# Несогласованность точки в слове, карточка 1777:
# EN: 'That makes 97.50 €.'
# FI: Tää tekee 97,50 €.
#
# Несогласованность регистра в слове, карточка 1783:
# EN: I have
# FI: mulla on
#
# Несогласованность регистра в слове, карточка 1793:
# EN: size M
# FI: M ämmä
#
# Несогласованность регистра в слове, карточка 1795:
# EN: "Do you have this in red?"
# FI: Onko tätä punaisena?
#
# Несогласованность регистра в слове, карточка 1799:
# EN: "Do you have this in black?"
# FI: Onko tätä myös mustana?
#
# Несогласованность регистра в слове, карточка 1817:
# EN: "I'm looking for a sweater."
# FI: Mä etsin villapuseroa.
#
# Несогласованность точки в слове, карточка 1817:
# EN: "I'm looking for a sweater."
# FI: Mä etsin villapuseroa.
#
# Несогласованность регистра в слове, карточка 1823:
# EN: ID card
# FI: henkilötodistus
#
# Несогласованность регистра в слове, карточка 1838:
# EN: "Here you go!"
# FI: Näin ole hyvä!
#
# Несогласованность регистра в слове, карточка 1949:
# EN: At nine o'clock.
# FI: kello yhdeksän (yhdeksältä)
#
# Несогласованность точки в слове, карточка 1949:
# EN: At nine o'clock.
# FI: kello yhdeksän (yhdeksältä)
#
# Несогласованность регистра в слове, карточка 1954:
# EN: I'm going.
# FI: mä meen
#
# Несогласованность точки в слове, карточка 1954:
# EN: I'm going.
# FI: mä meen
#
# Несогласованность регистра в слове, карточка 1955:
# EN: You're going.
# FI: sä meet
#
# Несогласованность точки в слове, карточка 1955:
# EN: You're going.
# FI: sä meet
#
# Несогласованность регистра в слове, карточка 1957:
# EN: We're going.
# FI: me mennään
#
# Несогласованность точки в слове, карточка 1957:
# EN: We're going.
# FI: me mennään
#
# Несогласованность регистра в слове, карточка 1958:
# EN: You all are going
# FI: te meette
#
# Несогласованность регистра в слове, карточка 1959:
# EN: They go.
# FI: ne menee
#
# Несогласованность точки в слове, карточка 1959:
# EN: They go.
# FI: ne menee
#
# Несогласованность регистра в слове, карточка 1960:
# EN: I'm coming.
# FI: mä tuun
#
# Несогласованность точки в слове, карточка 1960:
# EN: I'm coming.
# FI: mä tuun
#
# Несогласованность регистра в слове, карточка 1961:
# EN: You're coming.
# FI: sä tuut
#
# Несогласованность точки в слове, карточка 1961:
# EN: You're coming.
# FI: sä tuut
#
# Несогласованность регистра в слове, карточка 1962:
# EN: It's coming.
# FI: se tulee
#
# Несогласованность точки в слове, карточка 1962:
# EN: It's coming.
# FI: se tulee
#
# Несогласованность регистра в слове, карточка 1963:
# EN: We're coming.
# FI: me tullaan
#
# Несогласованность точки в слове, карточка 1963:
# EN: We're coming.
# FI: me tullaan
#
# Несогласованность регистра в слове, карточка 1964:
# EN: You will come.
# FI: te tuutte
#
# Несогласованность точки в слове, карточка 1964:
# EN: You will come.
# FI: te tuutte
#
# Несогласованность регистра в слове, карточка 1965:
# EN: They will come.
# FI: ne tulee
#
# Несогласованность точки в слове, карточка 1965:
# EN: They will come.
# FI: ne tulee
#
# Несогласованность регистра в слове, карточка 1967:
# EN: "Shall we go swimming?"
# FI: Mennäänks uimaan?
#
# Несогласованность регистра в слове, карточка 1968:
# EN: "Do you want to grab a coffee with me?"
# FI: Tuuk sä mun kanssa kahville?
#
# Несогласованность регистра в слове, карточка 2048:
# EN: Email address
# FI: sähköpostiosoite
#
# Несогласованность регистра в слове, карточка 2094:
# EN: Cozy
# FI: kodikas
#
# Несогласованность регистра в слове, карточка 2112:
# EN: Toaster
# FI: leivänpaahdin
#
# Несогласованность регистра в слове, карточка 2118:
# EN: TV stand
# FI: tv-taso
#
# Несогласованность регистра в слове, карточка 2130:
# EN: Bathtub
# FI: kylpyamme
#
# Несогласованность регистра в слове, карточка 2131:
# EN: Sink
# FI: pesuallas
#
# Несогласованность регистра в слове, карточка 2141:
# EN: Townhouse
# FI: rivitalo
#
# Несогласованность регистра в слове, карточка 2155:
# EN: Walk-in closet
# FI: vaatehuone
#
# Несогласованность регистра в слове, карточка 2161:
# EN: Garage
# FI: autotalli
#
# Несогласованность регистра в слове, карточка 2164:
# EN: Outdoor equipment storage room
# FI: ulkovälinevarasto
#
# Несогласованность регистра в слове, карточка 2165:
# EN: Bike storage room
# FI: pyörävarasto
#
# Несогласованность регистра в слове, карточка 2178:
# EN: Sauna time
# FI: saunavuoro
#
# Несогласованность регистра в слове, карточка 2180:
# EN: Aha
# FI: ahaa
#
# Несогласованность точки в слове, карточка 2188:
# EN: Clear
# FI: Selvä.
#
# Несогласованность точки в предложении, карточка 2195:
# EN: His name was on the tip of my tongue.
# FI: Minulla oli hänen nimensä kieleni päällä
#
# Несогласованность регистра в слове, карточка 2198:
# EN: in Vantaa
# FI: Vantaalla
#
# Несогласованность регистра в слове, карточка 2199:
# EN: in Tampere
# FI: Tampereella
#
# Несогласованность регистра в слове, карточка 2200:
# EN: in Rovaniemi
# FI: Rovaniemellä
#
# Несогласованность регистра в слове, карточка 2201:
# EN: in Imatra
# FI: Imatralla
#
# Несогласованность регистра в слове, карточка 2222:
# EN: to Porvoo
# FI: Porvooseen
#
# Несогласованность регистра в слове, карточка 2226:
# EN: {
#     "translation": "He's going to the square."
# }
# FI: Hän menee torille.
#
# Несогласованность точки в слове, карточка 2226:
# EN: {
#     "translation": "He's going to the square."
# }
# FI: Hän menee torille.
#
# Несогласованность точки в предложении, карточка 2228:
# EN: He goes to the square.
# FI:
#
# Несогласованность регистра в слове, карточка 2253:
# EN: Dachshund
# FI: mäyräkoira
#
# Несогласованность регистра в слове, карточка 2266:
# EN: Long time no see
# FI: pitkästä aikaa
#
# Несогласованность регистра в слове, карточка 2268:
# EN: Here (this)
# FI: tässä (tämä)
#
# Несогласованность регистра в слове, карточка 2273:
# EN: ```json
# {
#   "translation": "Come to the table!"
# }
# ```
# FI: Tulkaa pöytään!
#
# Несогласованность регистра в слове, карточка 2285:
# EN: Museum center
# FI: museokeskus
#
# Несогласованность точки в предложении, карточка 2314:
# EN: Thank you, I'd be happy to.
# FI:
#
# Несогласованность регистра в слове, карточка 2344:
# EN: Parking
# FI: pysäköinti
#
# Несогласованность точки в предложении, карточка 2373:
# EN: We have a double room.
# FI: Meillä on kahden hengen huone
#
# Несогласованность точки в слове, карточка 2375:
# EN: Exactly.
# FI: Just niin (Juuri niin)
#
# Несогласованность точки в слове, карточка 2413:
# EN: Wow! You had a really long day.
# FI: Ohhoh! Sinulla oli tosi pitkä päivä
#
# Несогласованность регистра в слове, карточка 2414:
# EN: I was
# FI: olin
#
# Несогласованность регистра в слове, карточка 2419:
# EN: I arrived
# FI: tulin
#
# Несогласованность регистра в слове, карточка 2424:
# EN: I went
# FI: menin
#
# Несогласованность регистра в слове, карточка 2425:
# EN: Did you go
# FI: menit
#
# Несогласованность регистра в слове, карточка 2427:
# EN: Did you go
# FI: menitte
#
# Несогласованность регистра в слове, карточка 2429:
# EN: I had
# FI: minulla oli
#
# Несогласованность регистра в слове, карточка 2431:
# EN: He had
# FI: hänellä oli
#
# Несогласованность регистра в слове, карточка 2432:
# EN: Did you have
# FI: teillä oli
#
# Несогласованность регистра в слове, карточка 2452:
# EN: Shopping list
# FI: ostoslista
#
# Несогласованность регистра в слове, карточка 2488:
# EN: Name day
# FI: nimipäivä
#
# Несогласованность регистра в слове, карточка 2521:
# EN: Carrot
# FI: porkkana
#
# Несогласованность регистра в слове, карточка 2531:
# EN: Meat
# FI: liha
#
# Несогласованность регистра в слове, карточка 2532:
# EN: Pork
# FI: porsaanliha
#
# Несогласованность регистра в слове, карточка 2563:
# EN: Bottle
# FI: pullo
#
# Несогласованность регистра в слове, карточка 2585:
# EN: Porridge
# FI: puuro
#
# Несогласованность регистра в слове, карточка 2587:
# EN: Karelian pasty (Karelian pie)
# FI: karjalanpiirakka
#
# Несогласованность регистра в слове, карточка 2618:
# EN: I am leaving
# FI: mä lähden (lähden)
#
# Несогласованность регистра в слове, карточка 2645:
# EN: "There is spaghetti on the plate."
# FI: Lautasella on spagettia.
#
# Несогласованность точки в слове, карточка 2645:
# EN: "There is spaghetti on the plate."
# FI: Lautasella on spagettia.
#
# Несогласованность регистра в слове, карточка 2649:
# EN: "That cake looks really good."
# FI: Tuo kakku näyttää tosi hyvältä.
#
# Несогласованность точки в слове, карточка 2649:
# EN: "That cake looks really good."
# FI: Tuo kakku näyttää tosi hyvältä.
#
# Несогласованность регистра в слове, карточка 2655:
# EN: Fourth
# FI: neljäs
#
# Несогласованность регистра в слове, карточка 2656:
# EN: Fifth
# FI: viides
#
# Несогласованность регистра в слове, карточка 2657:
# EN: Sixth
# FI: kuudes
#
# Несогласованность регистра в слове, карточка 2658:
# EN: Seventh
# FI: seitsemäs
#
# Несогласованность регистра в слове, карточка 2659:
# EN: Eighth
# FI: kahdeksas
#
# Несогласованность регистра в слове, карточка 2660:
# EN: Ninth
# FI: yhdeksäs
#
# Несогласованность регистра в слове, карточка 2661:
# EN: Tenth
# FI: kymmenes
#
# Несогласованность регистра в слове, карточка 2662:
# EN: Eleventh
# FI: yhdestoista
#
# Несогласованность регистра в слове, карточка 2663:
# EN: Twelfth
# FI: kahdestoista
#
# Несогласованность регистра в слове, карточка 2665:
# EN: Fourteenth
# FI: neljästoista
#
# Несогласованность регистра в слове, карточка 2666:
# EN: Fifteenth
# FI: viidestoista
#
# Несогласованность регистра в слове, карточка 2667:
# EN: Sixteenth
# FI: kuudestoista
#
# Несогласованность регистра в слове, карточка 2668:
# EN: Seventeenth
# FI: seitsemästoista
#
# Несогласованность регистра в слове, карточка 2669:
# EN: Eighteenth
# FI: kahdeksastoista
#
# Несогласованность регистра в слове, карточка 2670:
# EN: Nineteenth
# FI: yhdeksästoista
#
# Несогласованность регистра в слове, карточка 2671:
# EN: Twentieth
# FI: kahdeskymmenes
#
# Несогласованность регистра в слове, карточка 2672:
# EN: Twenty-first
# FI: kahdeskymmenesensimmäinen
#
# Несогласованность регистра в слове, карточка 2673:
# EN: Twenty-second
# FI: kahdeskymmenestoinen
#
# Несогласованность регистра в слове, карточка 2674:
# EN: Twenty-fifth
# FI: kahdeskymmenesviides
#
# Несогласованность регистра в слове, карточка 2675:
# EN: Twenty-sixth
# FI: kahdeskymmeneskuudes
#
# Несогласованность регистра в слове, карточка 2676:
# EN: Twenty-seventh
# FI: kahdeskymmenesseitsemäs
#
# Несогласованность регистра в слове, карточка 2677:
# EN: Twenty-eighth
# FI: kahdeskymmeneskahdeksas
#
# Несогласованность регистра в слове, карточка 2678:
# EN: Twenty-ninth
# FI: kahdeskymmenesyhdeksäs
#
# Несогласованность регистра в слове, карточка 2680:
# EN: Thirty-first
# FI: kolmaskymmenesensimmäinen
#
# Несогласованность регистра в слове, карточка 2687:
# EN: 'Pedro thinks Helsinki is a nice summer city.'
# FI: Pedrosta Helsinki on kiva kesäkaupunki.
#
# Несогласованность точки в слове, карточка 2687:
# EN: 'Pedro thinks Helsinki is a nice summer city.'
# FI: Pedrosta Helsinki on kiva kesäkaupunki.
#
# Несогласованность точки в слове, карточка 2701:
# EN: I think so too
# FI: Niin minustakin.
#
# Несогласованность регистра в слове, карточка 2733:
# EN: IT department
# FI: it-osasto
#
# Несогласованность точки в слове, карточка 2752:
# EN: Alright then
# FI: No niin.
#
# Несогласованность точки в слове, карточка 2753:
# EN: Good to know
# FI: Hyvä tietää.
#
# Несогласованность регистра в слове, карточка 2754:
# EN: "Yeah, nice."
# FI: Joo, kiva.
#
# Несогласованность точки в слове, карточка 2754:
# EN: "Yeah, nice."
# FI: Joo, kiva.
#
# Несогласованность регистра в слове, карточка 2791:
# EN: Taxi driver
# FI: taksikuski
#
# Несогласованность регистра в слове, карточка 2803:
# EN: Engineer
# FI: insinööri
#
# Несогласованность регистра в слове, карточка 2812:
# EN: CEO
# FI: toimitusjohtaja
#
# Несогласованность регистра в слове, карточка 2813:
# EN: Human Resources Manager
# FI: henkilöstöpäällikkö
#
# Несогласованность регистра в слове, карточка 2822:
# EN: Kitchen assistant
# FI: keittiöapulainen
#
# Несогласованность регистра в слове, карточка 2828:
# EN: Interpreter
# FI: tulkki
#
# Несогласованность регистра в слове, карточка 2855:
# EN: "I wanted to reserve a table for four."
# FI: Halusin varata pöydän neljälle.
#
# Несогласованность точки в слове, карточка 2855:
# EN: "I wanted to reserve a table for four."
# FI: Halusin varata pöydän neljälle.
#
# Несогласованность регистра в слове, карточка 2865:
# EN: whom
# FI: Kenet?
#
# Несогласованность регистра в слове, карточка 2894:
# EN: "We are talking about courses."
# FI: Me juttelemme kursseista.
#
# Несогласованность точки в слове, карточка 2894:
# EN: "We are talking about courses."
# FI: Me juttelemme kursseista.
#
# Несогласованность регистра в слове, карточка 2896:
# EN: 'Colleagues are discussing their vacation.'
# FI: Työkaverit keskustelevat lomasta.
#
# Несогласованность точки в слове, карточка 2896:
# EN: 'Colleagues are discussing their vacation.'
# FI: Työkaverit keskustelevat lomasta.
#
# Несогласованность регистра в слове, карточка 2924:
# EN: I have
# FI: minulla
#
# Несогласованность регистра в слове, карточка 2977:
# EN: "On Saturday, I woke up early."
# FI: Lauantaina heräsin aikaisin.
#
# Несогласованность точки в слове, карточка 2977:
# EN: "On Saturday, I woke up early."
# FI: Lauantaina heräsin aikaisin.
#
# Несогласованность регистра в слове, карточка 2996:
# EN: November 16, 2022
# FI: 16. marraskuuta 2022
#
# Несогласованность регистра в слове, карточка 2998:
# EN: "In which week?"
# FI: Millä viikolla?
#
# Несогласованность регистра в слове, карточка 3022:
# EN: 'In a couple of months, it will already be winter.'
# FI: Parin kuukauden kuluttua on jo talvi.
#
# Несогласованность точки в слове, карточка 3022:
# EN: 'In a couple of months, it will already be winter.'
# FI: Parin kuukauden kuluttua on jo talvi.
#
# Несогласованность точки в слове, карточка 3026:
# EN: We are traveling for a week.
# FI: Olemme matkalla viikon. (yhden viikon)
#
# Несогласованность регистра в слове, карточка 3094:
# EN: I slept
# FI: nukuin
#
# Несогласованность регистра в слове, карточка 3100:
# EN: I said
# FI: sanoin
#
# Несогласованность регистра в слове, карточка 3101:
# EN: I preserved
# FI: säilöin
#
# Несогласованность регистра в слове, карточка 3102:
# EN: I spoke
# FI: puhuin
#
# Несогласованность регистра в слове, карточка 3103:
# EN: I asked
# FI: kysyin
#
# Несогласованность регистра в слове, карточка 3104:
# EN: I waited
# FI: odotin
#
# Несогласованность регистра в слове, карточка 3105:
# EN: I liked
# FI: pidin
#
# Несогласованность регистра в слове, карточка 3106:
# EN: I studied
# FI: opiskelin
#
# Несогласованность регистра в слове, карточка 3107:
# EN: I swim
# FI: uin
#
# Несогласованность регистра в слове, карточка 3108:
# EN: I started
# FI: aloin
#
# Несогласованность регистра в слове, карточка 3109:
# EN: I sang
# FI: lauloin
#
# Несогласованность регистра в слове, карточка 3110:
# EN: I drank
# FI: join
#
# Несогласованность регистра в слове, карточка 3111:
# EN: I ate
# FI: söin
#
# Несогласованность регистра в слове, карточка 3112:
# EN: I brought, I took
# FI: vein
#
# Несогласованность регистра в слове, карточка 3113:
# EN: I got
# FI: sain
#
# Несогласованность регистра в слове, карточка 3114:
# EN: I sold
# FI: myin
#
# Несогласованность регистра в слове, карточка 3115:
# EN: I stayed
# FI: jäin
#
# Несогласованность регистра в слове, карточка 3122:
# EN: I woke up
# FI: heräsin
#
# Несогласованность регистра в слове, карточка 3123:
# EN: I wanted
# FI: halusin
#
# Несогласованность регистра в слове, карточка 3124:
# EN: I responded
# FI: vastasin
#
# Несогласованность регистра в слове, карточка 3125:
# EN: I flew
# FI: lensin
#
# Несогласованность регистра в слове, карточка 3126:
# EN: I understood
# FI: ymmärsin
#
# Несогласованность регистра в слове, карточка 3220:
# EN: Call
# FI: puhelu
#
# Несогласованность точки в слове, карточка 3245:
# EN: No, I mean...
# FI: Eiku (Ei vaan...)
#
# Несогласованность регистра в слове, карточка 3289:
# EN: {
#     "final_translation": "What's wrong?"
# }
# FI: Mikä sulla on?
#
# Несогласованность регистра в слове, карточка 3336:
# EN: Bacteria
# FI: bakteeri
#
# Несогласованность регистра в слове, карточка 3367:
# EN: "Now I am reading a book."
# FI: Nyt minä luen kirjaa.
#
# Несогласованность точки в слове, карточка 3367:
# EN: "Now I am reading a book."
# FI: Nyt minä luen kirjaa.
#
# Несогласованность регистра в слове, карточка 3375:
# EN: ```json
# {
#   "translation": "I love him."
# }
# ```
# FI: Minä rakastan häntä.
#
# Несогласованность точки в слове, карточка 3375:
# EN: ```json
# {
#   "translation": "I love him."
# }
# ```
# FI: Minä rakastan häntä.
#
# Несогласованность регистра в слове, карточка 3380:
# EN: Sorry
# FI: sori (anteeksi)
#
# Несогласованность регистра в слове, карточка 3411:
# EN: Fortunately
# FI: onneksi
#
# Несогласованность регистра в слове, карточка 3442:
# EN: "Let's stop somewhere on the way!"
# FI: Pysähdytään matkalla jossain!
#
# Несогласованность точки в предложении, карточка 3463:
# EN: Could you pour water on the sauna stones? It's too cold for me.
# FI: Voisitko heittää löylyä, minulle on liian kylmä?
#
# Несогласованность регистра в слове, карточка 3503:
# EN: Goose
# FI: hanhi
#
# Несогласованность регистра в слове, карточка 3516:
# EN: Rowan (or Mountain Ash)
# FI: pihlaja
#
# Несогласованность регистра в слове, карточка 3550:
# EN: "He's coming from the terrace after eating."
# FI: Hän tulee terassilta syömästä.
#
# Несогласованность точки в слове, карточка 3550:
# EN: "He's coming from the terrace after eating."
# FI: Hän tulee terassilta syömästä.
#
# Несогласованность регистра в слове, карточка 3582:
# EN: I am getting older
# FI: minä vanhenen
#
# Несогласованность регистра в слове, карточка 3583:
# EN: You're getting older.
# FI: sinä vanhenet
#
# Несогласованность точки в слове, карточка 3583:
# EN: You're getting older.
# FI: sinä vanhenet
#
# Несогласованность регистра в слове, карточка 3584:
# EN: He is getting older
# FI: hän vanhenee
#
# Несогласованность регистра в слове, карточка 3586:
# EN: You are getting older.
# FI: te vanhenette
#
# Несогласованность точки в слове, карточка 3586:
# EN: You are getting older.
# FI: te vanhenette
#
# Несогласованность регистра в слове, карточка 3589:
# EN: I flee
# FI: minä pakenen
#
# Несогласованность регистра в слове, карточка 3627:
# EN: In my opinion
# FI: musta (minusta)
#
# Несогласованность регистра в слове, карточка 3632:
# EN: TV
# FI: telkkari (televisio)
#
# Несогласованность регистра в слове, карточка 3670:
# EN: "I enjoy swimming."
# FI: Harrastan uintia.
#
# Несогласованность точки в слове, карточка 3670:
# EN: "I enjoy swimming."
# FI: Harrastan uintia.
#
# Несогласованность точки в предложении, карточка 3673:
# EN: I enjoy downhill skiing as a hobby.
# FI:
#
# Несогласованность регистра в слове, карточка 3675:
# EN: "I enjoy cycling."
# FI: Harrastan pyöräilyä.
#
# Несогласованность точки в слове, карточка 3675:
# EN: "I enjoy cycling."
# FI: Harrastan pyöräilyä.
#
# Несогласованность регистра в слове, карточка 3681:
# EN: "I'm a sports fan."
# FI: Harrastan penkkiurheilua.
#
# Несогласованность точки в слове, карточка 3681:
# EN: "I'm a sports fan."
# FI: Harrastan penkkiurheilua.
#
# Несогласованность регистра в слове, карточка 3696:
# EN: "I'm taking a language course."
# FI: Olen kielikurssilla.
#
# Несогласованность точки в слове, карточка 3696:
# EN: "I'm taking a language course."
# FI: Olen kielikurssilla.
#
# Несогласованность регистра в слове, карточка 3706:
# EN: Rarely
# FI: harvoin
#
# Несогласованность регистра в слове, карточка 3711:
# EN: 'From where to where?'
# FI: Mistä mihin?
#
# Несогласованность регистра в слове, карточка 3733:
# EN: Research
# FI: tutkimus
#
# Несогласованность регистра в слове, карточка 3767:
# EN: Opportunity
# FI: mahdollisuus
#
# Несогласованность регистра в слове, карточка 3780:
# EN: "I also like swimming."
# FI: Minäkin pidän uimisesta.
#
# Несогласованность точки в слове, карточка 3780:
# EN: "I also like swimming."
# FI: Minäkin pidän uimisesta.
#
# Несогласованность точки в предложении, карточка 3797:
# EN: They love swimming in lakes.
# FI:
#
# Несогласованность точки в предложении, карточка 3802:
# EN: I did not buy anything.
# FI:
#
# Несогласованность регистра в слове, карточка 3804:
# EN: I did not read
# FI: minä en lukenut
#
# Несогласованность регистра в слове, карточка 3810:
# EN: I didn't eat
# FI: minä en syönyt
#
# Несогласованность регистра в слове, карточка 3816:
# EN: I did not know
# FI: minä en tiennyt (en tiennyt)
#
# Несогласованность регистра в слове, карточка 3817:
# EN: I did not come
# FI: minä en tullut
#
# Несогласованность регистра в слове, карточка 3823:
# EN: I didn't wash
# FI: minä en pessyt
#
# Несогласованность регистра в слове, карточка 3829:
# EN: I couldn't
# FI: minä en osannut
#
# Несогласованность регистра в слове, карточка 3835:
# EN: I didn't need
# FI: minä en tarvinnut
#
# Несогласованность регистра в слове, карточка 3841:
# EN: I didn't run away
# FI: minä en paennut
#
# Несогласованность регистра в слове, карточка 3847:
# EN: I haven't read
# FI: mä en lukenu
#
# Несогласованность регистра в слове, карточка 3853:
# EN: I didn't come
# FI: mä en tullu
#
# Несогласованность регистра в слове, карточка 3859:
# EN: I didn't know how
# FI: mä en osannu
#
# Несогласованность регистра в слове, карточка 3885:
# EN: "Nice to get to the cottage after a long time!"
# FI: Kiva päästä mökille pitkästä aikaa!
#
# Несогласованность регистра в слове, карточка 3887:
# EN: "Does it hurt here?"
# FI: Sattuuko tähän?
#
# Несогласованность регистра в слове, карточка 3889:
# EN: "Is a hostel okay for you?"
# FI: Kelpaako teille hostelli?
#
# Несогласованность регистра в слове, карточка 3907:
# EN: {
#     "Translation": "That's true!"
# }
# FI: Niin onkin!
#
# Несогласованность точки в слове, карточка 3932:
# EN: You had bad luck.
# FI: Teillä kävi huono tuuri. (Teillä oli huono onni.)
#
# Несогласованность регистра в слове, карточка 3954:
# EN: "There's all sorts of stuff scattered all over the floor."
# FI: Lattialla on sikin sokin kaikenlaista tavaraa.
#
# Несогласованность точки в слове, карточка 3954:
# EN: "There's all sorts of stuff scattered all over the floor."
# FI: Lattialla on sikin sokin kaikenlaista tavaraa.
#
# Несогласованность регистра в слове, карточка 3981:
# EN: Due date
# FI: eräpäivä
#
# Несогласованность регистра в слове, карточка 3989:
# EN: ID card
# FI: henkilökortti
#
# Несогласованность точки в предложении, карточка 4016:
# EN: The fisherman uses nets.
# FI: Kalastaja käyttää verkkoja
#
# Несогласованность точки в слове, карточка 4020:
# EN: You're welcome.
# FI: Eipä mitään. (Ei kestä)
#
# Несогласованность регистра в слове, карточка 4024:
# EN: I have read
# FI: minä olen lukenut
#
# Несогласованность регистра в слове, карточка 4030:
# EN: I haven't read
# FI: minä en ole lukenut
#
# Несогласованность регистра в слове, карточка 4036:
# EN: I have read
# FI: mä oon lukenu
#
# Несогласованность регистра в слове, карточка 4042:
# EN: I haven't read
# FI: mä en oo lukenu
#
# Несогласованность регистра в слове, карточка 4052:
# EN: 'I have already lived in Finland for 4 years.'
# FI: Olen asunut Suomessa jo 4 vuotta.
#
# Несогласованность точки в слове, карточка 4052:
# EN: 'I have already lived in Finland for 4 years.'
# FI: Olen asunut Suomessa jo 4 vuotta.
#
# Несогласованность регистра в слове, карточка 4095:
# EN: Someone
# FI: joltakin
#
# Несогласованность регистра в слове, карточка 4097:
# EN: "Is this some kind of joke?"
# FI: Onko tämä jokin vitsi?
#
# Несогласованность регистра в слове, карточка 4132:
# EN: New Year
# FI: uusivuosi
#
# Несогласованность регистра в слове, карточка 4160:
# EN: In everyone's opinion
# FI: kaikkien mielestä
#
# Несогласованность регистра в слове, карточка 4200:
# EN: Valentine's Day 14.2.
# FI: ystävänpäivä 14.2.
#
# Несогласованность регистра в слове, карточка 4201:
# EN: Shrovetide in February
# FI: laskiainen helmikuussa
#
# Несогласованность регистра в слове, карточка 4202:
# EN: Easter in March-April
# FI: pääsiäinen maalis-huhtikuussa
#
# Несогласованность регистра в слове, карточка 4203:
# EN: May Day
# FI: vappu 1.5.
#
# Несогласованность точки в слове, карточка 4203:
# EN: May Day
# FI: vappu 1.5.
#
# Несогласованность регистра в слове, карточка 4204:
# EN: Midsummer in June
# FI: juhannus kesäkuussa
#
# Несогласованность регистра в слове, карточка 4205:
# EN: Independence Day 12/6
# FI: itsenäisyyspäivä 6.12.
#
# Несогласованность точки в слове, карточка 4205:
# EN: Independence Day 12/6
# FI: itsenäisyyspäivä 6.12.
#
# Несогласованность регистра в слове, карточка 4207:
# EN: Christmas Eve 24.12.
# FI: jouluaatto 24.12.
#
# Несогласованность регистра в слове, карточка 4209:
# EN: Godmother, godfather, godparents
# FI: kummitäti, kummisetä, kummi
#
# Несогласованность регистра в слове, карточка 4224:
# EN: "We are celebrating Easter at home."
# FI: Vietämme pääsiäistä kotona.
#
# Несогласованность точки в слове, карточка 4224:
# EN: "We are celebrating Easter at home."
# FI: Vietämme pääsiäistä kotona.
#
# Несогласованность точки в предложении, карточка 4274:
# EN: Can you come to my room? I have something to show you.
# FI: Voitko tulla huoneeseeni, minulla on sinulle jotain näytettävää?
#
# Несогласованность регистра в слове, карточка 4275:
# EN: "Our new house has a sauna."
# FI: Uudessa talossamme on sauna.
#
# Несогласованность точки в слове, карточка 4275:
# EN: "Our new house has a sauna."
# FI: Uudessa talossamme on sauna.
#
# Несогласованность регистра в слове, карточка 4282:
# EN: I had read
# FI: olin lukenut
#
# Несогласованность регистра в слове, карточка 4288:
# EN: I hadn't read
# FI: en ollut lukenut
#
# Несогласованность регистра в слове, карточка 4294:
# EN: I had read
# FI: mä olin lukenu
#
# Несогласованность регистра в слове, карточка 4295:
# EN: I hadn't read
# FI: mä en ollu lukenu
#
# Несогласованность точки в предложении, карточка 4307:
# EN: I have lived in several different cities here.
# FI:
#
# Несогласованность регистра в слове, карточка 4347:
# EN: Negative
# FI: kielteinen
#
# Несогласованность регистра в слове, карточка 4359:
# EN: Information and communication technology
# FI: tieto- ja viestintätekniikka
#
# Несогласованность регистра в слове, карточка 4376:
# EN: Absolutely, of course
# FI: ehdottomasti
#
# Несогласованность регистра в слове, карточка 4413:
# EN: Competent
# FI: pätevä
#
# Несогласованность регистра в слове, карточка 4418:
# EN: Doctor
# FI: tohtori
#
# Несогласованность регистра в слове, карточка 4421:
# EN: Professional Master's degree
# FI: ylempi AMK-tutkinto
#
# Несогласованность регистра в предложении, карточка 4423:
# EN: "Secondary education" in Finland refers to both general upper secondary education and vocational education and training.
# FI: Toinen aste tarkoittaa Suomessa lukio- ja ammatillista koulutusta.
#
# Несогласованность регистра в слове, карточка 4448:
# EN: Excuse me, I apologize
# FI: anteeks (anteeksi)
#
# Несогласованность регистра в слове, карточка 4451:
# EN: Language proficiency, Knowledge of the language
# FI: kielitaito
#
# Несогласованность регистра в слове, карточка 4457:
# EN: Easier
# FI: helpompi
#
# Несогласованность регистра в слове, карточка 4487:
# EN: "Behind the houses, there is a forest."
# FI: Talojen takana on metsä.
#
# Несогласованность точки в слове, карточка 4487:
# EN: "Behind the houses, there is a forest."
# FI: Talojen takana on metsä.
#
# Несогласованность регистра в слове, карточка 4510:
# EN: 'Oh, to those tall ones?'
# FI: Ai niihin korkeisiin?
#
# Несогласованность регистра в слове, карточка 4557:
# EN: "We are learning tango in the dance class."
# FI: Tanssikurssilla opettelemme tangoa.
#
# Несогласованность точки в слове, карточка 4557:
# EN: "We are learning tango in the dance class."
# FI: Tanssikurssilla opettelemme tangoa.
#
# Несогласованность регистра в слове, карточка 4558:
# EN: "We are learning to dance in the dance class."
# FI: Tanssikurssilla opettelemme tanssimaan.
#
# Несогласованность точки в слове, карточка 4558:
# EN: "We are learning to dance in the dance class."
# FI: Tanssikurssilla opettelemme tanssimaan.
#
# Несогласованность регистра в слове, карточка 4562:
# EN: "On a business trip, we met foreign colleagues."
# FI: Työmatkalla tutustuimme ulkomaalaisiin kollegoihin.
#
# Несогласованность точки в слове, карточка 4562:
# EN: "On a business trip, we met foreign colleagues."
# FI: Työmatkalla tutustuimme ulkomaalaisiin kollegoihin.
#
# Несогласованность регистра в слове, карточка 4607:
# EN: Wireless
# FI: langaton
#
# Несогласованность регистра в слове, карточка 4659:
# EN: Payer
# FI: maksaja
#
# Несогласованность регистра в слове, карточка 4794:
# EN: I have
# FI: mulla
#
# Несогласованность регистра в слове, карточка 4808:
# EN: "This food is really good!"
# FI: Tää ruoka on tosi hyvää!
#
# Несогласованность регистра в слове, карточка 4809:
# EN: "And these olives taste amazing."
# FI: Ja nää oliivit maistuu ihanilta.
#
# Несогласованность точки в слове, карточка 4809:
# EN: "And these olives taste amazing."
# FI: Ja nää oliivit maistuu ihanilta.
#
# Несогласованность регистра в слове, карточка 4811:
# EN: "It's nothing, I love to help!"
# FI: Ei mitään, musta on kiva auttaa!
#
# Несогласованность регистра в слове, карточка 4812:
# EN: I live
# FI: mä asun
#
# Несогласованность регистра в слове, карточка 4818:
# EN: I don't live
# FI: mä en asu
#
# Несогласованность регистра в слове, карточка 4825:
# EN: I'm not
# FI: mä en oo
#
# Несогласованность регистра в слове, карточка 4830:
# EN: I am not going
# FI: mä en mee
#
# Несогласованность регистра в слове, карточка 4836:
# EN: I won't come
# FI: mä en tuu
#
# Несогласованность регистра в слове, карточка 4842:
# EN: I lived
# FI: mä asuin
#
# Несогласованность регистра в слове, карточка 4847:
# EN: I didn't live
# FI: mä en asunu
#
# Несогласованность регистра в слове, карточка 4854:
# EN: I have lived
# FI: mä oon asunu
#
# Несогласованность регистра в слове, карточка 4860:
# EN: I haven't lived
# FI: mä en oo asunu
#
# Несогласованность регистра в слове, карточка 4866:
# EN: I lived
# FI: mä olin asunu
#
# Несогласованность регистра в слове, карточка 4872:
# EN: I had not lived
# FI: mä en ollu asunu
#
# Несогласованность регистра в слове, карточка 4878:
# EN: "Do you live in Jyväskylä?"
# FI: Asuks sä Jyväskylässä?
#
# Несогласованность точки в предложении, карточка 4893:
# EN: You need to sort the waste.
# FI: Teidän täytyy laijitella jätteet
#
# Несогласованность точки в предложении, карточка 4897:
# EN: Every city resident is a consumer of electricity.
# FI: Jokainen kaupungin asukas on sähkönkuluttaja
#
# Несогласованность регистра в слове, карточка 4899:
# EN: Consisting of three people
# FI: kolmihenkinen
#
# Несогласованность регистра в слове, карточка 4952:
# EN: Water consumption
# FI: vedenkulutus
#
# Несогласованность регистра в слове, карточка 4972:
# EN: I would say
# FI: sanoisin
#
# Несогласованность регистра в слове, карточка 4983:
# EN: Would you wake up
# FI: heräisit
#
# Несогласованность регистра в слове, карточка 4987:
# EN: I would do
# FI: minä tekisin
#
# Несогласованность регистра в слове, карточка 4988:
# EN: I wouldn't do it
# FI: minä en tekisi
#
# Несогласованность точки в предложении, карточка 4999:
# EN: Didn't she? She could have won last year if she had participated.
# FI:
#
# Несогласованность регистра в слове, карточка 5047:
# EN: {
#   "translation": "Safe travels!"
# }
# FI: Onnea matkaan!
#
# Несогласованность регистра в слове, карточка 5093:
# EN: Art exhibition
# FI: taidenäyttely
#
# Несогласованность точки в предложении, карточка 5175:
# EN: Before four works for me.
# FI: Minulle käy ennen neljää
#
# Несогласованность точки в слове, карточка 5185:
# EN: Two o'clock works for me.
# FI: Minulle käy kahdelta
#
# Несогласованность регистра в слове, карточка 5186:
# EN: "I'm available after two."
# FI: Minulle käy kahden jälkeen
#
# Несогласованность регистра в слове, карточка 5187:
# EN: "I'm available until four."
# FI: Minulle käy neljään asti
#
# Несогласованность регистра в слове, карточка 5188:
# EN: "Anytime until four works for me."
# FI: Minulle käy neljään saakka
#
# Несогласованность регистра в слове, карточка 5189:
# EN: 'Anytime between two and four works for me.'
# FI: Minulle käy kahden ja neljän välillä
#
# Несогласованность точки в слове, карточка 5190:
# EN: I'm available from two to four.
# FI: Minulle käy kahdesta neljään
#
# Несогласованность регистра в слове, карточка 5199:
# EN: 'Strawberries are sold at the market.'
# FI: Torilla myydään mansikoita.
#
# Несогласованность точки в слове, карточка 5199:
# EN: 'Strawberries are sold at the market.'
# FI: Torilla myydään mansikoita.
#
# Несогласованность регистра в слове, карточка 5206:
# EN: 'Sunglasses are also often bought from an optician's.'
# FI: Myös aurinkolasit ostetaan usein optikolta.
#
# Несогласованность точки в слове, карточка 5206:
# EN: 'Sunglasses are also often bought from an optician's.'
# FI: Myös aurinkolasit ostetaan usein optikolta.
#
# Несогласованность регистра в слове, карточка 5207:
# EN: "They no longer teach Japanese at the university."
# FI: Yliopistossa ei enää opeteta japania.
#
# Несогласованность точки в слове, карточка 5207:
# EN: "They no longer teach Japanese at the university."
# FI: Yliopistossa ei enää opeteta japania.
#
# Несогласованность регистра в слове, карточка 5226:
# EN: 'You can learn couple dances at Rautatientori.'
# FI: Rautatientorilla voi opetella paritansseja.
#
# Несогласованность точки в слове, карточка 5226:
# EN: 'You can learn couple dances at Rautatientori.'
# FI: Rautatientorilla voi opetella paritansseja.
#
# Несогласованность регистра в слове, карточка 5257:
# EN: Stone Age
# FI: kivikausi
#
# Несогласованность регистра в слове, карточка 5259:
# EN: B.C. (before the common era)
# FI: eaa. (ennen ajanlaskun alkua)
#
# Несогласованность регистра в слове, карточка 5260:
# EN: Revolution
# FI: vallankumous
#
# Несогласованность регистра в слове, карточка 5261:
# EN: Ice Age
# FI: jääkausi
#
# Несогласованность регистра в слове, карточка 5264:
# EN: Gradually
# FI: vähitellen
#
# Несогласованность регистра в слове, карточка 5273:
# EN: Winter War
# FI: talvisota
#
# Несогласованность регистра в слове, карточка 5274:
# EN: Continuation War
# FI: jatkosota
#
# Несогласованность регистра в слове, карточка 5279:
# EN: Christianity
# FI: kristinusko
#
# Несогласованность регистра в слове, карточка 5281:
# EN: Lutheran
# FI: luterilainen
#
# Несогласованность регистра в слове, карточка 5289:
# EN: Olympic Games
# FI: olympialaiset
#
# Несогласованность регистра в слове, карточка 5305:
# EN: Politics
# FI: politiikka
#
# Несогласованность регистра в слове, карточка 5348:
# EN: "Are the potatoes already boiled?"
# FI: Onko perunat jo keitetty?
#
# Несогласованность регистра в слове, карточка 5353:
# EN: "Really? But why weren't we invited?!"
# FI: Ihanko totta? Mutta miksi meitä ei ollut kutsuttu?!
#
# Несогласованность точки в предложении, карточка 5364:
# EN: We are concluding the tour at the hotel.
# FI:
#
# Несогласованность регистра в слове, карточка 5385:
# EN: Indian
# FI: intiaani
#
# ...
# FI: Suurimmissa kaupungeissa on ihan toisenlaista kuin pienemmissä paikoissa.
#
# Несогласованность регистра в слове, карточка 5807:
# EN: "Why don't you take a trip to Lappeenranta?"
# FI: Matkustapa vaikka Lappeenrantaan!
#
# Несогласованность регистра в слове, карточка 5814:
# EN: "There wasn't a bigger house in the city!"
# FI: Kaupungista ei löytynyt tätä isompaa taloa!
#
# Несогласованность регистра в слове, карточка 5824:
# EN: "China has bigger cities than Finland."
# FI: Kiinnassa on isompia kaupunkeja kuin Suomessa.
#
# Несогласованность точки в слове, карточка 5824:
# EN: "China has bigger cities than Finland."
# FI: Kiinnassa on isompia kaupunkeja kuin Suomessa.
#
# Несогласованность регистра в слове, карточка 5836:
# EN: In which of the two
# FI: kummassa
#
# Несогласованность регистра в слове, карточка 5837:
# EN: Which of the two
# FI: kumpana
#
# Несогласованность регистра в слове, карточка 5860:
# EN: "Have you already gotten used to the dark Finnish winters?"
# FI: Oletteko jo tottuneet Suomen pimeisiin talviin?
#
# Несогласованность регистра в слове, карточка 5876:
# EN: Semitic
# FI: seemiläinen
#
# Несогласованность регистра в слове, карточка 5923:
# EN: Indeed
# FI: totisesti
#
# Несогласованность регистра в слове, карточка 5926:
# EN: Publisher
# FI: kustantaja
#
# Несогласованность регистра в слове, карточка 5953:
# EN: Assembly
# FI: kokoaminen
#
# Несогласованность регистра в слове, карточка 5970:
# EN: Within 30 days
# FI: 30 päivän sisällä
#
# Несогласованность регистра в слове, карточка 6042:
# EN: "The book presents the largest cities in France."
# FI: Kirjassa esitellään Ranskan isoimpia kaupunkeja.
#
# Несогласованность точки в слове, карточка 6042:
# EN: "The book presents the largest cities in France."
# FI: Kirjassa esitellään Ranskan isoimpia kaupunkeja.
#
# Несогласованность точки в предложении, карточка 6048:
# EN: He is the owner of the largest hair salon in the city.
# FI: Hän on kaupungin isoimman kampamon omistaja
#
# Несогласованность регистра в слове, карточка 6111:
# EN: "I need help."
# FI: Mä tartten apua.
#
# Несогласованность точки в слове, карточка 6111:
# EN: "I need help."
# FI: Mä tartten apua.
#
# Несогласованность регистра в слове, карточка 6122:
# EN: "Buy that kind of bun!"
# FI: Osta tommonen pulla!
#
# Несогласованность регистра в слове, карточка 6123:
# EN: "We also have a nice vacuum cleaner."
# FI: Meilläkin on semmonen hieno imuri.
#
# Несогласованность точки в слове, карточка 6123:
# EN: "We also have a nice vacuum cleaner."
# FI: Meilläkin on semmonen hieno imuri.
#
# Несогласованность регистра в слове, карточка 6167:
# EN: Formula 1 racing
# FI: formula-ajot
#
# Несогласованность регистра в слове, карточка 6177:
# EN: Walk (or Outing)
# FI: ulkoilu
#
# Несогласованность регистра в слове, карточка 6178:
# EN: Sports spectating
# FI: penkkiurheilu
#
# Несогласованность регистра в слове, карточка 6183:
# EN: World Championship
# FI: maailmanmestaruuskilpailut
#
# Несогласованность регистра в слове, карточка 6187:
# EN: Player
# FI: pelaaja
#
# Несогласованность регистра в слове, карточка 6270:
# EN: 'He came from home after cleaning.'
# FI: Hän tuli kotoa siivoamasta.
#
# Несогласованность точки в слове, карточка 6270:
# EN: 'He came from home after cleaning.'
# FI: Hän tuli kotoa siivoamasta.
#
# Несогласованность точки в предложении, карточка 6272:
# EN: They left the sauna uncleaned.
# FI:
#
# Несогласованность точки в предложении, карточка 6275:
# EN: The room is filled with many people.
# FI:
#
# Несогласованность регистра в слове, карточка 6283:
# EN: 'In winter, you get more tired than in summer.'
# FI: Talvella väsyttää enemmän kuin kesällä.
#
# Несогласованность точки в слове, карточка 6283:
# EN: 'In winter, you get more tired than in summer.'
# FI: Talvella väsyttää enemmän kuin kesällä.
#
# Несогласованность регистра в слове, карточка 6295:
# EN: Understood
# FI: selvä
#
# Несогласованность регистра в слове, карточка 6307:
# EN: Dutch
# FI: alankomaalainen
#
# Несогласованность регистра в слове, карточка 6324:
# EN: Finnishness
# FI: suomalaisuus
#
# Несогласованность регистра в слове, карточка 6353:
# EN: Channel Four
# FI: nelonen
#
# Несогласованность регистра в слове, карточка 6354:
# EN: A grade of five
# FI: vitonen
#
# Несогласованность регистра в слове, карточка 6366:
# EN: "On the twenty or the sixty-five."
# FI: Kakskymppisellä tai kuusvitosella.
#
# Несогласованность точки в слове, карточка 6366:
# EN: "On the twenty or the sixty-five."
# FI: Kakskymppisellä tai kuusvitosella.
#
# Несогласованность регистра в слове, карточка 6417:
# EN: I believe I am suitable
# FI: uskon sopivani (uskon, että sovin)
#
# Несогласованность регистра в слове, карточка 6436:
# EN: Skill
# FI: taito
#
# Несогласованность регистра в слове, карточка 6444:
# EN: Patience
# FI: kärsivällisyys
#
# Несогласованность регистра в слове, карточка 6454:
# EN: Programming
# FI: ohjelmointi
#
# Несогласованность регистра в слове, карточка 6458:
# EN: Social media
# FI: sosiaalinen media
#
# Несогласованность регистра в слове, карточка 6487:
# EN: Union
# FI: ammattiliitto
#
# Несогласованность регистра в слове, карточка 6516:
# EN: {"translation": "This is Paula Mäkelä, hi!"}
# FI: Tässä on Paula Mäkelä, hei!
#
# Несогласованность регистра в слове, карточка 6517:
# EN: 'I wonder if Anni Salo is here?'
# FI: Onkohan Anni Salo paikalla?
#
# Несогласованность регистра в слове, карточка 6523:
# EN: "Could you connect me to Anni Salo?"
# FI: Voitteko yhdistää Anni Salolle?
#
# Несогласованность регистра в слове, карточка 6524:
# EN: "One moment, I'll connect you."
# FI: Hetkinen, yhdistän.
#
# Несогласованность точки в слове, карточка 6524:
# EN: "One moment, I'll connect you."
# FI: Hetkinen, yhdistän.
#
# Несогласованность регистра в слове, карточка 6547:
# EN: The boy eating a pear
# FI: pääryynää syövä poika
#
# Несогласованность регистра в слове, карточка 6550:
# EN: 'The man packing a suitcase over there is in a hurry.'
# FI: Tuolla matkalaukkua pakkaavalla miehellä on kiire.
#
# Несогласованность точки в слове, карточка 6550:
# EN: 'The man packing a suitcase over there is in a hurry.'
# FI: Tuolla matkalaukkua pakkaavalla miehellä on kiire.
#
# Несогласованность регистра в слове, карточка 6559:
# EN: Teaching
# FI: opetus
#
# Несогласованность регистра в слове, карточка 6570:
# EN: Employment
# FI: työllistyminen
#
# Несогласованность регистра в слове, карточка 6635:
# EN: New Year
# FI: vuodenvaihde
#
# Несогласованность регистра в слове, карточка 6641:
# EN: In the mornings and evenings
# FI: aamuisin illoin
#
# Несогласованность регистра в слове, карточка 6653:
# EN: One day
# FI: eräänä päivänä
#
# Несогласованность точки в слове, карточка 6672:
# EN: It would be nice...
# FI: Olis kyl hyvä…
#
# Несогласованность точки в слове, карточка 6673:
# EN: But it would be nice...
# FI: Mut oishan se hyvä…
#
# Несогласованность регистра в слове, карточка 6675:
# EN: "Could it be possible...?"
# FI: Oiskohan mahdollista…?
#
# Несогласованность регистра в слове, карточка 6677:
# EN: "Yeah. Uh-huh."
# FI: Joo. Nii-i.
#
# Несогласованность точки в слове, карточка 6677:
# EN: "Yeah. Uh-huh."
# FI: Joo. Nii-i.
#
# Несогласованность точки в слове, карточка 6678:
# EN: That's what I think too.
# FI: Sitä minäkin. (Sitä mäkin.)
#
# Несогласованность точки в слове, карточка 6679:
# EN: I think so too.
# FI: Niin minustakin. (Niin mustakin.)
#
# Несогласованность точки в слове, карточка 6686:
# EN: Maybe yes, but...
# FI: Ehkä joo, mut…
#
# Несогласованность регистра в слове, карточка 6687:
# EN: "Maybe, but…"
# FI: Voi olla, mut…
#
# Несогласованность регистра в слове, карточка 6688:
# EN: "Maybe, but…"
# FI: Saattaa olla, mut…
#
# Несогласованность регистра в предложении, карточка 6695:
# EN: 'sentence', 'The matter should remain unmentionable.'
# FI: Asia on vaiettava.
#
# Несогласованность точки в предложении, карточка 6695:
# EN: 'sentence', 'The matter should remain unmentionable.'
# FI: Asia on vaiettava.
#
# Несогласованность регистра в слове, карточка 6699:
# EN: "There's not a single item yet in the big suitcase that will be packed in the evening."
# FI: Illalla pakattavassa isossa matkalaukussa ei ole vielä yhtään tavaraa.
#
# Несогласованность точки в слове, карточка 6699:
# EN: "There's not a single item yet in the big suitcase that will be packed in the evening."
# FI: Illalla pakattavassa isossa matkalaukussa ei ole vielä yhtään tavaraa.
#
# Несогласованность регистра в слове, карточка 6732:
# EN: Hinder
# FI: vaikeuttaa
#
# Несогласованность регистра в слове, карточка 6734:
# EN: Latino
# FI: latino
#
# Несогласованность регистра в слове, карточка 6736:
# EN: Certainly
# FI: todellakin
#
# Несогласованность регистра в слове, карточка 6759:
# EN: Activity
# FI: toiminta
#
# Несогласованность регистра в слове, карточка 6762:
# EN: Ingenuity
# FI: kekseliäisyys
#
# Несогласованность точки в слове, карточка 6775:
# EN: A reflector can save your life.
# FI: Heijastin voi pelastaa henkesi
#
# Несогласованность регистра в слове, карточка 6776:
# EN: Reflector
# FI: heijastin
#
# Несогласованность точки в предложении, карточка 6776:
# EN: A reflector can save your life.
# FI: Heijastin voi pelastaa henkesi
#
# Несогласованность регистра в слове, карточка 6792:
# EN: Safety
# FI: turvallisuus
#
# Несогласованность регистра в слове, карточка 6817:
# EN: Uncertainty
# FI: tuntemattomuus
#
# Несогласованность регистра в слове, карточка 6823:
# EN: Stop
# FI: estä
#
# Несогласованность регистра в слове, карточка 6857:
# EN: "Alright, is everything packed? Can we go?"
# FI: No niin, onko kaikkien tavarat pakattu? Voidaanko lähteä?
#
# Несогласованность регистра в слове, карточка 6865:
# EN: "Oh, that's a shame."
# FI: Ai jaa, sepä harmi.
#
# Несогласованность точки в слове, карточка 6865:
# EN: "Oh, that's a shame."
# FI: Ai jaa, sepä harmi.
#
# Несогласованность регистра в слове, карточка 6868:
# EN: "Oh, is that so? Glad you told me!"
# FI: Ai on vai?? Hyvä että kerroit!
#
# Несогласованность регистра в слове, карточка 6889:
# EN: 'The person who stole the computers got caught.'
# FI: Tietokoneita varastanut jäi kiinni.
#
# Несогласованность точки в слове, карточка 6889:
# EN: 'The person who stole the computers got caught.'
# FI: Tietokoneita varastanut jäi kiinni.
#
# Несогласованность регистра в слове, карточка 6899:
# EN: Peeled apple
# FI: kuorittu omena
#
# Несогласованность регистра в слове, карточка 6913:
# EN: 'The weather will become cloudy.'
# FI: Sää muuttuu pilviseksi.
#
# Несогласованность точки в слове, карточка 6913:
# EN: 'The weather will become cloudy.'
# FI: Sää muuttuu pilviseksi.
#
# Несогласованность регистра в слове, карточка 6919:
# EN: "5-10 pieces of jewelry are made each day."
# FI: Koruja valmistuu 5–10 kappaletta päivässä.
#
# Несогласованность точки в слове, карточка 6919:
# EN: "5-10 pieces of jewelry are made each day."
# FI: Koruja valmistuu 5–10 kappaletta päivässä.
#
# Несогласованность регистра в слове, карточка 6925:
# EN: The more – the better
# FI: mitä – sitä
#
# Несогласованность регистра в слове, карточка 6934:
# EN: Western
# FI: länsimainen
#
# Несогласованность регистра в слове, карточка 6935:
# EN: Culture
# FI: sivistys
#
# Несогласованность регистра в слове, карточка 6963:
# EN: Tile
# FI: laatta
#
# Несогласованность регистра в слове, карточка 6965:
# EN: National Romanticism
# FI: kansallisromantiikka
#
# Несогласованность регистра в слове, карточка 7001:
# EN: Finishing
# FI: viimeistely
#
# Несогласованность точки в слове, карточка 7026:
# EN: I’m not really sure...
# FI: Emmä oikeen tiiä…
#
# Несогласованность точки в слове, карточка 7027:
# EN: Well, let's see...
# FI: No katotaan…
#
# Несогласованность регистра в слове, карточка 7039:
# EN: "I'm not really sure…"
# FI: En mä oikein tiiä…
#
# Несогласованность регистра в слове, карточка 7050:
# EN: "I'm going to apply for a summer job at Sokos."
# FI: Aion hakea kesätöihin Sokokselle.
#
# Несогласованность точки в слове, карточка 7050:
# EN: "I'm going to apply for a summer job at Sokos."
# FI: Aion hakea kesätöihin Sokokselle.
#
# Несогласованность регистра в слове, карточка 7054:
# EN: "I'd be happy to tell you more about myself."
# FI: Tulen mielelläni kertomaan lisää itsestäni.
#
# Несогласованность точки в слове, карточка 7054:
# EN: "I'd be happy to tell you more about myself."
# FI: Tulen mielelläni kertomaan lisää itsestäni.
#
# Несогласованность регистра в слове, карточка 7078:
# EN: "There's not much stuff in the suitcase that the man is packing."
# FI: Tuossa miehen pakkaamassa matkalaukussa ei ole kovin paljon tavaraa.
#
# Несогласованность точки в слове, карточка 7078:
# EN: "There's not much stuff in the suitcase that the man is packing."
# FI: Tuossa miehen pakkaamassa matkalaukussa ei ole kovin paljon tavaraa.
#
# Несогласованность точки в слове, карточка 7080:
# EN: Sometimes the MA-participle can refer to the present tense.
# FI: Joskus MA-partisiippi voi viitata nykyhetkeen
#
# Несогласованность регистра в слове, карточка 7088:
# EN: "His girlfriend is also coming to the party."
# FI: Juhliin tulee myös hänen tyttöystävänsä.
#
# Несогласованность точки в слове, карточка 7088:
# EN: "His girlfriend is also coming to the party."
# FI: Juhliin tulee myös hänen tyttöystävänsä.
#
# Несогласованность регистра в слове, карточка 7089:
# EN: 'Jarkko's girlfriend is also coming to the party.'
# FI: Juhliin tulee myös Jarkon tyttöystävä.
#
# Несогласованность точки в слове, карточка 7089:
# EN: 'Jarkko's girlfriend is also coming to the party.'
# FI: Juhliin tulee myös Jarkon tyttöystävä.
#
# Несогласованность регистра в слове, карточка 7099:
# EN: "Jussi has a cousin. Liisa met his cousin on the street."
# FI: Jussilla on serkku. Liisa tapasi hänen serkkunsa kadulla.
#
# Несогласованность точки в слове, карточка 7099:
# EN: "Jussi has a cousin. Liisa met his cousin on the street."
# FI: Jussilla on serkku. Liisa tapasi hänen serkkunsa kadulla.
#
# Несогласованность регистра в слове, карточка 7174:
# EN: Great job
# FI: hieno homma
#
# Несогласованность точки в предложении, карточка 7176:
# EN: The couple thought they had lost something.
# FI:
#
# Несогласованность точки в предложении, карточка 7179:
# EN: The couple thought they had lost.
# FI: Pariskunta luuli menettäneensä
#
# Несогласованность регистра в слове, карточка 7197:
# EN: Undoubtedly
# FI: kieltämättä
#
# Несогласованность регистра в слове, карточка 7204:
# EN: Soil
# FI: maaperä
#
# Несогласованность регистра в слове, карточка 7218:
# EN: Failed
# FI: epäonnistunut
#
# Несогласованность регистра в слове, карточка 7254:
# EN: "Scandalous celebrity Titta Turtiainen caught for drunk driving – apologizes to her fans"
# FI: Kohujulkkis Titta Turtiainen kärähti rattijuopumuksesta – pyytää faneiltaan anteeksi
#
# Несогласованность регистра в слове, карточка 7276:
# EN: You will receive
# FI: saanne (todennäköisesti saa)
#
# Несогласованность регистра в слове, карточка 7289:
# EN: Hurricane
# FI: hirmumyrsky
#
# Несогласованность регистра в слове, карточка 7311:
# EN: Accident
# FI: onnettomuus
#
# Несогласованность регистра в слове, карточка 7320:
# EN: Crime
# FI: rikollisuus
#
# Несогласованность регистра в слове, карточка 7324:
# EN: Deception
# FI: petos
#
# Несогласованность регистра в слове, карточка 7353:
# EN: Of course
# FI: tietenkin
#
# Несогласованность регистра в слове, карточка 7355:
# EN: Of course
# FI: ilman muuta
#
# Несогласованность регистра в слове, карточка 7370:
# EN: "When Maija talks, you just have to be quiet and listen."
# FI: Maijan puhuessa täytyy vain olla hiljaa ja kuunnella.
#
# Несогласованность точки в слове, карточка 7370:
# EN: "When Maija talks, you just have to be quiet and listen."
# FI: Maijan puhuessa täytyy vain olla hiljaa ja kuunnella.
#
# Несогласованность регистра в слове, карточка 7374:
# EN: "I tried to tell Maija about my trip so we would talk about something other than her problems."
# FI: Yritin kertoa Maijalle matkastani, jotta puhuisimme muustakin kuin hänen ongelmistaan.
#
# Несогласованность точки в слове, карточка 7374:
# EN: "I tried to tell Maija about my trip so we would talk about something other than her problems."
# FI: Yritin kertoa Maijalle matkastani, jotta puhuisimme muustakin kuin hänen ongelmistaan.
#
# Несогласованность точки в предложении, карточка 7393:
# EN: His roommate had only come home just then.
# FI:
#
# Несогласованность регистра в слове, карточка 7398:
# EN: "Toni said that after this he would definitely remember to always take his keys with him!"
# FI: Toni sanoi tämän jälkeen todellakin muistavansa ottaa avaimet aina mukaan!
#
# Несогласованность регистра в слове, карточка 7406:
# EN: "Kalle, take those broken shoes to the trash!"
# FI: Kalle, vie noi rikkinäiset kengät roskikseen!
#
# Несогласованность регистра: 542 карточек
# Несогласованность точки в конце: 143 карточек
# Всего несогласованностей: 685

# %%
def get_ru_finn_cards_by_ids(ids):
    file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
    file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
    file_names.append('sm2_new_puhekieli.json')
    file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])
    file_names.extend([f'sm4_kap{i}.json' for i in range(1, 6)])

    cards = []
    for file_name in file_names:
        cards.extend(get_ru_finn_cards_from_file(file_name))

    return [card for card in cards if card['id'] in ids]

bad_ru_finn_cards = get_ru_finn_cards_by_ids(en_fi_bad_cards_ids)

# %%
len(bad_ru_finn_cards)
# Out:
# 600

# %%
source_cards = [{'word': card["wordSecondLang"], 'sentence': card["sentenceSecondLang"], 'id': card['id']} for card in bad_ru_finn_cards[0:50]]
secondary_cards = [{'word': card["wordFirstLang"], 'sentence': card["sentenceFirstLang"], 'id': card['id']} for card in bad_ru_finn_cards[0:50]]

source_lang, target_lang, secondary_lang = 'Finnish', 'English', 'Russian'

source_target_cards, eval_results = generate_source_target_cards_with_eval_results(source_cards, secondary_cards, source_lang, target_lang, secondary_lang)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
source_target_cards
# Out:
# [{'wordFirstLang': 'minä',
#   'sentenceFirstLang': 'Minä olen opiskelija.',
#   'wordSecondLang': 'I',
#   'sentenceSecondLang': 'I am a student.',
#   'id': 1005},
#  {'wordFirstLang': 'sukunimi',
#   'sentenceFirstLang': 'Minun sukunimeni on Ivanova.',
#   'wordSecondLang': 'last name',
#   'sentenceSecondLang': 'My last name is Ivanova.',
#   'id': 1018},
#  {'wordFirstLang': 'Joo',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'yes',
#   'sentenceSecondLang': '',
#   'id': 1039},
#  {'wordFirstLang': 'maanantai',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'monday',
#   'sentenceSecondLang': '',
#   'id': 1042},
#  {'wordFirstLang': 'tiistai',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Tuesday',
#   'sentenceSecondLang': '',
#   'id': 1043},
#  {'wordFirstLang': 'keskiviikko',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Wednesday',
#   'sentenceSecondLang': '',
#   'id': 1044},
#  {'wordFirstLang': 'torstai',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'thursday',
#   'sentenceSecondLang': '',
#   'id': 1045},
#  {'wordFirstLang': 'perjantai',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Friday',
#   'sentenceSecondLang': '',
#   'id': 1046},
#  {'wordFirstLang': 'lauantai',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Saturday',
#   'sentenceSecondLang': '',
#   'id': 1047},
#  {'wordFirstLang': 'sunnuntai',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Sunday',
#   'sentenceSecondLang': '',
#   'id': 1048},
#  {'wordFirstLang': 'viikonloppu',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'weekend',
#   'sentenceSecondLang': '',
#   'id': 1049},
#  {'wordFirstLang': 'tiistaina',
#   'sentenceFirstLang': '',
#   'wordSecondLang': '(word, on Tuesday)',
#   'sentenceSecondLang': '',
#   'id': 1053},
#  {'wordFirstLang': 'keskiviikkona',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'on Wednesday',
#   'sentenceSecondLang': '',
#   'id': 1054},
#  {'wordFirstLang': 'perjantaina',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'on Friday',
#   'sentenceSecondLang': '',
#   'id': 1056},
#  {'wordFirstLang': 'lauantaina',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'on Saturday',
#   'sentenceSecondLang': '',
#   'id': 1057},
#  {'wordFirstLang': 'sunnuntaina',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'on Sunday',
#   'sentenceSecondLang': '',
#   'id': 1058},
#  {'wordFirstLang': 'toissapäivänä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'the day before yesterday',
#   'sentenceSecondLang': '',
#   'id': 1059},
#  {'wordFirstLang': 'eilen',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'yesterday',
#   'sentenceSecondLang': '',
#   'id': 1060},
#  {'wordFirstLang': 'tänään',
#   'sentenceFirstLang': '',
#   'wordSecondLang': '(word, today)',
#   'sentenceSecondLang': '',
#   'id': 1061},
#  {'wordFirstLang': 'huomenna',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'tomorrow',
#   'sentenceSecondLang': '',
#   'id': 1062},
#  {'wordFirstLang': 'ylihuomenna',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'the day after tomorrow',
#   'sentenceSecondLang': '',
#   'id': 1063},
#  {'wordFirstLang': 'nolla',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'zero',
#   'sentenceSecondLang': '',
#   'id': 1064},
#  {'wordFirstLang': 'yksi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'one',
#   'sentenceSecondLang': '',
#   'id': 1065},
#  {'wordFirstLang': 'kaksi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'two',
#   'sentenceSecondLang': '',
#   'id': 1066},
#  {'wordFirstLang': 'kolme',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'three',
#   'sentenceSecondLang': '',
#   'id': 1067},
#  {'wordFirstLang': 'kaksikymmentäyksi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'twenty-one',
#   'sentenceSecondLang': '',
#   'id': 1068},
#  {'wordFirstLang': 'kaksisataa',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'two hundred',
#   'sentenceSecondLang': '',
#   'id': 1070},
#  {'wordFirstLang': 'neljä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'four',
#   'sentenceSecondLang': '',
#   'id': 1072},
#  {'wordFirstLang': 'viisi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'five',
#   'sentenceSecondLang': '',
#   'id': 1073},
#  {'wordFirstLang': 'kuusi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'six / spruce',
#   'sentenceSecondLang': '',
#   'id': 1074},
#  {'wordFirstLang': 'seitsemän',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'seven',
#   'sentenceSecondLang': '',
#   'id': 1075},
#  {'wordFirstLang': 'kahdeksan',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eight',
#   'sentenceSecondLang': '',
#   'id': 1076},
#  {'wordFirstLang': 'yhdeksän',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'nine',
#   'sentenceSecondLang': '',
#   'id': 1077},
#  {'wordFirstLang': 'kymmenen',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'ten',
#   'sentenceSecondLang': '',
#   'id': 1078},
#  {'wordFirstLang': 'yksitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eleven',
#   'sentenceSecondLang': '',
#   'id': 1079},
#  {'wordFirstLang': 'kaksitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'twelve',
#   'sentenceSecondLang': '',
#   'id': 1080},
#  {'wordFirstLang': 'kolmekymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'thirty',
#   'sentenceSecondLang': '',
#   'id': 1081},
#  {'wordFirstLang': 'neljätoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'fourteen',
#   'sentenceSecondLang': '',
#   'id': 1082},
#  {'wordFirstLang': 'viisitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'fifteen',
#   'sentenceSecondLang': '',
#   'id': 1083},
#  {'wordFirstLang': 'kuusitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'sixteen',
#   'sentenceSecondLang': '',
#   'id': 1084},
#  {'wordFirstLang': 'seitsemäntoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'seventeen',
#   'sentenceSecondLang': '',
#   'id': 1085},
#  {'wordFirstLang': 'kahdeksantoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eighteen',
#   'sentenceSecondLang': '',
#   'id': 1086},
#  {'wordFirstLang': 'yhdeksäntoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'nineteen',
#   'sentenceSecondLang': '',
#   'id': 1087},
#  {'wordFirstLang': 'kaksikymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'twenty',
#   'sentenceSecondLang': '',
#   'id': 1088},
#  {'wordFirstLang': 'neljäkymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'forty',
#   'sentenceSecondLang': '',
#   'id': 1089},
#  {'wordFirstLang': 'viisikymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'fifty',
#   'sentenceSecondLang': '',
#   'id': 1090},
#  {'wordFirstLang': 'kuusikymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'sixty',
#   'sentenceSecondLang': '',
#   'id': 1091},
#  {'wordFirstLang': 'seitsemänkymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'seventy',
#   'sentenceSecondLang': '',
#   'id': 1092},
#  {'wordFirstLang': 'kahdeksankymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eighty',
#   'sentenceSecondLang': '',
#   'id': 1093},
#  {'wordFirstLang': 'yhdeksänkymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'ninety',
#   'sentenceSecondLang': '',
#   'id': 1094}]

# %%
source_target_cards
# Out:
# [{'wordFirstLang': 'seitsemän',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'seven',
#   'sentenceSecondLang': '',
#   'id': 1075},
#  {'wordFirstLang': 'kahdeksan',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eight',
#   'sentenceSecondLang': '',
#   'id': 1076},
#  {'wordFirstLang': 'yhdeksän',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'nine',
#   'sentenceSecondLang': '',
#   'id': 1077},
#  {'wordFirstLang': 'kymmenen',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'ten',
#   'sentenceSecondLang': '',
#   'id': 1078},
#  {'wordFirstLang': 'yksitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eleven',
#   'sentenceSecondLang': '',
#   'id': 1079},
#  {'wordFirstLang': 'kaksitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'twelve',
#   'sentenceSecondLang': '',
#   'id': 1080},
#  {'wordFirstLang': 'kolmekymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'thirty',
#   'sentenceSecondLang': '',
#   'id': 1081},
#  {'wordFirstLang': 'neljätoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'fourteen',
#   'sentenceSecondLang': '',
#   'id': 1082},
#  {'wordFirstLang': 'viisitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'fifteen',
#   'sentenceSecondLang': '',
#   'id': 1083},
#  {'wordFirstLang': 'kuusitoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'sixteen',
#   'sentenceSecondLang': '',
#   'id': 1084},
#  {'wordFirstLang': 'seitsemäntoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'seventeen',
#   'sentenceSecondLang': '',
#   'id': 1085},
#  {'wordFirstLang': 'kahdeksantoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eighteen',
#   'sentenceSecondLang': '',
#   'id': 1086},
#  {'wordFirstLang': 'yhdeksäntoista',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'nineteen',
#   'sentenceSecondLang': '',
#   'id': 1087},
#  {'wordFirstLang': 'kaksikymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'twenty',
#   'sentenceSecondLang': '',
#   'id': 1088},
#  {'wordFirstLang': 'neljäkymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'forty',
#   'sentenceSecondLang': '',
#   'id': 1089},
#  {'wordFirstLang': 'viisikymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'fifty',
#   'sentenceSecondLang': '',
#   'id': 1090},
#  {'wordFirstLang': 'kuusikymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'sixty',
#   'sentenceSecondLang': '',
#   'id': 1091},
#  {'wordFirstLang': 'seitsemänkymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'seventy',
#   'sentenceSecondLang': '',
#   'id': 1092},
#  {'wordFirstLang': 'kahdeksankymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'eighty',
#   'sentenceSecondLang': '',
#   'id': 1093},
#  {'wordFirstLang': 'yhdeksänkymmentä',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'ninety',
#   'sentenceSecondLang': '',
#   'id': 1094},
#  {'wordFirstLang': 'satayksi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'one hundred and one',
#   'sentenceSecondLang': '',
#   'id': 1095},
#  {'wordFirstLang': 'kolmesataa',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'three hundred',
#   'sentenceSecondLang': '',
#   'id': 1096},
#  {'wordFirstLang': 'tuhat',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'thousand',
#   'sentenceSecondLang': '',
#   'id': 1097},
#  {'wordFirstLang': 'kaksituhatta',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'two thousand',
#   'sentenceSecondLang': '',
#   'id': 1098},
#  {'wordFirstLang': 'viisisataatuhatta',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'five hundred thousand',
#   'sentenceSecondLang': '',
#   'id': 1099},
#  {'wordFirstLang': 'suomen kurssi',
#   'sentenceFirstLang': 'Olen ilmoittautunut suomen kurssille.',
#   'wordSecondLang': 'Finnish course',
#   'sentenceSecondLang': 'I have enrolled in a Finnish course.',
#   'id': 1103},
#  {'wordFirstLang': 'okei',
#   'sentenceFirstLang': 'Okei, teen sen.',
#   'wordSecondLang': 'okay',
#   'sentenceSecondLang': "Okay, I'll do it.",
#   'id': 1112},
#  {'wordFirstLang': 'kurssipäivä',
#   'sentenceFirstLang': 'Seuraava kurssipäivä on ensi tiistaina.',
#   'wordSecondLang': 'course day, class',
#   'sentenceSecondLang': 'The next course day is next Tuesday.',
#   'id': 1113},
#  {'wordFirstLang': 'minä olen',
#   'sentenceFirstLang': 'Minä olen ohjelmoija.',
#   'wordSecondLang': 'I am',
#   'sentenceSecondLang': 'I am a programmer.',
#   'id': 1114},
#  {'wordFirstLang': 'mä oon',
#   'sentenceFirstLang': 'Mä oon kotona.',
#   'wordSecondLang': 'I am',
#   'sentenceSecondLang': 'I am at home.',
#   'id': 1123},
#  {'wordFirstLang': 'me ollaan',
#   'sentenceFirstLang': 'Me ollaan kahvilassa.',
#   'wordSecondLang': 'we are',
#   'sentenceSecondLang': 'We are at the cafe.',
#   'id': 1125},
#  {'wordFirstLang': 'fysiikka',
#   'sentenceFirstLang': 'Fysiikka kiinnostaa monia.',
#   'wordSecondLang': 'physics',
#   'sentenceSecondLang': 'Physics interests many people.',
#   'id': 1131},
#  {'wordFirstLang': 'biologia',
#   'sentenceFirstLang': 'Biologia tutkii eläviä organismeja.',
#   'wordSecondLang': 'biology',
#   'sentenceSecondLang': 'Biology studies living organisms.',
#   'id': 1132},
#  {'wordFirstLang': 'ruotsi',
#   'sentenceFirstLang': 'Opiskelen ruotsia.',
#   'wordSecondLang': 'Swedish',
#   'sentenceSecondLang': 'I am studying Swedish.',
#   'id': 1133},
#  {'wordFirstLang': 'liikunta',
#   'sentenceFirstLang': 'Liikunta on tärkeää terveydelle.',
#   'wordSecondLang': 'exercise',
#   'sentenceSecondLang': 'Exercise is important for health.',
#   'id': 1134},
#  {'wordFirstLang': 'englanti',
#   'sentenceFirstLang': 'Puhun englantia.',
#   'wordSecondLang': 'English',
#   'sentenceSecondLang': 'I speak English.',
#   'id': 1140},
#  {'wordFirstLang': 'ranska',
#   'sentenceFirstLang': 'Ranska on kaunis kieli.',
#   'wordSecondLang': 'French',
#   'sentenceSecondLang': 'French is a beautiful language.',
#   'id': 1141},
#  {'wordFirstLang': 'brasilialainen',
#   'sentenceFirstLang': 'Ystäväni on brasilialainen.',
#   'wordSecondLang': 'Brazilian',
#   'sentenceSecondLang': 'My friend is Brazilian.',
#   'id': 1168},
#  {'wordFirstLang': 'espanja',
#   'sentenceFirstLang': 'Hän opiskelee espanjaa.',
#   'wordSecondLang': 'Spanish',
#   'sentenceSecondLang': 'She is studying Spanish.',
#   'id': 1171},
#  {'wordFirstLang': 'portugali',
#   'sentenceFirstLang': 'Opiskelen portugalia.',
#   'wordSecondLang': 'Portuguese',
#   'sentenceSecondLang': 'I am studying Portuguese.',
#   'id': 1173},
#  {'wordFirstLang': 'tietysti',
#   'sentenceFirstLang': 'Tietysti autan sinua.',
#   'wordSecondLang': 'of course',
#   'sentenceSecondLang': "Of course, I'll help you.",
#   'id': 1175},
#  {'wordFirstLang': 'ai jaa',
#   'sentenceFirstLang': 'Ai jaa, en tiennyt sitä.',
#   'wordSecondLang': 'Oh, I see',
#   'sentenceSecondLang': "Oh, I see. I didn't know that.",
#   'id': 1188},
#  {'wordFirstLang': 'puhutko',
#   'sentenceFirstLang': 'Puhutko suomea?',
#   'wordSecondLang': 'Do you speak',
#   'sentenceSecondLang': 'Do you speak Finnish?',
#   'id': 1189},
#  {'wordFirstLang': 'ymmärrätkö',
#   'sentenceFirstLang': 'Ymmärrätkö minua?',
#   'wordSecondLang': 'Do you understand',
#   'sentenceSecondLang': 'Do you understand me?',
#   'id': 1190},
#  {'wordFirstLang': 'Suomi on ihana maa',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Finland is a wonderful country',
#   'sentenceSecondLang': '',
#   'id': 1192},
#  {'wordFirstLang': 'Kreikka on kuuma maa',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Greece is a hot country',
#   'sentenceSecondLang': '',
#   'id': 1194},
#  {'wordFirstLang': 'Islanti on kaunis maa',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Iceland is a beautiful country',
#   'sentenceSecondLang': '',
#   'id': 1195},
#  {'wordFirstLang': 'Venäjä on iso maa',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'Russia is a big country',
#   'sentenceSecondLang': '',
#   'id': 1197},
#  {'wordFirstLang': 'suomalainen',
#   'sentenceFirstLang': 'Hänen ystävänsä on suomalainen.',
#   'wordSecondLang': 'Finn',
#   'sentenceSecondLang': 'His friend is a Finn.',
#   'id': 1199},
#  {'wordFirstLang': 'ranskalainen',
#   'sentenceFirstLang': 'Hänen kollegansa on ranskalainen.',
#   'wordSecondLang': 'French',
#   'sentenceSecondLang': 'Her colleague is French.',
#   'id': 1200},
#  {'wordFirstLang': 'kreikkalainen',
#   'sentenceFirstLang': 'Opettajani on kreikkalainen.',
#   'wordSecondLang': 'Greek',
#   'sentenceSecondLang': 'My teacher is Greek.',
#   'id': 1201},
#  {'wordFirstLang': 'islantilainen',
#   'sentenceFirstLang': 'Heidän jalkapallovalmentajansa on islantilainen.',
#   'wordSecondLang': 'Icelander',
#   'sentenceSecondLang': 'Their football coach is an Icelander.',
#   'id': 1202},
#  {'wordFirstLang': 'egyptiläinen',
#   'sentenceFirstLang': 'Kuuluisa arkeologi on egyptiläinen.',
#   'wordSecondLang': 'Egyptian',
#   'sentenceSecondLang': 'The famous archaeologist is Egyptian.',
#   'id': 1203},
#  {'wordFirstLang': 'venäläinen',
#   'sentenceFirstLang': 'Tämä kirjailija on venäläinen.',
#   'wordSecondLang': 'Russian',
#   'sentenceSecondLang': 'This author is Russian.',
#   'id': 1204},
#  {'wordFirstLang': 'pakistanilainen',
#   'sentenceFirstLang': 'Naapurini on pakistanilainen.',
#   'wordSecondLang': 'Pakistani',
#   'sentenceSecondLang': 'My neighbor is a Pakistani.',
#   'id': 1205},
#  {'wordFirstLang': 'suomi',
#   'sentenceFirstLang': 'Opiskelen suomea.',
#   'wordSecondLang': 'Finnish',
#   'sentenceSecondLang': 'I am studying Finnish.',
#   'id': 1206},
#  {'wordFirstLang': 'kreikka',
#   'sentenceFirstLang': 'Hän puhuu kreikkaa.',
#   'wordSecondLang': 'Greek',
#   'sentenceSecondLang': 'She speaks Greek.',
#   'id': 1207},
#  {'wordFirstLang': 'islanti',
#   'sentenceFirstLang': 'Islanti on vaikea oppia.',
#   'wordSecondLang': 'Icelandic',
#   'sentenceSecondLang': 'Icelandic is hard to learn.',
#   'id': 1208},
#  {'wordFirstLang': 'arabia',
#   'sentenceFirstLang': 'Arabia kirjoitetaan oikealta vasemmalle.',
#   'wordSecondLang': 'Arabic',
#   'sentenceSecondLang': 'Arabic is written from right to left.',
#   'id': 1209},
#  {'wordFirstLang': 'venäjä',
#   'sentenceFirstLang': 'Venäjä on äidinkieleni.',
#   'wordSecondLang': 'Russian',
#   'sentenceSecondLang': 'Russian is my native language.',
#   'id': 1210},
#  {'wordFirstLang': 'urdu',
#   'sentenceFirstLang': 'Hän opiskelee urdua.',
#   'wordSecondLang': 'Urdu',
#   'sentenceSecondLang': 'He is studying Urdu.',
#   'id': 1211},
#  {'wordFirstLang': 'pohjoinen',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'north',
#   'sentenceSecondLang': '',
#   'id': 1223},
#  {'wordFirstLang': 'länsi',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'west',
#   'sentenceSecondLang': '',
#   'id': 1226},
#  {'wordFirstLang': 'minäkin',
#   'sentenceFirstLang': 'Minäkin haluan mennä.',
#   'wordSecondLang': 'I also',
#   'sentenceSecondLang': 'I also want to go.',
#   'id': 1264},
#  {'wordFirstLang': 'nämä',
#   'sentenceFirstLang': 'Nämä kirjat ovat mielenkiintoisia.',
#   'wordSecondLang': 'these',
#   'sentenceSecondLang': 'These books are interesting.',
#   'id': 1268},
#  {'wordFirstLang': 'tarvitsetko',
#   'sentenceFirstLang': 'Tarvitsetko apua?',
#   'wordSecondLang': 'Do you need',
#   'sentenceSecondLang': 'Do you need help?',
#   'id': 1270},
#  {'wordFirstLang': 'kiitti',
#   'sentenceFirstLang': 'Kiitti avusta!',
#   'wordSecondLang': 'Thanks',
#   'sentenceSecondLang': 'Thanks for the help!',
#   'id': 1272},
#  {'wordFirstLang': 'minä puhun',
#   'sentenceFirstLang': 'Minä puhun venäjää.',
#   'wordSecondLang': 'I speak',
#   'sentenceSecondLang': 'I speak Russian.',
#   'id': 1274},
#  {'wordFirstLang': 'mä puhun',
#   'sentenceFirstLang': 'Mä puhun kaverin kanssa.',
#   'wordSecondLang': "I'm talking",
#   'sentenceSecondLang': "I'm talking with my friend.",
#   'id': 1280},
#  {'wordFirstLang': 'viis',
#   'sentenceFirstLang': '',
#   'wordSecondLang': 'five',
#   'sentenceSecondLang': '',
#   'id': 1285}]
