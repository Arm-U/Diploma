# %%
import openai
from openai import AzureOpenAI, AsyncAzureOpenAI
from tqdm.notebook import tqdm
import os
from dotenv import load_dotenv, find_dotenv
import requests
import base64

GPT_3_5_TURBO = "gpt-3.5-turbo"
GPT_4_TURBO_PREVIEW = "gpt-4-turbo-preview"
GPT_4 = 'gpt-4'
GPT_4o = 'gpt-4o'

def get_openai_api_key():
    _ = load_dotenv(find_dotenv())

    return os.getenv("OPENAI_API_KEY")

OPENAI_API_KEY = get_openai_api_key()
azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),  
    api_version="2024-07-01-preview",
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT")
)

# %%
import json


EVAL_FOLDER = '../../data/russian-english/cards/eval_results/ru_eng_'
def get_eval_results_from_file(file_name):
    data = []
    file_path = EVAL_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data


RU_ENG_OUTPUT_FOLDER = '../../data/russian-english/cards/test_cards/ru_eng_'
def get_ru_eng_cards_from_file(file_name):
    data = []
    file_path = OUTPUT_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data


RU_FINN_FOLDER_WITH_JSON = '../../data/russian-finnish/cards/curated_platform_cards/'
def get_ru_finn_cards_from_file(file_name):
    data = []
    file_path = RU_FINN_FOLDER_WITH_JSON + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    res = []
    for card in data:
        if 'isMarkedDeleted' not in card.keys():
            res.append(card)
    return res


ENG_FINN_OUTPUT_FOLDER = '../../data/english-finnish/cards/test_cards/eng_finn_'
def get_eng_finn_cards_from_file(file_name):
    data = []
    file_path = ENG_FINN_OUTPUT_FOLDER + file_name
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data


OUTPUT_FOLDER = '../../data/english-finnish/cards/test_cards/eng_finn_'
def write_cards_to_file(file_name, cards):
    file_path = OUTPUT_FOLDER + file_name
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(cards, f, ensure_ascii=False, indent=2)
        
        
EVAL_FOLDER = '../../data/english-finnish/cards/eval_results/eng_finn_'
def write_eval_results_to_file(file_name, results):
    file_path = EVAL_FOLDER + file_name
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

# %%
def check_eval(eval_result, is_phrase_card):
    if is_phrase_card:
        return eval_result['translationAccuracy']['isCorrect']
    
    w_tr_accuracy = eval_result['wordTranslationAccuracy']['isCorrect']
    s_tr_accuracy = eval_result['sentenceTranslationAccuracy']['isCorrect']
    s_accuracy = eval_result['englishSentenceCorrectness']['isCorrect']
    w_accuracy = eval_result['wordUsage']['isCorrect']
    
    return all([w_tr_accuracy, s_tr_accuracy, s_accuracy, w_accuracy])

# %%
def get_bad_cards_from_files(file_names):
    results = []
    for file_name in file_names:
        eng_finn_cards = get_eng_finn_cards_from_file(file_name)
        eval_results = get_eval_results_from_file(file_name)

        assert(len(eng_finn_cards) == len(eval_results))

        for eng_finn, eval_res in list(zip(eng_finn_cards, eval_results)):
            is_phrase_card = (eng_finn['sentenceFirstLang'] == '')
            if not check_eval(eval_res, is_phrase_card):
                eng_finn['is_phrase_card'] = is_phrase_card
                eng_finn.update(eval_res)
                full_output = eng_finn
                results.append(full_output)
    
    return results

# %%
file_names = [f'sm1_new_kap{i}.json' for i in range(1, 10)]
file_names.extend([f'sm2_new_kap{i}.json' for i in range(1, 9)])
file_names.append('sm2_new_puhekieli.json')
file_names.extend([f'sm3_kap{i}.json' for i in range(1, 9)])

# %%
fourth_chapter = [f'sm4_kap{i}.json' for i in range(1, 6)]

# %%
bad_cards = get_bad_cards_from_files(fourth_chapter)

# %%
import pandas as pd

bad_cards_df = pd.DataFrame(bad_cards)

# %%
bad_cards_df
# Out:
#            wordFirstLang                                  sentenceFirstLang  \
# 0         evening outing             Shall we go out together this evening?
# 1              diversely                             He can sing diversely.
# 2                weekday              The weekdays usually start on Monday.
# 3        packed suitcase  We're getting ready for the trip, so the packe...
# 4                 eating     I am having lunch in a restaurant that's busy.
# 5       family's desired  This trip is exactly what the family's desired...
# 6               day club       My child attends the day club every weekday.
# 7          to get out of           I can get out of the meeting by 3:00 PM.
# 8             functional                     This device works really well.
# 9     raspberry-flavored        Raspberry-flavored jam is really delicious.
# 10                lining  Could you check if the lining of the coat is c...
# 11                baking                              Baking a cake is fun.
# 12                   car                         This car is very reliable.
# 13               refugee          The refugee is searching for a safe home.
# 14                 still         I am still waiting for you at the station.
# 15             let alone   He doesn't like vegetables, let alone asparagus.
# 16        definitely not       He will definitely not come to school today.
# 17                 slept                           I slept well this night.
# 18     box of chocolates            I forgot to open the box of chocolates.
# 19       firmly attached                 Bird feathers are firmly attached.
# 20               flashed                                He flashed a smile.
# 21         swimming hall             I went to the swimming hall yesterday.
# 22               already                           Do you already know him?
# 23  "You can't miss it!"
# 24               thermos     Take a thermos with you when you go on a hike.
# 25     after having been      He took a shower after having been for a run.
# 26            poor thing    He's such a poor thing, his bicycle was stolen.
# 27                  even                Do you even understand what I mean?
# 28               meeting                   See you at the meeting tomorrow!
# 29         threateningly                He was approaching us with threats.
# 30                 looks                  The cat looks very playful today.
# 31              finished                  I finished just before the party.
# 32             shipwreck             The ship was wrecked during the storm.
# 33           responsible              He is responsible for this situation.
#
#                wordSecondLang  \
# 0                    iltameno
# 1              monipuolisesti
# 2                        arki
# 3         pakattu matkalaukku
# 4                    syömässä
# 5             perheen toivoma
# 6                  päiväkerho
# 7                    vapautua
# 8                     toimiva
# 9            vadelmanmakuinen
# 10                      vuori
# 11                 leipominen
# 12                       auto
# 13                 pakolainen
# 14                      vielä
# 15              ei varsinkaan
# 16            ei varmastikaan
# 17                     nukuin
# 18                suklaarasia
# 19             kiinnittyneenä
# 20                    välähti
# 21                  uimahalli
# 22               entuudestaan
# 23  Sä et voi olla tulematta!
# 24                     termos
# 25                    oltuaan
# 26                      parka
# 27                 ylipäätään
# 28                     kokous
# 29                     uhaten
# 30                    näyttää
# 31                     valmis
# 32                haaksirikko
# 33                  syyllinen
#
#                                    sentenceSecondLang    id  is_phrase_card  \
# 0       Lähdetäänkö yhdessä iltamenoihin tänä iltana?  6375           False
# 1                     Hän osaa laulaa monipuolisesti.  6427           False
# 2             Arkipäivät alkavat yleensä maanantaina.  6440           False
# 3   Valmistaudumme matkalle, joten pakattu matkala...  6530           False
# 4              Syön lounasta vilkkaassa ravintolassa.  6535           False
# 5   Tämä matka on juuri se, mitä perheen toivoma k...  6589           False
# 6           Lapseni käy päiväkerhossa joka arkipäivä.  6605           False
# 7          Voin vapautua kokouksesta klo 15 mennessä.  6634           False
# 8                    Tämä laite toimii todella hyvin.  6662           False
# 9      Vadelmanmakuinen hillo on todella herkullista.  6721           False
# 10          Voisitko katsoa, onko takin vuori puhdas?  6784           False
# 11                       Kakun leipominen on hauskaa.  6790           False
# 12                  Tämä auto on erittäin luotettava.  6796           False
# 13                Pakolainen etsii turvallista kotia.  6804           False
# 14                       Odotan vielä sinua asemalla.  6847           False
# 15  Hän ei pidä vihanneksista, ei varsinkaan parsa...  6849           False
# 16           Hän ei varmastikaan tule tänään kouluun.  6851           False
# 17                            Nukuin hyvin tänä yönä.  6872           False
# 18                        Unohdin avata suklaarasian.  6900           False
# 19    Lintujen höyhenet ovat tiukasti kiinnittyneinä.  6911           False
# 20                                Hän väläytti hymyn.  6933           False
# 21                          Kävin uimahallissa eilen.  6984           False
# 22                                 Tunnetko hänet jo?  7012           False
# 23                          Sä et voi olla tulematta!  7033            True
# 24       Ota termospullo mukaan, kun lähdet retkelle.  7112           False
# 25               Hän kävi suihkussa oltuaan lenkillä.  7146           False
# 26    Hän on raukka, kun hänen pyöränsä varastettiin.  7173           False
# 27                   Ymmärrätkö edes, mitä tarkoitan?  7196           False
# 28                      Nähdään kokouksessa huomenna!  7205           False
# 29                         Hän lähestyi meitä uhaten.  7221           False
# 30         Kissa näyttää tänään erittäin leikkisältä.  7243           False
# 31                    Olen valmis juuri ennen juhlia.  7262           False
# 32                  Laiva koki haaksirikon myrskyssä.  7316           False
# 33               Hän on syyllinen tähän tilanteeseen.  7343           False
#
#                            englishSentenceCorrectness  \
# 0   {'isCorrect': True, 'explanation': 'The Englis...
# 1   {'isCorrect': False, 'explanation': 'The sente...
# 2   {'isCorrect': True, 'explanation': 'The Englis...
# 3   {'isCorrect': False, 'explanation': 'The Engli...
# 4   {'isCorrect': False, 'explanation': 'The Engli...
# 5   {'isCorrect': False, 'explanation': 'The sente...
# 6   {'isCorrect': False, 'explanation': 'The term ...
# 7   {'isCorrect': True, 'explanation': 'The Englis...
# 8   {'isCorrect': False, 'explanation': 'The trans...
# 9   {'isCorrect': True, 'explanation': 'The Englis...
# 10  {'isCorrect': True, 'explanation': 'The Englis...
# 11  {'isCorrect': True, 'explanation': 'The Englis...
# 12  {'isCorrect': True, 'explanation': 'The Englis...
# 13  {'isCorrect': True, 'explanation': 'The Englis...
# 14  {'isCorrect': True, 'explanation': 'The Englis...
# 15  {'isCorrect': True, 'explanation': 'The senten...
# 16  {'isCorrect': False, 'explanation': 'The sente...
# 17  {'isCorrect': False, 'explanation': 'The sente...
# 18  {'isCorrect': True, 'explanation': 'The Englis...
# 19  {'isCorrect': False, 'explanation': 'The Engli...
# 20  {'isCorrect': True, 'explanation': 'The Englis...
# 21  {'isCorrect': True, 'explanation': 'The senten...
# 22  {'isCorrect': True, 'explanation': 'The Englis...
# 23                                                NaN
# 24  {'isCorrect': True, 'explanation': 'The senten...
# 25  {'isCorrect': False, 'explanation': 'The Engli...
# 26  {'isCorrect': True, 'explanation': 'The Englis...
# 27  {'isCorrect': True, 'explanation': 'The Englis...
# 28  {'isCorrect': True, 'explanation': 'The senten...
# 29  {'isCorrect': True, 'explanation': 'The Englis...
# 30  {'isCorrect': True, 'explanation': 'The Englis...
# 31  {'isCorrect': True, 'explanation': 'The Englis...
# 32  {'isCorrect': True, 'explanation': 'The Englis...
# 33  {'isCorrect': True, 'explanation': 'The Englis...
#
#                                             wordUsage  \
# 0   {'isCorrect': False, 'explanation': 'The Engli...
# 1   {'isCorrect': False, 'explanation': 'Although ...
# 2   {'isCorrect': True, 'explanation': 'The word '...
# 3   {'isCorrect': True, 'explanation': 'The word '...
# 4   {'isCorrect': False, 'explanation': 'The Engli...
# 5   {'isCorrect': False, 'explanation': 'The phras...
# 6   {'isCorrect': False, 'explanation': ''Day club...
# 7   {'isCorrect': True, 'explanation': 'The word '...
# 8   {'isCorrect': False, 'explanation': 'The Engli...
# 9   {'isCorrect': False, 'explanation': 'The Engli...
# 10  {'isCorrect': True, 'explanation': 'The Englis...
# 11  {'isCorrect': False, 'explanation': 'The Engli...
# 12  {'isCorrect': False, 'explanation': 'The Engli...
# 13  {'isCorrect': True, 'explanation': 'The Englis...
# 14  {'isCorrect': True, 'explanation': 'The word '...
# 15  {'isCorrect': True, 'explanation': 'The word '...
# 16  {'isCorrect': True, 'explanation': 'The word '...
# 17  {'isCorrect': True, 'explanation': 'The word '...
# 18  {'isCorrect': False, 'explanation': 'The provi...
# 19  {'isCorrect': True, 'explanation': ''Firmly at...
# 20  {'isCorrect': True, 'explanation': 'The word '...
# 21  {'isCorrect': True, 'explanation': 'The word '...
# 22  {'isCorrect': True, 'explanation': 'The word '...
# 23                                                NaN
# 24  {'isCorrect': True, 'explanation': 'The Englis...
# 25  {'isCorrect': False, 'explanation': 'The phras...
# 26  {'isCorrect': True, 'explanation': 'The word '...
# 27  {'isCorrect': True, 'explanation': 'The word '...
# 28  {'isCorrect': True, 'explanation': 'The word '...
# 29  {'isCorrect': False, 'explanation': 'The Engli...
# 30  {'isCorrect': True, 'explanation': 'The word '...
# 31  {'isCorrect': False, 'explanation': 'The Engli...
# 32  {'isCorrect': False, 'explanation': 'While the...
# 33  {'isCorrect': False, 'explanation': 'The Engli...
#
#                               wordTranslationAccuracy  \
# 0   {'isCorrect': True, 'explanation': 'The word '...
# 1   {'isCorrect': True, 'explanation': 'The word '...
# 2   {'isCorrect': False, 'explanation': 'The word ...
# 3   {'isCorrect': False, 'explanation': 'The Finni...
# 4   {'isCorrect': True, 'explanation': 'The transl...
# 5   {'isCorrect': False, 'explanation': 'The trans...
# 6   {'isCorrect': False, 'explanation': 'The Engli...
# 7   {'isCorrect': False, 'explanation': 'The trans...
# 8   {'isCorrect': True, 'explanation': 'The transl...
# 9   {'isCorrect': False, 'explanation': 'The word ...
# 10  {'isCorrect': True, 'explanation': 'The transl...
# 11  {'isCorrect': False, 'explanation': 'The trans...
# 12  {'isCorrect': False, 'explanation': 'The Engli...
# 13  {'isCorrect': False, 'explanation': 'The trans...
# 14  {'isCorrect': True, 'explanation': ''Still' is...
# 15  {'isCorrect': True, 'explanation': 'The transl...
# 16  {'isCorrect': True, 'explanation': 'The transl...
# 17  {'isCorrect': True, 'explanation': 'The Englis...
# 18  {'isCorrect': False, 'explanation': 'The trans...
# 19  {'isCorrect': False, 'explanation': ''Firmly a...
# 20  {'isCorrect': False, 'explanation': 'The Finni...
# 21  {'isCorrect': False, 'explanation': 'The Finni...
# 22  {'isCorrect': True, 'explanation': 'The word '...
# 23                                                NaN
# 24  {'isCorrect': False, 'explanation': 'The Finni...
# 25  {'isCorrect': True, 'explanation': 'The transl...
# 26  {'isCorrect': True, 'explanation': 'The word '...
# 27  {'isCorrect': False, 'explanation': 'The word ...
# 28  {'isCorrect': True, 'explanation': 'The word '...
# 29  {'isCorrect': True, 'explanation': 'The transl...
# 30  {'isCorrect': False, 'explanation': 'The Engli...
# 31  {'isCorrect': False, 'explanation': 'The word ...
# 32  {'isCorrect': True, 'explanation': 'The Englis...
# 33  {'isCorrect': False, 'explanation': 'The Engli...
#
#                           sentenceTranslationAccuracy  \
# 0   {'isCorrect': False, 'explanation': 'The Engli...
# 1   {'isCorrect': True, 'explanation': 'The Englis...
# 2   {'isCorrect': False, 'explanation': 'The sente...
# 3   {'isCorrect': False, 'explanation': 'The trans...
# 4   {'isCorrect': False, 'explanation': 'The Engli...
# 5   {'isCorrect': False, 'explanation': 'The Engli...
# 6   {'isCorrect': False, 'explanation': 'The Engli...
# 7   {'isCorrect': False, 'explanation': 'The Engli...
# 8   {'isCorrect': False, 'explanation': 'The trans...
# 9   {'isCorrect': False, 'explanation': 'The origi...
# 10  {'isCorrect': False, 'explanation': 'The origi...
# 11  {'isCorrect': False, 'explanation': 'The trans...
# 12  {'isCorrect': False, 'explanation': 'The Finni...
# 13  {'isCorrect': True, 'explanation': 'The senten...
# 14  {'isCorrect': False, 'explanation': 'The Finni...
# 15  {'isCorrect': False, 'explanation': 'The Finni...
# 16  {'isCorrect': True, 'explanation': 'The transl...
# 17  {'isCorrect': True, 'explanation': 'The senten...
# 18  {'isCorrect': False, 'explanation': 'The Finni...
# 19  {'isCorrect': True, 'explanation': 'The transl...
# 20  {'isCorrect': True, 'explanation': 'The Englis...
# 21  {'isCorrect': False, 'explanation': 'The trans...
# 22  {'isCorrect': False, 'explanation': 'The trans...
# 23                                                NaN
# 24  {'isCorrect': False, 'explanation': 'The Finni...
# 25  {'isCorrect': True, 'explanation': 'The transl...
# 26  {'isCorrect': False, 'explanation': 'There is ...
# 27  {'isCorrect': True, 'explanation': 'The senten...
# 28  {'isCorrect': False, 'explanation': 'The Finni...
# 29  {'isCorrect': False, 'explanation': 'The Engli...
# 30  {'isCorrect': True, 'explanation': 'The senten...
# 31  {'isCorrect': False, 'explanation': 'The provi...
# 32  {'isCorrect': True, 'explanation': 'The Englis...
# 33  {'isCorrect': False, 'explanation': 'The Engli...
#
#                                   translationAccuracy
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  {'isCorrect': False, 'explanation': 'The provi...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN

# %%
bad_cards_df.to_excel('fourth_book_bad_cards.xlsx')
