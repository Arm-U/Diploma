# %%
import json

# def print_json_from_jsonlines(file_path):
#     with open(file_path, 'r', encoding='utf-8') as file:
#         for line in file:
#             try:
#                 json_object = json.loads(line.strip())
#                 print(json.dumps(json_object, ensure_ascii=False, indent=2))
#             except json.JSONDecodeError as e:
#                 print(f"Error decoding JSON: {e}")

# def print_incorrect_evaluations(file_path):
#     def has_incorrect_field(evaluation):
#         # Check if any evaluation field has isCorrect set to false
#         fields = ['russianSentence', 'finnishSentence', 'translationAccuracy', 'russianWordUsage', 'finnishWordUsage']
#         return any(not evaluation.get(field, {}).get('isCorrect', True) for field in fields)
    
#     with open(file_path, 'r', encoding='utf-8') as file:
#         for line in file:
#             try:
#                 json_object = json.loads(line.strip())
#                 evaluation = json_object.get('evaluation', {})
#                 if has_incorrect_field(evaluation):
#                     print(json.dumps(json_object, ensure_ascii=False, indent=2))
#             except json.JSONDecodeError as e:
#                 print(f"Error decoding JSON: {e}")
                
                
def print_incorrect_fields(file_path):
    def get_incorrect_fields(evaluation):
        # Check if any evaluation field has isCorrect set to false and return those fields
        fields = ['russianSentence', 'finnishSentence', 'translationAccuracy', 'russianWordUsage', 'finnishWordUsage']
        incorrect_fields = {}
        for field in fields:
            if not evaluation.get(field, {}).get('isCorrect', True):
                incorrect_fields[field] = evaluation[field]
        return incorrect_fields
    
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            try:
                json_object = json.loads(line.strip())
                evaluation = json_object.get('evaluation', {})
                incorrect_fields = get_incorrect_fields(evaluation)
                if incorrect_fields:
                    print(json.dumps({"id": json_object.get("id"), "incorrect_fields": incorrect_fields}, ensure_ascii=False, indent=2))
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")

# %%
# Example usage
chapter_name = 'sm2_new_kap4'
jsonlines_file_path = f"{chapter_name}_evaluations_filtered.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 3595,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'досуг' does not appear in the Russian sentence. The sentence uses 'свободного времени,' which is a synonymous phrase.",
#       "suggestedFixSentence": "У меня много досуга в этот уикенд.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3604,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'тренироваться' does not appear in the sentence. A synonym or related term should be used.",
#       "suggestedFixSentence": "Ты можешь тренироваться в финском языке каждый день.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3608,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Сиско это моя близкая подруга.' has a small issue with the name 'Сиско,' which is not a common Russian name and seems to be interpolated incorrectly. It might be better to use a more common Russian name or to use 'Сестра' (Sister) to align it with the Finnish sentence.",
#       "suggestedFix": "Сестра это моя близкая подруга."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The provided Russian word 'близкий человек' does not appear in the sentence in any form. The sentence uses 'близкая подруга,' which translates to 'close female friend.'",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "близкий человек, близкий, близкая подруга"
#     }
#   }
# }
# {
#   "id": 3611,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'очень много' does not appear in the provided Russian sentence. To make the sentence correct and natural while including the phrase 'очень много', the sentence could be rewritten.",
#       "suggestedFixSentence": "У Ольги было очень много времени.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3613,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Сначала Алекс однако не умел ничего.' is grammatically incorrect. The word 'однако' should be used in a different part of the sentence.",
#       "suggestedFix": "Сначала Алекс не умел ничего, однако."
#     }
#   }
# }
# {
#   "id": 3614,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'расслабленный' does not appear in the sentence. The sentence uses 'расслаблен', which is grammatically correct but a different form.",
#       "suggestedFixSentence": "Я сегодня расслабленный.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3617,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is mostly correct but there is an orthographic issue. The correct version should be В настоящее время instead of В настоящеё время, removing the unnecessary dieresis on 'е'.",
#       "suggestedFix": "В настоящее время я умею наслаждаться тем, что нахожусь дома."
#     }
#   }
# }
# {
#   "id": 3618,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Прекрасно лежать на траве' sounds somewhat unnatural in Russian, primarily due to the use of 'прекрасно' with the infinitive form of 'лежать'. It can be improved to sound more natural.",
#       "suggestedFix": "Прекрасно лежать на траве в жаркий летний день."
#     }
#   }
# }
# {
#   "id": 3619,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'справочник' more accurately translates to 'hakuteos' in Finnish, while 'tietokirja' translates to 'научно-популярная книга' or 'познавательная книга'. The given translation doesn't fully capture the meaning.",
#       "suggestedFix": "Minulla on hyvä hakuteos."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'tietokirja' does appear in the Finnish sentence, but given the translation mismatch, it should be 'hakuteos' to match the Russian word 'справочник'.",
#       "suggestedFix": "hakuteos"
#     }
#   }
# }
# {
#   "id": 3620,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Olen kiinnostunut oppimaan suomea.' has a grammatical issue. The correct verb form should be 'oppiMan' instead of 'oppiMaan'.",
#       "suggestedFix": "Olen kiinnostunut oppimaan suomea."
#     }
#   }
# }
# {
#   "id": 3625,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Ei edes yritä tehdä sitä.' is unnatural. The correct form should be 'Älä edes yritä tehdä sitä.'",
#       "suggestedFix": "Älä edes yritä tehdä sitä."
#     }
#   }
# }
# {
#   "id": 3627,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'по-моему' does appear in the sentence. However, 'по-моему' can be considered informal or subjective.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "по-моему, мне кажется"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'musta' (meaning 'must' in English) does appear in the sentence, but the intended meaning from Russian 'по-моему' should be translated as 'minusta'. Thus, 'minusta' is correctly used.",
#       "suggestedFix": "minusta"
#     }
#   }
# }
# {
#   "id": 3630,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'увлечен' is accurate but the sentence would be more natural with a different verb conjugation considering 'я'. 'Увлечен' is a passive form and doesn't fit well here.",
#       "suggestedFix": "Я очень увлечен изучением финского языка."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not fully accurate. The original sentence in Russian would be better translated to Finnish with slight modifications for naturalness.",
#       "suggestedFix": "Olen hyvin innostunut suomen kielen oppimisesta."
#     }
#   }
# }
# {
#   "id": 3632,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'телевизор' does not appear in the Russian sentence. A related term 'телевизору' is used but the word should ideally appear in the form it is given.",
#       "suggestedFixSentence": "Смотрю свою любимую передачу по телевизору.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3634,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Opiskelija kannustaa toisiaan tenttiin valmistautuessaan.' has a grammatical error. The singular 'Opiskelija' does not match the plural 'toisiaan'. It should be 'Opiskelijat' to correctly match the plural form.",
#       "suggestedFix": "Opiskelijat kannustavat toisiaan tenttiin valmistautuessaan."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence given translates to 'The student encourages each other in preparing for the exam,' which is not an accurate translation of the Russian sentence 'Students support each other in preparing for the exam.' The word 'kannustaa' means 'to encourage' rather than 'to support'. A more accurate Finnish translation should use a verb that corresponds to 'to support'.",
#       "suggestedFix": "Opiskelijat tukevat toisiaan tenttiin valmistautuessaan."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kannustaa' does not accurately reflect the meaning of 'поддерживать'. A better word would be 'tukea' which means 'to support'.",
#       "suggestedFix": "tukea"
#     }
#   }
# }
# {
#   "id": 3635,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Älä huutaa, vaan puhu normaalilla äänellä.' is not grammatically correct. 'Älä' requires the verb to be in the infinitive, which should be 'huuda' instead of 'huutaa'.",
#       "suggestedFix": "Älä huuda, vaan puhu normaalilla äänellä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'huutaa' should be in the correct form 'huuda' to match the imperative mood required by 'Älä'.",
#       "suggestedFix": "huuda"
#     }
#   }
# }
# {
#   "id": 3662,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence provided is more complex than the Finnish translation. The Russian phrase 'Я хожу на занятие по фитнесу' translates more accurately to 'Käyn kuntosalilla' in Finnish.",
#       "suggestedFix": "Käyn kuntosalilla."
#     }
#   }
# }
# {
#   "id": 3709,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'один раз' does not appear in the sentence 'Я хожу в кино раз в неделю.'. However, 'раз в неделю' is a correct and natural expression.",
#       "suggestedFixSentence": "Я хожу в кино один раз в неделю.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3731,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'выясняться' does not appear in the Russian sentence. The sentence uses 'стало ясно' which is synonymous, but the given word needs to appear.",
#       "suggestedFixSentence": "Из исследования выяснилось, что физическая активность улучшает настроение.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3735,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian 'Он хочет объявить о своём дне рождения.' is grammatically correct and natural, but does not use the provided word 'сообщить.' Instead, it uses 'объявить,' which has a slightly different nuance.",
#       "suggestedFix": "Он хочет сообщить о своём дне рождения."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The provided word 'сообщить' should appear in the Russian sentence. Instead, the word 'объявить' is used, which should be replaced.",
#       "suggestedFixSentence": "Он хочет сообщить о своём дне рождения.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3736,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'когда опять' does not appear in the sentence. However, related terms 'когда' and 'опять' are used individually.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "когда, опять"
#     }
#   }
# }
# {
#   "id": 3737,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. The Russian sentence means 'Distribution by importance helps keep things in order,' while the Finnish sentence means 'Priority order helps keep things in order.'",
#       "suggestedFix": "Raskausjärjestys auttaa pitämään asiat järjestyksessä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'важность' does not appear in the sentence. However, 'распределение по важности' is a natural phrase.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "важность, приоритет"
#     }
#   }
# }
# {
#   "id": 3738,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is inaccurate. 'Menen yli kadun.' translates to 'Я перехожу через дорогу.' in Russian. The current Russian sentence does not include the preposition 'через' which means 'across.'",
#       "suggestedFix": "Я перехожу через дорогу."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'через' meaning 'across' does not appear in the Russian sentence. The sentence should clearly use 'через' to maintain accuracy.",
#       "suggestedFixSentence": "Я перехожу через дорогу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3746,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from 'Minä kuulun urheiluseuraan.' (I belong to a sports club) to 'Я состою в спортивном клубе.' (I belong to a sports club) is not accurate because 'urheiluseura' means 'sports society' while 'sportivnij club' means 'sports club'. The sentence in Russian should reflect 'спортивное общество'.",
#       "suggestedFix": "Я состою в спортивном обществе."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'спортивное общество' does not appear in the Russian sentence. Instead, 'спортивный клуб' (sports club) is used, which is not the same.",
#       "suggestedFixSentence": "Я состою в спортивном обществе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3747,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Russian 'популярный' does not appear in the sentence 'Этот ресторан популярен'.",
#       "suggestedFixSentence": "Этот ресторан очень популярный.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3749,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'прогулка' does not appear in the Russian sentence. A synonym or related term needs to be used.",
#       "suggestedFixSentence": "Я иду на прогулку в парк.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3751,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate as 'jumppa' in Finnish translates to 'аэробика' in Russian, not 'фитнесс'. The correct translation should involve some form of the word 'аэробика'.",
#       "suggestedFix": "Я занимаюсь аэробикой каждый вторник."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'аэробика' does not appear in the Russian sentence. To ensure the sentence remains natural and accurate, the word 'аэробика' should be used instead of 'фитнесс'.",
#       "suggestedFixSentence": "Я занимаюсь аэробикой каждый вторник.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3754,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Использование телефона лёгко.' is not grammatically correct or natural. The correct form should be 'Использование телефона легко.'",
#       "suggestedFix": "Использование телефона легко."
#     }
#   }
# }
# {
#   "id": 3755,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Это бесплатно.' is grammatically correct but does not use the word 'бесплатный' in any form. It uses 'бесплатно', which is an adverb.",
#       "suggestedFix": "Эта вещь бесплатная."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Это бесплатно.' does not use the word 'бесплатный' in any form. It uses 'бесплатно', which is an adverb.",
#       "suggestedFixSentence": "Эта вещь бесплатная.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3758,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The correct form should be 'Minä menen festivaaleille ensi viikonloppuna.' 'Festivaaleille' is the appropriate case form here, indicating 'to the festival'.",
#       "suggestedFix": "Minä menen festivaaleille ensi viikonloppuna."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'festivaali' should be in the case form 'festivaaleille' to align with the proper grammar.",
#       "suggestedFix": "festivaaleille"
#     }
#   }
# }
# {
#   "id": 3759,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minä syön tavallinen leipä aamiaiseksi.' is grammatically incorrect. The adjective 'tavallinen' should be in the partitive form 'tavallista' because it is describing a mass noun.",
#       "suggestedFix": "Minä syön tavallista leipää aamiaiseksi."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'tavallinen' is used in the wrong case in the Finnish sentence. It should be 'tavallista' as it is describing the mass noun 'bread' in a partitive sense.",
#       "suggestedFix": "tavallista"
#     }
#   }
# }
# {
#   "id": 3760,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'играл' does not appear in any form in the provided Russian sentence.",
#       "suggestedFixSentence": "Я учусь играть на гитаре.",
#       "suggestedFixWord": "играть"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'soitin' does not appear in the provided Finnish sentence. The appropriate word for the provided sentence would be 'soittamaan'.",
#       "suggestedFix": "soittamaan"
#     }
#   }
# }
# {
#   "id": 3761,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Teen paljon käsityötä.' is close to being correct, but the word 'käsityötä' should be in plural form for better grammar.",
#       "suggestedFix": "Teen paljon käsitöitä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'käsityöt' should be used in the plural form as 'käsitöitä' for better grammar.",
#       "suggestedFix": "käsitöitä"
#     }
#   }
# }
# {
#   "id": 3764,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'приготовление пищи' is not used in the Russian sentence.",
#       "suggestedFixSentence": "Я учусь приготовлению пищи.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3771,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct but sounds less natural. A more natural phrasing would use the word 'горожанин'.",
#       "suggestedFix": "Я горожанин Хельсинки."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'горожанин' does not appear in the Russian sentence. A synonym or related term should be used to ensure the sentence remains natural and accurate.",
#       "suggestedFixSentence": "Я горожанин Хельсинки.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3772,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. The Finnish word 'ulkoliikunta' is translated as 'уличные виды спорта' in Russian, but the Russian sentence uses 'активными видами спорта на свежем воздухе,' which is a bit different.",
#       "suggestedFix": "Я люблю заниматься уличными видами спорта."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'уличные виды спорта' does not occur in the Russian sentence.",
#       "suggestedFixSentence": "Я люблю заниматься уличными видами спорта.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3774,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a minor typographical error. The correct form is 'löytääkseen uusia polkuja.'",
#       "suggestedFix": "He suunnistavat metsässä löytääkseen uusia polkuja."
#     }
#   }
# }
# {
#   "id": 3777,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Olemme menossa vesille veneellä.' is awkward. 'Vesille' means 'onto the water', which is not a direct translation.",
#       "suggestedFix": "Olemme vesillä veneellä."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Olemme menossa vesille veneellä.' does not accurately reflect 'Мы плывем по воде на лодке.', as it implies future action instead of present continuous.",
#       "suggestedFix": "Olemme vesillä veneellä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vesillä' is correct and should be used in the sentence to reflect the meaning accurately.",
#       "suggestedFix": "vesillä"
#     }
#   }
# }
# {
#   "id": 3782,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The specific word 'игра на музыкальном инструменте' does not appear in the Russian sentence. Instead, 'игра на гитаре' is used. However, 'игра на гитаре' naturally fits within the context as a specific instance of playing a musical instrument.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "игра на музыкальном инструменте, игра на гитаре"
#     }
#   }
# }
# {
#   "id": 3793,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'уборка ванной комнаты' does not appear in the sentence. A more appropriate phrase should be used to incorporate the term.",
#       "suggestedFixSentence": "Сегодня я занимаюсь уборкой ванной комнаты.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kylpyhuoneen siivoaminen' does not appear in the sentence. A more appropriate phrase should be used to incorporate the term.",
#       "suggestedFix": "Tänään olen kylpyhuoneen siivoamisessa."
#     }
#   }
# }
# {
#   "id": 3796,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'купание в озере' is not used in the sentence. Instead, a related form 'купаться в озере' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "купание, купаться в озере"
#     }
#   }
# }
# {
#   "id": 3799,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not use the exact phrase 'поход на рынок'.",
#       "suggestedFixSentence": "Совершаем поход на рынок со своими друзьями.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence does not use the exact phrase 'torilla käyminen'.",
#       "suggestedFix": "Menen ystävieni kanssa torilla käymistä."
#     }
#   }
# }
# {
#   "id": 3810,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'я не ел' does not appear in the Russian sentence. A synonymous or related term should be used.",
#       "suggestedFixSentence": "Сегодня я не ел завтрак.",
#       "suggestedFixWord": "я не завтракал"
#     }
#   }
# }
# {
#   "id": 3811,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically incorrect. The correct form would be 'Ты не ел завтрак сегодня утром' or 'Ты не поел завтрак сегодня'.",
#       "suggestedFix": "Ты не поел завтрак сегодня."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is accurate in terms of content but not fully correct because of the Russian sentence's issue.",
#       "suggestedFix": "Sinä et syönyt aamupalaa tänään."
#     }
#   }
# }
# {
#   "id": 3812,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'он не ел' doesn't directly appear in the Russian sentence. A synonym or related term could be used instead.",
#       "suggestedFixSentence": "Он не ел сегодня завтрак.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3813,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence means 'We did not have breakfast today', while the Finnish sentence translates to 'We did not eat breakfast today'. Both convey the same meaning, but the verbs used differ (завтракать vs. syödä aamupalaa).",
#       "suggestedFix": "Me emme syöneet tänään."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы не ели' (we did not eat) does not appear in any form in the Russian sentence. The sentence uses 'завтракать' (to have breakfast), which is a more specific term.",
#       "suggestedFixSentence": "Мы не ели сегодня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3815,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'они не ели' in Russian does not appear in the sentence. However, a related term 'завтракали' is used.",
#       "suggestedFixSentence": "Они не ели сегодня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3820,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы не пришли' does not appear in the given Russian sentence. The sentence uses 'мы не приехали' instead.",
#       "suggestedFixSentence": "Мы не пришли на автобусе.",
#       "suggestedFixWord": "мы не приехали"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me emme tulleet' does not appear in the given Finnish sentence. The sentence uses 'me emme tulleet' instead.",
#       "suggestedFix": "me emme tulleet"
#     }
#   }
# }
# {
#   "id": 3824,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ты не помыл' is not used in the sentence, though 'ты не мыл' is close but not exact. 'Помыл' is the perfective aspect of 'мыл', but for a more accurate match, the sentence can be adjusted.",
#       "suggestedFixSentence": "Ты не помыл посуду вчера.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3825,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'он не вымыл' does not occur in the sentence 'Он не вымыл собаку.' in its entirety. However, 'вымыл' does.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "он не вымыл, не вымыл"
#     }
#   }
# }
# {
#   "id": 3826,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы не постирали' does not occur in some form in the Russian sentence. The sentence should be adjusted to include the phrase or a synonym.",
#       "suggestedFixSentence": "Мы не постирали белье вчера.",
#       "suggestedFixWord": "постирали"
#     }
#   }
# }
# {
#   "id": 3827,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The exact phrase 'вы не мыли посуду' does occur in the sentence, but it needs to match the form. The base form 'мыли' can be changed if necessary but it is not required in this case.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "мыли посуду"
#     }
#   }
# }
# {
#   "id": 3830,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'ты не сумел' does not appear in the Russian sentence. A synonym or related term such as 'не смог' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "ты не сумел, не смог"
#     }
#   }
# }
# {
#   "id": 3834,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Они не могли понять математику.' translates to 'They could not understand math,' whereas the Finnish sentence 'He eivät osanneet matematiikkaa.' translates to 'They did not know math.' The translations are not equivalent.",
#       "suggestedFix": "Они не умели математику."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'они не умели' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Они не умели математику.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3835,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мне не понадобилось' does not appear in the sentence 'Я не нуждался в помощи.' A more appropriate word should be used in the sentence.",
#       "suggestedFixSentence": "Мне не понадобилась помощь.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3836,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тебе не понадобилось' does not appear in the Russian sentence 'Тебе не понадобилась помощь.'",
#       "suggestedFixSentence": "Тебе не понадобилось помощь.",
#       "suggestedFixWord": "тебе не понадобилось, тебе не понадобилась"
#     }
#   }
# }
# {
#   "id": 3838,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нам не понадобились' does not appear in any form in the Russian sentence. 'Не нуждались' is used instead.",
#       "suggestedFixSentence": "Мы не нуждались в новой одежде после похода по магазинам.",
#       "suggestedFixWord": "не нуждались, нам не понадобились"
#     }
#   }
# }
# {
#   "id": 3840,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'им не понадобилось' does not appear in the sentence. However, a related term 'не понадобилась' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "им не понадобилось, им не понадобился, им не понадобилась"
#     }
#   }
# }
# {
#   "id": 3841,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'я не бежал' does not occur in the sentence. Instead, 'я не убежал' is used, which is a more natural form in this context.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "я не убежал"
#     }
#   }
# }
# {
#   "id": 3844,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Me emme paenneet metsässä.' is not correct because it incorrectly uses 'metsässä' which means 'in the forest' rather than 'out of the forest'.",
#       "suggestedFix": "Me emme paenneet metsästä."
#     }
#   }
# }
# {
#   "id": 3849,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Se ei lukenu kirjaa.' is not grammatically correct in Finnish. The correct form should be 'Se ei lukenut kirjaa.'",
#       "suggestedFix": "Se ei lukenut kirjaa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word provided 'он не читал' matches the usage but it is inflected incorrectly for a vocabulary item translation. The word should be 'читать' to provide a stative form.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "читать"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word provided 'se ei lukenu' is an incorrect form, as it should be 'se ei lukenut'.",
#       "suggestedFix": "se ei lukenut"
#     }
#   }
# }
# {
#   "id": 3850,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Me ei luettu kirjaa eilen.' is not grammatically correct. The standard form should be 'Me emme lukeneet kirjaa eilen.'",
#       "suggestedFix": "Me emme lukeneet kirjaa eilen."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me ei luettu' is not a correct form in Finnish. The appropriate form should be 'me emme lukeneet'.",
#       "suggestedFix": "me emme lukeneet"
#     }
#   }
# }
# {
#   "id": 3851,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Te ette lukenu kirjaa.' is missing the correct past tense form in Finnish. The correct form should be 'lukeneet'.",
#       "suggestedFix": "Te ette lukeneet kirjaa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The exact phrase 'вы не читали' does not occur in the sentence. Instead, 'Вы не читали' is used, which is similar.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вы не читали, не читали"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The exact word 'te ette lukenu' does not occur in the sentence. The correct form should be 'te ette lukeneet.'",
#       "suggestedFix": "te ette lukeneet"
#     }
#   }
# }
# {
#   "id": 3852,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "'Ne ei lukenu kirjaa.' is colloquial and not correct in standard Finnish. The correct form should be 'He eivät lukeneet kirjaa.'",
#       "suggestedFix": "He eivät lukeneet kirjaa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne ei lukenu' should match the corrected, standard Finnish sentence.",
#       "suggestedFix": "he eivät lukeneet"
#     }
#   }
# }
# {
#   "id": 3855,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Se ei tullu bussipysäkille ajoissa.' contains a typo. The correct pronunciation and spelling should be 'tullut' instead of 'tullu'.",
#       "suggestedFix": "Se ei tullut bussipysäkille ajoissa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Finnish provided is 'se ei tullu', but the correct spelling should be 'se ei tullut'.",
#       "suggestedFix": "se ei tullut"
#     }
#   }
# }
# {
#   "id": 3856,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is not correct in standard Finnish. It should be 'Me emme tulleet kouluun tänään' for proper grammar.",
#       "suggestedFix": "Me emme tulleet kouluun tänään."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate because the Finnish sentence uses informal spoken language which doesn't match the standard Russian sentence.",
#       "suggestedFix": "For a more accurate translation, use proper Finnish: 'Me emme tulleet kouluun tänään.' or adjust the Russian sentence to match the informal tone: 'Мы не были в школе сегодня.'"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me ei tultu' should be 'me emme tulleet' to match proper grammar.",
#       "suggestedFix": "me emme tulleet"
#     }
#   }
# }
# {
#   "id": 3857,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Te ette tullu.' is not grammatically correct. The proper form should be 'te ette tulleet.'",
#       "suggestedFix": "Te ette tulleet."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish phrase 'te ette tullu' is not used correctly in the sentence. The correct form should be 'te ette tulleet.'",
#       "suggestedFix": "te ette tulleet"
#     }
#   }
# }
# {
#   "id": 3858,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a grammatical issue. The correct form should be 'Ne eivät tulleet kauppaan.'",
#       "suggestedFix": "Ne eivät tulleet kauppaan."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is incorrect. The correct form should be 'они не пришли.'",
#       "suggestedFix": "Ne eivät tulleet"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne ei tullu' is incorrect in Finnish. The correct form should be 'ne eivät tulleet.'",
#       "suggestedFix": "ne eivät tulleet"
#     }
#   }
# }
# {
#   "id": 3862,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Me ei osattu laittaa ruokaa.' is colloquial but not grammatically correct. The formal and grammatically correct version would be 'Me emme osanneet laittaa ruokaa.'",
#       "suggestedFix": "Me emme osanneet laittaa ruokaa."
#     }
#   }
# }
# {
#   "id": 3863,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Te ette osannu puhua suomea.' contains a dialectical form 'osannu'. The standard form is 'osanneet'.",
#       "suggestedFix": "Te ette osanneet puhua suomea."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'te ette osannu' is not in the standard form in Finnish.",
#       "suggestedFix": "te ette osanneet"
#     }
#   }
# }
# {
#   "id": 3864,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Ne eit osannu soittaa kitaraa.' is not grammatically correct. 'Eit' is a typo and should be 'ei'.",
#       "suggestedFix": "Ne ei osannu soittaa kitaraa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne ei osannu' (corrected to 'ei') appears in the Finnish sentence.",
#       "suggestedFix": "ei osannu"
#     }
#   }
# }
# {
#   "id": 3865,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translations 'Что делает?' and 'Miten tekee?' are not proper translations of each other. 'Miten tekee?' can be better translated as 'Как сделать?'.",
#       "suggestedFix": "Как сделать?"
#     }
#   }
# }
# {
#   "id": 3867,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän katsoi vihaaisesti toista oppilasta kohti.' is not entirely natural. The use of 'kohti' at the end is redundant with 'katsoi'.",
#       "suggestedFix": "Hän katsoi vihaisesti toista oppilasta."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vihaisesti' should be 'vihaisesti' instead of 'vihaaisesti'. 'Vihaisesti' is the correct adverb form.",
#       "suggestedFix": "vihaisesti"
#     }
#   }
# }
# {
#   "id": 3879,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translations of the word and sentence are mismatched.",
#       "suggestedFix": "Алекс хотел попробовать что-то новое в командных видах спорта. - Alex halusi kokeilla jotakin uutta joukkuelajeja."
#     }
#   }
# }

# %%
# Example usage
chapter_name = 'sm2_new_kap5'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 3896,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в то же время, одновременно' does not appear in the given Russian sentence. A synonym 'в одно и то же время' is used, which conveys the same meaning.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "в одно и то же время"
#     }
#   }
# }
# {
#   "id": 3897,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вдруг' does not appear in the Russian sentence. A closely related term 'внезапно' is used instead, which also means 'suddenly.'",
#       "suggestedFixSentence": "Он вдруг встал и ушёл.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3899,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'тот' in this context sounds slightly unnatural; a more idiomatic way to express this would be 'Это мой дом.'",
#       "suggestedFix": "Это мой дом."
#     }
#   }
# }
# {
#   "id": 3903,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is mostly correct but the part 'on niin sotkua' sounds unnatural. It should be 'on niin paljon sotkua' to be grammatically correct and natural.",
#       "suggestedFix": "Tässä huoneessa on niin paljon sotkua, että se täytyy siivota heti."
#     }
#   }
# }
# {
#   "id": 3904,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в бардаке' does not appear in the Russian sentence. Instead, 'бардак' is used.",
#       "suggestedFixSentence": "В моей комнате царил бардак, пока я приводил в порядок свои вещи.",
#       "suggestedFixWord": "бардак, беспорядок"
#     }
#   }
# }
# {
#   "id": 3908,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'выясняться' does not appear in the Russian sentence. Instead, the sentence uses 'стало ясно,' which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "выясняться, становиться ясным"
#     }
#   }
# }
# {
#   "id": 3909,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Своим заявлением он заставил меня врасплох.' is not entirely correct. The phrase 'заставил меня врасплох' should be corrected to 'застал меня врасплох'.",
#       "suggestedFix": "Своим заявлением он застал меня врасплох."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'заставлять врасплох' does not appear in the sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "заставать врасплох, удивлять"
#     }
#   }
# }
# {
#   "id": 3913,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'выносить' does not appear in the Russian sentence. Only 'красть' is used in its form 'украсть'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "украсть (выносить, красть)"
#     }
#   }
# }
# {
#   "id": 3914,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'пропадать' does not appear in any form in the Russian sentence. However, 'пропадать' can be a synonym for 'исчезать', which is used in the sentence.",
#       "suggestedFixSentence": "Ключи бесследно пропали, и я нигде не мог их найти.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3918,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun kahvikuppi on punainen.' has a grammatical error; 'kahvikuppi' should be in possessive form.",
#       "suggestedFix": "Minun kahvikuppini on punainen."
#     }
#   }
# }
# {
#   "id": 3919,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'взломщик' from the card is not used in the sentence. The word 'грабитель' is used instead. While 'грабитель' is correct, it would be better to use 'взломщик' or include it in some form.",
#       "suggestedFixSentence": "Взломщик проник в дом через окно.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3921,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is not grammatically correct. The correct form should be 'Minun kynäni tuntuu aina katoavan, kun eniten sitä tarvitsen.'",
#       "suggestedFix": "Minun kynäni tuntuu aina katoavan, kun eniten sitä tarvitsen."
#     }
#   }
# }
# {
#   "id": 3934,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence provided does not contain the word 'хронология' or 'план по времени' or any of their forms. This word has to be incorporated into the sentence.",
#       "suggestedFixSentence": "Хронология выбора времени может иметь большое значение для успешного маркетинга.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3935,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "In the Russian sentence, 'нужно новая страховка' should be corrected to 'нужна новая страховка' to match the gender and case.",
#       "suggestedFix": "Нам нужна новая страховка для жилья, прежде чем мы переедем в новую квартиру."
#     }
#   }
# }
# {
#   "id": 3940,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'уточнить' from the given translation is correctly used in the sentence, but it does not match the provided primary word 'объяснить'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "объяснить, уточнить, разъяснить"
#     }
#   }
# }
# {
#   "id": 3941,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The specific Russian word 'подать заявление о преступлении' does not appear in the sentence. However, the sentence meaning is correct but could be more precise.",
#       "suggestedFixSentence": "Он решил подать заявление о преступлении в полицию об украденном велосипеде.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3944,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'попадаться' or its form does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он пытался украсть сладости из магазина, но попался.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3946,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not include the phrase 'ходатайствовать о компенсации ущерба' or any related terms. The closest translation related to the original context would be 'требование о компенсации'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "требовать компенсацию ущерба"
#     }
#   }
# }
# {
#   "id": 3950,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'собственная ответственность' or 'франшиза' needs to appear in the sentence, but only 'франшиза' is used. The translation can either use 'франшиза' in the word definition or change the sentence to include 'собственная ответственность'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "Франшиза, собственная ответственность"
#     }
#   }
# }
# {
#   "id": 3955,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian phrase 'Зимние шины, в свою очередь, вору не подошли.' translates to 'Talvirenkaat sen sijaan eivät ole kelvanneet varkaalle.' The Finnish phrase means 'Winter tires, on the other hand, did not suit the thief,' while the Russian phrase seems slightly off and may need rephrasing to 'Зимние шины, в свою очередь, вору не подошли.' to match the Finnish.",
#       "suggestedFix": "Зимние шины, в свою очередь, вору не подошли."
#     }
#   }
# }
# {
#   "id": 3962,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вернуть форму' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Обязательно верните форму не позднее следующей пятницы.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3968,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct, but it does not use the word 'приложение'. It uses 'вложения', which is synonymous but not the given word.",
#       "suggestedFix": "Мог бы ты отправить мне эти документы с приложениями по электронной почте?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not contain the word 'приложение'.",
#       "suggestedFixSentence": "Мог бы ты отправить мне эти документы с приложениями по электронной почте?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3972,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'филиал, точка обслуживания, офис' should appear in the sentence, but only 'офис' does. To maintain accuracy while keeping the sentence natural, we should suggest making the word translation more specific by including 'офис'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "филиал, точка обслуживания, офис"
#     }
#   }
# }
# {
#   "id": 3974,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. 'Virkailija' translates to 'служащий,' but 'Сотрудник' was used, which generally means 'employee.'",
#       "suggestedFix": "Служащий заполнит для вас формы."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'служащий' does not appear in the Russian sentence. 'Сотрудник' was used instead, which is a broader term.",
#       "suggestedFixSentence": "Служащий заполнит для вас формы.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3980,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian is not fully natural or grammatically correct. 'счет' should be 'счёт', and the word order can be improved for clarity.",
#       "suggestedFix": "Можешь ли ты оплатить счёт, если платёж просрочен?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'платёж' does occur in the sentence, but the initial sentence has grammatical issues.",
#       "suggestedFixSentence": "Можешь ли ты оплатить счёт, если платёж просрочен?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3981,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Срок оплаты счёта на следующей неделе.' is not fully grammatical and natural in Russian. The correct form should explicitly mention that it is the 'срок платежа'.",
#       "suggestedFix": "Срок платежа за счёт наступает на следующей неделе."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'срок платежа' is not used in the sentence. Instead, 'срок оплаты' is used, which is slightly different.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "срок платежа, срок оплаты"
#     }
#   }
# }
# {
#   "id": 3984,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ходатайствовать о компенсации' does not appear in the Russian sentence. 'обратиться за компенсацией' is not a direct synonym or closely related term.",
#       "suggestedFixSentence": "Пострадавший может ходатайствовать о компенсации в страховой компании. ",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3985,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'возмещать, компенсировать' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Страховая компания обещала возместить весь ущерб.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3986,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'войти по банковским реквизитам' does not occur in the Russian sentence.",
#       "suggestedFixSentence": "Вы можете войти по банковским реквизитам для идентификации себя в онлайн-банкинге.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3989,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'удостоверение личности' should appear in some form in the Russian sentence. Currently, 'ID карта' is used instead.",
#       "suggestedFixSentence": "Можешь показать мне своё удостоверение личности, пожалуйста?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3992,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is understandable but not entirely natural. A more natural construction would be 'Мне нужен вид на жительство, чтобы я мог жить в Финляндии.'",
#       "suggestedFix": "Мне нужен вид на жительство, чтобы я мог жить в Финляндии."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'разрешение на проживание' is not a direct translation of 'вид на жительство'. 'Вид на жительство' should be used instead.",
#       "suggestedFixSentence": "Мне нужен вид на жительство, чтобы я мог жить в Финляндии.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 3999,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates to 'Это действительно важный вопрос для меня.' which means 'This is a really important issue for me'. The word 'вопрос' should align with 'asia' for accurate correspondence.",
#       "suggestedFix": "Это действительно важное дело для меня."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'дело' does not appear in the Russian sentence. The sentence uses 'вопрос' which means 'question' instead of 'дело'.",
#       "suggestedFixSentence": "Это действительно важное дело для меня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4000,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'нынешний' does not appear in the sentence. The term 'текущее' is used instead.",
#       "suggestedFixSentence": "Моё нынешнее местоположение – в Хельсинки.",
#       "suggestedFixWord": "нынешний, текущий"
#     }
#   }
# }
# {
#   "id": 4006,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not explicitly use the word 'основной, базовый'.",
#       "suggestedFixSentence": "Важно освоить основные понятия, прежде чем переходить к более сложным заданиям.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4007,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "Слово 'широкий' используется корректно, однако слово 'расширенный' не фигурирует в предложении.",
#       "suggestedFixSentence": "Компания предлагает расширенный ассортимент продуктов и услуг.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4008,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "В предложении опечатка: 'растояние' должно быть 'расстояние'.",
#       "suggestedFix": "Сохраняйте безопасное расстояние"
#     }
#   }
# }
# {
#   "id": 4010,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a grammatical error. The correct form of 'vaatia' should be 'vaatii'.",
#       "suggestedFix": "Tämä työ vaatii paljon aikaa ja kärsivällisyyttä."
#     }
#   }
# }
# {
#   "id": 4011,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'движимое имущество' or a synonym does not appear in the Russian sentence. However, the sentence is natural as is.",
#       "suggestedFixSentence": "Страховка жилья покрывает ущерб движимому имуществу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4012,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence is grammatically correct but does not use the given word 'ущерб движимому имуществу' directly.",
#       "suggestedFix": "У тебя есть страховка, которая покрывает ущерб движимому имуществу?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The specific term 'ущерб движимому имуществу' is not used in the Russian sentence.",
#       "suggestedFixSentence": "У тебя есть страховка, которая покрывает ущерб движимому имуществу?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4018,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a minor grammatical issue. The phrase 'miten voin saada niitä?' is slightly incorrect.",
#       "suggestedFix": "Olen unohtanut pankkitunnukset, miten voin saada ne takaisin?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence does not accurately translate the meaning of the Russian sentence. It misses the aspect of 'restoring' or 'recovering' the codes.",
#       "suggestedFix": "Olen unohtanut pankkitunnukset, miten voin palauttaa ne?"
#     }
#   }
# }
# {
#   "id": 4023,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word given in Russian is a complete sentence and not a singular word. It should be a singular word like 'кататься' or 'лыжи'.",
#       "suggestedFixSentence": "Я не катался на лыжах, но много раз катался на коньках.",
#       "suggestedFixWord": "кататься"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word given in Finnish is a complete sentence and not a singular word. It should be a singular word like 'hiihtää' or 'luistella'.",
#       "suggestedFix": "hiihtää"
#     }
#   }
# }
# {
#   "id": 4024,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'я прочитал' in Russian doesn't appear in the exact form in the sentence. The provided sentence uses 'прочитал,' but 'я' is implicit, attached to the verb 'прочитал'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "прочитал"
#     }
#   }
# }
# {
#   "id": 4027,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы прочитали' does not appear in the Russian sentence. The word used is 'прочли'.",
#       "suggestedFixSentence": "Мы уже дважды прочитали эту книгу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4028,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вы прочитали' does not appear in any form in the sentence. The sentence uses 'прочли', which is a different form of the verb.",
#       "suggestedFixSentence": "Вы уже прочитали все книги.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4030,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'я не прочитал' does not exactly appear in the sentence. However, 'прочитал' is a form of the verb and 'я' is also present.",
#       "suggestedFixSentence": "Извините, я ещё не успел прочитать эту книгу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4031,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ты не прочитал' does not appear in the sentence 'Ты ещё не читал эту книгу.' Though 'читал' is a close synonym, the exact word usage is missing.",
#       "suggestedFixSentence": "Ты ещё не прочитал эту книгу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4033,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы не прочли' does not appear in the sentence. A more natural synonym phrase 'мы ещё не прочитали' has been used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "мы не прочли, мы ещё не прочитали"
#     }
#   }
# }
# {
#   "id": 4035,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'они ещё не прочитали' does not exactly appear in the Russian sentence, although its components do.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "не прочитали"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'he eivät ole lukeneet' does not exactly appear in the Finnish sentence, although its components do.",
#       "suggestedFix": "eivät ole lukeneet"
#     }
#   }
# }
# {
#   "id": 4038,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Se on lukenu tämän kirjan monta kertaa.' is incorrect. The correct form should be 'Se on lukenut tämän kirjan monta kertaa.' as 'lukenu' is a colloquial form.",
#       "suggestedFix": "Se on lukenut tämän kirjan monta kertaa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from the corrected Finnish sentence 'Se on lukenut tämän kirjan monta kertaa.' to the Russian sentence is generally accurate, but 'он прочитал' would translate to 'he has read' which indicates the perfective aspect. The Russian sentence uses the imperfective aspect 'читал'.",
#       "suggestedFix": "To match the perfective aspect, the Russian sentence should be changed to 'Он прочитал эту книгу много раз.'"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'он прочитал' does not occur in the given Russian sentence. The sentence uses 'он читал', which suggests an imperfective aspect instead of the perfective aspect that 'прочитал' implies.",
#       "suggestedFixSentence": "Он прочитал эту книгу много раз.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'se on lukenu' does not occur in the given Finnish sentence. The correct form 'se on lukenut' should be used.",
#       "suggestedFix": "se on lukenut"
#     }
#   }
# }
# {
#   "id": 4039,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Kirjastossa me ollaan luettu paljon kirjoja.' is not grammatically correct. A more natural sentence would use 'olemme' instead of 'ollaan' in this context.",
#       "suggestedFix": "Kirjastossa me olemme lukeneet paljon kirjoja."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is close but 'мы прочитали' translates more exactly to 'olemme lukeneet' rather than 'ollaan luettu'.",
#       "suggestedFix": "Kirjastossa me olemme lukeneet paljon kirjoja."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы читали' does not appear in the sentence in any form. The verb form 'продчитали' is used instead.",
#       "suggestedFixSentence": "В библиотеке мы читали много книг.",
#       "suggestedFixWord": "мы прочитали"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me ollaan luettu' does appear in the sentence, but it could be made more grammatically correct.",
#       "suggestedFix": "me olemme lukeneet"
#     }
#   }
# }
# {
#   "id": 4040,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The phrase 'вы уже прочитали' fully matches the word in Russian provided, but the context suggests that 'прочитали' alone covers the intended meaning.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вы прочитали"
#     }
#   }
# }
# {
#   "id": 4041,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses colloquial and somewhat dialectal forms ('lukenu' instead of 'lukenut' and 'ne' instead of 'he'). It should be adjusted to standard Finnish.",
#       "suggestedFix": "Tiedätkö, että he ovat lukeneet kaikki nämä artikkelit jo?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate because the Finnish sentence uses a colloquial style whereas the Russian sentence does not.",
#       "suggestedFix": "Tiedätkö, että he ovat jo lukeneet kaikki nämä artikkelit?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'lukenu' should be corrected to the standard Finnish form 'lukeneet' to match the provided sentence.",
#       "suggestedFix": "lukenut"
#     }
#   }
# }
# {
#   "id": 4042,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'я не читал' does not appear in the sentence. Instead, 'я ещё не прочитал' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "я ещё не прочитал"
#     }
#   }
# }
# {
#   "id": 4044,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'он не прочитал' does not occur in any form in the Russian sentence. To maintain accuracy, a synonym or related form should be used.",
#       "suggestedFixSentence": "Он ещё не прочитал этот отчет.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4045,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Me ei olla luettu sitä kirjaa vielä.' is grammatically incorrect. The correct form should be 'Me emme ole lukeneet sitä kirjaa vielä.'",
#       "suggestedFix": "Me emme ole lukeneet sitä kirjaa vielä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы ещё не прочитали' does not appear in the sentence. The sentence uses 'читали', but the expected word is 'прочитали'.",
#       "suggestedFixSentence": "Мы ещё не прочитали эту книгу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4046,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is not grammatically correct or natural. 'oo lukenu' is colloquial and should be 'ole lukenut'.",
#       "suggestedFix": "Miksi te ette ole lukenut läksyjään?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence implies that the Finnish translation should be using past tense in a completed sense, which is 'olette lukeneet' in standard Finnish.",
#       "suggestedFix": "Miksi te ette ole lukeneet läksyjään?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'oo lukenu' does not match the expected form of past tense 'ole lukenut' in standard Finnish.",
#       "suggestedFix": "ole lukenut"
#     }
#   }
# }
# {
#   "id": 4047,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Russian 'они не читали' is not used explicitly in the sentence. The sentence uses 'они не прочитали', which is a perfective aspect.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "они не читали, они не прочитали"
#     }
#   }
# }
# {
#   "id": 4051,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish translation does not exactly match the provided Russian text. The Russian sentence translates to 'I have lived and continue living in Paris all my life,' while the Finnish sentence translates as 'I have lived in Paris all my life.'",
#       "suggestedFix": "Olen asunut ja jatkan asua Pariisissa koko elämäni."
#     }
#   }
# }
# {
#   "id": 4059,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The provided sentence is incomplete and contains a parenthesis with 'Я живу' which is unrelated to the primary translation.",
#       "suggestedFix": "Когда ты родился? - Я родился в 1995 году."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The provided sentence is incomplete and contains a parenthesis with 'Minä elän' which is unrelated to the primary translation.",
#       "suggestedFix": "Milloin sinä olet syntynyt? - Minä olen syntynyt vuonna 1995."
#     }
#   }
# }
# {
#   "id": 4066,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence provided is not a single word but rather a full sentence. The issue seems to be that there is no separate sentence given for evaluation.",
#       "suggestedFix": "When Pedro writes a letter in Finnish, he asks Hannah for help."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence provided is not a single word but rather a full sentence. The issue seems to be that there is no separate sentence given for evaluation.",
#       "suggestedFix": "When Pedro writes a letter in Finnish, he asks Hannah for help."
#     }
#   }
# }
# {
#   "id": 4074,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Вот книга, из которой ты можешь научиться финскому.' is not using the word 'от которого,' but rather 'из которой.'",
#       "suggestedFix": "Вот книга, от которого ты можешь научиться финскому."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Tässä on kirja, jolta voit oppia suomea.' is not natural in Finnish. 'Jolta' is used with people, not inanimate objects like a book.",
#       "suggestedFix": "Tässä on kirja, josta voit oppia suomea."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation accuracy is compromised because 'от которого' implies a source (typically a person), but 'jolta' should be used with animate entities.",
#       "suggestedFix": "Use 'из которого' instead of 'от которого' for a book."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'от которого' does not appear in the given Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "из которого"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'jolta' does not fit the context of learning from a book in Finnish.",
#       "suggestedFix": "josta"
#     }
#   }
# }
# {
#   "id": 4077,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Olen menossa johonkuhun, joten en voi auttaa sinua nyt.' is not correct. 'johonkuhun' means 'into someone' and does not fit the context of the sentence.",
#       "suggestedFix": "Olen menossa jonnekin, joten en voi auttaa sinua nyt."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'johonkuhun' is not used correctly in the Finnish sentence. 'johonkuhun' should be 'jonnekin' to fit the context of going somewhere.",
#       "suggestedFix": "jonnekin"
#     }
#   }
# }
# {
#   "id": 4078,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'jossakussa' is not appropriate or correct in this context. The correct word should be 'jossain', which means 'somewhere'.",
#       "suggestedFix": "Kauppakeskus on jossain kaupungin keskustan tuntumassa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'jossakussa' is incorrect and doesn't translate accurately to 'где-то'. The corrected word 'jossain' should be used instead.",
#       "suggestedFix": "Word in Finnish: jossain"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'jossakussa' is inappropriate for this context and should be replaced with 'jossain'.",
#       "suggestedFix": "Kauppakeskus on jossain kaupungin keskustan tuntumassa."
#     }
#   }
# }
# {
#   "id": 4079,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän ajattelee jostakusta erityisestä.' is not completely correct. In Finnish, the expression should be 'jostakusta erityisestä henkilöstä' to sound more natural.",
#       "suggestedFix": "Hän ajattelee jostakusta erityisestä henkilöstä."
#     }
#   }
# }
# {
#   "id": 4082,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'у кого-то' does not appear in the sentence. Instead, 'у кого-нибудь' is used. This affects the sentence.",
#       "suggestedFixSentence": "Мог бы ты спросить у кого-то, где я найду ближайший банкомат?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4087,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Мог бы ты дать мне что-нибудь(какой-то предмет), чем я могу писать?' is not grammatically natural. The use of 'что-нибудь' together with 'какой-то предмет' is redundant.",
#       "suggestedFix": "Мог бы ты дать мне какой-то предмет, чем я могу писать?"
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Voisitko antaa minulle jokin esine, jolla voin kirjoittaa?' is not correct. It should be 'jonkin esineen' in the partitive case to be grammatically correct.",
#       "suggestedFix": "Voisitko antaa minulle jonkin esineen, jolla voin kirjoittaa?"
#     }
#   }
# }
# {
#   "id": 4092,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of the Russian sentence to Finnish is accurate, but the word context 'откуда-нибудь' and 'jostakin' don't match completely. 'Мог бы ты рассказать мне о какой-нибудь интересной книге?' translates into 'Voisitko kertoa minulle jostakin mielenkiintoisesta kirjasta?', which is accurate if the word used was 'какой-нибудь' instead of 'откуда-нибудь'. 'Откуда-нибудь' translates more closely to 'from somewhere' or 'from anywhere'.",
#       "suggestedFix": null
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'откуда-нибудь' doesn't appear in the Russian sentence. The sentence instead uses 'какой-нибудь', which is appropriate for the context.",
#       "suggestedFixSentence": "Мог бы ты рассказать мне откуда-нибудь о какой-нибудь интересной книге?",
#       "suggestedFixWord": "какой-нибудь, откуда-нибудь"
#     }
#   }
# }
# {
#   "id": 4096,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has an issue with the past tense, while the original Russian sentence uses a timeless present tense.",
#       "suggestedFix": "Jotkin salaisuudet ovat liian tärkeitä säilytettäviksi."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence speaks about the importance of keeping secrets in the present tense, while the Finnish sentence implies these secrets were important in the past.",
#       "suggestedFix": "Jotkin salaisuudet ovat liian tärkeitä säilytettäviksi."
#     }
#   }
# }
# {
#   "id": 4100,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'никто' does not appear in the Russian sentence. The phrase uses 'Ни один человек', which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "никто / ни один человек"
#     }
#   }
# }
# {
#   "id": 4103,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'ничьи' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Я не хочу обижать ничьи чувства.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4107,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'никому' does not appear in the provided Russian sentence. The sentence uses 'кому-либо', which is a valid synonym, but the task requires the use of 'никому'.",
#       "suggestedFixSentence": "Я не хочу доставлять беспокойство никому.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4108,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The phrase 'У никого не было лишней ручки' is not grammatical. The correct phrase should be 'Ни у кого не было лишней ручки' which aligns with the negative expression.",
#       "suggestedFix": "Ни у кого не было лишней ручки."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ни у кого' should appear in the sentence. The phrase 'У никого' is incorrect.",
#       "suggestedFixSentence": "Ни у кого не было лишней ручки.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4113,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'это не что-то (вещь, предмет)' does not appear in any form in the Russian sentence. A synonym or related term needs to be included.",
#       "suggestedFixSentence": "Это не просто вещь, это моя первая книга.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4114,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence contains a typographic mistake 'ни какая'. The correct form should be 'никакая'.",
#       "suggestedFix": "Это никакая не шутка!"
#     }
#   }
# }
# {
#   "id": 4116,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Я не могу найти ткань какого-либо цвета.' is grammatically correct but not natural. A more natural way to say this would be 'Я не могу найти ткань ни одного цвета.'",
#       "suggestedFix": "Я не могу найти ткань ни одного цвета."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'никакого' does not appear in the Russian sentence. A possible synonym for 'никакого' could be used to fit the sentence context more naturally.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "никакого, какого-либо"
#     }
#   }
# }
# {
#   "id": 4120,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence means 'Underpants have no value for me.' while the Finnish sentence means 'I don't give value to any cowards.' There is a mismatch in meaning.",
#       "suggestedFix": "En anna arvoa millekään vaatteille."
#     }
#   }
# }
# {
#   "id": 4122,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Не чувствуется ничего.' is grammatically correct but sounds unnatural. A more natural way to express this would be 'Ничего не чувствуется.'",
#       "suggestedFix": "Ничего не чувствуется."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The Russian sentence does not convey the same meaning as the word 'miltään' which implies a lack of feeling from anything.",
#       "suggestedFix": "Не чувствуется от чего-либо."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'от чего-либо' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Не чувствуется от чего-либо.",
#       "suggestedFixWord": null
#     }
#   }
# }

# %%
# Example usage
chapter_name = 'sm2_new_kap6'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 4127,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'участвовать' does not appear in the sentence. Instead 'принять участие' (to take part) is used.",
#       "suggestedFixSentence": "Я хотел бы участвовать в этом мероприятии.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4128,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'круг' is used in the sentence, but the given word 'обход' is not used.",
#       "suggestedFixSentence": "Мы сделаем ещё один обход по городу перед возвращением домой.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4131,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'помолвиться' is not quite synonymous with 'обручиться' and sounds less formal. Also, the preposition before 'следующую весну' should be 'на' instead of 'в'.",
#       "suggestedFix": "Они решили обручиться на следующую весну."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обручиться' does not appear in the Russian sentence. The sentence should be adjusted to use 'обручиться'.",
#       "suggestedFixSentence": "Они решили обручиться на следующую весну.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4133,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'долго' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Как долго тебе потребуется, чтобы завершить работу?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4134,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'недоделанный' does not appear in the Russian sentence. The word 'недочитанной' (left unread) is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "недоделанный, недочитанный"
#     }
#   }
# }
# {
#   "id": 4139,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is grammatically incorrect. The word 'ensimmäiseksi' should be 'ensi' to sound natural.",
#       "suggestedFix": "Ennen kuin aloitat, sinun pitäisi laittaa turvavyösi ensi."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ensimmäiseksi' is not used naturally in the given context. 'Ensi' would be more appropriate in this context.",
#       "suggestedFix": "Ensi"
#     }
#   }
# }
# {
#   "id": 4142,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'подружка невесты' does not appear in the sentence.",
#       "suggestedFixSentence": "Нередко лучшая подружка невесты – это её подруга.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4143,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'свидетель' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Свидетель является лучшим другом жениха.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4146,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish is grammatically incorrect. The correct form should be 'Minun sukulaiseni asuu Helsingissä.' Using 'sukulainen' requires a possessive suffix because in Finnish, possessive forms are often marked with suffixes.",
#       "suggestedFix": "Minun sukulaiseni asuu Helsingissä."
#     }
#   }
# }
# {
#   "id": 4153,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'vilu' typically means 'cold' or 'chill' in a more general sense, not specifically the state of feeling cold as 'холодно' in Russian. The correct Finnish word for 'feeling cold' in this specific context would be 'kylmä.'",
#       "suggestedFix": "Minulla on kylmä, voisitko sulkea ikkunan?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vilu' is not appropriately used in this context as it doesn't specifically mean 'feeling cold.'",
#       "suggestedFix": "Minulla on kylmä, voisitko sulkea ikkunan?"
#     }
#   }
# }
# {
#   "id": 4154,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Kaverini on opettanut minua ommella vaatteita.' contains a grammatical error. In Finnish, the correct form should be 'Kaverini on opettanut minut ompelemaan vaatteita.'",
#       "suggestedFix": "Kaverini on opettanut minut ompelemaan vaatteita."
#     }
#   }
# }
# {
#   "id": 4155,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Mistä voin ostaa hääpukuni?' is not entirely correct. 'Hääpukuni' means 'my wedding dress,' implying possession, which is not present in the Russian sentence.",
#       "suggestedFix": "Mistä voin ostaa hääpuvun?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'свадебный костюм' in Russian translates to 'hääpuku' (wedding dress) or 'morsiuspuku' in Finnish. The Russian sentence does not imply possession, while the Finnish sentence has a possessive form. There's a mismatch in terms of the type of dress being referred to.",
#       "suggestedFix": "Use 'hääpuvun' instead of 'hääpukuni' or adjust the Russian word and sentence."
#     }
#   }
# }
# {
#   "id": 4159,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence means 'You’ll be invited to the table at 18:00.', while the Finnish sentence means 'Dinner starts at 18:00', which is not the same.",
#       "suggestedFix": "Kutsu illalliselle on klo 18.00."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'подача блюд, приглашение к столу' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Подача блюд начнется в 18:00.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4160,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'по мнению всех' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "По мнению всех, эта книга действительно захватывающая.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4161,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'произносить речь' does not occur in the Russian sentence. However, 'произносить речь' is synonymous with 'произнести речь' and they both mean 'to give a speech.'",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "произносить речь, произнести речь"
#     }
#   }
# }
# {
#   "id": 4162,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish verb 'tulkata' specifically means 'to interpret' (as in verbal translation), whereas 'перевести' in Russian translates to 'to translate' generally. The contextually more accurate Finnish translation for 'перевести' in this sentence should be 'kääntää'.",
#       "suggestedFix": "Voisitko kääntää tämän lauseen minulle?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'tulkata' is not the most accurate translation for 'перевести' in this context. 'Kääntää' would be a better choice.",
#       "suggestedFix": "kääntää"
#     }
#   }
# }
# {
#   "id": 4163,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun täytyy valmistella huomisen esitystä.' translates to 'I need to prepare tomorrow's presentation.' which would align more with 'Мне нужно подготовить завтрашнюю презентацию.' in Russian.",
#       "suggestedFix": "Minun täytyy valmistautua huomisen esitykseen."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'подготовить' does not appear in the sentence; instead, a reflexive form 'подготовиться' is used.",
#       "suggestedFixSentence": "Мне нужно подготовить завтрашнюю презентацию.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4171,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'чувствовать' is not used in the sentence 'Мне кажется, что я учу финский язык быстро.' Only 'казаться' is used.",
#       "suggestedFixSentence": "чувствую, что я учу финский язык быстро.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4172,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'поладить' does not appear in the Russian sentence. A synonym 'ладить' is used instead.",
#       "suggestedFixSentence": "Нам нужно поладить друг с другом.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4173,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Большое удовольствие встретить тебя.' is grammatically correct but may sound slightly unnatural compared to 'Большая радость встретить тебя.'",
#       "suggestedFix": "Большая радость встретить тебя."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The original sentence does not use the word 'радость'.",
#       "suggestedFixSentence": "Большая радость встретить тебя.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4180,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun miestystäväni, naistystäväni tai kumppanini on tulossa käymään huomenna.' contains a typo: 'miestystäväni' should be 'miesystäväni' and 'naistystäväni' should be 'naisystäväni'. Furthermore, it's not common to list both 'miesystävä' and 'naisystävä' in this context in Finnish. The more common expressions would be either 'kumppani' or a combination of 'miesystävä/naisystävä'.",
#       "suggestedFix": "Minun kumppanini on tulossa käymään huomenna."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains 'miesystäväni' and 'naisystäväni', but they were typoed and hence are incorrect. The more common and natural expression here would be simply 'kumppanini'.",
#       "suggestedFix": "kumppanini"
#     }
#   }
# }
# {
#   "id": 4186,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a minor grammatical issue; it should be 'Hän on ollut eronnut jo vuosia.'",
#       "suggestedFix": "Hän on ollut eronnut jo vuosia."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'доблесный человек' does not accurately translate the Finnish sentence 'Hän on eronnut jo vuosia.'",
#       "suggestedFix": "Hän on ollut eronnut jo vuosia."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть разведённым' does not appear in the sentence in any form. The sentence uses 'разведён' instead. Either the word or sentence should be adjusted.",
#       "suggestedFixSentence": "Он уже годы как разведённый.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4187,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun täytyy erota työstäni ensi kuussa' translates to 'Мне нужно уволиться с работы в следующем месяце.' However, the Russian sentence provided is 'Мне нужно уйти с работы в следующем месяце,' which slightly changes the meaning from 'to quit' to 'to leave.'",
#       "suggestedFix": "Translations should be more precise."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'уволиться' does not appear in the provided Russian sentence. Synonyms or related terms should be used to keep the sentence accurate and natural.",
#       "suggestedFixSentence": "Мне нужно уволиться в следующем месяце.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4192,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'He ovat olla kihloissa jo kuusi kuukautta.' is not correct. The verb form 'ovat olla' is incorrect; it should just be 'ovat'.",
#       "suggestedFix": "He ovat olleet kihloissa jo kuusi kuukautta."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The phrase 'быть помолвленными' does not appear directly in the Russian sentence. The term 'помолвлены' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "помолвлены, быть помолвленными"
#     }
#   }
# }
# {
#   "id": 4194,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть женатым' is not directly used in the sentence. Instead, a related term 'женаты' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "быть женатым, женаты"
#     }
#   }
# }
# {
#   "id": 4196,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not contain the exact word 'союз двух мужчин или двух женщин'.",
#       "suggestedFixSentence": "Союз двух мужчин или двух женщин является законным в Финляндии.",
#       "suggestedFixWord": "союз двух мужчин или двух женщин, брак"
#     }
#   }
# }
# {
#   "id": 4201,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "Масленица в России является православным праздником, а не финским. Предложение звучит неестественно.",
#       "suggestedFix": "Масленица в феврале — это традиционный русский праздник."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "Mikulaisen helmikuussa ei ole perinteinen suomalainen juhla, vaan venäläinen. Suomalaisen kontekstin takaamiseksi lause on käännettävä oikein.",
#       "suggestedFix": "Maseleeni helmikuussa on perinteinen venäläinen juhla."
#     }
#   }
# }
# {
#   "id": 4202,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'пасху празднуют в марте-апреле' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Пасху празднуют в марте-апреле — важный праздник в Финляндии.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'pääsiäinen maalis-huhtikuussa' does not appear in any form in the Finnish sentence.",
#       "suggestedFix": "Pääsiäistä vietetään maalis-huhtikuussa; se on tärkeä juhla Suomessa."
#     }
#   }
# }
# {
#   "id": 4203,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'Первомай' does not appear in the sentence in Russian. A synonym or a related term should be used.",
#       "suggestedFixSentence": "Первомай — это праздник весны, труда и студентов.",
#       "suggestedFixWord": "Первомай, праздник труда"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vappu 1.5.' does not appear in the sentence in Finnish. The word should be adjusted.",
#       "suggestedFix": "vappu"
#     }
#   }
# }
# {
#   "id": 4204,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'день Ивана Купалы (Юханнус) празднуют в июне' is not used in the sentence in any form.",
#       "suggestedFixSentence": "День Ивана Купалы в июне – популярное время для путешествия в Финляндию.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4206,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'рождественские корпоративы в ноябре-декабре' does not occur in the provided Russian sentence.",
#       "suggestedFixSentence": "У нас рождественские корпоративы в ноябре-декабре.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4207,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сочельник' (Christmas Eve) does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Мы отмечаем сочельник вместе с семьёй дома.",
#       "suggestedFixWord": "сочельник"
#     }
#   }
# }
# {
#   "id": 4208,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence refers to 'veljeni vauvalle' (my brother's baby), whereas the Russian sentence refers to 'моего племянника' (my nephew).",
#       "suggestedFix": "Vanhempani järjestävät veljeni vauvalle ristiäiset ensi viikonloppuna -> Vanhempani järjestävät serkulleni ristiäiset ensi viikonloppuna."
#     }
#   }
# }
# {
#   "id": 4210,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence uses 'празднование' instead of 'праздник'. It is grammatically correct but does not match the given word.",
#       "suggestedFix": "Праздник конфирмации является важным событием в жизни молодого человека."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The given word 'праздник конфирмации' does not occur in the sentence. Instead, 'празднование' is used.",
#       "suggestedFixSentence": "Праздник конфирмации является важным событием в жизни молодого человека.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4214,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'He kutsuivat minut heidän kihlajaisiin.' is not fully natural in Finnish. The pronoun 'heidän' should be 'heidän' in Finnish vocabulary but normally used pronoun would be 'kutsui minut kihlajaisiinsa'. The correct form is 'He kutsuivat minut kihlajaisiinsa.'",
#       "suggestedFix": "He kutsuivat minut kihlajaisiinsa."
#     }
#   }
# }
# {
#   "id": 4215,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian translation 'Он подарил мне красивое кольцо на помолвку.' translates back to 'He gave me a beautiful ring for the engagement.' which is slightly different from 'Hän antoi minulle kauniin kihlasormuksen.' which means 'He gave me a beautiful engagement ring.'",
#       "suggestedFix": "Он подарил мне красивое кольцо в честь помолвки."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'кольцо в честь помолвки' does not appear directly in the sentence; the sentence uses 'кольцо на помолвку' instead.",
#       "suggestedFixSentence": "Он подарил мне красивое кольцо в честь помолвки.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4218,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kirkko (maistraatti)' appears in the Finnish sentence, but 'maistraatti' is not necessary here and confuses the meaning.",
#       "suggestedFix": "kirkko"
#     }
#   }
# }
# {
#   "id": 4219,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence should use the correct form of the verb 'vihkiä', which is 'vihkii' in this context. Additionally, the verb should agree in tense and number with the subject.",
#       "suggestedFix": "Pappi vihkii heidät kirkossa ensi lauantaina."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'венчать' in its base form does not occur in the Russian sentence. Instead, the conjugated form 'повенчает' is used. While it is correct, for learning purposes, it might be better to include the base form.",
#       "suggestedFixSentence": "Священник будет венчать их в церкви в следующую субботу.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vihkiä' in its base form does not occur in the Finnish sentence. The sentence should be corrected to use the base form, making it more educationally appropriate for the context.",
#       "suggestedFix": null
#     }
#   }
# }
# {
#   "id": 4220,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'syntymäpäivä' appears in the Finnish sentence, but it does not match 'syntymäpäivät, synttärit' provided in the word translation.",
#       "suggestedFix": "syntymäpäivä, synttärit"
#     }
#   }
# }
# {
#   "id": 4227,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'дело' is not used in the sentence. The sentence 'Это интересная история.' only includes the word 'история.'",
#       "suggestedFixSentence": "Это интересное дело.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4228,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "Although both sentences are grammatical and natural, 'группа' is more accurately translated to 'ryhmä' in Finnish, while 'bändi' specifically refers to a music band, aligning with the sentence context.",
#       "suggestedFix": "Word in Finnish: bändi"
#     }
#   }
# }
# {
#   "id": 4241,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minua naurattaa kun katson komediashowta.' contains a minor grammatical error. A comma should be added before 'kun'.",
#       "suggestedFix": "Minua naurattaa, kun katson komediashowta."
#     }
#   }
# }
# {
#   "id": 4242,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'очень' does not appear in the sentence. Although 'много' (a lot) is used correctly in the context, 'очень' (very) is another word that needs to be incorporated.",
#       "suggestedFixSentence": "Он работает очень много для достижения своих целей.",
#       "suggestedFixWord": "очень, много"
#     }
#   }
# }
# {
#   "id": 4243,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Ostin kaupasta muutama omena.' is incorrect. The word 'muutama' should be in its partitive form 'muutamia' to match the plural and partitive case required for 'omena'.",
#       "suggestedFix": "Ostin kaupasta muutamia omenia."
#     }
#   }
# }
# {
#   "id": 4247,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'успокоиться' or 'утихнуть' does not appear in the sentence.",
#       "suggestedFixSentence": "Когда вошла учительница, класс успокоился.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4248,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'понять' does not appear in the Russian sentence. 'понимаю' is a form of 'понимать', which is related but not the same verb.",
#       "suggestedFixSentence": "Я не могу понять, как работает это устройство.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4249,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate because 'olla pahoillaan' translates to 'быть расстроенным' or 'сожалеть'. The Russian sentence does not convey this apology.",
#       "suggestedFix": "Мне очень жаль, но у меня сегодня нет времени на встречу."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть расстроенным' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Я расстроен, но у меня сегодня нет времени на встречу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4253,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Hän vitsillä ja kaikki nauroivat.' is not grammatically correct. The correct phrasing should be 'Hän kertoi vitsin ja kaikki nauroivat.'",
#       "suggestedFix": "Hän kertoi vitsin ja kaikki nauroivat."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate. The Russian sentence 'Он рассказал хорошую шутку, и все смеялись.' should be translated as 'Hän kertoi hyvän vitsin, ja kaikki nauroivat.'",
#       "suggestedFix": "Hän kertoi hyvän vitsin, ja kaikki nauroivat."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'шуткой' does not appear in the Russian sentence. A synonym or related term like 'шутка' is used instead.",
#       "suggestedFixSentence": "Он рассказал хорошую шутку, и все смеялись.",
#       "suggestedFixWord": "шуткой, шутка"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vitsillä' does not make sense in the context of the Finnish sentence. A related term 'vitsi' should be used.",
#       "suggestedFix": "vitsi"
#     }
#   }
# }
# {
#   "id": 4254,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains a grammatical issue. The word 'просят' is not typically used in this context. Additionally, it’s unclear who is being referenced by the word 'они'. A more common phrase would use a different verb form.",
#       "suggestedFix": "Извините, где здесь можно оплатить счёт?"
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The use of 'ne pyytää' is not standard in Finnish; 'he pyytävät' should be used for the pronoun 'they'. Moreover, it is not a natural way to ask where to pay a bill.",
#       "suggestedFix": "Anteeksi, missä täällä voi maksaa laskun?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation does not accurately reflect the original Russian sentence, especially since the pronouns and verb forms are incorrect.",
#       "suggestedFix": "Anteeksi, missä täällä voi maksaa laskun?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'они просят' does not appear naturally in the context of asking where to pay a bill. A more appropriate phrase would be 'где здесь можно оплатить счёт?'",
#       "suggestedFixSentence": "Извините, где здесь можно оплатить счёт?",
#       "suggestedFixWord": "заплатить"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne pyytää' is not appropriate in this context. 'He pyytävät' would be the correct conjugation, but even then, the sentence would be awkward. It's better to restructure it.",
#       "suggestedFix": "he pyytävät, maksaa"
#     }
#   }
# }
# {
#   "id": 4259,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'моя книга' does not appear in the sentence. However, the word 'свою книгу' is used, which is a related term.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "моя книга, своя книга"
#     }
#   }
# }
# {
#   "id": 4260,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'твоё имя' does not appear in the Russian sentence. A synonym like 'имя' should be included to match the flashcard.",
#       "suggestedFixSentence": "Как твоё имя?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4261,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The usage of 'hänen' in 'Hän unohti hänen avaimensa kotiin.' is incorrect because it implies that the keys belong to someone else. It should be 'Hän unohti avaimensa kotiin.'",
#       "suggestedFix": "Hän unohti avaimensa kotiin."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'его ключи' does not appear in the Russian sentence. Instead, 'свои ключи' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "свои ключи"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'hänen avaimesa' is used incorrectly in the Finnish sentence. The correct form to imply possession by the subject would be 'avaimensa'.",
#       "suggestedFix": "avaimensa"
#     }
#   }
# }
# {
#   "id": 4266,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "While the sentence is mostly correct, using 'teiän' is very informal and dialectal (typically used in spoken language). The standard written form would be 'teidän'.",
#       "suggestedFix": "Anteeksi, mutta uskon, että teidän lippu on pudonnut maahan."
#     }
#   }
# }
# {
#   "id": 4267,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Voitko kertoa minulle niiden osoite?' is grammatically incorrect. It should be 'Voitko kertoa minulle niiden osoitteen?' to properly use the genitive case for 'address.'",
#       "suggestedFix": "Voitko kertoa minulle niiden osoitteen?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'niiden osoite' should be in the genitive form to fit naturally in the sentence.",
#       "suggestedFix": "niiden osoitteen"
#     }
#   }
# }
# {
#   "id": 4270,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Missä on taloasi?' is not grammatically correct or natural in Finnish. The correct form should be 'Missä talosi on?'",
#       "suggestedFix": "Missä talosi on?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'taloasi' does not occur in the correct form and context in the Finnish sentence. The correct word should be 'talosi'.",
#       "suggestedFix": "talosi"
#     }
#   }
# }
# {
#   "id": 4271,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish is grammatically incorrect. The correct phrase should be 'kaupungin ulkopuolella', not 'kaupungistanne ulkopuolella'.",
#       "suggestedFix": "Onko tämä ensimmäinen kerta, kun vierailette kaupungin ulkopuolella?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вашего города' is present, but the intended phrase 'из вашего города' is not used. For semantic accuracy, the word or phrase should match the flashcard prompt.",
#       "suggestedFixSentence": "Это первый раз, когда вы посещаете места из-за вашего города?",
#       "suggestedFixWord": "вашего города"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kaupungistanne' is present in the sentence but used incorrectly.",
#       "suggestedFix": "kaupungin"
#     }
#   }
# }
# {
#   "id": 4272,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Hän viettää iltaa hänen ystävänsä kanssa.' is grammatically incorrect. The pronoun 'hänen' should not be repeated; it should be 'ystävänsä kanssa'.",
#       "suggestedFix": "Hän viettää iltaa ystävänsä kanssa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The exact phrase 'его друг' is not used in the sentence. Instead, a form of 'свой' is used, which is more natural in this context. Using 'его друг' in the sentence would make it less natural.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "свой друг"
#     }
#   }
# }
# {
#   "id": 4280,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided Finnish sentence 'Oliko Aino eilen Johanna juhlissa?' translates to 'Was Aino at Johanna's party yesterday?' The Russian phrase 'Айно была вчера на вечеринке у Йоханны?' closely matches this translation in terms of meaning, but there's no literal translation of 'Was Aino yesterday at Johanna's party?'",
#       "suggestedFix": "Is the translation of the meaning and intent accurate, despite the structural difference?"
#     }
#   }
# }
# {
#   "id": 4283,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence should be in a conditional form to correctly convey the meaning. It should be 'Jos olisit lukenut ohjeet huolellisesti, et olisi tehnyt virhettä.'",
#       "suggestedFix": "Jos olisit lukenut ohjeet huolellisesti, et olisi tehnyt virhettä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'olit lukenut' should be in a conditional form for proper usage in the given context.",
#       "suggestedFix": "olisit lukenut"
#     }
#   }
# }
# {
#   "id": 4285,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The verb 'прочли' is a bit unnatural in this context. 'Прочитали' would be a more commonly used form.",
#       "suggestedFix": "На летних каникулах мы прочитали все книги о Гарри Поттере."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The correct past perfect form should be 'olimme lukeneet' instead of 'olimme lukenut'.",
#       "suggestedFix": "Kesälomalla olimme lukeneet kaikki Harry Potter -kirjat."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence correctly translates to 'Мы прочитали все книги о Гарри Поттере на летних каникулах'.",
#       "suggestedFix": "Kesälomalla olimme lukeneet kaikki Harry Potter -kirjat."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы прочитали' needs to be used in the Russian sentence to match the given word.",
#       "suggestedFixSentence": "На летних каникулах мы прочитали все книги о Гарри Поттере.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'olimme lukenut' needs to be changed to its correct form 'olimme lukeneet' to match the verb usage in the sentence.",
#       "suggestedFix": "olimme lukeneet"
#     }
#   }
# }
# {
#   "id": 4286,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Olitteko te lukenut tämän kirjan jo ennen?' is grammatically incorrect. The correct form should be 'Oletteko te lukeneet tämän kirjan jo aiemmin?'.",
#       "suggestedFix": "Oletteko te lukeneet tämän kirjan jo aiemmin?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is inaccurate because it changes the aspect from past perfect (olitte lukenut) to past (читали). The correct translation would involve 'вы прочитали'.",
#       "suggestedFix": "Вы прочитали эту книгу раньше?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'вы прочитали' does not appear in the sentence given. Instead, the past tense form 'читали' is used.",
#       "suggestedFixSentence": "Вы прочитали эту книгу раньше?",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'olitte lukenut' does not follow the correct grammar rules. The correct usage would involve 'olette lukeneet'.",
#       "suggestedFix": "olette lukeneet"
#     }
#   }
# }
# {
#   "id": 4287,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian has a small mistake. Instead of 'в школу,' it should be 'в школу.'",
#       "suggestedFix": "Они уже прочитали книгу до того, как мы получили её в школу."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish has a minor mistake. 'olivat lukenet' should be 'olivat lukeneet'.",
#       "suggestedFix": "He olivat lukeneet kirjan jo ennen kuin saimme sen kouluun."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'lukenet' is a typo and should be 'lukeneet' for the sentence to be correct.",
#       "suggestedFix": "lukeneet"
#     }
#   }
# }
# {
#   "id": 4288,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The Finnish sentence uses the past perfect tense to describe an action that wasn't completed before another action occurred, whereas the Russian sentence seems to describe the inability to read the book before it ended, which weakens the past perfect nuance.",
#       "suggestedFix": "Я не прочитал книгу, когда она закончилась."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'я не прочитал' does not appear in the Russian sentence. The sentence uses 'успел прочитать', which doesn't convey the same meaning.",
#       "suggestedFixSentence": "Я не прочитал книгу, когда она закончилась.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4289,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Ты не прочитал книгу, прежде чем отдал её мне.' translates more closely to 'You didn't finish reading the book before giving it to me' instead of 'You hadn't read the book before you gave it to me.' The Finnish sentence 'Et ollut lukenut kirjaa ennen kuin annoit sen minulle.' translates to 'You hadn't read the book before you gave it to me.'",
#       "suggestedFix": "Ты не читал книгу, прежде чем отдал её мне."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The phrase 'ты не прочитал' from the sentence does not exactly match the provided word 'ты не читал' although it is a correct form. For consistency with the word 'ты не читал', we can modify the sentence.",
#       "suggestedFixSentence": "Ты не читал книгу, прежде чем отдал её мне.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4291,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Emme olleet lukenet kirjaa.' is grammatically incorrect. The correct form is 'Emme olleet lukeneet kirjaa.'",
#       "suggestedFix": "Emme olleet lukeneet kirjaa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'emme olleet lukenet' is slightly incorrect. The correct form is 'emme olleet lukeneet' to match the grammatical tense.",
#       "suggestedFix": "emme olleet lukeneet"
#     }
#   }
# }
# {
#   "id": 4292,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вы не прочитали' does not appear in any form in the Russian sentence. A synonym or related term such as 'вы не читали' is used instead.",
#       "suggestedFixSentence": "Хотя вы не прочитали книгу, вы всё равно поняли её основные идеи.",
#       "suggestedFixWord": "вы не читали"
#     }
#   }
# }
# {
#   "id": 4294,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Russian 'я читал' does not appear in the sentence. Instead, 'прочитал' is used, which is the perfective form of 'читать'.",
#       "suggestedFixSentence": "Я уже читал эту книгу, прежде чем она стала популярной.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4296,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ты прочитал' does not occur in the given Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "прочитал"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'sä olit lukenu' does not occur in the given Finnish sentence. The given sentence uses the word 'olit lukenu', which is the same but without the colloquial form 'sä'.",
#       "suggestedFix": "olit lukenu"
#     }
#   }
# }
# {
#   "id": 4297,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ты ещё не прочитал' does not appear in the given Russian sentence. A related term 'ты её ещё не читал' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "ты ещё не читал"
#     }
#   }
# }
# {
#   "id": 4299,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän tarkisti kirjan, mutta se ei ollu lukenu sitä vielä.' has a few issues. It should be 'Hän tarkisti kirjan, mutta ei ollut lukenut sitä vielä.'",
#       "suggestedFix": "Hän tarkisti kirjan, mutta ei ollut lukenut sitä vielä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'он не прочитал' does not appear in its exact form in the sentence. However, it is implied semantically by 'не прочитал её'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "не прочитал"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'se ei ollu lukenu' does not appear in its exact form and is incorrect colloquially. The correct form should be 'ei ollut lukenut'.",
#       "suggestedFix": "ei ollut lukenut"
#     }
#   }
# }
# {
#   "id": 4300,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Kirjasta me oltiin luettu jo puolet ennen lomaa.' is not entirely grammatically correct. It should be 'Kirjasta olimme jo lukeneet puolet ennen lomaa.'",
#       "suggestedFix": "Kirjasta olimme jo lukeneet puolet ennen lomaa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not entirely accurate. The corrected Finnish sentence should be 'Kirjasta olimme jo lukeneet puolet ennen lomaa.', which translates to 'Мы уже прочли половину книги до отпуска.'",
#       "suggestedFix": "Kirjasta olimme jo lukeneet puolet ennen lomaa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы прочли' does not occur in the Russian sentence. The word 'прочитали' is its synonym and fits well into the sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "мы прочитали, мы прочли"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me oltiin luettu' does not fit well in the Finnish sentence. The correct form should be 'me olimme lukeneet'.",
#       "suggestedFix": "me olimme lukeneet"
#     }
#   }
# }
# {
#   "id": 4301,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish uses a colloquial form which can be seen as incorrect in standard written language. Correct standard form would be 'emme olleet lukeneet'.",
#       "suggestedFix": "Ennen matkaa, emme olleet lukeneet sitä karttaa kunnolla."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мы не прочли' does not appear in any form in the sentence. A synonym or related term should be used.",
#       "suggestedFixSentence": "Перед поездкой, мы не прочли этот план как следует.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me ei oltu luettu' does not appear in the correct standard form in the sentence. Correct form should be 'emme olleet lukeneet'.",
#       "suggestedFix": "emme olleet lukeneet"
#     }
#   }
# }
# {
#   "id": 4302,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a grammatical error. The correct form should be 'Mina huomasin, että te olitte lukeneet tuon kirjan jo aiemmin.' The verb should be in the past participle form 'lukeneet' instead of 'lukenu'.",
#       "suggestedFix": "Minä huomasin, että te olitte lukeneet tuon kirjan jo aiemmin."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вы прочитали' does not appear explicitly in the provided sentence. The verb 'прочитали' is used in the sentence but not with 'вы'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "прочитали"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'te olitte lukenu' is not grammatically correct in Finnish. The correct usage should be 'te olitte lukeneet'.",
#       "suggestedFix": "te olitte lukeneet"
#     }
#   }
# }
# {
#   "id": 4303,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains minor grammatical issues with the phrase 'прочли то электронное письмо'. It would be more natural to say 'прочитали то электронное письмо'.",
#       "suggestedFix": "Извините, но вы не прочитали то электронное письмо, которое я отправил вчера."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains grammatical errors. 'ollu' should be 'ollut' and 'lukenu' should be 'lukenut'.",
#       "suggestedFix": "Anteeksi, mutta te ette olleet lukeneet tuota sähköpostia, jonka lähetin eilen."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translations 'вы не прочли' and 'te ette ollu lukenu' are not accurate translations of each other. The corrected sentence in Finnish translates more accurately after fixing the grammar.",
#       "suggestedFix": "Suggested correction would be to adjust the Finnish sentence to ensure the meaning is consistent with the corrected Russian sentence."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вы не прочли' does not appear in the corrected sentence. 'Прочитали' is used instead to ensure the sentence is grammatically correct.",
#       "suggestedFixSentence": "Извините, но вы не прочитали то электронное письмо, которое я отправил вчера.",
#       "suggestedFixWord": "прочитали"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'te ette ollu lukenu' does not appear in the corrected sentence. 'Olette lukeneet' is used instead to ensure grammaticality.",
#       "suggestedFix": "te ette olleet lukeneet"
#     }
#   }
# }
# {
#   "id": 4304,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a grammatical error. 'Ne oli lukenu' should be 'Ne olivat lukeneet' to be grammatically correct.",
#       "suggestedFix": "Muistatko nuo kirjat? Ne olivat lukeneet jo viime viikolla."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'они прочитали' does not appear in the sentence. Instead, a synonym 'их уже прочитали' does appear.",
#       "suggestedFixSentence": "Ты помнишь эти книги? Они их уже прочитали на прошлой неделе.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'ne oli lukenu' does not appear in the corrected Finnish sentence. Instead, 'ne olivat lukeneet' is the correct form.",
#       "suggestedFix": "ne olivat lukeneet"
#     }
#   }
# }
# {
#   "id": 4307,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian translation 'Я жил здесь во многих городах.' translates to 'I've lived here in many cities,' which does not match the Finnish 'Olen asunut täällä monessa kaupungissa,' meaning 'I've lived here in many cities,' which should be more accurately translated to 'Я жил в этом городе много раз.'",
#       "suggestedFix": "Я жил в этом городе много раз."
#     }
#   }
# }

# %%
# Example usage
chapter_name = 'sm2_new_kap7'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 4335,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'собеседование' is used in the Russian sentence, which should be translated to 'job interview' rather than 'interview' in general. To match the word 'интервью,' the sentence in Russian should use 'интервью' instead.",
#       "suggestedFix": "Translation of 'интервью': 'haastattelu, интервью'"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'интервью' does not appear in the Russian sentence. The word 'собеседование' is used instead, which might slightly differ in meaning.",
#       "suggestedFixSentence": "Он волнуется, потому что у него завтра интервью.",
#       "suggestedFixWord": "интервью, собеседование"
#     }
#   }
# }
# {
#   "id": 4336,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'появляется' does not appear in the Russian sentence in any form. A related term such as 'выйдет' is used instead.",
#       "suggestedFixSentence": "Моя новая книга появится на следующей неделе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4337,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "There is a slight nuance difference. The Russian sentence translates to 'I watched a new episode of the series yesterday evening,' whereas the Finnish sentence translates to 'I watched a new episode of the series yesterday evening.' It would be more accurate to use 'jakso' for episode.",
#       "suggestedFix": "Katsoin eilen illalla uuden jakson sarjasta."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'sarja' is not used in the exact form intended. The sentence used 'jakso' instead.",
#       "suggestedFix": "Katsoin eilen illalla uuden sarjan jakson."
#     }
#   }
# }
# {
#   "id": 4338,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть на очереди' does not appear in the sentence 'Кто будет следующим по очереди?'. Instead, its synonym 'по очереди' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "быть на очереди, по очереди"
#     }
#   }
# }
# {
#   "id": 4339,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Uusi lukukausi alkaa syyskuussa.' translates directly to 'Новый семестр начинается в сентябре.' The Russian sentence given translates to 'Uusi lukuvuosi alkaa syyskuussa,' which signifies an academic year instead of a semester.",
#       "suggestedFix": "Новый семестр начинается в сентябре."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'семестр' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Новый семестр начинается в сентябре.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4340,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обмен студентами' does not appear in the Russian sentence. A related term 'студенческий обмен' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "обмен студентами, студенческий обмен"
#     }
#   }
# }
# {
#   "id": 4346,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Могу ли я отправить заявку на работу по электронной почте?' is close but not commonly used. The more natural phrase would be 'Могу ли я отправить заявку о приёме на работу по электронной почте?'",
#       "suggestedFix": "Могу ли я отправить заявку о приёме на работу по электронной почте?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The specific phrase 'заявка о приёме на работу' is not used in the sentence. The used phrase 'заявка на работу' is slightly different.",
#       "suggestedFixSentence": "Могу ли я отправить заявку о приёме на работу по электронной почте?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4348,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän pyytä apua' contains a grammatical error. The verb should be 'pyytää' instead of 'pyytä'.",
#       "suggestedFix": "Hän pyytää apua"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'pyytä' in the sentence is incorrect. It should be 'pyytää' to match the word in Finnish 'pyytää apua'.",
#       "suggestedFix": "pyytää"
#     }
#   }
# }
# {
#   "id": 4351,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The phrase 'тем путём (через это место)' is a bit awkward and redundant. It would be more natural to say 'через это место' directly.",
#       "suggestedFix": "Ты легко найдёшь отель, если пойдёшь через это место."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'через это' does not appear in a straightforward manner in the Russian sentence.",
#       "suggestedFixSentence": "Ты легко найдёшь отель, если пойдёшь через это место.",
#       "suggestedFixWord": "через это место"
#     }
#   }
# }
# {
#   "id": 4356,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Uudet asukkaat muuttavat taloihin pian.' is almost correct but 'taloihin' should be 'taloon' to match the singular 'дом' in the Russian sentence.",
#       "suggestedFix": "Uudet asukkaat muuttavat taloon pian."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is mostly accurate but the singular 'дом' should match a singular form in Finnish, which is 'taloon' instead of 'taloihin'.",
#       "suggestedFix": "Uudet asukkaat muuttavat taloon pian."
#     }
#   }
# }
# {
#   "id": 4358,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'стремиться' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он всегда стремится делать всё возможное в школе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4359,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'информационно-коммуникационные технологии' does not appear in the sentence. Its synonyms 'информационные и коммуникационные технологии' are used, which is more common in this context.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "информационные и коммуникационные технологии (информационно-коммуникационные технологии)"
#     }
#   }
# }
# {
#   "id": 4364,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence should use the partitive case for 'työryhmä'. The correct form should be 'työryhmää' instead of 'työryhmän'.",
#       "suggestedFix": "Projektipäällikkö johtaa tämän työryhmää."
#     }
#   }
# }
# {
#   "id": 4367,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Jokainen meistä on erilainen.' accurately translates to 'Каждый из нас разный.' in Russian. However, the Russian sentence provided uses 'уникален' which translates to 'unique,' not 'different.'",
#       "suggestedFix": "Каждый из нас разный."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "'разный' does not appear in the provided Russian sentence. Instead, the word 'уникален' is used, which means 'unique' and does not convey the same meaning.",
#       "suggestedFixSentence": "Каждый из нас разный.",
#       "suggestedFixWord": "уникален"
#     }
#   }
# }
# {
#   "id": 4371,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'фирма' (firma) does not appear in the Russian sentence. Instead, 'компания' (company) was used.",
#       "suggestedFixSentence": "Это финская фирма, которая специализируется на разработке программного обеспечения.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4374,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Мне нужно учить новый язык.' is grammatically correct but not natural in this context. The verb 'учить' means 'to teach' or 'to learn (a subject),' whereas 'учиться' means 'to learn' or 'to study (a skill or an activity).' In this context, 'учиться' is the appropriate verb.",
#       "suggestedFix": "Мне нужно учиться новому языку."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not entirely accurate. The Finnish verb 'opetella' is better translated as 'учиться' in Russian.",
#       "suggestedFix": "Minun täytyy opetella uusi kieli. (Мне нужно учиться новому языку.)"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'учиться' does not appear in the Russian sentence. To make the sentence natural and ensure the word is used, 'учиться' should be included.",
#       "suggestedFixSentence": "Мне нужно учиться новому языку.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4381,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'эпизод' is not used in the Russian sentence. Additionally, the current sentence uses 'период' in parentheses.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "часть, период"
#     }
#   }
# }
# {
#   "id": 4385,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. 'Выпускные экзамены в лицее' refers more to final exams in a lyceum/high school, while 'ylioppilaskirjoitukset' are specifically matriculation exams in Finland, which are for high school graduation.",
#       "suggestedFix": "Minun täytyy opiskella paljon lukion päättökokeita varten."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ylioppilaskirjoitukset' does not exactly match 'выпускные экзамены в лицее'. A more accurate term would be 'lukion päättökokeet'.",
#       "suggestedFix": "lukion päättökokeet"
#     }
#   }
# }
# {
#   "id": 4388,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'законченное образование' does not appear in any form in the sentence. The sentence uses 'медицинское образование' instead.",
#       "suggestedFixSentence": "Моя мечта – получить законченное медицинское образование.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4390,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сдавать экзамены на получение аттестата лицея' does not appear in any form in the Russian sentence. A synonym or a related term should be used to ensure natural usage.",
#       "suggestedFixSentence": "Он собирается сдавать экзамены на получение аттестата лицея следующей весной.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4392,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct, but it does not use the given word 'рабочая задача'.",
#       "suggestedFix": "Я хотел бы узнать больше об этой рабочей задаче."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'рабочая задача' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Я хотел бы узнать больше об этой рабочей задаче.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4405,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'внимательный' does not appear directly in the sentence. The sentence uses the related form 'внимателен'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "внимателен, внимательный"
#     }
#   }
# }
# {
#   "id": 4406,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The phrase 'с чувством юмора' does not occur in the given Russian sentence.",
#       "suggestedFixSentence": "Он действительно обладaет чувством юмора и заставляет всех смеяться.",
#       "suggestedFixWord": "обладает чувством юмора"
#     }
#   }
# }
# {
#   "id": 4407,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is generally correct, but the usage of 'организован' suggests someone who is organized in general. It might be more fitting to use 'организованный' to match the given word precisely.",
#       "suggestedFix": "Он очень организованный в своей работе."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'организованный' is not used in the Russian sentence, making it inaccurate according to the given word.",
#       "suggestedFixSentence": "Он очень организованный в своей работе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4409,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'амбициозный' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он очень амбициозный и хочет преуспеть в своей карьере.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4417,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'korkeakoulut' in its current form doesn't match the singular form used in the Finnish sentence.",
#       "suggestedFix": "korkeakouluun"
#     }
#   }
# }
# {
#   "id": 4418,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'доктор наук' is not used in the sentence 'Доктор наук Виртанен изучает редкие болезни.' The term 'доктор наук' specifically refers to someone holding an academic doctoral degree, whereas 'доктор' can be broader.",
#       "suggestedFixSentence": "Доктор наук Виртанен изучает редкие болезни.",
#       "suggestedFixWord": "доктор наук"
#     }
#   }
# }
# {
#   "id": 4419,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'kevänä' is incorrect. The correct form is 'keväänä'.",
#       "suggestedFix": "Hän valmistui maisteriksi viime keväänä"
#     }
#   }
# }
# {
#   "id": 4420,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Он получил степень кандидата (бакалавра) прошлой весной' is grammatically awkward because 'кандидата' usually refers to a candidate or a PhD degree in Russian, which might not fit here. Typically, 'бакалавра' is an appropriate term for a bachelor's degree.",
#       "suggestedFix": "Он получил степень бакалавра прошлой весной"
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a minor grammatical error. The correct form is 'viime keväänä' instead of 'viime kevänä'.",
#       "suggestedFix": "Hän valmistui kandidaatiksi viime keväänä"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not fully accurate due to the potential confusion between 'кандидата' and 'бакалавра'. The sentence is supposed to reflect the earning of a bachelor's degree, so using 'бакалавра' is more precise.",
#       "suggestedFix": "Он получил степень бакалавра прошлой весной"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'кандидат' does not naturally fit into the context of earning a bachelor's degree. In Russian, 'бакалавр' is more appropriate for this context.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "бакалавр"
#     }
#   }
# }
# {
#   "id": 4421,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence translates to 'I studied for four years to get a Master of Applied Sciences degree,' which is different from the concept of 'профессиональная магистратура' which directly translates to 'ylempi AMK-tutkinto.'",
#       "suggestedFix": "Я учился четыре года, чтобы получить профессиональную магистратуру."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'магистратура' or its form does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Я учился четыре года, чтобы получить профессиональную магистратуру.",
#       "suggestedFixWord": "магистратура, профессиональная магистратура"
#     }
#   }
# }
# {
#   "id": 4422,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence mentions 'бакалаврская степень,' which translates to 'Bachelor's degree,' whereas the Finnish sentence uses the term 'alempi AMK-tutkinto,' which typically translates to 'lower university of applied sciences degree' and is not an exact match.",
#       "suggestedFix": "Minulla on kandidaatin tutkinto liiketaloudesta."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'бакалавр' does not appear in the Russian sentence in its direct form; instead, the adjective 'бакалаврская' is used. While related, it's better to use a synonym or related term to maintain the word usage in context.",
#       "suggestedFixSentence": "У меня есть степень бакалавра по бизнесу.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'alempi AMK-tutkinto' appears in the Finnish sentence, but it does not match the context of 'бакалавр' accurately.",
#       "suggestedFix": "alempi AMK-tutkinto, kandidaatin tutkinto"
#     }
#   }
# }
# {
#   "id": 4425,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates to 'Он только что закончил школу и стал выпускником лицея.' The existing translations do not directly match.",
#       "suggestedFix": "Hän on juuri valmistunut lukiosta."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'выпускник лицея' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он только что стал выпускником лицея.",
#       "suggestedFixWord": "свободное время"
#     }
#   }
# }
# {
#   "id": 4429,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate because 'подготовительный класс' translates to 'valmistava luokka' not 'esikoulu.' 'Esikoulu' translates to 'детский сад' or 'подготовительная школа'.",
#       "suggestedFix": "esikoulu: детский сад, подготовительная школа"
#     }
#   }
# }
# {
#   "id": 4431,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Назови свой персональный идентификационный номер?' is technically correct, but unnatural and not commonly used in standard or casual communication. A more natural way would be to say 'Назовите свой персональный идентификационный номер?'",
#       "suggestedFix": "Назовите свой персональный идентификационный номер?"
#     }
#   }
# }
# {
#   "id": 4432,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мои ключи нигде не находятся.' is incorrect as 'находиться' should be in a different form to indicate that 'keys are nowhere to be found'.",
#       "suggestedFix": "Мои ключи нигде не могут найтись."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'найтись' does not occur in the Russian sentence in the appropriate form.",
#       "suggestedFixSentence": "Мои ключи нигде не могут найтись.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4433,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate: 'hammashoitaja' means 'dental nurse,' but 'стоматолог' means 'dentist'.",
#       "suggestedFix": "Minun täytyy varata aika hammaslääkärille."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'hammashoitaja' does not mean 'стоматолог' (dentist); it means 'dental nurse'.",
#       "suggestedFix": "hammaslääkäri"
#     }
#   }
# }
# {
#   "id": 4434,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть готовым' in its different forms does not appear in the sentence. A possible usage would be 'Я готов.'",
#       "suggestedFixSentence": "Я готов.",
#       "suggestedFixWord": "готовым, готов"
#     }
#   }
# }
# {
#   "id": 4435,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'перед тем как' does not occur in the Russian sentence. The word 'прежде чем' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "прежде чем"
#     }
#   }
# }
# {
#   "id": 4438,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The postposition 'klinikaan' should be corrected to 'klinikalle'. The Finnish translation misses the natural usage.",
#       "suggestedFix": "Mennään klinikalle tarkistamaan sinun terveytesi."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish translation is not entirely accurate. The suggested fix for the Finnish sentence and the accuracy are aligned.",
#       "suggestedFix": "Mennään klinikalle tarkistamaan sinun terveytesi."
#     }
#   }
# }
# {
#   "id": 4439,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. 'Трудовая книжка' means 'workbook' or 'employment record book', whereas 'työtodistus' means 'work certificate'.",
#       "suggestedFix": "Moglj бы вы дать мне työtodistus, прежде чем я уйду?"
#     }
#   }
# }
# {
#   "id": 4445,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of 'Tietokoneen järjestelmä on hyvin monimutkainen.' is not reflected accurately in the Russian sentence 'Программное обеспечение очень сложное.' since it doesn't mention 'järjestelmä' which corresponds to 'система' in Russian.",
#       "suggestedFix": "Система компьютера очень сложная."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'система' does not appear in the Russian sentence provided.",
#       "suggestedFixSentence": "Система компьютера очень сложная.",
#       "suggestedFixWord": "система, программное обеспечение"
#     }
#   }
# }
# {
#   "id": 4447,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a grammatical mistake. The correct phrase should be 'kotoutumissuunnitelman' instead of 'kotoutumissuunnitelmaa' and 'maahanmuuttajille' instead of 'maahanmuutajille'.",
#       "suggestedFix": "Te-toimisto tekee kotoutumissuunnitelman maahanmuuttajille."
#     }
#   }
# }
# {
#   "id": 4451,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish 'Kielitaito on tärkeä työelämässä.' translates to 'Языковые навыки важны в профессиональной жизни.' rather than 'Знание языка важно в профессиональной жизни.' The concept of 'kielitaito' aligns more with 'языковые навыки' than 'языковой уровень'.",
#       "suggestedFix": "Языковые навыки важны в профессиональной жизни."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'языковой уровень' does not occur in the sentence. The sentence uses 'Знание языка', which means 'knowledge of the language'.",
#       "suggestedFixSentence": "Языковой уровень важен в профессиональной жизни.",
#       "suggestedFixWord": "языковой уровень, знание языка"
#     }
#   }
# }
# {
#   "id": 4452,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в следующую очередь, дальше' does not appear in the Russian sentence. The word 'дальше' is used, which fits 'дальше' but not 'в следующую очередь'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "дальше, в следующую очередь"
#     }
#   }
# }
# {
#   "id": 4454,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'сфера ухода за больными' (nursing care sector) is more specific than 'hoitoala' (care/nursing field). The translation should be aligned to match the nuances.",
#       "suggestedFix": "Word in Finnish: sairaanhoitoala"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сфера ухода за больными' does not appear in the sentence. Instead, 'уход за больными' is used, which means 'nursing care'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "уход за больными, сфера ухода за больными"
#     }
#   }
# }
# {
#   "id": 4456,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'компетентность' does not appear in the Russian sentence, which uses 'квалификация'.",
#       "suggestedFixSentence": "У меня есть необходимая компетентность для этой работы.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4458,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translations are not accurate. 'Obuchenie ot sluzhby zanyatosti' does not correspond directly to 'työllistymiskoulutus'.",
#       "suggestedFix": "Obuchenie ot sluzhby zanyatosti should be translated as 'työllistymiskoulutus' or 'ammatillinen koulutus'."
#     }
#   }
# }
# {
#   "id": 4459,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Milloin minun pitäisi hakea työttömyystuki?' is not grammatically correct. The word 'työttömyystuki' should be in the partitive case as it is an object of the verb 'hakea.'",
#       "suggestedFix": "Milloin minun pitäisi hakea työttömyystukea?"
#     }
#   }
# }
# {
#   "id": 4460,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'сначала' in Russian directly translates to 'ensimmäiseksi' in Finnish, which was considered as 'Ekaks' in the Finnish sentence. However, the sentence 'Во-первых, сними обувь, когда входишь внутрь.' would more accurately be translated to 'Poista kengät ensin, kun tulet sisään.' in Finnish, because 'Во-первых' translates to 'ensinnäkin'.",
#       "suggestedFix": "Poista kengät ensin, kun tulet sisään."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сначала' does not appear in any form in the Russian sentence. The closest word used is 'Во-первых', which translates to 'во-первых' or 'вначале'.",
#       "suggestedFixSentence": "Сначала сними обувь, когда входишь внутрь.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4463,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän yrittää aina söpöillä kun haluaa jotain.' translates more directly to 'Он всегда пытается быть милым, когда хочет чего-то.' instead of using 'стараться быть милым.'",
#       "suggestedFix": "Word in Russian: пытаться быть милым"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'стараться быть милым' is not used in the sentence. The sentence instead uses 'пытается быть милым,' which is not fully equivalent.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "пытается быть милым"
#     }
#   }
# }
# {
#   "id": 4464,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains a grammatical mistake. The verb 'появился' is not appropriate for describing snow layering on the streets. It should be 'лежит'.",
#       "suggestedFix": "По улицам лежит толстый слой снега."
#     }
#   }
# }
# {
#   "id": 4466,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'хорошими' does not appear in any form in the Russian sentence 'Эти яблоки действительно вкусные.'",
#       "suggestedFixSentence": "Эти яблоки действительно хорошие.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4467,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'поездами' does not appear in the sentence.",
#       "suggestedFixSentence": "Я часто путешествую поездами по служебным делам.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4468,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "There is a typo in the sentence 'что бы' should be corrected to 'чтобы'. Also, 'позабочусь' is not quite the right verb here. 'Приехать' or 'прибыть' fits better.",
#       "suggestedFix": "Я постараюсь приехать заранее в аэропорт."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'заранее' does not appear in the sentence in a natural way.",
#       "suggestedFixSentence": "Я постараюсь приехать заранее в аэропорт.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4470,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Hänen sanoissa on paljon viisautta' is slightly incorrect. In Finnish, the correct expression would be 'Hänen sanoissaan on paljon viisautta' with the full possessive form.",
#       "suggestedFix": "Hänen sanoissaan on paljon viisautta"
#     }
#   }
# }
# {
#   "id": 4471,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в туалеты' does not appear in the Russian sentence. However, 'туалета' is used, which is a relevant term but in singular form.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "туалет, туалеты"
#     }
#   }
# }
# {
#   "id": 4474,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Ihmiset nostivat rahaa pankeista.' uses the past tense 'nostivat', while the Russian sentence is in the present tense.",
#       "suggestedFix": "Ihmiset nostavat rahaa pankeista."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "While the general meaning is accurate, the tense mismatch affects the translation accuracy.",
#       "suggestedFix": "Ihmiset nostavat rahaa pankeista."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'из банков' does not appear in the sentence. A synonym or related structure should be used.",
#       "suggestedFixSentence": "Люди снимают наличные деньги из банков.",
#       "suggestedFixWord": "из банков, в банках"
#     }
#   }
# }
# {
#   "id": 4476,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'из комнат' does not appear in the sentence.",
#       "suggestedFixSentence": "Одна из комнат твоя.",
#       "suggestedFixWord": "из комнат, комната"
#     }
#   }
# }
# {
#   "id": 4477,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is not entirely correct. The word 'hitailla' is not appropriately used here, it should be 'hitaasti' which means 'slowly'.",
#       "suggestedFix": "Tämä kirja on vaikea lukea, joten luen sitä hitaasti."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'hitailla' is improperly used in this context. The correct word should be 'hitaasti'.",
#       "suggestedFix": "hitaasti"
#     }
#   }
# }
# {
#   "id": 4483,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence sounds slightly odd and could be more naturally expressed as 'Olemme olleet ystäviä jo monta vuotta.'",
#       "suggestedFix": "Olemme olleet ystäviä jo monta vuotta."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is partially inaccurate. 'ystävyksissä' should be directly translated to 'в дружбе', but the meaning here is more naturally expressed with 'Olemme olleet ystäviä'.",
#       "suggestedFix": "Olemme olleet ystäviä jo monta vuotta."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в дружбе' does not appear in the Russian sentence 'Мы уже много лет дружим.'.",
#       "suggestedFixSentence": "Мы уже много лет в дружбе.",
#       "suggestedFixWord": "дружим"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ystävyksissä' is quite rare and not used in the given Finnish sentence. A better term would be 'ystäviä'.",
#       "suggestedFix": "ystäviä"
#     }
#   }
# }
# {
#   "id": 4491,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translation 'Taloilla on yhteinen saunarakennus' translates to 'The houses have a shared sauna building.' However, 'У домов есть отдельная общая сауна.' translates to 'The houses have an individual shared sauna.' The word 'отдельная' indicates 'individual' which is not present in the Finnish translation.",
#       "suggestedFix": "The correct translation should be 'Taloilla on erillinen yhteinen sauna.' or the Russian original can be adjusted to 'У домов есть общая сауна.'"
#     }
#   }
# }
# {
#   "id": 4498,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'делах, вещах' in Russian contains 'делах' which does not appear in the Russian sentence. To align with the Finnish word 'asioista', the word 'вещах' is already used, but 'делах' is not. It may be more appropriate to adjust the word translation to match the sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вещах"
#     }
#   }
# }
# {
#   "id": 4504,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a minor error in the form of greeting. 'Onnea syntymäpäivänäsi' should be 'Onnea syntymäpäivänä' for better naturalness.",
#       "suggestedFix": "Onnea syntymäpäivänä ihanille ystävilleni!"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of 'днём рождения моим прекрасным друзьям' as 'syntymäpäivänä ihanille ystävilleni' implies 'to my lovely friends' which should be 'to my wonderful friends' for better precision.",
#       "suggestedFix": "Onnea syntymäpäivänä upeille ystävilleni!"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ihanille' is used correctly in the sentence, but for better accuracy 'upeille' is a closer match to 'прекрасным'.",
#       "suggestedFix": "upeille"
#     }
#   }
# }
# {
#   "id": 4506,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian phrase 'сумерек' should be in the form 'сумерками' to fit grammatically within the context of the sentence.",
#       "suggestedFix": "Когда день сменяется сумерками на ночь, уличные фонари зажигаются."
#     }
#   }
# }
# {
#   "id": 4508,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'для важных' in the provided form does not appear in the Russian sentence. 'важных' appears but not 'для важных'. It would be better to translate 'трудный' as 'важный/важные'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "важных"
#     }
#   }
# }
# {
#   "id": 4511,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Он прибыл на весёлые дни рождения с опозданием.' is grammatically incorrect. The word 'весёлые' is used incorrectly for the context of 'days of birthdays.'",
#       "suggestedFix": "Он прибыл на весёлую вечеринку с опозданием."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of 'весёлые дни рождения' to 'iloisiin syntymäpäiväjuhliin' is not entirely accurate. 'Весёлые' is not quite fitting the context here, but 'iloisiin syntymäpäiväjuhliin' implies cheerful birthday celebrations, which is correct.",
#       "suggestedFix": null
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'весёлые' does not correctly match the context of the sentence. It is better to use 'весёлую' if referring to a singular 'party' or 'весёлые' could be kept if referring to 'celebrations'.",
#       "suggestedFixSentence": "Он прибыл на весёлую вечеринку с опозданием.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4512,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Artikkeli julkaistaan lehtiin.' is grammatically incorrect. The correct form should use the inessive case 'lehdissä' instead of the illative case 'lehtiin'.",
#       "suggestedFix": "Artikkeli julkaistaan lehdissä."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish translation 'Artikkeli julkaistaan lehtiin.' is incorrect because it uses the wrong case. The correct translation should be 'Artikkeli julkaistaan lehdissä.'",
#       "suggestedFix": "Artikkeli julkaistaan lehdissä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в газетах' does appear in the sentence, but it should be the base word 'газеты' instead of 'в газетах'.",
#       "suggestedFixSentence": "Статью опубликуют в газетах.",
#       "suggestedFixWord": "в газетах"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'lehtiin' is used in the sentence; however, the correct form should be 'lehdissä'.",
#       "suggestedFix": "lehdissä"
#     }
#   }
# }
# {
#   "id": 4514,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Russian 'в дома' is not used in the sentence. Instead, 'дома' is used without the preposition 'в'.",
#       "suggestedFixSentence": "Жители переезжают в новые дома на улице Коскикату в мае.",
#       "suggestedFixWord": "дома"
#     }
#   }
# }
# {
#   "id": 4515,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Я иду завтра в магазины купить еды.' is almost correct, but the correct phrasing should use infinitive after the verb 'иду': 'Я иду завтра в магазины за едой.'",
#       "suggestedFix": "Я иду завтра в магазины за едой."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'kauppoihiin' contains a typo. The correct form is 'kauppoihin'.",
#       "suggestedFix": "Menen huomenna kauppoihin ostamaan ruokaa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kauppoihiin' contains a typo and should be 'kauppoihin'.",
#       "suggestedFix": "kauppoihin"
#     }
#   }
# }
# {
#   "id": 4518,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is accurate in meaning, but the form of 'сделали бы' or 'tehtaisiin' is not used directly in the sentences.",
#       "suggestedFix": "Что, если бы мы приготовили сами ужин сегодня? // Mitä jos tehtäisiin itse illallinen tänään?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сделали бы' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Что, если бы мы приготовили сами ужин сегодня?",
#       "suggestedFixWord": "сделали бы, приготовили"
#     }
#   }
# }
# {
#   "id": 4519,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'kaunisiin' is misspelled. The correct form should be 'kauniisiin'.",
#       "suggestedFix": "Aurinkolasku värjäsi taivaan kauniisiin väreihin."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kaunisiin' in the Finnish sentence is misspelled. The correct form should be 'kauniisiin'.",
#       "suggestedFix": "kauniisiin"
#     }
#   }
# }
# {
#   "id": 4520,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence has a grammatical issue. The phrase 'чувствуем себя усталыми' is awkward. It would be more natural to say 'чувствуем себя слишком усталыми'.",
#       "suggestedFix": "Мы берём такси, потому что чувствуем себя слишком усталыми, чтобы идти пешком."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence has a grammatical issue. The correct form should be 'liian väsyneitä' instead of 'liian väsyneisiin'.",
#       "suggestedFix": "Otamme taksin, koska olemme liian väsyneitä kävelemään."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'väsyneisiin' is used incorrectly in the sentence. The correct form should be 'väsyneitä'.",
#       "suggestedFix": "väsyneitä"
#     }
#   }
# }
# {
#   "id": 4522,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of the word 'Tapasin Niemiset. Niemiset muuttivat tänne Oulusta.' to Russian doesn't include the word in a form occurring in the word given. It should closely match the meaning of the Finnish sentence.",
#       "suggestedFix": "Встретился с Ниеминен. Ниеминен переехали сюда из Оулу."
#     }
#   }
# }
# {
#   "id": 4527,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Tämä on kirja, joille olen kirjoittanut muistiinpanoja.' is incorrect. The relative pronoun 'joille' is incorrect because it refers to a plural noun in allative case, whereas 'kirja' is singular nominative.",
#       "suggestedFix": "Tämä on kirja, johon olen kirjoittanut muistiinpanoja."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The correct Finnish translation 'Tämä on kirja, johon olen kirjoittanut muistiinpanoja.' matches the Russian sentence 'Это книга, в которую я записывал заметки.'",
#       "suggestedFix": "Tämä on kirja, johon olen kirjoittanut muistiinpanoja."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'которым' does not appear in the Russian sentence. Instead, 'которую' is used due to grammatical agreement with 'книга' (feminine singular accusative).",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "которому, которой, которым, которую"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'joille' does not correctly fit in the provided Finnish sentence due to grammatical mismatch. The word 'johon' (singular illative form) would fit correctly.",
#       "suggestedFix": "johon"
#     }
#   }
# }
# {
#   "id": 4529,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a minor issue; 'joilta' should normally be used with a referent that is an animate object.",
#       "suggestedFix": "Nämä ovat kirjat, joista opin suomea."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'joilta' does not fit the context correctly in the Finnish sentence. The word 'joista' would be a better choice.",
#       "suggestedFix": "joista"
#     }
#   }
# }
# {
#   "id": 4533,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'к этим' does not appear in the sentence in any form. A better fit would be 'в эти' to match the context of the Finnish 'näihin'.",
#       "suggestedFixSentence": "Можешь показать мне, как я могу попасть к этим настройкам?",
#       "suggestedFixWord": "в эти"
#     }
#   }
# }
# {
#   "id": 4536,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'этим' does not appear exactly in the sentence, but 'Этим книгам' is close. If this is considered acceptable, this can be ignored.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "этим, эти"
#     }
#   }
# }
# {
#   "id": 4538,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'с этих' does not appear in any form in the given Russian sentence. The sentence uses 'На этих' instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "с этих, на этих"
#     }
#   }
# }
# {
#   "id": 4540,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence contains a grammatical error. The word 'тех' is used incorrectly. It should be 'теми': 'Видишь ли ты парк между теми домами?'",
#       "suggestedFix": "Видишь ли ты парк между теми домами?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is slightly off due to the incorrect usage of 'тех'. It should be 'темими домами'.",
#       "suggestedFix": "Näetkö noiden talojen välissä olevan puiston? = Видишь ли ты парк между теми домами?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тех' is not used correctly in the Russian sentence. It should be 'теми'.",
#       "suggestedFixSentence": "Видишь ли ты парк между теми домами?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4541,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Аллан влюблён в те булочки.' sounds unnatural in Russian. A more natural way to say it would be 'Аллан любит те булочки.'",
#       "suggestedFix": "Аллан любит те булочки."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The verb 'влюблён' in Russian is stronger and more romantic than 'ihastunut' in Finnish, which means 'fond of'. The Russian sentence uses a more intense expression of affection, which is not an accurate translation.",
#       "suggestedFix": "Аллан любит те булочки."
#     }
#   }
# }
# {
#   "id": 4543,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'из тех' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Мари нравятся из тех больших шоколадных пирожных.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4545,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'на тех' does not appear in the Russian sentence, the correct form 'на этих' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "на тех, на этих"
#     }
#   }
# }
# {
#   "id": 4548,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'А, в те высокие?' is incomplete and sounds unnatural. It lacks context and a subject.",
#       "suggestedFix": "А, ты о тех высоких зданиях?"
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "While the Finnish sentence is grammatically correct, it is uncommon and lacks context. The sentence would benefit from being more specific.",
#       "suggestedFix": "Ai, niihin korkeisiin rakennuksiin?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided translation is not accurate and lacks context. It should specify what is being referred to.",
#       "suggestedFix": "Ai, niihin korkeisiin rakennuksiin?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в те' does occur in the Russian sentence, but the sentence is incomplete and unnatural.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "ты о тех"
#     }
#   }
# }
# {
#   "id": 4551,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a typo. 'nille' should be 'niille'.",
#       "suggestedFix": "Voitko antaa nämä kirjat niille opiskelijoille?"
#     }
#   }
# }
# {
#   "id": 4552,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "There is a grammatical error. The Finnish sentence should use 'niillä' instead of 'nillä', and 'lautaseilla' should be corrected to 'lautasilla'.",
#       "suggestedFix": "Voitko näyttää minulle, mitä sinulla on niillä lautasilla?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'nillä' is used incorrectly due to a typographical error; it should be 'niillä'.",
#       "suggestedFix": "niillä"
#     }
#   }
# }
# {
#   "id": 4553,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'с них' does not appear in the sentence 'Я взял книги с этих полок.'",
#       "suggestedFixSentence": "Я взял книги с них.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4563,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided translations seem accurate, but the grammar and natural usage in the sentences need evaluation once they are provided."
#     }
#   }
# }

# %%
# Example usage
chapter_name = 'sm2_new_kap8'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 4576,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'быть в силе, быть действительным' does not occur in the form 'быть' or 'быть в силе' in the sentence. The word 'действителен' is used, which is related but not an exact form of the given word.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "быть действительным, действующий"
#     }
#   }
# }
# {
#   "id": 4579,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses a colloquial and somewhat ungrammatical form. A more natural and grammatically correct sentence would be 'Me haluaisimme mennä elokuviin tänään.'",
#       "suggestedFix": "Me haluaisimme mennä elokuviin tänään."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me haluttais' is the colloquial form and is technically derived from 'me haluaisimme'. If the sentence uses the grammatically correct form, the word should also match.",
#       "suggestedFix": "me haluaisimme"
#     }
#   }
# }
# {
#   "id": 4584,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses a colloquial form 'katella,' which can be less formal or dialectal. The standard form is 'katsella.'",
#       "suggestedFix": "Voisitko katsella lapsia hetken kun käyn kaupassa?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The colloquial Finnish term 'katella' is less formal and its standard form is 'katsella.'",
#       "suggestedFix": "Word in Finnish: katsella (katella)"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'katella' should ideally be 'katsella' for grammatical correctness in standard Finnish.",
#       "suggestedFix": "katsella (katella)"
#     }
#   }
# }
# {
#   "id": 4589,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вмещаться' does not appear in the given Russian sentence. Instead, the verb 'умещаться' is used, which is a close synonym but not the exact word provided.",
#       "suggestedFixSentence": "Все сумки не вмещаются в машину.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4591,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a grammatical error. The part 'parasta ominaisuutta on sen pitkä akun kesto' should be corrected.",
#       "suggestedFix": "Tämän puhelimen paras ominaisuus on sen pitkä akun kesto."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'особенность' does not occur in the Russian sentence. A synonym should be included to match the given word.",
#       "suggestedFixSentence": "Лучшей особенностью этого телефона является долгий срок службы его аккумулятора.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4592,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'так же важно, как и' is not used in the given form in the sentence. However, the phrase 'так же важна, как и' closely resembles the target word.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "важна, как и"
#     }
#   }
# }
# {
#   "id": 4594,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Anteeksi, me tarvittais apua tämän kartan kanssa.' is slightly incorrect. The proper form would be 'Anteeksi, me tarvitsisimme apua tämän kartan kanssa.'",
#       "suggestedFix": "Anteeksi, me tarvitsisimme apua tämän kartan kanssa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is not an accurate translation of the Russian sentence. The Russian sentence means 'Sorry, we need help with this map.', while the Finnish sentence implies 'Sorry, we would need help with this map.'",
#       "suggestedFix": "Anteeksi, me tarvitsemme apua tämän kartan kanssa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нам бы понадобилось' does not appear in the Russian sentence. A synonym or related term should be used to ensure the sentence remains natural and accurate.",
#       "suggestedFixSentence": "Извините, нам бы понадобилась помощь с этой картой.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me tarvittais (tarvitsisimme)' appears in a slightly incorrect form in the Finnish sentence. The correct form should be used.",
#       "suggestedFix": "tarvitsisimme"
#     }
#   }
# }
# {
#   "id": 4595,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Tää on mun kahvi, missä on sun?' translates to 'Это мой кофе, где твой?' in Russian and vice versa. However, the provided word in Russian 'этот' does not appear in either sentence.",
#       "suggestedFix": "Translation consistency needs to be checked between the word and sentence."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'этот' does not appear in the sentence. 'Это' is a different form related to the pronoun 'this' but not the exact word provided.",
#       "suggestedFixSentence": "Этот мой кофе, где твой?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4597,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'трудный' does not appear in the Russian sentence. The word 'сложная' is used instead, which is synonymous but doesn't match the given word.",
#       "suggestedFixSentence": "Эта задача по математике действительно трудная.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4598,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тот' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Та кофейная чашка – это моя.",
#       "suggestedFixWord": "тa, этот"
#     }
#   }
# }
# {
#   "id": 4601,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'какая цена' is used in the Russian sentence, but 'сколько стоит' is not represented. Both should be accounted for.",
#       "suggestedFixSentence": "Ты знаешь, сколько стоит эта рубашка?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4604,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence is grammatically incorrect. The demonstrative pronoun 'этот' uses the wrong gender and case here, as 'книга' is feminine. The correct form should be 'эту.'",
#       "suggestedFix": "Можешь дать мне эту книгу?"
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses colloquial language. In standard written Finnish, 'tän' should be 'tämän.'",
#       "suggestedFix": "Voitko antaa tämän kirjan minulle?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'этот' is not used correctly in the sentence. The appropriate form is 'эту' to match the feminine noun 'книга.'",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "этот, эта, это, эти"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'tän' (tämän) should be used in its standard form 'tämän' in this context, as 'tän' is colloquial.",
#       "suggestedFix": "tämän"
#     }
#   }
# }
# {
#   "id": 4605,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a grammatical error. The correct form for 'my headphones are broken, I need new ones' should be 'Minun kuulokkeeni ovat rikki, tarvitsen uudet'. 'kuulokkeet' should be 'kuulokkeeni' to properly indicate possession.",
#       "suggestedFix": "Minun kuulokkeeni ovat rikki, tarvitsen uudet."
#     }
#   }
# }
# {
#   "id": 4606,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate as it does not capture the intended meaning of 'обязательно' which means 'definitely' or 'necessarily'. Instead, the Russian sentence uses 'Безусловно', which translates to 'undoubtedly'.",
#       "suggestedFix": "Безусловно, voimme tavata huomenna kahvilassa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обязательно' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Обязательно, мы можем встретиться завтра в кафе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4609,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'быть в наличии, остаться' does not appear in the sentence 'Сколько времени ещё осталось?'. The word 'остаться' should be used in the sentence.",
#       "suggestedFixSentence": "Сколько времени еще осталось в наличии?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4614,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мне нужно быть сегодня в продуктовом магазине.' is grammatically correct but sounds unnatural. 'быть' (to be) is not typically used in this context. Instead, more natural verbs like 'идти' (to go) or 'пойти' (to go) would be used.",
#       "suggestedFix": "Мне нужно пойти сегодня в продуктовый магазин."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish 'Minun täytyy olla tänään ruokakaupassa.' to Russian 'Мне нужно быть сегодня в продуктовом магазине.' is accurate in meaning but both sound unnatural. They should use verbs that naturally fit the context.",
#       "suggestedFix": "Minun täytyy mennä tänään ruokakauppaan. -> Мне нужно пойти сегодня в продуктовый магазин."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть' does not fit well in the context of the sentence. It should be replaced with verbs like 'идти' or 'пойти'.",
#       "suggestedFixSentence": "Мне нужно пойти сегодня в продуктовый магазин.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'olla (käydä ostoksilla)' does not fit well in the context of the sentence. The correct verb should be 'mennä' or 'käydä' in this context.",
#       "suggestedFix": "Minun täytyy mennä tänään ruokakauppaan."
#     }
#   }
# }
# {
#   "id": 4622,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. 'магазин подержанных товаров' translates to 'second-hand store' in English, which is not the same as 'kierrätyskeskus' in Finnish, which means 'recycling center.'",
#       "suggestedFix": "Word in Russian: киоск секонд-хенд"
#     }
#   }
# }
# {
#   "id": 4629,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is missing a pronoun and should use 'tämä' in place of 'tämän' to be grammatically correct.",
#       "suggestedFix": "Voiko tämän tuotteen palauttaa, jos minulla on palautusoikeus?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence structure differs slightly, and 'tämän' should be corrected to 'tämä' to match properly with 'этот'.",
#       "suggestedFix": "Voiko tämän tuotteen palauttaa, jos minulla on palautusoikeus?"
#     }
#   }
# }
# {
#   "id": 4632,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'плохого качества' does not appear in the Russian sentence. Instead, 'низкого качества' is used, which is a synonym and sounds natural.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "низкого качества"
#     }
#   }
# }
# {
#   "id": 4634,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The specific word 'корзина для покупок' does not appear in the sentence. However, 'корзина' is a part of it and can be considered suitable.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "корзина, корзина для покупок"
#     }
#   }
# }
# {
#   "id": 4639,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Мог бы ты объяснить мне условия доставки из этого договора?' is grammatically incorrect and unnatural in Russian. The correct term should be 'условия поставки', not 'условия доставки'.",
#       "suggestedFix": "Мог бы ты объяснить мне условия поставки из этого договора?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'условия поставки' does not appear in the Russian sentence. Instead, the term 'условия доставки' is used, which is not correct.",
#       "suggestedFixSentence": "Мог бы ты объяснить мне условия поставки из этого договора?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4650,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish 'liike' to Russian 'магазин' is not entirely accurate. While 'магазин' translates to 'store' or 'shop,' 'liike' has a broader meaning, including 'movement' or 'business.' The more appropriate Russian translation for this context might be 'бизнес' instead of 'магазин.'",
#       "suggestedFix": "бизнес"
#     }
#   }
# }
# {
#   "id": 4655,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'оплата через интернет' does not appear in the Russian sentence. A related term 'интернет-банк' is used, but the specific word 'оплата через интернет' should be included for consistency.",
#       "suggestedFixSentence": "Вы можете без труда провести оплату через интернет в интернет-банке.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4661,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'знание, информация' does not appear in the Russian sentence. Only 'информация' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "информация"
#     }
#   }
# }
# {
#   "id": 4662,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian doesn't convey the exact same meaning as the Finnish sentence. The Finnish sentence specifically asks about the delivery charge ('toimitusmaksu'), while the Russian sentence asks about the delivery cost in general.",
#       "suggestedFix": "Можешь ли сказать, сколько составляет плата за доставку этого товара?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'плата за доставку' does not appear in the Russian sentence. To ensure the translation remains natural and accurate, the sentence should be adjusted to include this term.",
#       "suggestedFixSentence": "Можешь ли сказать, сколько составляет плата за доставку этого товара?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4664,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'доставить' does not appear in the Russian sentence. The verb 'отнести' is used instead.",
#       "suggestedFixSentence": "Можешь доставить этот пакет на почту?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4668,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'рассмотреть' does not appear in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "обработать"
#     }
#   }
# }
# {
#   "id": 4673,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Voisitko täyttä tämän palautuslomakkeen?' contains a grammatical error. The verb 'täyttä' should be in the infinitive form 'täyttää'.",
#       "suggestedFix": "Voisitko täyttää tämän palautuslomakkeen?"
#     }
#   }
# }
# {
#   "id": 4677,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains an unnecessary phrase '(присоединить)', which makes it sound unnatural. It would be more natural without it.",
#       "suggestedFix": "Проектная группа решила взять к себе нового участника."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has some missing expressions. 'päätös' should be used instead of 'päätti', and 'uuden jäsenen' should be in partitive case (uutta jäsentä).",
#       "suggestedFix": "Projektiryhmä päätti liittää uuden jäsenen tiimiinsä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'присоединить' is not literally present in the sentence. The verb 'взять к себе' is used instead.",
#       "suggestedFixSentence": "Проектная группа решила присоединить нового участника.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4678,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'внимательный' is not used in the sentence. The sentence uses 'внимателен', which is a form of the adjective 'внимательный'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "внимательный, внимателен"
#     }
#   }
# }
# {
#   "id": 4679,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence uses the word 'инструкции', which is plural. However, the context suggests the use of the singular form 'инструкция'. Also, 'инструкция' usually won't be used in such a context as routes or directions can be better described with 'инструкции'.",
#       "suggestedFix": "Могли бы вы дать мне инструкцию, как найти станцию?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'инструкция' is not used correctly in the sentence context.",
#       "suggestedFixSentence": "Могли бы вы дать мне инструкцию, как найти станцию?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4699,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Opettajia on kolme koulussamme.' is grammatically incorrect. The correct form should be 'Koulussamme on kolme opettajaa.'",
#       "suggestedFix": "Koulussamme on kolme opettajaa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'У нас в школе трое учителей.' and 'Koulussamme on kolme opettajaa.' are not an accurate translation of each other. The translation for 'трое учителей' should be 'kolme opettajaa', and 'в школе' to 'koulussamme.'",
#       "suggestedFix": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'opettajia' in the sentence 'Opettajia on kolme koulussamme.' should be fixed to match the correct sentence structure.",
#       "suggestedFix": "Koulussamme on kolme opettajaa."
#     }
#   }
# }
# {
#   "id": 4708,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'работы' does not directly appear in the given form in the Russian sentence.",
#       "suggestedFixSentence": "У меня много работы, которую нужно сделать.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4713,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is accurate in meaning but the word form used in the sentence doesn't match exactly with the provided Russian word.",
#       "suggestedFix": "Meidän koirat ovat väsyneitä pitkän kävelyn jälkeen. = Наши собаки усталые после долгой прогулки."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'усталые' does not appear directly in the sentence, though 'устали' is used.",
#       "suggestedFixSentence": "Наши собаки усталые после долгой прогулки.",
#       "suggestedFixWord": "устали"
#     }
#   }
# }
# {
#   "id": 4715,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minulla on punaisia mansikoita puutarhassani.' translates to 'I have red strawberries in my garden,' while the Russian sentence 'У меня в саду растёт красная клубника.' translates to 'Red strawberries grow in my garden.' The translations are not fully equivalent.",
#       "suggestedFix": "Minulla kasvaa punaisia mansikoita puutarhassani."
#     }
#   }
# }
# {
#   "id": 4719,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The phrase 'Книга женщин' is awkward and unnatural in Russian. A more appropriate phrase would be 'Женская книга' which means 'women's book'.",
#       "suggestedFix": "Женская книга находится на столе."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'naisien' is grammatically incorrect; it should be 'naisten'.",
#       "suggestedFix": "Naisten kirja on pöydällä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'женщин' does not appear in the suggested sentence. A synonym or related term should be used to keep the sentence natural.",
#       "suggestedFixSentence": "Книга женщин находится на столе.",
#       "suggestedFixWord": "женщин, женской"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'naisien' is used but should be 'naisten' to be correct.",
#       "suggestedFix": "naisten"
#     }
#   }
# }
# {
#   "id": 4720,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not contain the word 'вопросами' in any form. To make the sentence natural and accurate, a synonym or a related term should be used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вопросами, вопросы"
#     }
#   }
# }
# {
#   "id": 4722,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'столами' does not appear in the sentence. The correct form 'столами' means 'with tables', while 'под столами' means 'under the tables'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "столами, под столами"
#     }
#   }
# }
# {
#   "id": 4732,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Opiskelijoiden työjoukkue kokountuu ennen seuraavaa oppituntia.' contains a typo. The correct word is 'kokoontuu' instead of 'kokountuu'.",
#       "suggestedFix": "Opiskelijoiden työjoukkue kokoontuu ennen seuraavaa oppituntia."
#     }
#   }
# }
# {
#   "id": 4735,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish 'Pekka ei ole iloinen.' means 'Pekka is not happy.' in English. However, 'Пекка не рад.' specifically means 'Pekka is not glad.' This is a subtle difference in emotion that could be better captured.",
#       "suggestedFix": "Пекка не счастлив."
#     }
#   }
# }
# {
#   "id": 4737,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translation from Finnish 'Tytöt eivät ole iloisia.' to Russian 'Девочки не рады.' is correct, but there are small issues in the Finnish sentence provided.",
#       "suggestedFix": "Tytöt eivät ole iloisia."
#     }
#   }
# }
# {
#   "id": 4741,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'Печь' in Russian should translate to 'leipominen' in Finnish. The current translation 'Leipominen ei ole hauskaa' does not match 'Печь – не весело.'",
#       "suggestedFix": "Печь – не весело. -> Leipominen ei ole hauskaa."
#     }
#   }
# }
# {
#   "id": 4762,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Та машина новее, чем эта машина.' is grammatically correct but can be improved to sound more natural by removing the repetition of 'машина'.",
#       "suggestedFix": "Та машина новее, чем эта."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'более новый' does not appear in the sentence. 'Новее' is used, which is a comparative form of 'новый'. To keep 'более новый' in some form in the sentence, a slight modification is suggested.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "новее, более новый"
#     }
#   }
# }
# {
#   "id": 4763,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'новейший, самый новый' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Моя новейшая книга очень захватывающая.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4764,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun hiukseni ovat pitempi kuin sinun.' is not correct because the adjective 'pitempi' should be in the plural form to match 'hiukset'.",
#       "suggestedFix": "Minun hiukseni ovat pitemmät kuin sinun."
#     }
#   }
# }
# {
#   "id": 4765,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'самый длинный' does not appear in the specified form in the sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "самый длинный, самый длинная"
#     }
#   }
# }
# {
#   "id": 4766,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'лучший' is not in the normal word order for the phrase. Typically, it would be 'Ты – мой лучший друг.'.",
#       "suggestedFixSentence": "Ты – мой лучший друг.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4767,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Mitä sinä pidät eniten Suomessa?' is ungrammatical. In Finnish, the correct construction should be 'Mistä sinä pidät eniten Suomessa?'",
#       "suggestedFix": "Mistä sinä pidät eniten Suomessa?"
#     }
#   }
# }

# %%
# Example usage
chapter_name = 'sm2_new_kap8'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 4576,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть в силе, быть действительным' does not appear in any form in the Russian sentence. The sentence uses 'действителен,' which is correct but not one of the provided synonyms.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "быть в силе, быть действительным, действителен"
#     }
#   }
# }
# {
#   "id": 4579,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Me haluttais mennä elokuvissa tänään.' is not grammatically correct. The verb 'haluttais' should not be used in this context. The correct form is 'Me haluaisimme mennä elokuviin tänään.'",
#       "suggestedFix": "Me haluaisimme mennä elokuviin tänään."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'me haluttais' in Finnish is a slang form that does not appear in the formal sentence. The appropriate form 'haluaisimme' should be used.",
#       "suggestedFix": "me haluaisimme"
#     }
#   }
# }
# {
#   "id": 4584,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'посмотреть' specifically means 'to look' or 'to watch', but the sentence uses 'посмотреть за детьми', which translates to 'look after the children'. While 'посмотреть' is included in some form, it may be clearer to use 'присмотреть' which means 'to look after' someone.",
#       "suggestedFixSentence": "Мог бы ты присмотреть за детьми немного, пока я схожу в магазин?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4589,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'вмещаться' does not appear in the sentence. The word 'умещаться' is used instead, which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вмещаться, умещаться"
#     }
#   }
# }
# {
#   "id": 4591,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is grammatically incorrect. It should be 'Tämän puhelimen paras ominaisuus on sen pitkä akun kesto.'",
#       "suggestedFix": "Tämän puhelimen paras ominaisuus on sen pitkä akun kesto."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian does not use the word corresponding to 'ominaisuus'. The Russian sentence says 'Лучшей функцией', which translates to 'best function' rather than 'best feature/characteristic'.",
#       "suggestedFix": "Лучшей особенностью этого телефона является долгий срок службы его аккумулятора."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'особенность' or its forms do not appear in the Russian sentence.",
#       "suggestedFixSentence": "Лучшей особенностью этого телефона является долгий срок службы его аккумулятора.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4594,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not fully accurate. 'me tarvittais' translates to 'нам бы понадобилось', but the provided Russian sentence translates to 'we need help' which is 'нам нужна помощь'.",
#       "suggestedFix": "Извините, нам бы понадобилась помощь с этой картой."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нам бы понадобилось' does not appear in the Russian sentence. Instead, 'нам нужна помощь' is used.",
#       "suggestedFixSentence": "Извините, нам бы понадобилась помощь с этой картой.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4595,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Tää on mun kahvi, missä on sun?' is unnatural. A more natural sentence would use the form 'sun kahvi.'",
#       "suggestedFix": "Tää on mun kahvi, missä on sun kahvi?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'этот' does not appear explicitly in the sentence 'Это мой кофе, где твой?'",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "это (этот)"
#     }
#   }
# }
# {
#   "id": 4597,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'трудный' does not appear in the Russian sentence. The word 'сложная' is used instead, which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "трудный, сложный"
#     }
#   }
# }
# {
#   "id": 4598,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates to 'That is my coffee cup,' whereas the Russian sentence says 'This coffee cup is mine.' The nuance and phrasing differ slightly.",
#       "suggestedFix": "Tuo kahvikuppi on minun."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тот' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "та (тот, та, то, те)"
#     }
#   }
# }
# {
#   "id": 4601,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'какая цена' appears in the sentence, but the word 'сколько стоит', which is also part of the given word in Russian, does not appear in any form.",
#       "suggestedFixSentence": "Ты знаешь, сколько стоит эта рубашка?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4604,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Voitko antaa tän kirjan minulle?' uses an informal colloquial form 'tän'. It should be 'tämän' for standard Finnish.",
#       "suggestedFix": "Voitko antaa tämän kirjan minulle?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The provided Russian word is 'этот', but the sentence uses 'эту' which is a form of 'этот'. To ensure clarity, it's better to list all forms in the word definition.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "этот (эта, это, эти)"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The provided Finnish word is 'tän (tämän)', but 'tän' is colloquial and should be 'tämän' in standard language.",
#       "suggestedFix": "tämän (tän)"
#     }
#   }
# }
# {
#   "id": 4605,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence should use 'kuulokkeeni' instead of 'kuulokkeet' to be grammatically correct.",
#       "suggestedFix": "Minun kuulokkeeni ovat rikki, tarvitsen uudet."
#     }
#   }
# }
# {
#   "id": 4606,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence uses 'Безусловно,' which translates more closely to 'certainly' or 'undoubtedly' rather than 'обязательно' which translates to 'necessarily' or 'definitely.' This makes the sentence feel less natural.",
#       "suggestedFix": "Обязательно, мы можем встретиться завтра в кафе."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обязательно' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Обязательно, мы можем встретиться завтра в кафе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4609,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'остаться' or its synonym does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Сколько времени ещё осталось в наличии?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4612,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "Suomenkielinen lause ei ole täysin luonteva ja siinä on kielioppivirhe.",
#       "suggestedFix": "Minun täytyy tehdä ostokset viikonlopuksi."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "Suomenkielinen lause ei vastaa täysin venäläistä käännöstä, koska se ei sisällä sanaa 'viikonlopuksi'.",
#       "suggestedFix": "Minun täytyy tehdä ostokset viikonlopuksi."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "Sana 'ostos' ei esiinny täysin luonnollisessa muodossa suomenkielisessä lauseessa.",
#       "suggestedFix": "ostos, ostokset"
#     }
#   }
# }
# {
#   "id": 4614,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мне нужно быть сегодня в продуктовом магазине' is grammatically correct, but it sounds unnatural. The phrase 'быть в продуктовом магазине' doesn't correspond well with the idea of 'ходить за покупками'. It would be better to use a verb like 'пойти' or 'идти'.",
#       "suggestedFix": "Мне нужно пойти сегодня в продуктовый магазин."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun täytyy olla tänään ruokakaupassa' is grammatically correct, but it doesn't sound natural for the context. The phrase 'olla ruokakaupassa' doesn't convey the idea of 'käydä ostoksilla'. It would be better to use 'käydä'.",
#       "suggestedFix": "Minun täytyy käydä tänään ruokakaupassa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of the sentence is not accurate as the constructions used in both sentences do not convey the intended meaning of 'ходить за покупками' and 'käydä ostoksilla'. The suggested corrections should be 'Мне нужно пойти сегодня в продуктовый магазин.' (Russian) and 'Minun täytyy käydä tänään ruokakaupassa.' (Finnish).",
#       "suggestedFix": null
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть' does not naturally fit within the context of 'ходить за покупками'. The sentence should use a more appropriate verb for 'ходить за покупками' such as 'пойти'.",
#       "suggestedFixSentence": "Мне нужно пойти сегодня в продуктовый магазин.",
#       "suggestedFixWord": "пойти (ходить за покупками)"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'olla' does not naturally fit within the context of 'käydä ostoksilla'. The sentence should use 'käydä' to convey this idea properly.",
#       "suggestedFix": "käydä (käydä ostoksilla)"
#     }
#   }
# }
# {
#   "id": 4622,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian isn't accurate. 'Kierrätyskeskus' translates to 'центр переработки' or 'центр утилизации', not 'магазин подержанных товаров'.",
#       "suggestedFix": "Пойдём завтра в центр переработки, может что-то найдём?"
#     }
#   }
# }
# {
#   "id": 4632,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'плохого качества' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Эта футболка плохого качества, поэтому она не продержится долго.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4634,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'корзина для покупок' does not appear in the sentence 'Добавьте этот хлеб в корзину, пожалуйста.' There is a need for a synonym or related term to fit the given sentence.",
#       "suggestedFixSentence": "Добавьте этот хлеб в корзину для покупок, пожалуйста.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4639,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct, but the word 'доставка' (delivery) is used instead of 'поставка' (supply). 'Поставка' is more appropriate in this context.",
#       "suggestedFix": "Мог бы ты объяснить мне условия поставки из этого договора?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "'условия доставки' (delivery terms) is used instead of 'условия поставки' (supply terms).",
#       "suggestedFixSentence": "Мог бы ты объяснить мне условия поставки из этого договора?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4641,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'срок доставки' does not appear in the sentence in any form. 'Срок поставки' is used instead, which is closely related, but not the same.",
#       "suggestedFixSentence": "Каков срок доставки этого товара?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4643,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation provided for the word 'Kirjaudu' in Finnish corresponds to 'Войти' in Russian. Both mean 'to log in' or 'sign in'. Since there are no sentences provided, the translation accuracy is based only on the words.",
#       "suggestedFix": null
#     }
#   }
# }
# {
#   "id": 4650,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'liike' translates to 'business' or 'shop', which is not an exact match for the Russian 'магазин', which means 'store' or 'shop'. The sentences are otherwise accurate, but there's a slight discrepancy in the word meaning.",
#       "suggestedFix": "The Finnish word should be 'kauppa' instead of 'liike'. So, the Finnish sentence should be 'Tämä on uusi kauppa kaupungissamme.'"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The given word 'liike' does appear in the sentence, but 'liike' translates to 'business' rather than 'store'. The word 'kauppa' would be a more accurate translation for 'магазин'.",
#       "suggestedFix": "The Finnish word should be 'kauppa' instead of 'liike'."
#     }
#   }
# }
# {
#   "id": 4655,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'оплата через интернет' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Вы можете без труда провести оплату через интернет в интернет-банке.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4662,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence mentions 'сколько стоит доставка этого товара' which translates to 'how much is the delivery of this product', but it doesn't explicitly include 'плата за доставку' (delivery fee). The Finnish sentence explicitly asks for 'toimitusmaksu' (delivery fee), so the translation isn't fully accurate.",
#       "suggestedFix": "Можешь ли сказать, сколько составляет плата за доставку этого товара?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence uses 'доставка' which means 'delivery', but it does not include 'плата за доставку' which means 'delivery fee'.",
#       "suggestedFixSentence": "Можешь ли сказать, сколько составляет плата за доставку этого товара?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4664,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'доставить' does not appear in any form in the Russian sentence. However, a suitable synonym 'отнести' is used, which conveys the same meaning.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "доставить, отнести"
#     }
#   }
# }
# {
#   "id": 4673,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Voisitko täyttä tämän palautuslomakkeen?' is not grammatically correct. The verb should be 'täyttää'.",
#       "suggestedFix": "Voisitko täyttää tämän palautuslomakkeen?"
#     }
#   }
# }
# {
#   "id": 4677,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Proektiryhmä päätti liittää uuden jäsenen tiimiinsä' is mostly fine, but there is a typo: 'Proektiryhmä' should be 'Projektiryhmä.'",
#       "suggestedFix": "Projektiryhmä päätti liittää uuden jäsenen tiimiinsä."
#     }
#   }
# }
# {
#   "id": 4678,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'внимательный' does not appear in the sentence. Instead, 'внимателен' is used. We can use 'Будь внимательный' as it maintains the meaning and keeps the sentence natural.",
#       "suggestedFixSentence": "Будь внимательный, когда пишешь свой адрес.",
#       "suggestedFixWord": "внимателен"
#     }
#   }
# }
# {
#   "id": 4679,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is not entirely correct. The plural form 'инструкции' is used, while the singular form 'инструкция' would be more appropriate in this context.",
#       "suggestedFix": "Могли бы вы дать мне инструкцию, как найти станцию?"
#     }
#   }
# }
# {
#   "id": 4713,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'усталые' does not appear in any form in the Russian sentence. However, 'усталые' can be translated as 'устали'.",
#       "suggestedFixSentence": "Наши собаки усталые после долгой прогулки.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 4719,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Книга женщин находится на столе.' is grammatically incorrect and unnatural in Russian. The correct form should be 'Женская книга находится на столе.' or 'Книга женщин лежит на столе.'",
#       "suggestedFix": "Женская книга находится на столе."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Naisien kirja on pöydällä.' is grammatically unnatural in Finnish. The correct word should be 'naisten' instead of 'naisien'.",
#       "suggestedFix": "Naisten kirja on pöydällä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'naisien (naisten)' appears in an incorrect genetic form. The correct form should be 'naisten'.",
#       "suggestedFix": "naisten"
#     }
#   }
# }
# {
#   "id": 4720,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вопросами' does not appear in the given sentence in any form. The phrase uses 'вопросами' in the plural instrumental case.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вопросы"
#     }
#   }
# }
# {
#   "id": 4737,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish translation of 'Девочки не рады' is not accurate. The correct translation for 'Девочки не рады' would be 'Tytöt eivät ole iloisia'.",
#       "suggestedFix": "Tytöt eivät ole iloisia."
#     }
#   }
# }
# {
#   "id": 4743,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'В Лапландии не красиво' is not completely accurate. The Finnish sentence 'Lapissa ei ole kaunista' better translates to 'В Лапландии не красиво' or 'В Лапландии некрасиво' in Russian, which means 'Lapland is not beautiful' or 'There is nothing beautiful in Lapland.' To maintain the natural flow and correctness in Russian, the sentence should be adjusted accordingly.",
#       "suggestedFix": "В Лапландии некрасиво."
#     }
#   }
# }
# {
#   "id": 4751,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'старше' does not occur in the sentence in its exact form.",
#       "suggestedFixSentence": "Катя старше, чем Ирис.",
#       "suggestedFixWord": "старше (старше, чем)"
#     }
#   }
# }
# {
#   "id": 4762,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'более новый' does not appear in the Russian sentence in any form. Instead, the comparative form 'новее' is used.",
#       "suggestedFixSentence": "Та машина более новая, чем эта машина.",
#       "suggestedFixWord": "новее, более новый"
#     }
#   }
# }
# {
#   "id": 4764,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is not fully correct. The word 'pitempi' should be in plural form 'pidemmät' to agree with 'hiukseni' which is plural.",
#       "suggestedFix": "Minun hiukseni ovat pidemmät kuin sinun."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'pitempi' does not correctly agree with the plural noun 'hiukseni'. The correct form should be 'pidemmät'.",
#       "suggestedFix": "pidemmät"
#     }
#   }
# }
# {
#   "id": 4767,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Mitä sinä pidät eniten Suomessa?' is not grammatically correct. The correct phrase should be 'Mistä pidät eniten Suomessa?'.",
#       "suggestedFix": "Mistä pidät eniten Suomessa?"
#     }
#   }
# }

# %%
# !open .

# %%
chapter_name = 'sm3_kap4'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 5410,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вспоминаться' or its form does not appear in the Russian sentence. The sentence uses 'навевать,' which is not a synonym.",
#       "suggestedFixSentence": "Эта старая песня вспоминается летом.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5411,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'спустя' does not appear in the sentence. Instead, 'через' is used.",
#       "suggestedFixSentence": "Мы уезжаем в отпуск через неделю спустя.",
#       "suggestedFixWord": "спустя, через"
#     }
#   }
# }
# {
#   "id": 5412,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence uses a different word 'наверняка' which means 'for sure, probably', while 'обязательно' means 'necessarily, definitely'. It doesn't sound natural.",
#       "suggestedFix": "Это обязательно хорошая идея."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Tämä on taatusti hyvä idea.' aligns with 'обязательно' as 'definitely, certainly', not 'наверняка' as in the given Russian sentence.",
#       "suggestedFix": "Tämä on varmasti hyvä idea."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обязательно' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Это обязательно хорошая идея.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5416,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates to 'Join our company for dinner tonight,' whereas the Russian sentence says 'Join us for dinner tonight.' Both sentences are natural, but they slightly differ since the concept of 'company' or 'society' ('seura' or 'общество') is not clearly present in the Russian sentence.",
#       "suggestedFix": "Liity yhteiskuntaamme illalliselle tänään."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'общество' (society) does not appear in any form in the Russian sentence 'Присоединяйтесь к нам на ужин сегодня.'",
#       "suggestedFixSentence": "Присоединяйтесь к нашему обществу на ужин сегодня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5417,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'рынок' (market) does not appear in the sentence in any form. Instead, 'рыночной' appears, which is an adjective form meaning 'market square'.",
#       "suggestedFixSentence": "Завтра на рынке будет ярмарка.",
#       "suggestedFixWord": "рынок, рыночный"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'markkinat' does not appear explicitly in the sentence. Instead, 'kauppatorilla', which means 'market square' is used.",
#       "suggestedFix": "kauppatori, markkinat"
#     }
#   }
# }
# {
#   "id": 5418,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian is ungrammatical. The verb 'пришёл' isn’t typically followed by an infinitive like 'прочитать' without a preposition. It would be more natural to say, 'Я пришёл только что, чтобы прочитать новую новость.'",
#       "suggestedFix": "Я пришёл только что, чтобы прочитать новую новость."
#     }
#   }
# }
# {
#   "id": 5420,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'быть покорённым' does not appear in the Russian sentence in any form. 'Был полностью покорен' is the phrase used, but 'покорённым' is related.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "покорённый (быть покорённым)"
#     }
#   }
# }
# {
#   "id": 5421,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'помнить' or a related form does not appear in the sentence 'Не забудь взять с собой ключи.'",
#       "suggestedFixSentence": "Помни взять с собой ключи.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5422,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "In Finnish, the possessive suffix is typically used instead of the personal pronoun 'minun' for such phrases. Therefore, 'minun lempiväri' should be 'lempivärini'.",
#       "suggestedFix": "Lempivärini on sininen."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'lempiväri' should appear in its correct possessive form 'lempivärini' in the Finnish sentence to match natural usage.",
#       "suggestedFix": "lempivärini"
#     }
#   }
# }
# {
#   "id": 5425,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian translates 'kokonaan' as 'весь', which means 'all' or 'whole' rather than 'completely' or 'fully'. It does not accurately capture the sense of thoroughness conveyed by 'kokonaan'.",
#       "suggestedFix": "Он съел торт полностью."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'полностью' does not appear in the Russian sentence. Instead, 'весь' is used, which changes the nuance of the meaning.",
#       "suggestedFixSentence": "Он съел торт полностью.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5427,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'прежним' or its forms do not appear in the Russian sentence.",
#       "suggestedFixSentence": "Дом выглядел прежним после покраски.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5428,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish phrase 'pitkä viikonloppu' translates to 'long weekend' in English, which corresponds more to 'длинный уикэнд' in Russian rather than 'длинные выходные'. The term 'длинные выходные' translates to 'long holidays' and would be better translated as 'pitkät vapaapäivät' in Finnish.",
#       "suggestedFix": "pitkät vapaapäivät"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'pitkä viikonloppu' does not accurately reflect 'длинные выходные'. A more appropriate Finnish term would be 'pitkät vapaapäivät'.",
#       "suggestedFix": "pitkät vapaapäivät"
#     }
#   }
# }
# {
#   "id": 5429,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'увлекательная' in Russian translates to 'interesting' or 'engaging', whereas 'jännä' in Finnish translates to 'thrilling' or 'exciting'. The translations do not align perfectly as 'jännä' fits more closely with 'захватывающая'.",
#       "suggestedFix": "Tämä kirja on tosi kiinnostava!"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'захватывающая' does not occur in the Russian sentence. Instead, 'увлекательная' is used.",
#       "suggestedFixSentence": "Эта книга очень захватывающая!",
#       "suggestedFixWord": "увлекательная"
#     }
#   }
# }
# {
#   "id": 5433,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'С какого времени ты здесь учишься?' is grammatically correct but does not use 'с тех пор'.",
#       "suggestedFix": "С тех пор как ты здесь учишься?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Mistä asti sinä olet opiskellut täällä?' is translated more accurately as 'С каких пор ты здесь учишься?' which aligns better with 'с тех пор'.",
#       "suggestedFix": "С каких пор ты здесь учишься?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'с тех пор' does not occur in the given Russian sentence.",
#       "suggestedFixSentence": "С тех пор как ты здесь учишься?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5437,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Voisitko lopettaa melun?' is not entirely natural. A more natural sentence would be 'Voisitko lopettaa meluamisen?'",
#       "suggestedFix": "Voisitko lopettaa meluamisen?"
#     }
#   }
# }
# {
#   "id": 5438,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'illansuu' translates more closely to 'вечер' in Russian, rather than 'вечерняя пора' which feels more like 'evening time'. The essence of the sentence is correctly translated but there's a slight misalignment in specificity.",
#       "suggestedFix": "Ilta on kaunis aika käydä kävelyllä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вечер' does not appear in the Russian sentence. Instead, the word 'вечерняя' is used, which is an adjective form related to 'evening'. Even though it's related, the exact noun 'вечер' should appear as per the requirement.",
#       "suggestedFixSentence": "Вечер - прекрасное время для прогулки.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5440,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Ханна дорогая' appears incomplete and lacks a subject. In Russian, it's more natural to say 'Ханна, моя дорогая' or 'Дорогая Ханна'.",
#       "suggestedFix": "Ханна, моя дорогая"
#     }
#   }
# }
# {
#   "id": 5446,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'расспросить' does not appear in the Russian sentence. Only 'поспрашивать' (a variation of 'спрашивать') is present, but it is not a synonym of 'расспросить'.",
#       "suggestedFixSentence": "Можешь расспросить в ближайших ресторанах?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5468,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'давно' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Как здорово было увидеться спустя так давно!",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5508,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence translates to 'Let's go to the cinema today.' whereas the Finnish sentence translates to 'Let's go to the movies today.' Although both convey the same idea, the exact wording is different.",
#       "suggestedFix": "Lähdetään tänään elokuviin"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'lähdettäisiin' in Finnish suggests a conditional mood, whereas the Russian word 'пойдём' is in the indicative mood.",
#       "suggestedFix": "lähdetään"
#     }
#   }
# }
# {
#   "id": 5509,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is a bit awkward and would be more natural with 'На вечернюю прогулку мы не пошли бы, если бы шёл дождь.'",
#       "suggestedFix": "На вечернюю прогулку мы не пошли бы, если бы шёл дождь."
#     }
#   }
# }
# {
#   "id": 5511,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не давали бы' does not appear in the Russian sentence in any form. The sentence uses 'не дарили бы' which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "не дарили бы, не давали бы"
#     }
#   }
# }
# {
#   "id": 5513,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translation captures the essence of the conditional statement, but the precise translation of 'нельзя было бы' to 'ei voitaisi' is not completely accurate. A more accurate Finnish translation would be 'ei olisi voitu'.",
#       "suggestedFix": "Ellei sataisi, ei olisi voitu perua retkeä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нельзя было бы' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Если бы не шёл дождь, поездку нельзя было бы отменять.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ei voitaisi' is used, but given the context and the necessary precise translation, 'ei olisi voitu' fits better.",
#       "suggestedFix": "ei olisi voitu"
#     }
#   }
# }
# {
#   "id": 5515,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'ei mentäisi' should correspond to a more tentative or conditional form, but the provided sentence uses a direct form.",
#       "suggestedFix": "Ei mennä tänään ulos, koska sataa."
#     }
#   }
# }
# {
#   "id": 5516,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is ungrammatical. 'Avattaisiin' should be corrected to 'avata'.",
#       "suggestedFix": "Voisiko ikkunaa avata hieman?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence means 'Could the window be opened a little?' while the Russian sentence is 'Can we open the window a little?'. The intent is similar but not accurately translated.",
#       "suggestedFix": "Voisiko ikkunan avata hieman?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'открыли' (opened) doesn't match the necessity of exploring current potential action like 'открыть' (to open).",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "открыть"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "'Avattaisiin' (would be opened) is not suitable in the context of the given Finnish sentence.",
#       "suggestedFix": "avata"
#     }
#   }
# }
# {
#   "id": 5517,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не открыли бы' does not appear in any form in the sentence 'Дом не откроют без разрешения.'",
#       "suggestedFixSentence": "Дом не открыли бы без разрешения.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5520,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'А что если сбежать вместе из этой скучной ситуации?' is slightly ungrammatical and sounds awkward. The use of 'если' implies a conditional clause that is not correctly reflected in the rest of the sentence.",
#       "suggestedFix": "А что если мы сбежим вместе из этой скучной ситуации?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The original word 'сбежим' does not appear in the original sentence in any form. The closest form 'сбежать' appears, but it changes the meaning slightly.",
#       "suggestedFixSentence": "А что если мы сбежим вместе из этой скучной ситуации?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5521,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'не сбежали бы' does not appear in the sentence 'Из дома не сбежишь без ключа.' The sentence uses 'не сбежишь,' which is in a different form.",
#       "suggestedFixSentence": "Из дома не сбежали бы без ключа.",
#       "suggestedFixWord": "не сбежишь"
#     }
#   }
# }
# {
#   "id": 5525,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'было бы' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "В городе построили бы новый спортивный зал, если бы на это было бы деньги.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5526,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не было бы' does not appear in the Russian sentence, though the idea is conveyed with different words. The sentence 'Если бы на Рождество не дарили подарки, дети бы плакали.' does not use ",
#       "'не было бы', instead it says 'не дарили'. To keep the sentence natural, you could consider using synonyms or related terms in the translation.": "suggestedFixSentence",
#       "suggestedFixWord": "не дарили бы"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'ei olisi' does appear in the Finnish sentence in a slightly different form: 'ei olisi annettu'. This conveys the same meaning and is natural.",
#       "suggestedFix": "ei olisi annettu"
#     }
#   }
# }
# {
#   "id": 5528,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Без тебя еду бы не съели.' is slightly awkward. A more natural phrasing would be 'Без тебя еда бы не была съедена.'",
#       "suggestedFix": "Без тебя еда бы не была съедена."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не было бы съедено' does not appear in the Russian sentence in any form. The sentence uses 'не съели' instead, which is a different construction.",
#       "suggestedFixSentence": "Без тебя еда бы не была съедена.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5536,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'пока' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он живёт в Хельсинки пока.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5539,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of the Finnish sentence to Russian does not align well with the given word translation. 'olla tulossa' translates to 'быть в пути' in Russian, which is a better match for the context.",
#       "suggestedFix": "Автобус будет в пути через пять минут."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'прибывать' or any of its forms does not appear in the Russian sentence. The word used is 'приедет' which implies 'arrive' but does not reflect 'прибывать' properly.",
#       "suggestedFixSentence": "Автобус прибудет через пять минут.",
#       "suggestedFixWord": "прибывать, приезжать"
#     }
#   }
# }
# {
#   "id": 5540,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'до' does not appear in the sentence. Instead, 'с' is used, which means 'since'.",
#       "suggestedFixSentence": "Я ждал тебя до четырёх!",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5542,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'извиняться' does not appear in the Russian sentence 'Прошу прощения за задержку.'. A related term or synonym needs to be used in the sentence.",
#       "suggestedFixSentence": "Извиняюсь за задержку.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5544,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Russian 'почтой' does not appear in the sentence 'Вы можете отправить форму по почте.' Instead, the word 'почта' is used in the form 'по почте'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "по почте"
#     }
#   }
# }
# {
#   "id": 5546,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'по телефону' is not present in any form in the Russian sentence. The sentence uses the verb 'позвонить' (to call) instead.",
#       "suggestedFixSentence": "Можешь позвонить мне завтра по телефону?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5547,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'возбудить' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он собирается возбудить новый проект на следующей неделе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5548,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Laskuni tuli sähköisenä postissa.' is not grammatically correct. The correct form should be 'Laskuni tuli sähköpostitse.' to reflect the method of receiving the invoice more naturally.",
#       "suggestedFix": "Laskuni tuli sähköpostitse."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The Finnish sentence should indicate the receipt of the invoice through email. The current Finnish sentence suggests the electronic form but not specifically email.",
#       "suggestedFix": "Laskuni tuli sähköpostitse."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'sähköinen' should be used as 'sähköpostitse' in the context of receiving something by email.",
#       "suggestedFix": "Laskuni tuli sähköpostitse."
#     }
#   }
# }
# {
#   "id": 5550,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'рассмотрение' does not appear in the sentence 'Отзывы клиентов еще находятся в обработке.' The word 'обработке' is used instead.",
#       "suggestedFixSentence": "Отзывы клиентов еще находятся на рассмотрении.",
#       "suggestedFixWord": null
#     }
#   }
# }

# %%
chapter_name = 'sm3_kap3'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 5270,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is not grammatically correct. The correct form should be 'käydä sotia' instead of 'käydä sotaa' to fit in this context.",
#       "suggestedFix": "Kaikki haluavat rauhaa, mutta jotkut maat jatkavat käydä sotia."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'воевать' does not appear in the Russian sentence. Instead, the word 'вести войну' (to conduct war) is used.",
#       "suggestedFixSentence": "Все хотят мира, но некоторые страны продолжают воевать.",
#       "suggestedFixWord": "воевать, вести войну"
#     }
#   }
# }
# {
#   "id": 5275,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Johtaja on hyvä hallitseja.' is slightly unusual. The word 'hallitseja' is not typically used in this context. 'Johtaja' itself means leader or director.",
#       "suggestedFix": "Johtaja on hyvä johtaja."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'hallitseja' does not fit naturally in the given Finnish sentence. 'Johtaja' would be more appropriate.",
#       "suggestedFix": "johtaja"
#     }
#   }
# }
# {
#   "id": 5281,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Minun naapuri on luterilainen.' contains a grammatical error. The correct form should be 'Minun naapurini on luterilainen.'",
#       "suggestedFix": "Minun naapurini on luterilainen."
#     }
#   }
# }
# {
#   "id": 5282,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Usea lapsi leikkii puistossa.' is not fully correct. 'Usea lapsi' implies an individual, whereas the context suggests a plural form. 'Useita lapsia' is more accurate.",
#       "suggestedFix": "Useita lapsia leikkii puistossa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate due to the incorrect Finnish sentence. The corrected Finnish sentence translates accurately to the Russian sentence.",
#       "suggestedFix": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'usea' is not used in an appropriate form. It should be 'useita' to match the context of the sentence.",
#       "suggestedFix": "Useita"
#     }
#   }
# }
# {
#   "id": 5287,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence has a typo. 'писменного' should be corrected to 'письменного'.",
#       "suggestedFix": "Литературный язык — это официальный вариант письменного финского языка."
#     }
#   }
# }
# {
#   "id": 5295,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hänen aate on ympäristönsuojelu.' is grammatically incorrect. The correct form should use 'aatteensa' with possessive suffix.",
#       "suggestedFix": "Hänen aatteensa on ympäristönsuojelu."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'idea' in Russian translates to 'idea' in Finnish, not necessarily 'aate', which means 'ideology' or 'doctrine'. The sentences translate each other correctly, but the given word translations are mismatched.",
#       "suggestedFix": "Word in Finnish: idea"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'aate' does not appear in the Finnish sentence correctly due to grammar issues.",
#       "suggestedFix": "Word in Finnish: aate"
#     }
#   }
# }
# {
#   "id": 5297,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'влиять' from the word field 'казаться, влиять' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "казаться"
#     }
#   }
# }
# {
#   "id": 5311,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates to 'I hear the beautiful sound of birds in the forest.' which has the word 'ääni' that should correspond to 'звук' in Russian. However, the Russian sentence uses 'пение', which translates to 'singing.'",
#       "suggestedFix": "Я слышу красивый звук пения птиц в лесу."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'звук' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Я слышу красивый звук пения птиц в лесу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5329,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Sitä aihetta ei puhuttu eilen kokouksessa.' is not grammatically correct or natural in Finnish. A more natural construction would be 'Sitä aihetta ei käsitelty eilen kokouksessa.'",
#       "suggestedFix": "Sitä aihetta ei käsitelty eilen kokouksessa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given Finnish sentence 'Sitä aihetta ei puhuttu eilen kokouksessa.' does not accurately translate to the Russian sentence 'Эту тему вчера на собрании не обсуждали.', which means 'This topic was not discussed at the meeting yesterday.' The suggested fix 'Sitä aihetta ei käsitelty eilen kokouksessa.' better matches the meaning of the Russian sentence.",
#       "suggestedFix": "Sitä aihetta ei käsitelty eilen kokouksessa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'не обсуждалось' does not appear in any form in the sentence 'Эту тему вчера на собрании не обсуждали.'",
#       "suggestedFixSentence": "Эта тема вчера на собрании не обсуждалась.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'ei puhuttu' does not appear in any form in the sentence 'Sitä aihetta ei puhuttu eilen kokouksessa.'",
#       "suggestedFix": "ei käsitelty"
#     }
#   }
# }
# {
#   "id": 5337,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не пили' does not appear exactly in the sentence, but 'не пили' is close enough that synonyms 'не выпили', 'не употребили' could be used to make it match.",
#       "suggestedFixSentence": "Кофе не выпили утром.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5338,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мы гуляли в парке днем.' translates to 'We walked in the park in the afternoon,' which does not accurately match the Finnish sentence 'Me käveltiin puistossa iltapäivällä,' which translates to 'We walked in the park in the afternoon.' While both sentences describe a similar activity, the word choice should be consistent for accurate translation.",
#       "suggestedFix": "Мы ходили в парке днем."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'ходили' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Мы ходили в парке днем.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5339,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Me emme ole kävellyt kouluun tänään.' has a grammatical issue. The correct form would be 'kävelleet' for 'have walked' in the plural form.",
#       "suggestedFix": "Me emme ole kävelleet kouluun tänään."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is mostly accurate, but it slightly differs in meaning. 'ei kävelty' means 'have not walked' while 'не ходили' means 'didn't go'. A better match might be 'emmekä kävelleet' or similar.",
#       "suggestedFix": "not kävelleet"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ei kävelty' does not appear in the Finnish sentence; instead, the sentence uses 'kävellyt'.",
#       "suggestedFix": "emme kävelleet"
#     }
#   }
# }
# {
#   "id": 5341,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Me ei tavattu eilen.' is not grammatically correct. The correct form is 'Me emme tavanneet eilen.'",
#       "suggestedFix": "Me emme tavanneet eilen."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ei tavattu' does not appear in the correct form in the provided sentence. The appropriate form should be 'emme tavanneet'.",
#       "suggestedFix": "emme tavanneet"
#     }
#   }
# }
# {
#   "id": 5342,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation isn't entirely accurate. The Russian sentence focuses on the necessity for them to be on time, while the Finnish sentence suggests that they were needed at the meeting on time.",
#       "suggestedFix": "Heidän piti olla kokouksessa ajoissa."
#     }
#   }
# }
# {
#   "id": 5347,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Ruoka ei ole syöty.' is not correct because in Finnish, the passive perfect form should be used.",
#       "suggestedFix": "Ruokaa ei ole syöty."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ei ole syöty' occurs in the sentence but should be in a passive form, which is correctly applied in the suggested fix.",
#       "suggestedFix": "ei ole syöty"
#     }
#   }
# }
# {
#   "id": 5351,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate. The Russian sentence says 'because it wasn't eaten for a long time', while the Finnish sentence translates it literally as 'it hasn't been eaten'. The main nuance of 'not having been eaten' was lost.",
#       "suggestedFix": "Ruoka oli vanhaa, koska sitä ei oltu syöty pitkään aikaan."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не был съеден' or a related synonym does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Еда была старой, потому что её долго не съедали.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5362,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Он не хочет отпускать.' is incomplete because the verb 'отпускать' usually needs an object.",
#       "suggestedFix": "Он не хочет отпускать её/его/это."
#     }
#   }
# }
# {
#   "id": 5364,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided Russian and Finnish phrases do not exactly match in meaning. The Russian phrase translates to 'We end the tour at the hotel.' while the Finnish phrase translates to 'We end the tour to the hotel.'",
#       "suggestedFix": "Me päätämme kiertoajelun hotellilla."
#     }
#   }
# }
# {
#   "id": 5378,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Закрой обложки книг перед уходом.' is not fully natural. The correct phrase for closing the covers of books is 'Закрой крышки книг перед уходом.'",
#       "suggestedFix": "Закрой крышки книг перед уходом."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крышки' does not appear in some form in the given Russian sentence; instead, 'обложки' is used. 'крышки' should be used to align with the given word.",
#       "suggestedFixSentence": "Закрой крышки книг перед уходом.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5402,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Ne syö aamupalaa.' is not correct. In standard Finnish, the pronoun 'ne' is used for non-human plural subjects, whereas 'he' should be used for human plural subjects.",
#       "suggestedFix": "He syövät aamupalaa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne syö' does not correctly use proper Finnish grammar for human subjects.",
#       "suggestedFix": "he syövät"
#     }
#   }
# }
# {
#   "id": 5403,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'He eivät voi tulla nyt, koska ne pelaa jalkapalloa.' is not grammatically correct. The correct pronoun should be 'he' instead of 'ne', and 'pelaa' should be 'pelaavat'.",
#       "suggestedFix": "He eivät voi tulla nyt, koska he pelaavat jalkapalloa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne pelaa' does not appear in the Finnish sentence correctly. It should be 'he pelaavat'.",
#       "suggestedFix": "ne/he pelaavat"
#     }
#   }
# }

# %%
chapter_name = 'sm3_kap5'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 5553,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is incorrect. The Russian word 'тайна' should be used instead of 'секрет' to match the given term.",
#       "suggestedFix": "Это твоя тайна."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тайна' does not appear in any form in the sentence 'Это твой секрет.'.",
#       "suggestedFixSentence": "Это твоя тайна.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5555,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The given word 'загорелый' does not appear in any form in the sentence. However, the form 'загорел' is used instead.",
#       "suggestedFixSentence": "Он загорелый после отпуска.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5556,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'жизнерадостный' does not appear in the sentence 'Он всегда в таком хорошем настроении.'",
#       "suggestedFixSentence": "Он всегда такой жизнерадостный.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5560,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'взяться' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Он решил взяться за изучение финского языка.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5561,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'свободный писатель' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "свободный писатель, независимый писатель"
#     }
#   }
# }
# {
#   "id": 5566,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "In Finnish, possessive suffixes should be used to express possession. 'Meidän hääpäivä' should be 'meidän hääpäivämme'.",
#       "suggestedFix": "Muistathan, että meidän hääpäivämme on ensi viikolla."
#     }
#   }
# }
# {
#   "id": 5568,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is mostly correct but would be more natural with some adjustments, possibly adding a pronoun for clarity.",
#       "suggestedFix": "Tänään on tiistai, nimittäin minun lempipäiväni."
#     }
#   }
# }
# {
#   "id": 5570,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Kävin lääkärissä ja sain reseptin.' translates to 'Я ходил к врачу и получил рецепт.' However, it does not convey the sense of a 'visit' as the main action, but rather an incidental one.",
#       "suggestedFix": "Кäyntini lääkärissä oli hyödyllinen ja sain reseptin."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'визит' does not appear in the Russian sentence, which focuses on the action of going to the doctor rather than the visit itself.",
#       "suggestedFixSentence": "Мой визит к врачу был полезным, и я получил рецепт.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5571,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Срок родов ребенка в январе.' is not fully natural. A more typical way to say it would be 'Предполагаемая дата родов ребенка в январе.'",
#       "suggestedFix": "Предполагаемая дата родов ребенка в январе."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'предполагаемая дата родов' does not appear in the sentence 'Срок родов ребенка в январе.'.",
#       "suggestedFixSentence": "Предполагаемая дата родов ребенка в январе.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5575,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'неверный' does not appear in the sentence. The word used in the sentence is a form of 'неверен', which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "неверный, неверен"
#     }
#   }
# }
# {
#   "id": 5576,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'смочь' is not directly used in the Russian sentence. The synonym 'могу' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "мочь, смочь"
#     }
#   }
# }
# {
#   "id": 5579,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate. The Russian sentence means 'I wish you a good day,' while the Finnish sentence means 'I hope you have a good day.'",
#       "suggestedFix": "Toivotan sinulle hyvää päivää."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'надеяться' does not appear in any form in the given Russian sentence.",
#       "suggestedFixSentence": "Надеюсь, у тебя будет хороший день.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5581,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'адаптироваться' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Он постепенно учится адаптироваться к новой среде.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5586,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'невыразимый' does not appear in the sentence in any form. The word 'невыразимая' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "невыразимая, невыразимый"
#     }
#   }
# }
# {
#   "id": 5588,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'минуточку' does not appear in the sentence 'Подождите минутку, пожалуйста.'. A synonym 'минутку' is used instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "минутку, минуточку"
#     }
#   }
# }
# {
#   "id": 5590,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'уЗИ-снимок' does not appear in the Russian sentence. The sentence uses 'ультразвуковое изображение,' which is a different term.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "уЗИ-снимок, ультразвуковое изображение"
#     }
#   }
# }
# {
#   "id": 5591,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'беременна' is used in the sentence. However, the full equivalent phrase 'быть беременной' is not explicitly used, though the meaning is preserved. Since 'быть' is implied, it is contextually correct.",
#       "suggestedFixSentence": "Она сказала мне, что она беременна.",
#       "suggestedFixWord": "беременна, быть беременной"
#     }
#   }
# }
# {
#   "id": 5593,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minä synnyin Suomessa.' is slightly unnatural. The more natural form is 'Minä synnyin Suomessa.'",
#       "suggestedFix": "Synnyin Suomessa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "Both versions imply the act of giving birth. For the verb 'to be born' in Finnish, a better translation would be along the lines of 'olen syntynyt'.",
#       "suggestedFix": "Olen syntynyt Suomessa."
#     }
#   }
# }
# {
#   "id": 5596,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'rождение' in Russian translates to 'syntymä' in Finnish, but in this context, 'syntymäpäivänsä' is used instead. The translation could be more aligned by using 'день рождения' for birthday.",
#       "suggestedFix": "synnytys"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'рождение' does not appear in the sentence 'Его день рождения завтра.' The word used is 'день рождения', which is more accurate for 'birthday'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "рождение, день рождения"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'syntymä' does not appear in the sentence 'Hänen syntymäpäivänsä on huomenna.' The word 'syntymäpäivänsä' is used, which directly translates to 'birthday'.",
#       "suggestedFix": "syntymä, syntymäpäivä"
#     }
#   }
# }
# {
#   "id": 5603,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'отцовский отпуск' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Он берет отцовский отпуск после рождения ребенка.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5604,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'декретный отпуск' does not perfectly match 'perhevapaa', which translates more generally to 'parental leave'.",
#       "suggestedFix": "декретный отпуск или отпуск по уходу за ребенком"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'декретный отпуск' does not appear in the Russian sentence. Instead, a synonym 'отпуск по уходу за ребенком' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "декретный отпуск, отпуск по уходу за ребенком"
#     }
#   }
# }
# {
#   "id": 5606,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "Пособие по уходу за ребенком на дому не полностью представлено в предложении. Конструкция предложения звучит неестественно.",
#       "suggestedFix": "Пособие по уходу за ребенком на дому помогает семьям, в которых родители ухаживают за детьми дома."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "Основное слово 'пособие по уходу за ребенком на дому' не полностью присутствует в тексте.",
#       "suggestedFixSentence": "Пособие по уходу за ребенком на дому помогает семьям, в которых родители ухаживают за детьми дома.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5607,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'пособие на ребёнка' does not appear in the Russian sentence. Instead, 'детское пособие' is used, which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "пособие на ребёнка, детское пособие"
#     }
#   }
# }
# {
#   "id": 5610,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Tarvitsemme uuden kumin auton pyörään.' is mostly correct but 'kumin' should be 'renkaan' in this context.",
#       "suggestedFix": "Tarvitsemme uuden renkaan auton pyörään."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kummi' does not naturally fit the context. It should be 'rengas'.",
#       "suggestedFix": "rengas"
#     }
#   }
# }
# {
#   "id": 5614,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'разозлённый' is not used in the sentence. The word 'зол' is used instead.",
#       "suggestedFixSentence": "Он был разозлён из-за опоздания.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5617,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence's word 'обеспокоенный' translates to 'huolestunut' or 'levoton' but not 'ahdistunut' which would better match 'тревожный' in Russian.",
#       "suggestedFix": "Hän tuntuu huolestuneelta juuri nyt."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тревожный' does not appear in the Russian sentence in any form. A synonym like 'встревоженный' could fit well in the context.",
#       "suggestedFixSentence": "Он кажется встревоженным прямо сейчас.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5618,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses an incorrect form of the verb 'oppia'. It should be 'Olen kiinnostunut oppimaan suomea.' corrected to 'Olen kiinnostunut oppimaan suomea'.",
#       "suggestedFix": "Olen kiinnostunut oppimaan suomea."
#     }
#   }
# }
# {
#   "id": 5619,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian 'Я в восторге от этого нового проекта' translates to 'I am thrilled by this new project,' which is not the same as 'I am excited.' It sounds natural but doesn’t convey the same emotion as 'взволнованный.'",
#       "suggestedFix": "Я взволнован этим новым проектом."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'взволнованный' does not appear in the Russian sentence. The word used is 'в восторге,' which is not synonymous with 'взволнованный.'",
#       "suggestedFixSentence": "Я взволнован этим новым проектом.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5620,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of 'влюблённый' to 'ihastunut' is not entirely accurate. The correct translation should be 'rakastunut,' which more accurately captures the sense of 'being in love.' 'Ihastunut' means more like 'fond of' or 'taken with,' which is a milder expression.",
#       "suggestedFix": "Word in Finnish: rakastunut"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ihastunut' should be 'rakastunut' to match the sense of 'влюблённый.'",
#       "suggestedFix": "Olen rakastunut tähän kaupunkiin."
#     }
#   }
# }
# {
#   "id": 5622,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'испуганный' in Russian is an adjective, but the sentence uses the short-form participle 'испуган', which is also correct but doesn't match the form given in the flashcard word.",
#       "suggestedFixSentence": "Он испуганный, потому что увидел большого паука.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5623,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'облегчённый' does not appear in the sentence. Instead, 'облегчение' (relief) is used, which is related.",
#       "suggestedFixSentence": "Я действительно чувствую себя облегчённым, когда экзамен позади.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5625,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'молодой' does not appear in the sentence. However, its related term 'молодость' is used. To ensure accuracy, it would be better to include a synonym in the word list.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "молодой, молодость"
#     }
#   }
# }
# {
#   "id": 5626,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The term 'будучи богатым человеком' used in the sentence does not exactly match the given word 'будучи богатым мужчиной'. Since the word 'человек' (person) is used instead of 'мужчина' (man), the usage does not fully match.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "будучи богатым человеком"
#     }
#   }
# }
# {
#   "id": 5637,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'инженером' does not appear in any form in the Russian sentence. The sentence uses 'инженера', which is a different case.",
#       "suggestedFixSentence": "Алекс учился стать инженером.",
#       "suggestedFixWord": "инженера"
#     }
#   }
# }
# {
#   "id": 5638,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мы переделали старую сауну в дачу.' translates to 'We converted the old sauna into a dacha.' in English, while the Finnish sentence 'Me muutimme vanhan saunan mökiksi.' translates to 'We converted the old sauna into a cottage/hut.' Dacha is more associated with a summer house than a cottage/hut.",
#       "suggestedFix": "Мы переделали старую сауну в домик."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'домик' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Мы переделали старую сауну в домик.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5640,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not entirely accurate. The Finnish sentence 'Tuleeko vaimokseni?' means 'Will you become my wife?' The corresponding Russian sentence is 'Станешь моей женой?' which means 'Will you become my wife?' Thus, the translation difference is very subtle but notable in direct translation.",
#       "suggestedFix": "Tuleeko vaimokseni?"
#     }
#   }
# }
# {
#   "id": 5641,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word in Russian 'гостьей' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Тётя Лииса пришла к нам гостьей.",
#       "suggestedFixWord": "гости"
#     }
#   }
# }
# {
#   "id": 5664,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian 'Мы не можем решить проблему, не поговорив о ней.' is not using the word 'не говоря' in any form. The word 'поговорив' is used instead, which means 'having talked.'",
#       "suggestedFix": "Мы не можем решить проблему, не говоря о ней."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'не говоря' does not appear in the given Russian sentence.",
#       "suggestedFixSentence": "Мы не можем решить проблему, не говоря о ней.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5670,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'невыполнимый' translates to 'tehtävä' (impossible or unachievable task) and not 'tekemätön' (not done).",
#       "suggestedFix": "Tämä on mahdoton tehtävä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'tekemätön' (not done) does not accurately convey the meaning of 'невыполнимый'.",
#       "suggestedFix": "mahdoton"
#     }
#   }
# }
# {
#   "id": 5682,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Neljässä neljännes on sata prosenttia.' is slightly unnatural and grammatically incorrect in Finnish. It would be better phrased as 'Neljässä neljänneksessä on sata prosenttia.'",
#       "suggestedFix": "Neljässä neljänneksessä on sata prosenttia."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not entirely accurate. 'Neljännes' should correspond to 'четверть'. The sentence in Russian could be improved to better match the Finnish structure.",
#       "suggestedFix": "В четырёх четвертях содержится сто процентов."
#     }
#   }
# }
# {
#   "id": 5683,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The phrase 'живущий один' is grammatical but not as natural as it could be in Russian. A more natural way to say 'living alone' would be 'проживающий один'. Additionally, the word order could be improved.",
#       "suggestedFix": "Он проживающий один студент."
#     }
#   }
# }
# {
#   "id": 5684,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'часть' in Russian translates to 'part', whereas 'osuus' in Finnish translates to 'share' or 'portion'. The most accurate translation for 'osuus' would be closer to 'доля'.",
#       "suggestedFix": "Моя доля в этом проекте готова."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'доля' does not appear in the Russian sentence. Instead, the word 'часть' is used, which means 'part' and not 'share' or 'proportion' (доля).",
#       "suggestedFixSentence": "Моя доля в этом проекте готова.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5686,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not entirely accurate. The Russian phrase 'в частности' means 'in particular', which is close but not the same as 'mm.' (muun muassa) which means 'among other things'.",
#       "suggestedFix": "В продуктовом магазине продаются, в том числе, хлеб и молоко."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'в том числе' does not appear in some form in the Russian sentence as 'в частности' is used instead.",
#       "suggestedFixSentence": "В продуктовом магазине продаются, в том числе, хлеб и молоко.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5690,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The Russian sentence means 'People live longer,' while the Finnish sentence means 'People live older.'",
#       "suggestedFix": "Ihmiset elävät yhä pidempään."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'всё старше' in some form does not appear in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "всё дольше"
#     }
#   }
# }
# {
#   "id": 5694,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'весьма' is not used in the sentence in its form or synonymous form.",
#       "suggestedFixSentence": "Он весьма хороший повар.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5695,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Он уходящий руководитель' is grammatically correct, but 'уходящий руководитель' sounds slightly awkward and is not a commonly used expression. A more natural phrase would be 'уходящий с должности руководитель'.",
#       "suggestedFix": "Он уходящий с должности руководитель."
#     }
#   }
# }
# {
#   "id": 5696,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The provided Russian word 'оставаться' does not appear in the sentence.",
#       "suggestedFixSentence": "Оставайся спокойным, всё наладится.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5697,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Тот парень очень приятный.' translates to 'Tuo poika on tosi mukava.' in Finnish, but 'poika' means 'boy' or 'guy', not necessarily 'tyyppi'.",
#       "suggestedFix": "Тот тип очень приятный."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тип' does not appear in the Russian sentence. 'парень' means 'guy' or 'boy', which is a different term.",
#       "suggestedFixSentence": "Тот тип очень приятный.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5699,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'He ovat olleet avopari jo kolme vuotta.' translates to 'They have been a cohabiting couple for three years', while the Russian sentence translates more directly to 'They have been living in a civil marriage for three years'. 'Avopari' directly translates to 'cohabiting couple', while 'civil marriage' might be translated differently.",
#       "suggestedFix": "He ovat eläneet siviiliavioliitossa jo kolme vuotta."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish term 'avopari' does not correspond exactly to the Russian term 'гражданский брак'. It translates more directly to 'cohabiting couple'.",
#       "suggestedFix": "siviiliavioliitto"
#     }
#   }
# }
# {
#   "id": 5701,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word given is 'я положу,' but the sentence uses 'кладу' instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "кладу, я кладу"
#     }
#   }
# }
# {
#   "id": 5704,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided Russian sentence 'Мы накроем стол.' translates to 'Me katamme pöydän.' in Finnish. It is not a direct match for 'Me pannaan pöytä koreaksi.', which means 'We set the table festively.' or 'We decorate the table.'",
#       "suggestedFix": "Мы украшаем стол."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The given word 'мы накрываем' does not appear in the sentence 'Мы накроем стол.' The Russian sentence uses 'накроем,' which is a form of 'накрывать,' but it doesn't match the given word form 'мы накрываем.'",
#       "suggestedFixSentence": "Мы накрываем стол.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5706,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'He panee kirjat hyllyyn.' is not correct because 'panee' should be in plural form as 'panevat' when referring to 'they'.",
#       "suggestedFix": "He panevat kirjat hyllyyn."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ne panee' is incorrect as 'panee' should be in plural form 'panevat' when referring to 'they'.",
#       "suggestedFix": "ne panevat"
#     }
#   }
# }
# {
#   "id": 5709,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The word 'Odotanks mä sua?' in Finnish should be translated to 'Жду ли я тебя?' in Russian. Both words are in question form, the Russian phrase could also be used as 'Жду ли я тебя?'",
#       "suggestedFix": null
#     }
#   }
# }

# %%
chapter_name = 'sm3_kap6'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 5722,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'дело' does not occur in any form in the Russian sentence.",
#       "suggestedFixSentence": "Это интересное дело.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5728,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'где-то еще' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Я живу здесь, но работаю где-то еще.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5730,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The correct translation should capture the sense of 'olla tekemisissä' which means 'to interact' or 'to associate'.",
#       "suggestedFix": "Я хочу общаться с тобой."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'общаться' does not appear in the sentence 'Я хочу иметь дело с тобой'. A synonym or related term needs to be used to convey the meaning more accurately.",
#       "suggestedFixSentence": "Я хочу общаться с тобой.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5732,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'же' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Я люблю кофе, а Лииса же любит чай.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5733,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is mostly accurate in conveying the message, but it doesn't exactly match the given Russian phrase 'установить контакт'.",
#       "suggestedFix": "Voitko auttaa minua muodostamaan yhteyden naapureihin?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'установить контакт' does not appear in any form in the sentence.",
#       "suggestedFixSentence": "Можешь помочь мне установить контакт с соседями?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5735,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The Finnish sentence implies 'taka-ajatus', which directly translates to 'задняя мысль', not 'скрытый мотив'.",
#       "suggestedFix": "Кажется, у тебя есть задняя мысль."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'задняя мысль' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Кажется, у тебя есть задняя мысль.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5737,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'иметь обыкновение' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "У меня есть обыкновение бегать по утрам.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5742,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'другой' does not appear in the Russian sentence. 'Другой' translates to 'different' or 'other' and should be reflected in the sentence.",
#       "suggestedFixSentence": "Этот новый магазин другой, чем старый.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5748,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of 'Niin just!' (Niin juuri!) to Russian is missing. 'Niin just!' is a colloquial Finnish phrase that translates quite closely to 'Именно!' or 'Совершенно верно!' in Russian. This means 'Exactly!' or 'Precisely!' in English.",
#       "suggestedFix": "Именно!"
#     }
#   }
# }
# {
#   "id": 5749,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Tehdään se paremmalla ajalla.' translates to 'Сделаем это в более удобное время.' which slightly differs since 'в более удобное время' is closer in meaning to 'more convenient time' rather than 'more suitable time'.",
#       "suggestedFix": "Tehdään se sopivampaan aikaan."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в более удобное время' does not appear in the sentence in any form. 'более подходящее время' is somewhat close in meaning but not exactly the same.",
#       "suggestedFixSentence": "Сделаем это в более удобное время.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5751,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'совсем нет' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Нет! Совсем нет! Ни в коем случае!",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5753,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is mostly accurate, but the word 'например' (for example) is missing from both the Russian and Finnish sentences.",
#       "suggestedFix": "например, даже если идет дождь. / Voimme mennä mökille, vaikka esimerkiksi sataa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'например' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Мы можем поехать на дачу, например, даже если идет дождь.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'esimerkiksi' does not appear in the Finnish sentence in any form. Only 'vaikka' is present.",
#       "suggestedFix": "Voimme mennä mökille, vaikka esimerkiksi sataa."
#     }
#   }
# }
# {
#   "id": 5756,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "Although 'на самом деле' translates to 'ihän oikeasti' accurately, the Russian sentence does not contain the word 'правда' or its forms.",
#       "suggestedFix": null
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'правда' or its forms are not present in the Russian sentence.",
#       "suggestedFixSentence": "Мог бы ты правда вынести мусор?",
#       "suggestedFixWord": "правда, на самом деле"
#     }
#   }
# }
# {
#   "id": 5757,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate as 'Хорошие поступки могут принести пользу обществу.' translates to 'Hyvät teot voivat olla hyödyllisiä yhteisölle.' in Finnish, and vice versa.",
#       "suggestedFix": "Hyvät teot voivat olla hyödyllisiä yhteisölle."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'творить добро' does not occur in the Russian sentence in any form. A synonym like 'добрые дела' might be suitable for inclusion.",
#       "suggestedFixSentence": "Добрые дела могут принести пользу обществу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5759,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'предпочтительнее' does not appear in any form in the sentence. Instead, the word 'предпочел' which is derived from 'предпочесть' (to prefer) is used.",
#       "suggestedFixSentence": "Я бы предпочел пойти в кино сегодня, это предпочтительнее.",
#       "suggestedFixWord": "предпочел, предпочтительнее"
#     }
#   }
# }
# {
#   "id": 5762,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. The word 'ни один' translates to 'none' or 'neither' in English, similar to 'ei kumpikaan' in Finnish. However, the Russian sentence translates to 'None of us can play the piano.' which does not convey the specific meaning of 'ни один'.",
#       "suggestedFix": "Ни один из нас не умеет играть на пианино."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ни один' does not appear in the Russian sentence in any form. The sentence uses 'никто,' which means 'nobody', rather than 'ни один'.",
#       "suggestedFixSentence": "Ни один из нас не умеет играть на пианино.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5764,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'прекратить' does not appear in the Russian sentence 'Могу ли я закончить работу пораньше сегодня?'. Instead, the word 'закончить' is used, which is similar in meaning but not the same.",
#       "suggestedFixSentence": "Могу ли я прекратить работу пораньше сегодня?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5766,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нелюдимый' does not appear in the sentence. However, 'необщительный' is used, which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "необщительный, нелюдимый"
#     }
#   }
# }
# {
#   "id": 5773,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'забавный' does not appear in the Russian sentence in any form. A synonym 'смешной' is used instead.",
#       "suggestedFixSentence": "Этот фильм действительно забавный.",
#       "suggestedFixWord": "забавный, смешной"
#     }
#   }
# }
# {
#   "id": 5775,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'раздражающий' does not appear in the sentence 'Он иногда очень раздражает.'",
#       "suggestedFixSentence": "Он иногда бывает очень раздражающим.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5779,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'необычный' does not appear in the Russian sentence in any form. However, synonyms like 'особенный' or 'оригинальный' could be used.",
#       "suggestedFixSentence": "У него/неё есть необычный стиль одежды.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5787,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of 'Не говори больше!' is 'Älä puhu enää!' or 'Älä sano enempää!' in Finnish. 'Älä muuta sano!' translates directly to 'Don't say anything else!' which has a slightly different meaning from 'Don't say more!'",
#       "suggestedFix": "Älä puhu enää!"
#     }
#   }
# }
# {
#   "id": 5796,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'когда' in the Russian sentence should be 'тогда' to match the given word.",
#       "suggestedFixSentence": "Что тебе показалось самым странным в Финляндии, тогда когда ты сюда переехал?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5815,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is mostly correct but 'больше' should be replaced with 'большего', as 'большего' is in genitive case, which agrees with the comparative context provided by 'этого'.",
#       "suggestedFix": "В городе не нашлось дома большего этого!"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'большего' does not appear in the Russian sentence, although 'больше' is close. The correct form 'большего' should be used to match the given word.",
#       "suggestedFixSentence": "В городе не нашлось дома большего этого!",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5816,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence uses 'больше' as a comparative adverb. For 'большой' in its adjective form to be accurately conveyed, it should use 'больший' for a comparative context, especially with 'дом'.",
#       "suggestedFix": "Мы купили дом больший, чем у соседей."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'большой' does not appear in the correct form in the Russian sentence. The sentence uses 'больше' instead.",
#       "suggestedFixSentence": "Мы купили дом больший, чем у соседей.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5817,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мы переехали в дом больше, чем у соседей.' contains a grammatical error. The word 'больше' should agree in gender, number and case with 'дом' and be 'больший', also the comparative construction needs appropriate case after 'чем'.",
#       "suggestedFix": "Мы переехали в дом больший, чем у соседей."
#     }
#   }
# }
# {
#   "id": 5820,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is mostly correct but the word 'isompana' is not the most natural choice. 'Aikuisena' would be more appropriate.",
#       "suggestedFix": "Kun kasvan aikuisena, haluan matkustaa ympäri maailmaa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate. The Russian sentence does not capture the meaning of 'isompana' or 'aikuisena' in Finnish.",
#       "suggestedFix": "Когда я стану взрослым, я хочу путешествовать по всему миру."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'больше' or any of its forms do not appear in the Russian sentence.",
#       "suggestedFixSentence": "Когда я вырасту, я хочу больше путешествовать по всему миру.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5821,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence means 'I want to grow this plant more,' which is not idiomatic and sounds awkward. A more natural way would be 'Я хочу, чтобы это растение выросло больше,' meaning 'I want this plant to grow larger.'",
#       "suggestedFix": "Я хочу, чтобы это растение выросло больше."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'больше' does not naturally fit into the original Russian sentence. A better synonym like 'выше' (larger, taller) fits better.",
#       "suggestedFixSentence": "Я хочу, чтобы это растение выросло больше.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5825,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is incorrect. The Finnish sentence should convey the idea of moving to bigger cities from Helsinki.",
#       "suggestedFix": "Monet nuoret haluavat muuttaa suurempiin kaupunkeihin Helsingistä."
#     }
#   }
# }
# {
#   "id": 5827,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian is slightly unnatural. The word 'больше' should agree in gender and number with 'города', which is plural.",
#       "suggestedFix": "В Китае есть города больше, чем в Финляндии."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish contains a typo ('Kiinnassa' instead of 'Kiínassa').",
#       "suggestedFix": "Kiínassa on isompia kaupunkeja kuin Suomessa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'больше' is used instead of the provided word 'больших'. The grammatical number and case need to match the sentence structure.",
#       "suggestedFixSentence": "В Китае есть большие города, чем в Финляндии.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5828,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'больших' does not appear in the Russian sentence. Instead, 'старших' is used.",
#       "suggestedFixSentence": "Игрушки больших детей находятся здесь.",
#       "suggestedFixWord": "старших"
#     }
#   }
# }
# {
#   "id": 5829,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence is generally clear, but 'в более крупные города' could be misleading because Helsinki is already a large city. It might sound unnatural to suggest moving to 'larger' cities.",
#       "suggestedFix": "Многие молодые люди хотят переехать из Хельсинки в другие крупные города."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is mostly accurate, but both sentences imply moving to 'larger' cities than Helsinki, which might not be correct or natural.",
#       "suggestedFix": "Многие молодые люди хотят переехать из Хельсинки в другие крупные города. \n Monet nuoret haluavat muuttaa Helsinkiä muihin isoihin kaupunkeihin."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'большие' or its form does not appear in the sentence. The sentence uses 'крупные', which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "большие, крупные"
#     }
#   }
# }
# {
#   "id": 5830,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence uses 'крупных' instead of 'больших,' but it is grammatically correct and natural, although it uses a different word.",
#       "suggestedFix": "Китайцы живут в более больших городах, чем финны."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'больших' does not appear in the Russian sentence, instead 'крупных' is used.",
#       "suggestedFixSentence": "Китайцы живут в более больших городах, чем финны.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5831,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'большими' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Детская одежда садится при стирке и не подходит им, когда они становятся большими.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5832,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation of the Finnish sentence to Russian suggests that 'больше' should be used, but it is missing. The suggested translation should align with its meaning in the context of growing.",
#       "suggestedFix": "Дети растут больше / Дети становятся больше быстро."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'больше' does not appear in any form in the sentence 'Дети растут быстро.' This does not meet the requirement.",
#       "suggestedFixSentence": "Дети становятся больше быстро.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5833,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Kumpaa elokuvaa katsomme tänään?' is grammatically incorrect. A more natural way to ask the question is to use 'Mitä' instead of 'Kumpaa'.",
#       "suggestedFix": "Mitä elokuvaa katsomme tänään?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'kumpaa' in Finnish translates to 'which (one of two)' and not directly to 'which' like 'какой'. The more fitting translation for 'как?' would be 'mitä'.",
#       "suggestedFix": "Mitä elokuvaa katsomme tänään?"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kumpaa' does not naturally fit in this context. The word 'mitä' is a more appropriate translation for 'какой'.",
#       "suggestedFix": "mitä"
#     }
#   }
# }
# {
#   "id": 5836,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Kummassa kaupasta on paremmat hinnat?' is incorrect. The correct form should use 'kaupassa', not 'kaupasta'.",
#       "suggestedFix": "Kummassa kaupassa on paremmat hinnat?"
#     }
#   }
# }
# {
#   "id": 5837,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'когда' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Когда ты придешь на праздник, в субботу или в воскресенье?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5838,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct but not entirely natural. It would sound more natural to use 'что есть первым', preference-based wording, or simply 'что сначала' for such informal contexts.",
#       "suggestedFix": "Я не могу решить, что сначала, суп или салат."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "This sentence is close, but the word 'kummaksi' should be 'kumpi'. 'Kummaksi' would be more appropriate for 'which one' in the context of becoming something.",
#       "suggestedFix": "En osaa päättää, kumpi tulee ensin, keitto vai salaatti."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian and Finnish do not match correctly. The Russian version doesn't convey the concept of deciding the sequence (first or last) the same way as the Finnish one does. The suggestion fixes in both Russian and Finnish adjust this."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'странным' does not appear in any form in the given Russian sentence.",
#       "suggestedFixSentence": "Я не могу решить, будет странным сначала съесть суп или салат.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kummaksi' is used incorrectly here. The correct form would be 'kummaksi' in context of 'strange'. To make sense of 'strange' we need to adjust the synonym.",
#       "suggestedFix": "En osaa päättää, kumpi tuntuu kummaksi, keitto vai salaatti."
#     }
#   }
# }
# {
#   "id": 5841,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Я считаю оба варианта хорошими.' is grammatically correct, but it uses 'оба,' which is masculine/neuter, rather than 'обе,' which is feminine. Since we don't know the gender of 'вариант,' 'оба' is indeed the correct form.",
#       "suggestedFix": null
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate in terms of word choice. 'Обеих' translates to 'both' in the feminine form. The correct Russian sentence should reflect the feminine form specifically if 'вариант' was a feminine noun, but since it is not, the sentence remains correct but the choice of word 'оба' is appropriate.",
#       "suggestedFix": "Pidän molempia vaihtoehtoja hyvinä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обеих' does not appear in some form in the sentence. The sentence uses 'оба,' which is not the same as 'обеих.'",
#       "suggestedFixSentence": "Я считаю обеих варианты хорошими.",
#       "suggestedFixWord": "обеих, оба"
#     }
#   }
# }
# {
#   "id": 5842,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Оба ребёнка должны есть овощи.' uses 'оба' instead of 'обоих'. The word 'обоих' should appear in the sentence to match the flashcard word.",
#       "suggestedFix": "Обоих детей надо кормить овощами."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Оба ребёнка' does not correctly translate to 'kummankin'. It should use 'обоих детей'.",
#       "suggestedFix": "Обоих детей надо кормить овощами."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обоих' does not appear in the Russian sentence. The sentence uses 'оба' instead.",
#       "suggestedFixSentence": "Обоих детей надо кормить овощами.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5843,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в оба' does not appear in any form in the sentence. 'Оба' is used, but the phrase 'в оба' refers specifically to 'both in' rather than just 'both'.",
#       "suggestedFixSentence": "Я получил приглашение в оба праздника.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5845,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Я ел блины в оба дня выходных.' is grammatically correct but doesn't sound very natural in Russian.",
#       "suggestedFix": "Я ел блины оба дня выходных."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. The Finnish sentence indicates 'kumpanakin' which means 'both' in a distributive sense, whereas the Russian sentence does not convey this.",
#       "suggestedFix": "Я ел блины оба выходных дня."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'каждый' should be in the sentence, but it's missing.",
#       "suggestedFixSentence": "Я ел блины каждый выходной день.",
#       "suggestedFixWord": "каждый, оба"
#     }
#   }
# }
# {
#   "id": 5846,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian does not reflect the meaning 'for both days.' Using 'kummaksikin' implies 'for both,' but the Russian sentence only mentions 'on both days' without an equivalent emphasis.",
#       "suggestedFix": "Мы выбрали одно и то же занятие на оба дня."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'обоими' is not used in the sentence. The sentence uses 'оба дня' instead.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "на оба дня"
#     }
#   }
# }
# {
#   "id": 5848,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish 'ei kumpaakaan' to 'ни одного' is not accurate. 'ei kumpaakaan' means 'not either' or 'neither' in English and should be translated as 'ни того, ни другого' in Russian.",
#       "suggestedFix": "Word in Russian: ни того, ни другого"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ни одного' does not appear in the Russian sentence. The sentence uses 'ни того, ни другого', which is appropriate but does not match the provided word.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "ни одного, ни другого"
#     }
#   }
# }
# {
#   "id": 5849,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. The Russian sentence translates to 'Nobody liked the movie, nobody thought it was good.' The Finnish sentence translates to 'Neither liked the movie; neither thought it was good.'",
#       "suggestedFix": "Kukaan ei pitänyt elokuvasta, kukaan ei pitänyt sitä hyvänä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ни одного' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Фильм не понравился ни одному человеку, никто не считал его хорошим.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ei kummankaan' does not appear in any form in the Finnish sentence.",
#       "suggestedFix": "Kukaan ei pitänyt elokuvasta, kukaan ei pitänyt sitä hyvänä."
#     }
#   }
# }
# {
#   "id": 5851,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Minulla ei ole rahaa kummassakaan taskussa.' means 'I don't have money in either pocket,' whereas the Russian sentence 'У меня нет денег ни в одном из карманов.' translates more directly to 'I don't have money in a single pocket.'",
#       "suggestedFix": "Minulla ei ole rahaa yhdenkään taskun."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'ei kummassakaan' does not appear correctly in the context of the sentence. It should be revised to 'yhdenkään' to better match the Russian translation.",
#       "suggestedFix": "ei yhdenkään"
#     }
#   }
# }
# {
#   "id": 5852,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Я не люблю ни один из вариантов.' is not grammatically correct. It should be 'Мне не нравится ни один из вариантов.'",
#       "suggestedFix": "Мне не нравится ни один из вариантов."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not entirely accurate. 'Ei kumpanakaan' translates more aptly to 'ни один'. However, the sentence 'Я не люблю ни один из вариантов.' does not convey the same meaning as the Finnish sentence.",
#       "suggestedFix": "Мне не нравится ни один из вариантов."
#     }
#   }
# }
# {
#   "id": 5853,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Se ei kummaksikaan yllättänyt minua.' is awkward. The phrase 'ei kummaksikaan' is not a common expression in Finnish.",
#       "suggestedFix": "Se ei yllättänyt minua kummaksikaan."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'неудивительно' does not appear in the Russian sentence. Instead, the sentence uses 'не удивило' which means 'did not surprise'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "неудивительно, не удивительно"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ei kummaksikaan' is not used correctly in the Finnish sentence. Instead, the more natural phrase 'ei yllättänyt' is used.",
#       "suggestedFix": "ei yllättävästi"
#     }
#   }
# }
# {
#   "id": 5854,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not fully accurate. The Russian sentence 'Ни те, ни другие нам не подошли.' translates to 'Neither of them suited us' rather than 'Ei kummatkaan sopineet meille,' which specifically uses 'ei kummatkaan' to imply 'ei kumpikaan' (neither one).",
#       "suggestedFix": "Ei kumpikaan sopinut meille."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The phrase 'ни один' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Ни один из них нам не подошёл.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5858,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'присоединиться' does not appear in any form in the sentence. Instead, 'записаться' is used, which means 'to sign up' rather than 'to join'.",
#       "suggestedFixSentence": "Я хотел бы присоединиться к тренажерному залу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5864,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate. The Russian sentence means 'I had to stay home today,' which is different from the Finnish sentence 'Minä jouduin jäämään kotiin tänään,' which means 'I was forced to stay home today.'",
#       "suggestedFix": "Minun on täytynyt jäädä kotiin tänään."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'оказаться' does not appear in the Russian sentence. The word 'оказаться' means 'to find oneself' or 'to end up,' which fits the context of the sentence.",
#       "suggestedFixSentence": "Мне пришлось оказаться дома сегодня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5867,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'смочь' or any of its forms do not appear in the Russian sentence. The correct form would be 'могу' or 'смогу'.",
#       "suggestedFixSentence": "Я не смогу помочь тебе сегодня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5875,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'основной предмет' (основная специальность) does not appear as the exact term 'основная специальность' in the Russian sentence. The translation 'основная специальность' fits well in the context.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "основная специальность"
#     }
#   }
# }
# {
#   "id": 5883,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'чувство' in Russian does not occur in the provided sentence, which uses 'предчувствие' instead.",
#       "suggestedFixSentence": "У меня хорошее чувство насчет этого дня.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5886,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'собираться' does not appear in the sentence in any form. Instead, the past tense form 'собрались' is used, which is from the same root but technically a different aspect (perfective).",
#       "suggestedFixSentence": "Люди собирались на площади, чтобы праздновать.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5890,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'зловещий' should appear in some form in the Russian sentence. 'Зловеще' is the adverb form and doesn't directly match 'зловещий'.",
#       "suggestedFixSentence": "Небо сегодня выглядит действительно зловещим.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5891,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translation 'Kuulen lintujen ääniä metsässä.' accurately translates to 'Я слышу звуки птиц в лесу.', not 'Я слышу пение птиц в лесу.'",
#       "suggestedFix": "Я слышу звуки птиц в лесу."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'звук' or its form does not appear in the Russian sentence 'Я слышу пение птиц в лесу.'. Instead, the word 'пение' is used, which means 'singing' and not 'sound'.",
#       "suggestedFixSentence": "Я слышу звуки птиц в лесу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5892,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'совершенно' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Это было совершенно потрясающе!",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5907,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'забавлять' (to amuse, entertain) does not appear in any form in the sentence 'Меня не радует делать домашние задания.'. Instead, the word 'радовать' (to make happy, to please) is used.",
#       "suggestedFixSentence": "Меня не забавляет делать домашние задания.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5910,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'умереть' is not used in the sentence; a form of it ('умер') is used. Ideally, 'умереть' should be reflected in the suggested fixes for clarity.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "умереть (умер)"
#     }
#   }
# }
# {
#   "id": 5915,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word given is 'семя', but the sentence uses 'семечко'. Though related, they are different words. The word 'семя' is typically used in a more general sense, while 'семечко' often refers specifically to a small seed, such as from a fruit.",
#       "suggestedFixSentence": "Сегодня я посадил яблочное семя.",
#       "suggestedFixWord": "семечко"
#     }
#   }
# }
# {
#   "id": 5933,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'Suomes' is a colloquial form of 'Suomessa', which means 'in Finland'. The Russian counterpart 'В Суоми' could be more accurately or commonly expressed as 'в Финляндии' in formal contexts.",
#       "suggestedFix": "'в Финляндии'"
#     }
#   }
# }
# {
#   "id": 5936,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "In Finnish, 'kuitenki' is a colloquial form and should be 'kuitenkin' in standard writing.",
#       "suggestedFix": "Minun piti siivota tänään, mutta olin kuitenkin liian väsynyt."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kuitenki' should be 'kuitenkin' as it is the correct form in Finnish.",
#       "suggestedFix": "kuitenkin"
#     }
#   }
# }
# {
#   "id": 5937,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'En osannu vastata kysymykseen.' means 'I did not know how to answer the question,' which slightly differs from the Russian sentence 'Я не смог ответить на вопрос,' translating to 'I could not answer the question.' The main difference lies in the nuance of 'не смог' (could not) versus 'en osannu' (did not know how to).",
#       "suggestedFix": "En voinut vastata kysymykseen."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'en osannu' does not accurately match the concept of 'не смог' in Russian in the context of the provided sentences.",
#       "suggestedFix": "en voinut"
#     }
#   }
# }
# {
#   "id": 5938,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'Helsinkii' in the Finnish translation is misspelled; it should be 'Helsinki'.",
#       "suggestedFix": "Helsinki"
#     }
#   }
# }
# {
#   "id": 5939,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'punanen' is a dialectal or colloquial form of 'punainen'. In standard Finnish, 'punainen' should be used.",
#       "suggestedFix": "Kukkani on punainen."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'punanen' is used in the sentence, but it should be corrected to the standard form 'punainen'.",
#       "suggestedFix": "punainen"
#     }
#   }
# }
# {
#   "id": 5940,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'kirjottaa' is misspelled. The correct form is 'kirjoittaa'.",
#       "suggestedFix": "kirjoittaa"
#     }
#   }
# }
# {
#   "id": 5941,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'теленок' meaning 'calf' does not appear in the sentence 'Корова телится весной.'",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "телиться, теленок, родить теленка"
#     }
#   }
# }
# {
#   "id": 5942,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Tämä tehtävä on aika vaikee.' is not fully correct since 'vaikee' is colloquial. The standard form 'vaikea' should be used.",
#       "suggestedFix": "Tämä tehtävä on aika vaikea."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'трудный' does not appear in the Russian sentence. The sentence uses 'сложное,' which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "трудный, сложный"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'vaikee' does occur in the Finnish sentence, but it is colloquial. The standard form 'vaikea' should be used.",
#       "suggestedFix": "vaikea"
#     }
#   }
# }
# {
#   "id": 5943,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The word 'autoo' is in a colloquial or dialectal form. The correct form in standard Finnish should be 'autoa'.",
#       "suggestedFix": "Tarvitsemme autoa huomenna."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'autoo' does not match the standard grammatical form 'autoa'.",
#       "suggestedFix": "autoa"
#     }
#   }
# }

# %%
chapter_name = 'sm3_kap7'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 5946,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Meiltä puuttuu vielä muutama ruuvi.' is mostly correct, but the plural should be used to match the Russian version.",
#       "suggestedFix": "Meiltä puuttuu vielä muutama ruuvia."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Meiltä puuttuu vielä muutama ruuvi.' should use the plural form 'ruuvia' to properly translate 'нескольких винтов'.",
#       "suggestedFix": "Meiltä puuttuu vielä muutama ruuvia."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ruuvit' does not fully match the sentence context. The sentence uses 'ruuvi' where the context requires 'ruuvia' (partitive plural).",
#       "suggestedFix": "ruuvit, ruuvia"
#     }
#   }
# }
# {
#   "id": 5950,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нижняя полка' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Прикрепите верхнюю и нижнюю полку винтами к боковым доскам.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5951,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Voisitko antaa minulle naulat?' is grammatically unnatural in Finnish. The correct way to ask this would be 'Voisitko antaa minulle nauloja?'",
#       "suggestedFix": "Voisitko antaa minulle nauloja?"
#     }
#   }
# }
# {
#   "id": 5952,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'собирать' is not used in the sentence. Instead, 'собрать' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "собрать, собирать"
#     }
#   }
# }
# {
#   "id": 5955,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'эффективный' does not appear in any form in the Russian sentence. The Russian sentence uses the word 'мощный,' which means 'powerful.'",
#       "suggestedFixSentence": "Мой компьютер действительно эффективный.",
#       "suggestedFixWord": "эффективный, мощный"
#     }
#   }
# }
# {
#   "id": 5958,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тестовый победитель' does not directly appear in some form in the Russian sentence.",
#       "suggestedFixSentence": "Этот автомобиль является тестовым победителем многократных тестов.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5962,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'энергопотребление' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Энергопотребление зимой обычно больше, чем летом.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5964,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'воздушный поток' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Воздушный поток в комнате казался прохладным.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5966,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'фильтровать' or its forms do not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он использует кофейный фильтр, чтобы фильтровать кофейную гущу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5969,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Minun sydämessäni on paljon tyytyväisyyttä.' is mostly correct but the word 'tyytyväisyyttä' should be 'tyytyväisyyttä' due to partitive case being required after 'paljon'. ",
#       "suggestedFix": "Minun sydämessäni on paljon tyytyväisyyttä."
#     }
#   }
# }
# {
#   "id": 5971,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The original Russian sentence does not precisely translate 'в течение этого месяца' but rather 'каждый день в этом месяце', which means 'every day this month'. However, the Finnish sentence translates 'tämän kuun ajan', meaning 'during this month'.",
#       "suggestedFix": "Käyn kuntosalilla jokaisena päivänä tässä kuussa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в течение этого месяца' does not appear in the Russian sentence. The sentence uses 'в этом месяце' instead.",
#       "suggestedFixSentence": "Я хожу в тренажерный зал каждый день в течение этого месяца.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5972,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'приобрести' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Мне нужно приобрести новый зонт.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5973,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Стиральная машина - важный бытовой прибор.' translates to 'Pesukone on tärkeä kodinkone.' literally, meaning 'The washing machine is an important household appliance/device.' However, the provided Russian word is 'бытовая техника' which translates more accurately to 'household appliances' or 'home appliances.'",
#       "suggestedFix": "Стиральная машина - важная бытовая техника."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'бытовая техника' does not appear in the Russian sentence. Instead, the sentence uses 'бытовой прибор,' which is a more specific term referring to household appliance/device.",
#       "suggestedFixSentence": "Стиральная машина - важная бытовая техника.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5974,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'выкапывать' or its synonyms/related terms do not appear in the Russian sentence.",
#       "suggestedFixSentence": "Он выкапывает старые фотографии.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5975,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Ota kirja esille ja aloita lukeminen.' doesn't completely match 'Возьми книгу и начни читать.' The Russian word 'достать' more specifically matches 'ottaa esille' in Finnish.",
#       "suggestedFix": "Ota kirja ja aloita lukeminen."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'достать' does not appear in the sentence in any form.",
#       "suggestedFixSentence": "Достань книгу и начни читать.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5981,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a typographical error. The correct form should be 'alähyllylle' as 'alähylly' is not a correct Finnish word.",
#       "suggestedFix": "Laita kirjat alahyllylle."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a misspelling that makes the translation inaccurate.",
#       "suggestedFix": "The translation should use the correct form 'alahyllylle' to match the Russian 'нижнюю полку'."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'alähylly' is incorrect; it should be 'alahylly'.",
#       "suggestedFix": "alahylly"
#     }
#   }
# }
# {
#   "id": 5982,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'винт' translates more closely to 'screw' rather than 'ruuvi'. The correct translation for 'ruuvi' in Finnish to Russian should be 'болт'.",
#       "suggestedFix": "болт, винт"
#     }
#   }
# }
# {
#   "id": 5984,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "Russian sentence на полу doesn't sound quite right in this context. A more natural sentence would be: ‘Переверни книжный шкаф вверх дном’.",
#       "suggestedFix": "Переверни книжный шкаф вверх дном."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. ‘на полу’ translates to ‘on the floor’, which is not present in the Finnish sentence. A better Russian sentence would capture the meaning of ‘toisin päin’ more accurately.",
#       "suggestedFix": "Переверни книжный шкаф вверх дном."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word ‘наоборот’ does not appear in the Russian sentence. A more accurate translation would use it.",
#       "suggestedFixSentence": "Переверни книжный шкаф наоборот.",
#       "suggestedFixWord": "вверх дном"
#     }
#   }
# }
# {
#   "id": 5986,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a grammatical error. The noun 'tausta' should be in the partitive case after the verb 'olla' to indicate belonging.",
#       "suggestedFix": "Hänen taustansa on musiikissa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'proiskhozhdenie' usually translates to 'alkuperä', 'sukujuuret', or 'syntyperä' in Finnish, which means 'origin'. 'Tausta' is more commonly translated as 'background'.",
#       "suggestedFix": "Change 'proiskhozhdenie' to 'tausta' to match the given sentence."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'происхождение' does not appear in the Russian sentence in any form. The sentence uses the word 'тауст' in its context, relating to background, rather than origin or beginnings.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "тауст"
#     }
#   }
# }
# {
#   "id": 5990,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translation from Finnish to Russian does not match. The Finnish sentence means 'Lift the bookshelf upright against the wall,' which should translate to 'Подними книжный шкаф и поставь его к стене, чтобы он стоял вертикально.', whereas the provided Russian sentence means 'Lift the bookshelf and put it by the wall.'",
#       "suggestedFix": "Подними книжный шкаф и поставь его вертикально к стене."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'против' does not appear in the Russian sentence. 'Против' means 'against,' which fits better with 'к стене, противоположе(нно),' but is not present in this sentence.",
#       "suggestedFixSentence": "Подними книжный шкаф и поставь его противоположе стене.",
#       "suggestedFixWord": "к, напротив"
#     }
#   }
# }
# {
#   "id": 5993,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Можешь это прикрутить?' is grammatically correct and natural, but it uses the verb 'прикрутить' instead of 'закрутить'.",
#       "suggestedFix": "Можешь это закрутить?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'закрутить' does not appear in the sentence. Instead, 'прикрутить' is used.",
#       "suggestedFixSentence": "Можешь это закрутить?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 5995,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish has an issue because the word 'pultti' is used, which actually means 'bolt' in English. However, in the context of furniture, the appropriate term is 'ruuvi' (screw). The sentence should be 'Tarvitsen uuden ruuvin tähän tuoliin.' to be natural and accurate.",
#       "suggestedFix": "Tarvitsen uuden ruuvin tähän tuoliin."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate because the correct word for a bolt in Finnish is 'ruuvi' when referring to furniture.",
#       "suggestedFix": "Change the word 'pultti' to 'ruuvi' in Finnish."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'pultti' should not be used in the context of furniture as it generally refers to industrial bolts.",
#       "suggestedFix": "Use 'ruuvi' instead of 'pultti'."
#     }
#   }
# }
# {
#   "id": 6001,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сверлить' does not occur in the Russian sentence, although a form of the verb 'сверлить' (prosverlit') does.",
#       "suggestedFixSentence": "Отец собирается сверлить отверстие в стене.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6002,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'измеритель' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Можешь дать мне измеритель?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6005,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "In Finnish, the partitive case 'kakkua' should be 'kakun' in this context, as it refers to a specific object needing to be cut (similar to the English 'the cake' instead of 'some cake').",
#       "suggestedFix": "Voisitko leikata kakun, kiitos?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is mostly correct, but there is an issue with case usage in Finnish. 'kakkua' should be 'kakun'.",
#       "suggestedFix": "Voisitko leikata kakun, kiitos?"
#     }
#   }
# }
# {
#   "id": 6011,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'краска' does not appear in any form in the Russian sentence 'Я покрасил стену.'",
#       "suggestedFixSentence": "Я нанёс краску на стену.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6018,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'целый' does not appear in the sentence 'Книга цела.' in any form.",
#       "suggestedFixSentence": "Книга целая.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6019,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сломанный' does not appear in any form in the sentence. However, 'сломан' is used, which is a related term but not the exact given word.",
#       "suggestedFixSentence": "Телевизор сломанный.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6023,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct, but using 'поток' in the context of cookies in an oven sounds unnatural. It's better to use a word like 'противень' (baking tray) or 'партия' (batch).",
#       "suggestedFix": "Печенье находится на противне в духовке."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is grammatically correct, but using 'virta' in the context of cookies in an oven sounds unnatural in Finnish. It’s better to use a word like 'pellillä' (on the baking tray) or 'erä' (batch).",
#       "suggestedFix": "Evästeet ovat jatkuvasti pellillä uunissa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translations are not accurate given the context. 'Constant flow' should be translated to words like 'batch' or 'tray' in both languages to make sense in this context.",
#       "suggestedFix": "Печенье находится на противне в духовке. -> Evästeet ovat jatkuvasti pellillä uunissa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'поток' occurs in the sentence but it is not appropriate in this context.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "противень"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'virta' occurs in the sentence but it is not appropriate in this context.",
#       "suggestedFix": "pellillä"
#     }
#   }
# }
# {
#   "id": 6024,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate. 'Этот фильм просто отличный!' translates to 'Tämä elokuva on erinomainen!' in Finnish. The current Finnish sentence 'Tämä elokuva on huippuhyvä!' translates more accurately to 'Этот фильм просто супер!'",
#       "suggestedFix": "Этот фильм просто супер!"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'супер' does not appear in the Russian sentence. The sentence uses 'отличный' which is a synonym but does not directly translate to 'супер'.",
#       "suggestedFixSentence": "Этот фильм просто супер!",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6029,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates to 'I am terribly busy today.', whereas the Russian sentence translates to 'I have terribly many things to do today.' Thus, the translation is not accurate.",
#       "suggestedFix": "Minulla on hirveän paljon tekemistä tänään."
#     }
#   }
# }
# {
#   "id": 6030,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Tämä kirja on ei erityisen mielenkiintoinen.' is not grammatically correct or natural. In Finnish, 'ei erityisen' should be rephrased for the sentence to be natural.",
#       "suggestedFix": "Tämä kirja ei ole erityisen mielenkiintoinen."
#     }
#   }
# }
# {
#   "id": 6031,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'не очень' does not appear directly or in a similar form in the Russian sentence. Instead, 'не слишком' is used, which is a synonym but not the exact phrase.",
#       "suggestedFixSentence": "Это задание не очень сложное.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6045,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence structure is correct, but it uses 'самую важную роль' instead of 'самую большую роль', which is the focus word.",
#       "suggestedFix": "В большой семье самую большую роль обычно играет старший ребенок."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'самую большую' does not appear in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "самую важную"
#     }
#   }
# }
# {
#   "id": 6047,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крупнейших' does not appear in the Russian sentence. The form used is 'крупнейшие'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "крупнейшие, крупнейших"
#     }
#   }
# }
# {
#   "id": 6048,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Черепаха несет свой самый большой панцирь.' is almost correct but would be more natural as 'Черепаха несет свой самый большой панцирь'.",
#       "suggestedFix": "Черепаха несет самый большой панцирь."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'самую большую' is not used in the Russian sentence. 'самый большой' which is a different declension to suit the noun 'панцирь'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "самый большой"
#     }
#   }
# }
# {
#   "id": 6049,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крупнейшему' does not appear in any form in the Russian sentence. The sentence uses 'самый большой' instead of 'крупнейший'.",
#       "suggestedFixSentence": "Мои друзья переехали в крупнейший город Болгарии.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6050,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'isoimmassa' translates to 'в самом большом' rather than 'крупнейшем'. 'крупнейшем' is better translated as 'suurimmassa' in Finnish.",
#       "suggestedFix": "Ystäväni asuvat Bulgarian suurimmassa kaupungissa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крупнейшем' does not appear in the given Russian sentence. Instead, 'в самом большом' is used which means 'the biggest' rather than 'the largest'.",
#       "suggestedFixSentence": "Мои друзья живут в крупнейшем городе Болгарии.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'isoimmassa' means 'the biggest', which does not correspond to the Russian word 'крупнейшем'.",
#       "suggestedFix": "isoimmassa, suurimmassa"
#     }
#   }
# }
# {
#   "id": 6051,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Karhu on metsän isoimpana eläimenä.' is not grammatically correct. The correct structure should be 'Karhu on metsän suurin eläin.'",
#       "suggestedFix": "Karhu on metsän suurin eläin."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given Finnish sentence does not accurately describe the Russian sentence. The correct translation should be 'Karhu on metsän suurin eläin.'",
#       "suggestedFix": "Karhu on metsän suurin eläin."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'самым большим' does not appear in the Russian sentence. Instead, the synonym 'самым крупным' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "самым крупным"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'isoimpana' should be in the proper form to match the correct Finnish sentence.",
#       "suggestedFix": "suurin"
#     }
#   }
# }
# {
#   "id": 6052,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Дом сейчас быстро становится самым большим.' is unnatural in Russian. A more natural way to express this would be 'Дом сейчас быстро становится самым большим домом.'",
#       "suggestedFix": "Дом сейчас быстро становится самым большим домом."
#     }
#   }
# }
# {
#   "id": 6054,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a grammatical issue. 'Käyn usein kaupungin isoimpiin kauppoihin ostoksille' implies entering the shops to go shopping, however, 'isoimpiin' (which means 'to the biggest') requires a locative case for the action (going often to the biggest shops).",
#       "suggestedFix": "Käyn usein kaupungin suurimmissa kaupoissa ostoksilla."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not entirely accurate. The Russian sentence uses 'самые большие' which means 'the biggest', whereas the word given is 'крупнейшие' which means 'major' or 'largest'.",
#       "suggestedFix": "Я часто хожу за покупками в крупнейшие магазины города."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крупнейшие' does not appear in the Russian sentence; 'самые большие' is used instead.",
#       "suggestedFixSentence": "Я часто хожу за покупками в крупнейшие магазины города.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'isoimpiin' (which means 'to the biggest') is used correctly but it's in the wrong case for expressing 'going shopping'.",
#       "suggestedFix": "suurimmissa"
#     }
#   }
# }
# {
#   "id": 6055,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крупнейших' does not appear in the sentence in some form.",
#       "suggestedFixSentence": "В крупнейших городах много событий.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6056,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Heidän joulukuusensa ovat aina isoimpina.' is not correct. The correct form should be 'Heidän joulukuusensa ovat aina isoimpia.' to match the context and grammar.",
#       "suggestedFix": "Heidän joulukuusensa ovat aina isoimpia."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'isoimpina' should be 'isoimpia' to be grammatically correct in the given sentence.",
#       "suggestedFix": "isoimpia"
#     }
#   }
# }
# {
#   "id": 6057,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence Дети растут всё больше с каждым годом is grammatically correct but it does not use the word большими as required.",
#       "suggestedFix": "Дети становятся большими с каждым годом."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence means 'Children are growing more and more every year', whereas the Finnish sentence means 'Children grow bigger year by year'.",
#       "suggestedFix": "The Russian sentence should be closer to 'Children grow bigger year by year' to match the Finnish sentence."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'большими' does not appear in the Russian sentence. The word used 'больше' is a comparative form of 'большой'.",
#       "suggestedFixSentence": "Дети становятся большими с каждым годом.",
#       "suggestedFixWord": "большими"
#     }
#   }
# }
# {
#   "id": 6058,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Друг — лучшая помощь в повседневной жизни.' is mostly correct but could be slightly improved for better naturalness.",
#       "suggestedFix": "Друг — лучший помощник в повседневной жизни."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'лучший' does not appear in the suggested Russian sentence 'Друг — лучший помощник в повседневной жизни.'",
#       "suggestedFixSentence": "Друг — лучшая помощь в повседневной жизни.",
#       "suggestedFixWord": "лучший, лучшая, лучшее"
#     }
#   }
# }
# {
#   "id": 6059,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence means 'I always do my best.' The Russian sentence 'Я всегда стараюсь изо всех сил.' translates as 'I always try my best.' These sentences are similar in meaning but not a direct translation.",
#       "suggestedFix": "Minä yritän aina kaikkeni."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'лучшее' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Я всегда стараюсь сделать лучшее.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6061,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Хельсинки — самый большой город Финляндии.' is grammatically correct but uses 'самый большой,' which means 'the biggest'. 'Крупнейший' also means 'the biggest/largest' but isn't used in a superlative form here.",
#       "suggestedFix": "Хельсинки — крупнейший город Финляндии."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Helsinki on Suomen suurimpaan kaupunki.' is incorrect. 'Suurimpaan' should be in the basic form 'suurin' or 'suurimpia' if partitive is needed.",
#       "suggestedFix": "Helsinki on Suomen suurin kaupunki."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence translates to 'Helsinki is the largest city in Finland,' whereas the Finnish sentence means 'Helsinki is the largest city in Finland.' Due to the errors in both sentences, translation is correcting the Finnish sentence properly.",
#       "suggestedFix": "Helsinki on Suomen suurin kaupunki."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'крупнейшему' does not occur in the Russian sentence. The synonym 'крупнейший' should be used.",
#       "suggestedFixSentence": "Хельсинки — крупнейший город Финляндии.",
#       "suggestedFixWord": "крупнейшему, крупнейший"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'suurimpaan' is incorrectly used in the Finnish sentence. The correct form would be 'suurin'.",
#       "suggestedFix": "suurin"
#     }
#   }
# }
# {
#   "id": 6064,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ассортимент' does not appear in the sentence 'В магазине разнообразный выбор фруктов.'",
#       "suggestedFixSentence": "В магазине разнообразный ассортимент фруктов.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6066,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'метростанции' does not appear in the Russian sentence in the given form. Instead, 'станцию метро' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "метростанции, станция метро"
#     }
#   }
# }
# {
#   "id": 6068,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'работать' in some form does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Кофеварка функционирует неправильно.",
#       "suggestedFixWord": "функционировать, работать"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'toimia' in some form does not appear in the Finnish sentence.",
#       "suggestedFix": "toimii"
#     }
#   }
# }
# {
#   "id": 6072,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'совершенно' does not appear in any form in the Russian sentence. A synonym 'идеально' is used instead.",
#       "suggestedFixSentence": "Он справился с задачей совершенно.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6075,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'жарить' is supposed to be used in the sentence, but 'поджарить' is used instead.",
#       "suggestedFixSentence": "Утром приятно жарить хлеб на завтрак.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6076,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian is nearly correct but slightly unnatural. The term 'отличная' is technically correct but could be more naturally phrased.",
#       "suggestedFix": "Эта еда на вкус просто великолепна."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is understandable but again slightly unnatural. 'Mainiosti' is an adverb and doesn't fit well in this context.",
#       "suggestedFix": "Tämä ruoka maistuu mainiolta."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian should better reflect the nuance of 'mainiosti'. The current translation captures the essence but could be more precise.",
#       "suggestedFix": "Tämä ruoka maistuu mainiolta. -> Эта еда на вкус просто великолепна."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'отлично' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "великолепно, отлично"
#     }
#   }
# }
# {
#   "id": 6078,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'полный' or its form does not appear in the sentence. The word used in the sentence is 'полон', which is a form of 'полный' but not immediately recognizable as such without context.",
#       "suggestedFixSentence": "Ресторан полон сегодня вечером.",
#       "suggestedFixWord": "полон, полный"
#     }
#   }
# }
# {
#   "id": 6081,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'богатый' does not appear in the sentence 'Он очень богат.' in any form. The sentence uses the adjective 'богат' instead.",
#       "suggestedFixSentence": "Он очень богатый.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6082,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Voinko lainata kirjan?' translates to 'Могу я одолжить книгу?' in Russian. The current sentence does not accurately reflect the Finnish sentence.",
#       "suggestedFix": "Могу я одолжить книгу?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'одолжить' does not appear in the Russian sentence 'Могу я взять книгу?'",
#       "suggestedFixSentence": "Могу я одолжить книгу?",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6085,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нудный' (meaning 'boring' or 'tedious') does not appear in the Russian sentence. Instead, the word 'скучным' is used.",
#       "suggestedFixSentence": "Фильм был действительно нудным.",
#       "suggestedFixWord": "скучный (нудный)"
#     }
#   }
# }
# {
#   "id": 6088,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "There is a slight nuance difference. The Finnish sentence should emphasize 'excellent' humor sense, matching the Russian sentence more closely.",
#       "suggestedFix": "Hän on henkilö, jolla on erinomainen huumorintaju."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'с чувством юмора' is expected, but 'с отличным чувством юмора' is used. It's better to modify the word to show the accurate match.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "с отличным чувством юмора"
#     }
#   }
# }
# {
#   "id": 6091,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'нежная' does not appear in the sentence 'У него добрая улыбка.'.",
#       "suggestedFixSentence": "У него нежная улыбка.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6094,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän on hyvin viisas' translates to 'Он очень мудрый' rather than 'Он очень умный'.",
#       "suggestedFix": "Он очень мудрый."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мудрый' does not appear in any form in the sentence 'Он очень умный'.",
#       "suggestedFixSentence": "Он очень мудрый.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6095,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Он очень по-детски и любит игры.' is almost correct but 'по-детски' is an adverb and should be used to describe a verb. It would be better to use 'ребячливый' or a related adjective form to describe the person.",
#       "suggestedFix": "Он очень ребячливый и любит игры."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ребячливый' does not appear in the sentence in any form.",
#       "suggestedFixSentence": "Он очень ребячливый и любит игры.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6096,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Здоровое питание помогает оставаться в равновесии.' is grammatically correct but it does not sound very natural. A more natural translation would be 'Здоровое питание помогает сохранять уравновешенность.'",
#       "suggestedFix": "Здоровое питание помогает сохранять уравновешенность."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'уравновешенным' does not appear in the original Russian sentence in any form.",
#       "suggestedFixSentence": "Здоровое питание помогает сохранять уравновешенность.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6099,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'управляемый' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Этот проект хорошо управляем.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6101,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'мечтательный' should appear in the sentence in some form. However, 'мечтательно' is used instead which is an adverb form.",
#       "suggestedFixSentence": "Он смотрит в окно мечтательно.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6102,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'одарённый' does not appear in the Russian sentence in any form. The word 'талантливый' is used instead.",
#       "suggestedFixSentence": "Он действительно одаренный пианист.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6105,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from 'pulpahteleva' (Finnish) to 'булькающая' (Russian) is not accurate. 'Bулькающая' more accurately translates to 'gurgling' or 'bubbling', while 'pulpahteleva' is closer to 'pulsating' or 'frothy'.",
#       "suggestedFix": "Bулькающая: кипящая, пузырящаяся"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'булькающая' does not appear in the Russian sentence. Instead, 'пузырящаяся' is used, which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "пузырящаяся, бурлящая, кипящая"
#     }
#   }
# }
# {
#   "id": 6106,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hänen ihanne on rehellisyys ja ystävällisyys.' has a small grammatical issue. The correct form should be 'Hänen ihanteensa on rehellisyys ja ystävällisyys.'",
#       "suggestedFix": "Hänen ihanteensa on rehellisyys ja ystävällisyys."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'ihanne' does not appear in the correct possessive form in the Finnish sentence.",
#       "suggestedFix": "ihanteensa"
#     }
#   }
# }
# {
#   "id": 6107,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish 'majailla' to Russian 'проживать' does not accurately match the verb used in the sentence. The Finnish verb 'majailevat' aligns more closely with 'обитают' in Russian.",
#       "suggestedFix": "обитать, жить, проживать"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'проживать' does not appear in any form in the Russian sentence. The sentence uses 'обитают' instead, which is a synonym.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "обитать, жить, проживать"
#     }
#   }
# }
# {
#   "id": 6108,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'отношения' in the Russian sentence translates to 'relationship' in English, which is closer to 'ihmissuhde' in Finnish. However, the Russian word provided is 'взаимоотношение', which implies mutual relations. The Finnish sentence uses 'ihmissuhde', which refers to interpersonal relationships, not specifically mutual relations.",
#       "suggestedFix": "Use 'Hyvä suhde perustuu luottamukseen.' in Finnish to more accurately reflect the meaning of the Russian sentence."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The provided Russian word 'взаимоотношение' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": "Хорошие взаимоотношения основаны на доверии.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6120,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided Finnish sentence 'Mimmenen sää Lapissa on?' doesn't seem to be grammatically correct. The correct form should be 'Millainen sää Lapissa on?' which means 'What is the weather like in Lapland?' This phrase should be translated to Russian appropriately.",
#       "suggestedFix": "Millainen sää Lapissa on?"
#     }
#   }
# }
# {
#   "id": 6121,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence translations are missing.",
#       "suggestedFix": null
#     }
#   }
# }

# %%
chapter_name = 'sm3_kap8'
jsonlines_file_path = f"{chapter_name}_evaluations.jsonl"
print_incorrect_fields(jsonlines_file_path)
# Out:
# {
#   "id": 6125,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'измотанный' does not appear in the Russian sentence. Instead, the word 'вымотан' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вымотанный, измотанный"
#     }
#   }
# }
# {
#   "id": 6129,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'У тебя много силы духа.' translates to 'You have a lot of spirit' in English, which although related, does not directly translate to the Finnish sentence 'Sinulla on paljon sisu.' which means 'You have a lot of sisu.'",
#       "suggestedFix": "У тебя много упорства."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'упорство' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "У тебя много упорства.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6134,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Я действительно ужасно играю в футбол.' means 'I play football terribly', which is slightly different from 'I am terrible at playing football'. Also, the structure could be made more natural.",
#       "suggestedFix": "Я действительно ужасно играю в футбол."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Я действительно ужасно играю в футбол.' translates to 'I play football terribly', while the Finnish sentence 'Olen todella surkea pelaamaan jalkapalloa.' translates to 'I am really terrible at playing football'. The emphasis is slightly different.",
#       "suggestedFix": "Я действительно ужасен в игре в футбол."
#     }
#   }
# }
# {
#   "id": 6135,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Hän väittää olevansa asiantuntija muka.' is not grammatically natural. The word 'muka' should come before the verb to sound more natural.",
#       "suggestedFix": "Hän muka väittää olevansa asiantuntija."
#     }
#   }
# }
# {
#   "id": 6136,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'собираться' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Анна собиралась забыть ключи дома.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6139,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Этот певец действительно знаменитая суперзвезда.' is not grammatically correct because 'певец' is masculine and 'знаменитая суперзвезда' uses the feminine form 'знаменитая'.",
#       "suggestedFix": "Этот певец действительно знаменитый суперзвезда."
#     }
#   }
# }
# {
#   "id": 6144,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a small error in the verb form. The verb 'laukaista' should be 'laukaista' instead of 'laukaisa'.",
#       "suggestedFix": "Voitko laukaisa ilotulituksen nyt?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is mostly accurate, but it should account for the correct form of the verb in Finnish.",
#       "suggestedFix": "Voitko laukaisa ilotulituksen nyt?"
#     }
#   }
# }
# {
#   "id": 6147,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian and Finnish sentences both mean 'He paves the way for us.' However, the word 'выравнивать' means 'to level' or 'to align,' not 'to pave.'",
#       "suggestedFix": "Hän tasoittaa tietä meille. -> Hän tasoittaa meille tietä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'выравнивать' does not occur in any form in the Russian sentence.",
#       "suggestedFixSentence": "Он выравнивает нам путь.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6149,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'перерыв' translates to 'tauko' in Finnish rather than 'puoliaika'. 'Puoliaika' more specifically refers to 'halftime' in sports.",
#       "suggestedFix": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'puoliaika' does not accurately reflect 'перерыв'. It should be 'tauko' in this context.",
#       "suggestedFix": "tauko"
#     }
#   }
# }
# {
#   "id": 6150,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Гол очень важен в футболе.' is grammatically correct but does not convey the concept of a 'finish line' which is more relevant to racing or track events rather than football.",
#       "suggestedFix": "Финишная линия очень важна в гонках."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Maalipyikki on hyvin tärkeä jalkapallossa.' uses 'maalipyikki', which is not commonly used in Finnish and may seem confusing; it should convey the concept related to racing or finishing line.",
#       "suggestedFix": "Maaliviiva on hyvin tärkeä juoksukilpailuissa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate because 'Maalipyikki' and 'финишная линия' should be referring to the 'finish line', not goal in football.",
#       "suggestedFix": "Финишная линия on hyvin tärkeä juoksukilpailuissa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'финишная линия' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Финишная линия очень важна в гонках.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'maalipyikki' does not appear in a natural context in the Finnish sentence, and it should be replaced with a more appropriate term to convey the meaning of 'finish line'.",
#       "suggestedFix": "Maaliviiva on hyvin tärkeä juoksukilpailuissa."
#     }
#   }
# }
# {
#   "id": 6151,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'подряд' does not appear in the Russian sentence. Instead, 'друг за другом' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "друг за другом, подряд"
#     }
#   }
# }
# {
#   "id": 6152,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'On tärkeää ylläpitää hyvää suhdetta naapureiden välisen.' is not grammatically correct. It contains an error in the use of the word 'välisen'.",
#       "suggestedFix": "On tärkeää ylläpitää hyvää suhdetta naapurien välillä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'välinen' does not appropriately appear in the sentence. A more correct form would be 'välillä'.",
#       "suggestedFix": "välinen, välillä"
#     }
#   }
# }
# {
#   "id": 6154,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided Russian sentence 'Мой друг — настоящий мастер-шеф.' does not correctly translate the Finnish sentence 'Ystäväni on melkoinen mestarikokki.'",
#       "suggestedFix": "Мой друг — значительный мастер-шеф."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'значительный' does not appear in the provided Russian sentence.",
#       "suggestedFixSentence": "Мой друг — значительный мастер-шеф.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6155,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian translates 'hullaantunut' as 'без ума от', which means 'crazy about'. While contextually similar, the word 'влюблённый' means 'in love' and isn't directly translated here.",
#       "suggestedFix": "Я просто влюблён в эту новую книгу."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'влюблённый' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Я просто влюблён в эту новую книгу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6157,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation doesn't match well. 'Чемпионат Финляндии' translates closer to 'SM- kilpailut' or 'SM-kisat' as a standard, and 'SM' alone would be more intuitive for 'Suomen mestaruus'.",
#       "suggestedFix": "ЧМ (SM, Suomen mestaruuskilpailut)"
#     }
#   }
# }
# {
#   "id": 6159,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'heitää' does not appear in the Finnish sentence. The correct form 'heitä' should be used.",
#       "suggestedFix": "heitä"
#     }
#   }
# }
# {
#   "id": 6164,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Он справился на соревновании вторым по результативности' is grammatically correct, but it sounds somewhat unnatural due to the phrasing 'вторым по результативности'.",
#       "suggestedFix": "Он занял второе место по результативности на соревновании."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence does not directly translate the idea of 'toiseksi parhaiten'. The suggested fix involves changing the Russian translation to better capture the meaning 'second-best performance'.",
#       "suggestedFix": "Он занял второе место по результативности на соревновании."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'вторым лучшим образом' does not occur in the sentence in any form. The related idea 'вторым по результативности' is used, but it is not a direct match.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "вторым по результативности"
#     }
#   }
# }
# {
#   "id": 6166,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence should use the possessive suffix for the word 'tallikaveri'. It should be 'tallikaverini' instead of 'tallikaveri'.",
#       "suggestedFix": "Minun tallikaverini auttaa aina, kun tarvitsee."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'товарищ по команде' does not appear in the sentence.",
#       "suggestedFixSentence": "Мой товарищ по команде всегда помогает, когда нужно.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6167,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Гонки Формулы популярны.' is not fully natural. A more natural way to say this would be 'Гонки Формулы-1 популярны.' or 'Формула-1 популярна.'",
#       "suggestedFix": "Формула-1 популярна."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Гонки Формулы популярны.' is slightly off due to the missing reference to 'Формула-1'.",
#       "suggestedFix": "Формула-1 популярна. / Гонки Формулы-1 популярны."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'формула-гонки' does not appear in the Russian sentence in any form.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "Формула-1, гонки Формулы-1"
#     }
#   }
# }
# {
#   "id": 6169,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'начинать' or any of its forms does not appear in the sentence.",
#       "suggestedFixSentence": "Можешь начинать готовить, нарезая овощи.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6176,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian translates to 'Sport activities are a good way to improve health,' while the Finnish sentence translates directly to 'Fitness is a good way to improve health.' Hence, they aren't precise matches.",
#       "suggestedFix": "Kuntoiluharrastukset ovat hyvä tapa parantaa terveyttä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "'Фитнес' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Фитнес - это хороший способ улучшить здоровье.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6178,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'боление' or its form does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Боление по выходным — это весело.",
#       "suggestedFixWord": "боление, болеть за спорт"
#     }
#   }
# }
# {
#   "id": 6179,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not fully accurate because 'профессиональный спорт' and 'huippu-urheilu' are not exact equivalents. 'Профессиональный спорт' translates to 'ammattilaisurheilu' in Finnish. 'Huippu-urheilu' refers more to elite or top-level sports, which is a related but different concept.",
#       "suggestedFix": "Translate 'профессиональный спорт' to 'ammattilaisurheilu' in Finnish."
#     }
#   }
# }
# {
#   "id": 6180,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'тренировки' (trainings) in Russian does not occur in the sentence 'Занятия начинаются в шесть часов.'",
#       "suggestedFixSentence": "Тренировки начинаются в шесть часов.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6184,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'ЧЕ (Чемпионат Европы)' translates to 'EM (Euroopan mestaruus)' in Finnish. However, 'Чемпионат Европы' more accurately translates to 'Euroopan kilpailu.' Although 'EM' is commonly used as an abbreviation in Finnish, in this context 'European Championship' better translates to 'Euroopan mestaruuskilpailut' in full.",
#       "suggestedFix": "Word in Finnish: EM (Euroopan mestaruuskilpailut)"
#     }
#   }
# }
# {
#   "id": 6191,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'путь' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "путь, рельсы"
#     }
#   }
# }
# {
#   "id": 6193,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'инвестиция' does not appear in any form in the sentence.",
#       "suggestedFixSentence": "Он сделал хорошую инвестицию в акции.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6196,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence contains a minor grammatical error with 'в вчерашнем'. The correct form should be 'вчерашнем'.",
#       "suggestedFix": "Команда потерпела горькое поражение в вчерашнем матче."
#     }
#   }
# }
# {
#   "id": 6201,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'поклонник' translates to 'fan' or 'admirer,' which is close in meaning but not exactly synonymous with the Finnish word 'kannattaja,' which translates directly to 'supporter' or 'fan.' The Russian word 'болельщик' should be used to match the Finnish word directly.",
#       "suggestedFix": "Он большой болельщик футбольной команды."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'болельщик' does not appear in the Russian sentence. Instead, 'поклонник' is used, which is a related but not synonymous term.",
#       "suggestedFixSentence": "Он большой болельщик футбольной команды.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6230,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translations are not entirely accurate. The Russian sentence 'Я бы предпочел пойти в кино сегодня вечером.' directly translates to 'I would prefer to go to the movies tonight' rather than 'Menisin mieluiten elokuviin tänä iltana.' which translates to 'I would go to the movies most willingly tonight'.",
#       "suggestedFix": "Я бы пошёл в кино сегодня вечером с удовольствием."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word 'с удовольствием – охотнее – охотнее всего' does not appear in any form in the sentence 'Я бы предпочел пойти в кино сегодня вечером.'",
#       "suggestedFixSentence": "Я бы пошёл в кино сегодня вечером с удовольствием.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6232,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian sounds somewhat unnatural. The word 'третий' directly translates to 'third' and it should be in the comparative form for best fit in this context.",
#       "suggestedFix": "Я получил третий по величине результат на экзамене."
#     }
#   }
# }
# {
#   "id": 6234,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'в третий' does not appear in any form within the Russian sentence. The sentence uses 'третий' without 'в'.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "третий"
#     }
#   }
# }
# {
#   "id": 6236,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'третьего' does not appear in the sentence in any form.",
#       "suggestedFixSentence": "Мне больше всего нравится третьего варианты.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6237,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'третьему' does not appear in the sentence. The sentence uses 'третий', which is a different form and doesn't directly align with 'третьему'.",
#       "suggestedFixSentence": "Я иду встретиться с другом на третьему этажу.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6241,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'третьим' does not appear in the sentence 'Он занял третье место.'",
#       "suggestedFixSentence": "Он стал третьим.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6242,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Я жду третьи поезда.' is grammatically incorrect. The adjective 'третий' should agree in number, gender, and case with the noun 'поезд'. The correct form is 'третий поезд' for singular or 'третьи поезда' for plural, but here it doesn't make sense in context.",
#       "suggestedFix": "Я жду третий поезд."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Minä odotan kolmannet junat.' is grammatically incorrect. The correct form is either 'Minä odotan kolmatta junaa' (singular partitive) or 'Minä odotan kolmansia junia' (plural partitive), but here it doesn't make sense in context either.",
#       "suggestedFix": "Minä odotan kolmatta junaa."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Я жду третьи поезда.' to 'Minä odotan kolmannet junat.' is not accurate because both sentences are grammatically incorrect and misleading without proper numerical context.",
#       "suggestedFix": "Я жду третий поезд. => Minä odotan kolmatta junaa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kolmannet' appears in the sentence, but it is used incorrectly.",
#       "suggestedFix": "Minä odotan kolmatta junaa."
#     }
#   }
# }
# {
#   "id": 6243,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'третьим' does not appear in the Russian sentence. Instead, 'третье' is used, which refers to the same ordinal number but in a different form.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "третье, третьим"
#     }
#   }
# }
# {
#   "id": 6244,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Tänään vietämme hääpäiväämme kahdettakymmenettäviidettä kertaa.' is grammatically incorrect. The correct form should be 'Tänään vietämme hääpäivämme kahdettakymmenettäviidettä vuosipäivää.'.",
#       "suggestedFix": "Tänään vietämme hääpäivämme kahdettakymmenettäviidettä vuosipäivää."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The current translation does not accurately reflect the essence of being the 'twenty-fifth wedding anniversary'. The should convey the idea of an anniversary, not just mentioning twenty-fifth time, which is inappropriate here, or you can include word of times, counting the 25th times to stay more accurate.",
#       "suggestedFix": "Tänään vietämme kahdettakymmenettäviidettä hääpäiväämme."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kahdettakymmenettäviidettä' does not correctly fit the context of the Finnish sentence provided.",
#       "suggestedFix": "kahdettakymmenettäviidennettä"
#     }
#   }
# }
# {
#   "id": 6245,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minun syntymäpäiväni on kahdennekymmenennenviidennen päivän marraskuuta.' is almost correct but could be more natural. The more common way to say this would be 'Minun syntymäpäiväni on kahdennenkymmenennenneljäs marraskuuta.'",
#       "suggestedFix": "Minun syntymäpäiväni on kahdennetkymmenennenviidennen marraskuuta."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Russian to Finnish is mostly accurate, but the sentence needs a slight adjustment to be more natural in Finnish as 'Minun syntymäpäiväni on kahdennetkymmenennenviidennen marraskuuta.'",
#       "suggestedFix": "Minun syntymäpäiväni on kahdennetkymmenennenviidennen marraskuuta."
#     }
#   }
# }
# {
#   "id": 6247,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'двадцать пятом' does not directly appear in the sentence. It is used in a more precise form of 'в двадцать пятом эпизоде', which is relevant.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "двадцать пятом эпизоде"
#     }
#   }
# }
# {
#   "id": 6251,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is slightly incorrect. It should use the ablative case, resulting in 'Olen syntynyt kahdentenakymmenentenäviidentenä viikkona.'",
#       "suggestedFix": "Olen syntynyt kahdentenakymmenentenäviidentenä viikkona."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not exactly accurate due to the grammatical issue in the Finnish sentence.",
#       "suggestedFix": "Я родился на двадцать пятой неделе."
#     }
#   }
# }
# {
#   "id": 6253,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence says Лийса заняла двадцать пятое место в соревновании, meaning Liisa took the 25th place in the competition. The Finnish sentence translates to Liisa came in 25th in the competition.",
#       "suggestedFix": "Liisa tuli kisassa kahdenneksikymmenenneksi viidenneksi."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "'двадцать пятым' (25th) is not used in the sentence; instead 'двадцать пятое' (25th place) is used.",
#       "suggestedFixSentence": "Лийса заняла двадцать пятым место в соревновании.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6254,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is incorrect. The correct form for ordinal numbers like 'twenty-fifth' should be 'kahdentenakymmenentenäviidennen', not 'kahdennetkymmenennetviidenetä'.",
#       "suggestedFix": "Sain kirjeen kahdentenakymmenentenäviidentenä päivänä."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kahdennetkymmenennetviidenet' is not the correct form. The correct form should be 'kahdentenakymmenentenäviidenentenä'.",
#       "suggestedFix": "kahdentenakymmenentenäviidennen"
#     }
#   }
# }
# {
#   "id": 6255,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is fragmented and nonsensical due to the interruptions with ellipses.",
#       "suggestedFix": "Ты уже участвовал в двадцать пятых праздниках?"
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence is interrupted with ellipses which make it unnatural.",
#       "suggestedFix": "Oletko osallistunut jo kahdenskymmenensiviidensiin juhliin?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The fragmented structure in both sentences makes it difficult to evaluate accurate translation.",
#       "suggestedFix": "Ensure sentences are complete and properly structured."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Russian word appears in an incomplete and fragmented form.",
#       "suggestedFixSentence": "Ты уже участвовал в двадцать пятых праздниках?",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word appears in an incomplete and fragmented form.",
#       "suggestedFix": "kahdenskymmenensiviidensiin"
#     }
#   }
# }
# {
#   "id": 6256,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is missing. Therefore, I cannot determine the accuracy.",
#       "suggestedFix": "Предложенная русская фраза отсутствует."
#     }
#   }
# }
# {
#   "id": 6257,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "\"На каком этаже ты живёшь?\" translates to \"Which floor do you live on?\" while \"Monessako kerroksessa asut?\" translates to the same, hence it's accurate for this context but not for the words provided.",
#       "suggestedFix": "Для точного перевода \"скольких\" и \"mones\" можно использовать: \"Скольких этажей твоё здание?\" и \"Kuinka montako kerrosta rakennuksessasi on?\""
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "Слово \"скольких\" не используется в предложении.",
#       "suggestedFixSentence": "Скольких этажей дом, в котором ты живёшь?",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "Слово \"mones\" не используется в предложении.",
#       "suggestedFix": "Kuinka montako kerrosta rakennuksessasi on?"
#     }
#   }
# }
# {
#   "id": 6260,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given translation 'Kuinka monentena hän on kokonaipistetilastossa nyt?' corresponds closely to 'На каком он месте в общем зачете сейчас?'. However, the word 'kokonaipistetilastossa' has a typographical error and should be 'kokonaistilastossa'. Both phrases otherwise match in meaning.",
#       "suggestedFix": "Kuinka monentena hän on kokonaistilastossa nyt?"
#     }
#   }
# }
# {
#   "id": 6273,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Russian is missing.",
#       "suggestedFix": "Пекка любит печь торты."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence in Finnish is missing.",
#       "suggestedFix": "Pekka pitää kakkujen leipomisesta."
#     }
#   }
# }
# {
#   "id": 6290,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains a grammatical error: 'в вчерашней игре' is incorrect. The correct preposition should be 'во вчерашней игре'.",
#       "suggestedFix": "Его травма произошла во вчерашней игре."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence contains a grammatical error: 'Hänen loukaantuminen' should be in possessive form. It should be 'Hänen loukkaantumisensa'.",
#       "suggestedFix": "Hänen loukkaantumisensa tapahtui eilisessä pelissä."
#     }
#   }
# }
# {
#   "id": 6291,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'из-за' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Я прочитал эту книгу из-за рекомендации моего друга.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6293,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'энергичный' does not appear in the sentence 'Он бодрый и отзывчивый.'",
#       "suggestedFixSentence": "Он энергичный и отзывчивый.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6302,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "While the Finnish sentence is translated correctly, the Russian sentence uses 'с увлечением', which translates to 'with enthusiasm' rather than 'with passion' ('into' in Finnish translates more closely to 'страстно' in Russian).",
#       "suggestedFix": "Он говорит страстно о своем хобби."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'страстно' does not appear in any form in the Russian sentence provided.",
#       "suggestedFixSentence": "Он говорит страстно о своем хобби.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6305,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses 'lisäksi,' which translates as 'in addition to,' rather than 'except for,' which is what 'кроме' means in Russian.",
#       "suggestedFix": "Hän osaa suomea ja ruotsia, paitsi englantia."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'lisäksi' does not match the meaning of 'кроме' which is 'except for.' A better match for 'кроме' would be 'paitsi.'",
#       "suggestedFix": "paitsi"
#     }
#   }
# }
# {
#   "id": 6306,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence translates to 'The author of the goal kicked the ball into the net,' which doesn't correspond to 'maalintekijä' meaning 'goal scorer' in Finnish.",
#       "suggestedFix": "Автор гола -> Бомбардир"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The term 'бомбардир' does not appear in the Russian sentence.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "Автор гола"
#     }
#   }
# }
# {
#   "id": 6309,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'скаут' is not used in the Russian sentence in any form. Instead, 'искатель талантов' is used.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "скаут, искатель талантов"
#     }
#   }
# }
# {
#   "id": 6320,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Фильм повествовательный.' is not natural in Russian. It should be more descriptive and match the Finnish sentence.",
#       "suggestedFix": "Фильм, который представляет собой рассказ."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'представляющий' does not appear in the sentence in any form. 'Повествовательный' is used instead, which changes the meaning.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "рассказывающий, представляющий"
#     }
#   }
# }
# {
#   "id": 6322,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a minor error. The correct term for 'to get a tattoo' is 'ottaa tatuointi'.",
#       "suggestedFix": "Minä harkitsen tatuoinnin ottamista."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "'Tatointi' is an incorrect form and should be corrected to 'tatuointi'.",
#       "suggestedFix": "tatuointi"
#     }
#   }
# }
# {
#   "id": 6326,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not accurate because the Russian word 'успехом' does not correspond directly to 'suosio', which means 'popularity'. The word 'успехом' means 'success'.",
#       "suggestedFix": "Hänen konserttinsa oli hyvin suosittu."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'популярность' does not appear in any form in the given Russian sentence.",
#       "suggestedFixSentence": "Его концерт был очень популярным.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6327,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Можешь помочь мне, если сможешь здесь?' is not fully grammatically correct and sounds awkward in Russian. The phrase 'если сможешь здесь' is not idiomatic.",
#       "suggestedFix": "Можешь помочь мне, если будешь здесь?"
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation is not completely accurate. The Russian fix 'если будешь здесь' corresponds to 'if you will be here', while the Finnish is 'jos pystyt täällä' meaning 'if you can be here'.",
#       "suggestedFix": "Voitko auttaa minua, jos voit olla täällä?"
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'можешь здесь' does not appear in the Russian sentence. Only a part 'можешь' appears.",
#       "suggestedFixSentence": "Можешь помочь мне, если можешь здесь остаться?",
#       "suggestedFixWord": "можешь остаться здесь"
#     }
#   }
# }
# {
#   "id": 6328,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish word should be 'seitsemän' instead of 'seittämän'. The sentence 'Herään joka aamu kello seitsemän.' is grammatically correct and natural otherwise.",
#       "suggestedFix": "Herään joka aamu kello seitsemän."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word should be 'seitsemän' instead of 'seittämän'.",
#       "suggestedFix": "seitsemän"
#     }
#   }
# }
# {
#   "id": 6329,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence has a typo in the word 'seitsemäntoista' which is misspelled as 'seittämäntoist'.",
#       "suggestedFix": "Olen seitsemäntoista vuotta vanha."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'seittämäntoist' is incorrect, as it should be 'seitsemäntoista' in the sentence or in any form relating to it.",
#       "suggestedFix": "seitsemäntoista"
#     }
#   }
# }
# {
#   "id": 6330,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Minä herään aamulla kello kakskyneljä.' contains a non-standard form 'kakskyneljä'. The correct term should be 'kaksikymmentäneljä'.",
#       "suggestedFix": "Minä herään aamulla kello kaksikymmentäneljä."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence provided does not match the meaning of the Russian sentence. 'kello kaksikymmentäneljä' means 'twenty-four o'clock', while the Russian sentence refers to 'four o'clock in the morning'.",
#       "suggestedFix": "Minä herään aamulla kello neljä."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'двадцать четыре' (twenty-four) is not used in the Russian sentence, which instead uses 'в четыре часа' (at four o'clock).",
#       "suggestedFixSentence": "Я просыпаюсь утром в двадцать четыре часа.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kakskyneljä' (non-standard form of twenty-four) is used in the Finnish sentence, but it should be 'kaksikymmentäneljä' to match the standard form.",
#       "suggestedFix": "kaksikymmentäneljä"
#     }
#   }
# }
# {
#   "id": 6332,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Мне нужно проснуться в двадцать шесть утра.' is not grammatically correct or natural in Russian. 'Двадцать шесть' (26) is not a valid time format, and 'утра' is not used with specific times like that.",
#       "suggestedFix": "Мне нужно проснуться в шесть утра."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Minun pitää herätä kakskykuus aamulla.' is not correct or natural in Finnish. 'kakskykuus' is not a valid time format in Finnish.",
#       "suggestedFix": "Minun pitää herätä kuudelta aamulla."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from the Finnish sentence 'Minun pitää herätä kakskykuus aamulla.' to the Russian sentence 'Мне нужно проснуться в двадцать шесть утра.' was inaccurate because both sentences use an incorrect time format.",
#       "suggestedFix": "Minun pitää herätä kuudelta aamulla. = Мне нужно проснуться в шесть утра."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'двадцать шесть' does appear in the Russian sentence, but the context is incorrect.",
#       "suggestedFixSentence": "Мне нужно проснуться в шесть утра.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kakskykuus' appears in the Finnish sentence, but it is incorrect in this context.",
#       "suggestedFix": "kuusi"
#     }
#   }
# }
# {
#   "id": 6333,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence uses an informal dialect form 'kakskytseittämän,' which is not grammatically correct. The formal and correct form is 'kaksikymmentä seitsemän.'",
#       "suggestedFix": "Minä täytän kaksikymmentä seitsemän ensi viikolla."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kakskytseittämän' is an informal dialect form which does not match the grammatically correct Finnish form.",
#       "suggestedFix": "kaksikymmentä seitsemän"
#     }
#   }
# }
# {
#   "id": 6334,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence is mostly correct but uses 'kakskykaheksan', which is a colloquial form. The standard form is 'kaksikymmentäkahdeksan'.",
#       "suggestedFix": "Hän osti kaksi lippua junamatkalle ja maksoi kaksikymmentäkahdeksan euroa."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kakskykaheksan' is in colloquial form. The standard form 'kaksikymmentäkahdeksan' should be used instead.",
#       "suggestedFix": "kaksikymmentäkahdeksan"
#     }
#   }
# }
# {
#   "id": 6335,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Minä herään aina kello kakskyyheksän.' is colloquial Finnish. Standard Finnish should use 'kaksikymmentäyhdeksän'.",
#       "suggestedFix": "Minä herään aina kello kaksikymmentäkahdeksan."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation provided from the Finnish to Russian is not accurate. The Russian sentence states that the person wakes up at 8:20, while the Finnish sentence states 29 instead of 20.",
#       "suggestedFix": "Я всегда просыпаюсь в восемь двадцать девять."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'двадцать девять' does not appear in the Russian sentence.",
#       "suggestedFixSentence": "Я всегда просыпаюсь в восемь двадцать девять.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kakskyyheksän' appears in the Finnish sentence, but it's incorrect in this context as it's colloquial and should be 'kaksikymmentäyhdeksän'.",
#       "suggestedFix": "kaksikymmentäyhdeksän"
#     }
#   }
# }
# {
#   "id": 6336,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Сейчас тридцать два.' sounds incomplete and unnatural in Russian. It’s unclear what 'тридцать два' refers to.",
#       "suggestedFix": "Сейчас тридцать два градуса."
#     }
#   }
# }
# {
#   "id": 6338,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The word 'пятым' in Russian means 'the fifth'; however, the sentence translates it as 'пятое'. The Finnish equivalent 'viides' is translated correctly as 'fifth'.",
#       "suggestedFix": "Он пришёл пятым в соревновании."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'пятым' does not appear in the sentence. The sentence uses 'пятое' instead.",
#       "suggestedFixSentence": "Он пришёл пятым в соревновании.",
#       "suggestedFixWord": "пятое"
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'viies' is not the correct Finnish word; it should be 'viides' to match the numeral form used in the sentence.",
#       "suggestedFix": "viides"
#     }
#   }
# }
# {
#   "id": 6339,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'kuues' is incorrect; the correct form should be 'kuudes'.",
#       "suggestedFix": "kuudes"
#     }
#   }
# }
# {
#   "id": 6340,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Seitsemäs päivä viikossa on sunnuntai.' is grammatically incorrect. The correct form should use 'viikonpäivä' instead of 'päivä viikossa' to be more natural.",
#       "suggestedFix": "Seitsemäs viikonpäivä on sunnuntai."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation 'Seitsemäs päivä viikossa on sunnuntai.' is not completely accurate. A more accurate translation would use 'viikonpäivä' instead of 'päivä viikossa'.",
#       "suggestedFix": "Seitsemäs viikonpäivä on sunnuntai."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'seittemäs' does not appear in the Finnish sentence. The correct word 'seitsemäs' should be used.",
#       "suggestedFix": "seitsemäs"
#     }
#   }
# }
# {
#   "id": 6342,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Kello on yhdeksän aamulla.' is grammatically correct but could be made more natural by omitting 'aamulla'.",
#       "suggestedFix": "Kello on yhdeksän."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The flashcard has a typo; the word 'yheksäs' should be corrected to 'yhdeksän' to be consistent with the Finnish sentence.",
#       "suggestedFix": "yhdeksän"
#     }
#   }
# }
# {
#   "id": 6343,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Часы идут.' translates to 'The clock is running' or 'The clocks are running' rather than mentioning the time, which does not relate to 'одиннадцать' (eleven).",
#       "suggestedFix": "Сейчас одиннадцать часов."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The sentence 'Kello on yhtteist.' is incorrect. The correct sentence should be 'Kello on yksitoista.' meaning 'The clock is eleven.'",
#       "suggestedFix": "Kello on yksitoista."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The provided sentences do not correspond to the meaning 'The clock is eleven.'",
#       "suggestedFix": "Sana suomeksi: yksitoista. Lause suomeksi: Kello on yksitoista."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'одиннадцать' does not appear in any form in the given Russian sentence.",
#       "suggestedFixSentence": "Сейчас одиннадцать часов.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'yhetoist' is misspelled and does not occur in the given Finnish sentence.",
#       "suggestedFix": "yksitoista"
#     }
#   }
# }
# {
#   "id": 6344,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Meillä on kahestoist oppitunti tänään.' contains a dialectal or non-standard form 'kahestoist' for 'kahdestoista'. Proper Finnish should use 'kahdestoista'.",
#       "suggestedFix": "Meillä on kaksitoista oppitunti tänään."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The given Finnish translation 'Meillä on kahestoist oppitunti tänään.' doesn't correctly align with the Russian sentence 'У нас сегодня двенадцатый урок.'",
#       "suggestedFix": "Meillä on kahdestoista oppitunti tänään."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kahestoist' is not appropriate or correct in standard Finnish for 'twelfth'. The correct word should be 'kahdestoista'.",
#       "suggestedFix": "kahdestoista"
#     }
#   }
# }
# {
#   "id": 6345,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence contains a minor grammatical error. The word 'kolmastoist' should be 'kolmastoista'.",
#       "suggestedFix": "Tämä on jo minun kolmastoista yritykseni."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kolmastoist' is not correctly used in the Finnish sentence. It should be in the form 'kolmastoista'.",
#       "suggestedFix": "kolmastoista"
#     }
#   }
# }
# {
#   "id": 6346,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish word 'kaheskymmenes' should be spelled as 'kahdeskymmenes'.",
#       "suggestedFix": "Tänään on minun kahdeskymmenes syntymäpäiväni."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kaheskymmenes' should be corrected to 'kahdeskymmenes'.",
#       "suggestedFix": "kahdeskymmenes"
#     }
#   }
# }
# {
#   "id": 6347,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The term 'kaheskymmeneseka' is not correct in standard Finnish. The correct term should be 'kahdeskymmenesensimmäinen'. The rest of the sentence is correct.",
#       "suggestedFix": "Tämä on kahdeskymmenesensimmäinen kirja, jonka luen tänä vuonna."
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kaheskymmeneseka' does not appear in the correct form in the sentence. The correct form is 'kahdeskymmenesensimmäinen'.",
#       "suggestedFix": "kahdeskymmenesensimmäinen"
#     }
#   }
# }
# {
#   "id": 6348,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence translates directly to 'He is celebrating his fortieth birthday today,' while the Russian one translates to 'Today he is celebrating his 40th anniversary.' The concept of 'сорокалетие' refers specifically to a 40-year anniversary, not necessarily a birthday.",
#       "suggestedFix": "Hän juhlii tänään neljäkymmenvuotisjuhlaa."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'сороковой' does not appear in the Russian sentence in any form. Instead, the word 'сорокалетие' is used.",
#       "suggestedFixSentence": "Сегодня он празднует свой сороковой день рождения.",
#       "suggestedFixWord": "сорокалетие"
#     }
#   }
# }
# {
#   "id": 6349,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word ‘пятидесятый’ does not appear in the sentence in any form.",
#       "suggestedFixSentence": "На следующей неделе мне исполнится пятидесятый год.",
#       "suggestedFixWord": null
#     },
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word ‘viieskymmenes’ does not appear in the sentence in any form.",
#       "suggestedFix": "Täytän ensi viikolla viidennenkymmenennen vuoden."
#     }
#   }
# }
# {
#   "id": 6351,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The Russian sentence 'Мой любимый номер - два.' translates to 'Lempinumero on kaksi.', but the given Finnish sentence uses 'kakkonen', which is a colloquial term for 'two'. Hence, the translation is not accurate.",
#       "suggestedFix": "Minun lempinumero on kaksi."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'двойка' does not appear in any form in the Russian sentence.",
#       "suggestedFixSentence": "Моя любимая цифра - двойка.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6353,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The phrase 'четвёртый канал' does not appear in the Russian sentence in any form. The sentence uses 'четвертому каналу', which is a declined form.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "четвёртый канал, четвертый канал, четвёртому каналу, четвертому каналу"
#     }
#   }
# }
# {
#   "id": 6356,
#   "incorrect_fields": {
#     "russianSentence": {
#       "isCorrect": false,
#       "explanation": "In Russian educational grading system, there is no such mark as 'семёрка'. Usually, grades go from 1 to 5. 'Семёрка' might be acceptable in some informal contexts, but it's not standard.",
#       "suggestedFix": "Обычно он получает пятёрку за экзамены."
#     },
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The use of 'seiska' for '7' in grades is not common in Finnish. Grades usually range from 4 to 10 in Finland. '7' in this context is understood, but it is not commonly used.",
#       "suggestedFix": "Hän saa yleensä kasin kokeista."
#     },
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation maintains the context but fails in accurately representing the common grading scales in both languages.",
#       "suggestedFix": "Hän saa yleensä kasin kokeista. -> Обычно он получает восьмёрку за экзамены."
#     }
#   }
# }
# {
#   "id": 6357,
#   "incorrect_fields": {
#     "finnishWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'kasi' is incorrect. The correct form in Finnish is 'käsi', plural form 'kädet'.",
#       "suggestedFix": "kädet"
#     }
#   }
# }
# {
#   "id": 6359,
#   "incorrect_fields": {
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'пятёрка' does not appear in the Russian sentence. The Russian sentence uses 'десятку' instead of 'пятёрка.'",
#       "suggestedFixSentence": "Я получил пятёрку за тест.",
#       "suggestedFixWord": null
#     }
#   }
# }
# {
#   "id": 6362,
#   "incorrect_fields": {
#     "finnishSentence": {
#       "isCorrect": false,
#       "explanation": "The Finnish sentence 'Minulla on kolmekolmonen pullo.' is close to correct, but the word 'pullo' should be used as an adjective: 'Minulla on kolmekolmonen-pullo.'",
#       "suggestedFix": "Minulla on kolmekolmonen-pullo."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "The word 'у меня есть бутылка 33' doesn't appear in the sentence in some form. The number 33 should reference 0.33-liter bottle.",
#       "suggestedFixSentence": null,
#       "suggestedFixWord": "у меня есть бутылка 0.33 литра"
#     }
#   }
# }
# {
#   "id": 6363,
#   "incorrect_fields": {
#     "translationAccuracy": {
#       "isCorrect": false,
#       "explanation": "The translation from Finnish to Russian is not accurate. 'Satanen' directly translates to 'сотня', not 'ста евро'. The current translation uses 'ста евро', which isn't the direct translation of 'satanen'.",
#       "suggestedFix": "Мне не хватает еще сотни евро на билет."
#     },
#     "russianWordUsage": {
#       "isCorrect": false,
#       "explanation": "'Сотня' does not appear in the sentence. Instead, 'ста евро' is used.",
#       "suggestedFixSentence": "Мне не хватает еще сотни евро на билет.",
#       "suggestedFixWord": null
#     }
#   }
# }
