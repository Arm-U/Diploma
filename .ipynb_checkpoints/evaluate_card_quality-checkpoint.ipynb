# %%
import sys
import os

# Add the directory containing your module to the Python path (before importing it)
UTILS_DIR = '../voice_generation/'
module_dir = os.path.abspath(UTILS_DIR)
sys.path.insert(0, module_dir)

from data_utils import *

# %%
FOLDER_WITH_JSON = '../../../content_management/data/russian-finnish/cards/curated_platform_cards/'

# %%
# !pwd
# Out:
# /Users/vladimirgorovoy/Yandex.Disk.localized/0Projects/CrispConsulting_iOS/LearningFinnishWords/LangData/dev/content_generation/vocab_preparation

# %%
# user_prompt = f"""
#     You are given a flashcard containing a word and a sentence in Russian, along with its translation and a sentence in Finnish. Your task is to evaluate the correctness of the flashcard. Here’s what you need to check:

#     1. Whether the sentence in Russian is grammatically correct and natural.
#     2. Whether the sentence in Finnish is grammatically correct and natural.
#     3. Whether the translation from Russian to Finnish (or vice versa) is accurate.
#     4. Whether the word in Russian occurs in some form in the Russian sentence.
#     5. Whether the word in Finnish occurs in some form in the Finnish sentence.

#     Provide a detailed evaluation for each point and suggest fixes where necessary.

#     Here is the flashcard:

#     Word in Russian: {card.word_first_lang}
#     Sentence in Russian: {card.sentence_first_lang}
#     Word in Finnish: {card.word_second_lang}
#     Sentence in Finnish: {card.sentence_second_lang}

#     Respond in JSON format with the following structure:

#     {{
#       "russianSentence": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "finnishSentence": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "translationAccuracy": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "russianWordUsage": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "finnishWordUsage": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }}
#     }}
#     """

# %%
# system_prompt = f"""
#     You are a language expert proficient in both Russian and Finnish."""
    
#     user_prompt = f"""
#     You are given a flashcard containing a word and a sentence in Russian, along with its translation and 
#     a sentence in Finnish. Your task is to evaluate the correctness of the flashcard. Here’s what you need to check:

#     1. Whether the sentence in Russian is grammatically correct and natural.
#     2. Whether the sentence in Finnish is grammatically correct and natural.
#     3. Whether the translation from Finnish to Russian is accurate.
#     4. Whether the word in Russian occurs in some form in the Russian sentence.
#     5. Whether the word in Finnish occurs in some form in the Finnish sentence.
    
#     If both sentence in Russian and Finnish are missing it is ok, just check the translation to Finnish. 
#     If the word in Russian does not appear in the sentence, suggest using synonyms or related terms in the 
#     translation to ensure the sentence remains natural and accurate. You can changes either the sentence translation 
#     or the word translation.
#     For example, if the word is "досуг," it can be translated as "досуг" or "свободное время". So if the word "свободное время" 
#     is in some form used in the sentence and it sounds natural, suggested fix can be to change the word translation to "досуг, свободное время", 
#     keeping the sentence intact
#     In the suggestedFix fields don't provide explanations or instructions, just provide the final corrected string.
#     If it's better to fix word, not sentence, return null for suggestedFixSentence.


#     Provide a detailed evaluation for each point and suggest fixes where necessary.

#     Here is the flashcard:

#     Word in Russian: {card.word_first_lang}
#     Sentence in Russian: {card.sentence_first_lang}
#     Word in Finnish: {card.word_second_lang}
#     Sentence in Finnish: {card.sentence_second_lang}

#     Respond in JSON format with the following structure:

#     {{
#       "russianSentence": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "finnishSentence": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "translationAccuracy": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }},
#       "russianWordUsage": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFixSentence": "Suggested correction to the sentence if there is an issue"
#         "suggestedFixWord": "Suggested correction to the word if there is an issue"
#       }},
#       "finnishWordUsage": {{
#         "isCorrect": true/false,
#         "explanation": "Detailed explanation if there is an issue or why it's correct",
#         "suggestedFix": "Suggested correction if there is an issue"
#       }}
#     }}
    
    
#     If both sentence in Russian and Finnish are missing return only translationAccuracy block.
#     """

# %%
# import openai
from openai import OpenAI
import json
import openai



# Set up your OpenAI API key
openai_api_key = ''
client = OpenAI(api_key=openai_api_key)


def evaluate_flashcard(card):
    # Construct the prompt
    system_prompt = f"""
    You are a language expert proficient in both Russian and Finnish."""
    
    user_prompt = f"""
    You are given a flashcard containing a word and a sentence in Russian, along with its translation and 
    a sentence in Finnish. Your task is to evaluate the correctness of the flashcard. Here’s what you need to check:

    1. Whether the sentence in Russian is grammatically correct and natural.
    2. Whether the sentence in Finnish is grammatically correct and natural.
    3. Whether the translation from Finnish to Russian is accurate.
    4. Whether the word in Russian occurs in some form in the Russian sentence.
    5. Whether the word in Finnish occurs in some form in the Finnish sentence.
    
    If both sentence in Russian and Finnish are missing it is ok, just check the translation to Finnish. 
    
    Check that the word in Russian appear in the sentence in some form, diregarding the case and form of the word, or the order of the words, 
    if the words in russian consists of several words. For example if the word is 'в то же время' and in sentence it's 'в одно и то же время', it's ok. Or if 'когда опять' in the words and 'когда моя сестра опять' is in the sentence. 
    If there are several synonyms in russian word field, then if one of them appears in the sentences in some form it's ok. 
    For example if russian word is 'выносить, красть' and in sentence 'украсть' is used it's ok.
    
    If the word doesn't appear in some form, suggest using synonyms or related terms in the 
    translation to ensure the sentence remains natural and accurate. You can change either the sentence translation 
    or the word translation. For example, if the word is "досуг," it can be translated as "досуг" or "свободное время". So if the word "свободное время" 
    is in some form used in the sentence and it sounds natural, suggested fix can be to change the word translation to "досуг, свободное время", 
    keeping the sentence intact
    
    
    
    
    In the suggestedFix fields don't provide explanations or instructions, just provide the final corrected string.
    If it's better to fix word, not sentence, return null for suggestedFixSentence.


    Provide a detailed evaluation for each point and suggest fixes where necessary.

    Here is the flashcard:

    Word in Russian: {card.word_first_lang}
    Sentence in Russian: {card.sentence_first_lang}
    Word in Finnish: {card.word_second_lang}
    Sentence in Finnish: {card.sentence_second_lang}

    Respond in JSON format with the following structure:

    {{
      "russianSentence": {{
        "isCorrect": true/false,
        "explanation": "Detailed explanation if there is an issue or why it's correct",
        "suggestedFix": "Suggested correction if there is an issue"
      }},
      "finnishSentence": {{
        "isCorrect": true/false,
        "explanation": "Detailed explanation if there is an issue or why it's correct",
        "suggestedFix": "Suggested correction if there is an issue"
      }},
      "translationAccuracy": {{
        "isCorrect": true/false,
        "explanation": "Detailed explanation if there is an issue or why it's correct",
        "suggestedFix": "Suggested correction if there is an issue"
      }},
      "russianWordUsage": {{
        "isCorrect": true/false,
        "explanation": "Detailed explanation if there is an issue or why it's correct",
        "suggestedFixSentence": "Suggested correction to the sentence if there is an issue"
        "suggestedFixWord": "Suggested correction to the word if there is an issue"
      }},
      "finnishWordUsage": {{
        "isCorrect": true/false,
        "explanation": "Detailed explanation if there is an issue or why it's correct",
        "suggestedFix": "Suggested correction if there is an issue"
      }}
    }}
    
    
    If both sentence in Russian and Finnish are missing return only translationAccuracy block.
    """
    
    # Call the OpenAI API
#     response = openai.Completion.create(
#         engine="gpt-4o",
#         prompt=prompt,
#         max_tokens=500
#     )


    response = client.chat.completions.create(
      model="gpt-4o",
      response_format={ "type": "json_object" },
      messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
      ]
    )
#     print(response.choices[0].message.content)
    
    # Parse the response
#     evaluation = json.loads(response.choices[0].text.strip())
    evaluation = json.loads(response.choices[0].message.content)
    return evaluation

# # Example card
# card = {
#     "wordFirstLang": "тяжёлый",
#     "sentenceFirstLang": "Эта неделя была действительно тяжёлой.",
#     "wordSecondLang": "rankka",
#     "sentenceSecondLang": "Tämä viikko oli todella rankka.",
#     "id": 6124
# }

# Evaluate the example card
# evaluation = evaluate_flashcard(card)
# print(json.dumps(evaluation, indent=2, ensure_ascii=False))

# %%
def evalutate_chapter(chapter_name):
    i = 0
    CHAPTER_FILENAME = f"{chapter_name}.json"
    filename = FOLDER_WITH_JSON + CHAPTER_FILENAME
    AUDIO_FOLDER = f"{FOLDER_WITH_JSON}Audio/{chapter_name}/"
    word_pairs, word_set = get_word_pairs_and_word_set(filename)
    all_evaluations = []
    
    final_json_filename = f"{chapter_name}_evaluations.jsonl"
    processed_ids = set()
    if os.path.exists(final_json_filename):
        with open(final_json_filename, 'r', encoding='utf-8') as f:
            for line in f:
                evaluation_result = json.loads(line)
                processed_ids.add(evaluation_result['id'])

    with open(final_json_filename, 'a', encoding='utf-8') as f:
        for card in word_pairs:
            if card.id in processed_ids:
                print(f"{card.id} already processed, skipping")
                continue
            print(card.id)
            evaluation = evaluate_flashcard(card)
            evaluation_result = {
                "id": card.id,
                "evaluation": evaluation
            }
            all_evaluations.append(evaluation_result)
            f.write(json.dumps(evaluation_result, ensure_ascii=False) + '\n')
    return all_evaluations
        
    
    
#         for card in word_pairs:
#             print(card['id'])
#             evaluation = evaluate_flashcard(card)
            
#             f.write(json.dumps(evaluation_result, ensure_ascii=False) + '\n')
#     # Output the final JSON containing all evaluations
#     final_json_filename = f"{chapter_name}_evaluations.json"
#     with open(final_json_filename, 'w', encoding='utf-8') as f:
#         json.dump(all_evaluations, f, ensure_ascii=False, indent=2)
        
#     return p

# %%
# p = eva

# %%
chapter = 'sm2_new_kap4'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_kap4.json
# 3595 already processed, skipping
# 3596 already processed, skipping
# 3597 already processed, skipping
# 3598 already processed, skipping
# 3599 already processed, skipping
# 3600 already processed, skipping
# 3601 already processed, skipping
# 3602 already processed, skipping
# 3603 already processed, skipping
# 3604 already processed, skipping
# 3605 already processed, skipping
# 3606 already processed, skipping
# 3607 already processed, skipping
# 3608 already processed, skipping
# 3609 already processed, skipping
# 3610 already processed, skipping
# 3611 already processed, skipping
# 3612 already processed, skipping
# 3613 already processed, skipping
# 3614 already processed, skipping
# 3615 already processed, skipping
# 3616 already processed, skipping
# 3617 already processed, skipping
# 3618 already processed, skipping
# 3619 already processed, skipping
# ...

# %%
chapter = 'sm2_new_kap5'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_kap5.json
# 3894
# 3895
# 3896
# 3897
# 3898
# 3899
# 3900
# 3901
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# 3908
# 3909
# 3910
# 3911
# 3912
# 3913
# 3914
# 3915
# 3916
# 3917
# 3918
# 3919
# 3920
# 3921
# 3922
# 3923
# 3924
# 3925
# 3926
# 3927
# 3928
# 3929
# 3930
# 3931
# 3932
# 3933
# 3934
# 3935
# 3936
# 3937
# 3938
# 3939
# 3940
# 3941
# 3942
# 3943
# 3944
# 3945
# 3946
# 3947
# 3948
# 3949
# 3950
# 3951
# 3952
# 3953
# 3954
# 3955
# 3956
# 3957
# 3958
# 3959
# 3960
# 3961
# 3962
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# 3969
# 3970
# 3971
# 3972
# 3973
# 3974
# 3975
# 3976
# 3977
# 3978
# 3979
# 3980
# 3981
# 3982
# 3983
# 3984
# 3985
# 3986
# 3987
# 3988
# 3989
# 3990
# 3991
# 3992
# 3993
# 3994
# 3995
# 3996
# 3997
# 3998
# 3999
# 4000
# 4001
# 4002
# 4003
# 4004
# 4005
# 4006
# 4007
# 4008
# 4009
# 4010
# 4011
# 4012
# 4013
# 4014
# 4015
# 4016
# 4017
# 4018
# 4019
# ...

# %%
chapter = 'sm2_new_kap6'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_kap6.json
# 4334
# 4127
# 4128
# 4129
# 4130
# 4131
# 4132
# 4133
# 4134
# 4135
# 4136
# 4137
# 4138
# 4139
# 4140
# 4141
# 4142
# 4143
# 4144
# 4145
# 4146
# 4147
# 4148
# 4149
# 4150
# 4151
# 4152
# 4153
# 4154
# 4155
# 4156
# 4157
# 4158
# 4159
# 4160
# 4161
# 4162
# 4163
# 4164
# 4165
# 4166
# 4167
# 4168
# 4169
# 4170
# 4171
# 4172
# 4173
# 4174
# 4175
# 4176
# 4177
# 4178
# 4179
# 4180
# 4181
# 4182
# 4183
# 4184
# 4185
# 4186
# 4187
# 4188
# 4189
# 4190
# 4191
# 4192
# 4193
# 4194
# 4195
# 4196
# 4197
# 4198
# 4199
# 4200
# 4201
# 4202
# 4203
# 4204
# 4205
# 4206
# 4207
# 4208
# 4209
# 4210
# 4211
# 4212
# 4213
# 4214
# 4215
# 4216
# 4217
# 4218
# 4219
# 4220
# 4221
# 4222
# 4223
# 4224
# 4225
# 4226
# 4227
# 4228
# 4229
# 4230
# 4231
# 4232
# 4233
# 4234
# 4235
# 4236
# 4237
# 4238
# 4239
# 4240
# 4241
# 4242
# 4243
# 4244
# 4245
# 4246
# 4247
# 4248
# 4249
# 4250
# 4251
# ...

# %%
chapter = 'sm2_new_kap7'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_kap7.json
# 4335
# 4336
# 4337
# 4338
# 4339
# 4340
# 4341
# 4342
# 4343
# 4344
# 4345
# 4346
# 4347
# 4348
# 4349
# 4350
# 4351
# 4352
# 4353
# 4354
# 4355
# 4356
# 4357
# 4358
# 4359
# 4360
# 4361
# 4362
# 4363
# 4364
# 4365
# 4366
# 4367
# 4368
# 4369
# 4370
# 4371
# 4372
# 4373
# 4374
# 4375
# 4376
# 4377
# 4378
# 4379
# 4380
# 4381
# 4382
# 4383
# 4384
# 4385
# 4386
# 4387
# 4388
# 4389
# 4390
# 4391
# 4392
# 4393
# 4394
# 4395
# 4396
# 4397
# 4398
# 4399
# 4400
# 4401
# 4402
# 4403
# 4404
# 4405
# 4406
# 4407
# 4408
# 4409
# 4410
# 4411
# 4412
# 4413
# 4414
# 4415
# 4416
# 4417
# 4418
# 4419
# 4420
# 4421
# 4422
# 4423
# 4424
# 4425
# 4426
# 4427
# 4428
# 4429
# 4430
# 4431
# 4432
# 4433
# 4434
# 4435
# 4436
# 4437
# 4438
# 4439
# 4440
# 4441
# 4442
# 4443
# 4444
# 4445
# 4446
# 4447
# 4448
# 4449
# 4450
# 4451
# 4452
# 4453
# 4454
# 4455
# 4456
# 4457
# 4458
# 4459
# 4460
# ...

# %%
chapter = 'sm2_new_kap8'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_kap8.json
# 4573
# 4574
# 4575
# 4576
# 4577
# 4578
# 4579
# 4580
# 4581
# 4582
# 4583
# 4584
# 4585
# 4586
# 4587
# 4588
# 4589
# 4590
# 4591
# 4592
# 4593
# 4594
# 4595
# 4596
# 4597
# 4598
# 4599
# 4600
# 4601
# 4602
# 4603
# 4604
# 4605
# 4606
# 4607
# 4608
# 4609
# 4610
# 4611
# 4612
# 4613
# 4614
# 4615
# 4616
# 4617
# 4618
# 4619
# 4620
# 4621
# 4622
# 4623
# 4624
# 4625
# 4626
# 4627
# 4628
# 4629
# 4630
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# 4639
# 4640
# 4641
# 4642
# 4643
# 4644
# 4645
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656
# 4657
# 4658
# 4659
# 4660
# 4661
# 4662
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# 4669
# 4670
# 4671
# 4672
# 4673
# 4674
# 4675
# 4676
# 4677
# 4678
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4687
# 4688
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# ...

# %%
# !open .

# %%
chapter = 'sm2_new_kap1'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_kap1.json
# 2936 already processed, skipping
# 2937 already processed, skipping
# 2938 already processed, skipping
# 2939 already processed, skipping
# 2940 already processed, skipping
# 2941 already processed, skipping
# 2942 already processed, skipping
# 2943 already processed, skipping
# 2944 already processed, skipping
# 2945 already processed, skipping
# 2946 already processed, skipping
# 2947 already processed, skipping
# 2948 already processed, skipping
# 2949 already processed, skipping
# 2950 already processed, skipping
# 2951 already processed, skipping
# 2952 already processed, skipping
# 2953 already processed, skipping
# 2954 already processed, skipping
# 2955 already processed, skipping
# 2956 already processed, skipping
# 2957 already processed, skipping
# 2958 already processed, skipping
# 2959 already processed, skipping
# 2960 already processed, skipping
# ...

# %%
chapter = 'sm2_new_kap2'
all_evaluations = evalutate_chapter(chapter)

# %%
chapter = 'sm2_new_kap3'
all_evaluations = evalutate_chapter(chapter)

# %%
# !grep "false" sm2_new_kap4_evaluations.jsonl > sm2_new_kap4_evaluations_filtered.jsonl

# %%
# !open .

# %%
p.word_second_lang
# Out:
# 'досуг'

# %%
p.sentence_first_lang
# Out:
# 'У меня много свободного времени в этот уикенд.'

# %%
p.sentence_second_lang

# %%
chapter = 'sm3_kap4'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm3_kap4.json
# 5406
# 5407
# 5408
# 5409
# 5410
# 5411
# 5412
# 5413
# 5414
# 5415
# 5416
# 5417
# 5418
# 5419
# 5420
# 5421
# 5422
# 5423
# 5424
# 5425
# 5426
# 5427
# 5428
# 5429
# 5430
# 5431
# 5432
# 5433
# 5434
# 5435
# 5436
# 5437
# 5438
# 5439
# 5440
# 5441
# 5442
# 5443
# 5444
# 5445
# 5446
# 5447
# 5448
# 5449
# 5450
# 5451
# 5452
# 5453
# 5454
# 5455
# 5456
# 5457
# 5458
# 5459
# 5460
# 5461
# 5462
# 5463
# 5464
# 5465
# 5466
# 5467
# 5468
# 5469
# 5470
# 5471
# 5472
# 5473
# 5474
# 5475
# 5476
# 5477
# 5478
# 5479
# 5480
# 5481
# 5482
# 5483
# 5484
# 5485
# 5486
# 5487
# 5488
# 5489
# 5490
# 5491
# 5492
# 5493
# 5494
# 5495
# 5496
# 5497
# 5498
# 5499
# 5500
# 5501
# 5502
# 5503
# 5504
# 5505
# 5506
# 5507
# 5508
# 5509
# 5510
# 5511
# 5512
# 5513
# 5514
# 5515
# 5516
# 5517
# 5518
# 5519
# 5520
# 5521
# 5522
# 5523
# 5524
# 5525
# 5526
# 5527
# 5528
# 5529
# 5530
# 5531
# 5532
# ...

# %%
chapter = 'sm3_kap5'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm3_kap5.json
# 5553 already processed, skipping
# 5554 already processed, skipping
# 5555 already processed, skipping
# 5556 already processed, skipping
# 5557 already processed, skipping
# 5558 already processed, skipping
# 5559 already processed, skipping
# 5560 already processed, skipping
# 5561 already processed, skipping
# 5562 already processed, skipping
# 5563 already processed, skipping
# 5564 already processed, skipping
# 5565 already processed, skipping
# 5566 already processed, skipping
# 5567 already processed, skipping
# 5568 already processed, skipping
# 5569 already processed, skipping
# 5570 already processed, skipping
# 5571 already processed, skipping
# 5572 already processed, skipping
# 5573 already processed, skipping
# 5574 already processed, skipping
# 5575 already processed, skipping
# 5576 already processed, skipping
# 5577 already processed, skipping
# ...

# %%
chapter = 'sm3_kap6'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm3_kap6.json
# 5715
# 5716
# 5717
# 5718
# 5719
# 5720
# 5721
# 5722
# 5723
# 5724
# 5725
# 5726
# 5727
# 5728
# 5729
# 5730
# 5731
# 5732
# 5733
# 5734
# 5735
# 5736
# 5737
# 5738
# 5739
# 5740
# 5741
# 5742
# 5743
# 5744
# 5745
# 5746
# 5747
# 5748
# 5749
# 5750
# 5751
# 5752
# 5753
# 5754
# 5755
# 5756
# 5757
# 5758
# 5759
# 5760
# 5761
# 5762
# 5763
# 5764
# 5765
# 5766
# 5767
# 5768
# 5769
# 5770
# 5771
# 5772
# 5773
# 5774
# 5775
# 5776
# 5777
# 5778
# 5779
# 5780
# 5781
# 5782
# 5783
# 5784
# 5785
# 5786
# 5787
# 5788
# 5789
# 5790
# 5791
# 5792
# 5793
# 5794
# 5795
# 5796
# 5797
# 5798
# 5799
# 5800
# 5801
# 5802
# 5803
# 5804
# 5805
# 5806
# 5807
# 5808
# 5809
# 5810
# 5811
# 5812
# 5813
# 5814
# 5815
# 5816
# 5817
# 5818
# 5819
# 5820
# 5821
# 5822
# 5823
# 5824
# 5825
# 5826
# 5827
# 5828
# 5829
# 5830
# 5831
# 5832
# 5833
# 5834
# 5835
# 5836
# 5837
# 5838
# 5839
# 5840
# 5841
# ...

# %%
chapter = 'sm3_kap7'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm3_kap7.json
# 5945
# 5946
# 5947
# 5948
# 5949
# 5950
# 5951
# 5952
# 5953
# 5954
# 5955
# 5956
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 5965
# 5966
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5978
# 5979
# 5980
# 5981
# 5982
# 5983
# 5984
# 5985
# 5986
# 5987
# 5988
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994
# 5995
# 5996
# 5997
# 5998
# 5999
# 6000
# 6001
# 6002
# 6003
# 6004
# 6005
# 6006
# 6007
# 6008
# 6009
# 6010
# 6011
# 6012
# 6013
# 6014
# 6015
# 6016
# 6017
# 6018
# 6019
# 6020
# 6021
# 6022
# 6023
# 6024
# 6025
# 6026
# 6027
# 6028
# 6029
# 6030
# 6031
# 6032
# 6033
# 6034
# 6035
# 6036
# 6037
# 6038
# 6039
# 6040
# 6041
# 6042
# 6043
# 6044
# 6045
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058
# 6059
# 6060
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# ...

# %%
chapter = 'sm3_kap8'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm3_kap8.json
# 6124
# 6125
# 6126
# 6127
# 6128
# 6129
# 6130
# 6131
# 6132
# 6133
# 6134
# 6135
# 6136
# 6137
# 6138
# 6139
# 6140
# 6141
# 6142
# 6143
# 6144
# 6145
# 6146
# 6147
# 6148
# 6149
# 6150
# 6151
# 6152
# 6153
# 6154
# 6155
# 6156
# 6157
# 6158
# 6159
# 6160
# 6161
# 6162
# 6163
# 6164
# 6165
# 6166
# 6167
# 6168
# 6169
# 6170
# 6171
# 6172
# 6173
# 6174
# 6175
# 6176
# 6177
# 6178
# 6179
# 6180
# 6181
# 6182
# 6183
# 6184
# 6185
# 6186
# 6187
# 6188
# 6189
# 6190
# 6191
# 6192
# 6193
# 6194
# 6195
# 6196
# 6197
# 6198
# 6199
# 6200
# 6201
# 6202
# 6203
# 6204
# 6205
# 6206
# 6207
# 6208
# 6209
# 6210
# 6211
# 6212
# 6213
# 6214
# 6215
# 6216
# 6217
# 6218
# 6219
# 6220
# 6221
# 6222
# 6223
# 6224
# 6225
# 6226
# 6227
# 6228
# 6229
# 6230
# 6231
# 6232
# 6233
# 6234
# 6235
# 6236
# 6237
# 6238
# 6239
# 6240
# 6241
# 6242
# 6243
# 6244
# 6245
# 6246
# 6247
# 6248
# 6249
# 6250
# ...

# %%
chapter = 'sm3_kap3'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm3_kap3.json
# 5256
# 5257
# 5258
# 5259
# 5260
# 5261
# 5262
# 5263
# 5264
# 5265
# 5266
# 5267
# 5268
# 5269
# 5270
# 5271
# 5272
# 5273
# 5274
# 5275
# 5276
# 5277
# 5278
# 5279
# 5280
# 5281
# 5282
# 5283
# 5284
# 5285
# 5286
# 5287
# 5288
# 5289
# 5290
# 5291
# 5292
# 5293
# 5294
# 5295
# 5296
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# ...

# %%
chapter = 'sm2_new_puhekieli'
all_evaluations = evalutate_chapter(chapter)
# Out:
# processing v2 ../../../content_management/data/russian-finnish/cards/curated_platform_cards/sm2_new_puhekieli.json
# 4773 already processed, skipping
# 4774 already processed, skipping
# 4775 already processed, skipping
# 4776 already processed, skipping
# 4777 already processed, skipping
# 4778 already processed, skipping
# 4779 already processed, skipping
# 4780 already processed, skipping
# 4781 already processed, skipping
# 4782 already processed, skipping
# 4783 already processed, skipping
# 4784 already processed, skipping
# 4785 already processed, skipping
# 4786 already processed, skipping
# 4787 already processed, skipping
# 4788 already processed, skipping
# 4789 already processed, skipping
# 4790 already processed, skipping
# 4791 already processed, skipping
# 4792 already processed, skipping
# 4793 already processed, skipping
# 4794 already processed, skipping
# 4795 already processed, skipping
# 4796 already processed, skipping
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# ...

# %% [markdown]
# ### Test prompt with known-problems

# %%
card = WordPair("помолвленный", "Они недавно обручились и планируют свадьбу.", "kihloissa", "He ovat kihloissa ja suunnittelevat häitä.")

# %%
evaluate_flashcard(card)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The Russian sentence 'Они недавно обручились и планируют свадьбу.' is grammatically correct and sounds natural.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The Finnish sentence 'He ovat kihloissa ja suunnittelevat häitä.' is grammatically correct and sounds natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': False,
#   'explanation': "The translation is not precise. The Russian sentence 'Они недавно обручились и планируют свадьбу.' translates to 'He ovat hiljattain menneet kihloihin ja suunnittelevat häitä.' in Finnish, which specifically includes 'recently engaged'.",
#   'suggestedFix': 'He ovat hiljattain menneet kihloihin ja suunnittelevat häitä.'},
#  'russianWordUsage': {'isCorrect': False,
#   'explanation': "The word 'помолвленный' does not occur in the sentence. A better synonym to match the context is 'обручиться' or 'обручённый'.",
# ...

# %%
card = WordPair("Имя, отчество", "", "Etunimet", "")
evaluate_flashcard(card)
# Out:
# {'translationAccuracy': {'isCorrect': False,
#   'explanation': "The word 'Имя, отчество' in Russian does not directly translate to 'Etunimet' in Finnish. 'Имя, отчество' refers to 'First name, patronymic' in English, while 'Etunimet' refers to 'First names' (plural of 'First name'). A more precise translation to capture the meanings of both words could be 'Etunimi ja isännimi' or simply 'Etunimi' for a single first name.",
#   'suggestedFix': 'Etunimi ja isännimi'}}

# %%
card = WordPair("библиотечная карта", "У меня есть библиотечная карта.", "kirjastokortti", "Minulla on kirjastokortti.")
evaluate_flashcard(card)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The Russian sentence 'У меня есть библиотечная карта.' is grammatically correct and natural.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The Finnish sentence 'Minulla on kirjastokortti.' is grammatically correct and natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translation from Finnish to Russian is accurate. Both sentences convey the same meaning: 'I have a library card.'",
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'библиотечная карта' is used in the sentence in its correct form.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The word 'kirjastokortti' is used in the sentence in its correct form.",
#   'suggestedFix': None}}

# %%
card = WordPair("Размер XS","Моя футболка размера XS.","XS äx-ässä", "Minun T-paitani on kokoa XS.")
evaluate_flashcard(card)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The Russian sentence 'Моя футболка размера XS.' is grammatically correct and natural.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The Finnish sentence 'Minun T-paitani on kokoa XS.' is grammatically correct and natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Russian to Finnish is accurate.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'Размер XS' appears in the sentence in the form 'размера XS'.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': False,
#   'explanation': "The word 'XS äx-ässä' does not appear in the sentence. The sentence uses 'XS' without the 'äx-ässä' pronunciation.",
#   'suggestedFix': 'Minun T-paitani on kokoa XS äx-ässä.'}}

# %%
card = WordPair("Ольга на курсе с Анной и Алексом.","", "Olga on Annan ja Alexin kanssa kurssilla.", "")
evaluate_flashcard(card)
# Out:
# {'id': -1,
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translation from Finnish 'Olga on Annan ja Alexin kanssa kurssilla' to Russian 'Ольга на курсе с Анной и Алексом' is accurate."}}

# %%
card1 = WordPair("пара девушек", "Мы видели пару девушек в магазине.","pari tyttöä", "Näimme pari tyttöä kaupassa.")
card2 = WordPair("Размер M", "Есть ли это размера M?","M ämmä", "Onko tästä M-kokoa?")
card3 = WordPair("Это есть в красном цвете?","", "Onko tätä punaisena?", "")
card4 = WordPair("Это есть в черном?","", "Onko tätä myös mustana?", "")
card5 = WordPair("свой", "Это мой собственный дом.","oma", "Tämä on oma taloni.")

# %%
evaluate_flashcard(card1)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The Russian sentence 'Мы видели пару девушек в магазине.' is grammatically correct and sounds natural.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The Finnish sentence 'Näimme pari tyttöä kaupassa.' is grammatically correct and sounds natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Finnish to Russian is accurate. Both sentences convey the same meaning.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'пару девушек' is correctly used in the Russian sentence in the required form.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The word 'pari tyttöä' is correctly used in the Finnish sentence in the required form.",
#   'suggestedFix': None}}

# %%
evaluate_flashcard(card2)
# Out:
# {'russianSentence': {'isCorrect': False,
#   'explanation': "The Russian sentence 'Есть ли это размера M?' is not natural. The phrase 'размера M' should agree with 'это' and the sentence structure is awkward.",
#   'suggestedFix': 'Есть ли это в размере M?'},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The Finnish sentence 'Onko tästä M-kokoa?' is grammatically correct and natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Finnish to Russian is generally accurate. Both sentences essentially ask if a certain item is available in size M.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The Russian word 'размер M' occurs in the sentence as 'размера M' which is a correct form.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': False,
# ...

# %%
evaluate_flashcard(card3)
# Out:
# {'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translation from Russian 'Это есть в красном цвете?' to Finnish 'Onko tätä punaisena?' is accurate.",
#   'suggestedFix': None}}

# %%
evaluate_flashcard(card4)
# Out:
# {'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translations 'Это есть в черном?' in Russian and 'Onko tätä myös mustana?' in Finnish correspond correctly. Both sentences ask if something is available in black."}}

# %%
evaluate_flashcard(card5)
# Out:
# {'russianSentence': {'isCorrect': False,
#   'explanation': "The sentence 'Это мой собственный дом.' is grammatically correct but does not use the word 'свой,' which was provided as the word in Russian.",
#   'suggestedFix': 'Это мой свой дом.'},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Tämä on oma taloni.' is grammatically correct and natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': False,
#   'explanation': "The Russian sentences 'Это мой собственный дом.' or 'Это мой свой дом.' translates to 'Tämä on minun oma taloni,' not just 'oma.' The word 'oma' translates correctly to 'свой.'",
#   'suggestedFix': 'Tämä on minun oma taloni.'},
#  'russianWordUsage': {'isCorrect': False,
#   'explanation': "The word 'свой' is not used in any form in the provided sentence.",
#   'suggestedFixSentence': 'Это мой свой дом.',
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
# ...

# %% [markdown]
# ### cards with errors with v2 prompt

# %%
card6 = WordPair("в то же время, одновременно", "Они обедают в одно и то же время каждый день.", "samaan aikaan", "He syövät lounasta samaan aikaan joka päivä.")
card7 = WordPair("выносить, красть", "Вор пытался украсть ценное ювелирное изделие с витрины магазина.", "viedä (varastaa)", "Varas yritti viedä arvokkaan korun näyteikkunasta.")
card8 = WordPair("когда опять", "Я иду в школу пешком, когда моя сестра опять едет на автобусе.", "kun taas", "Kävelen kouluun, kun taas siskoni menee bussilla.")

# %%
evaluate_flashcard(card6)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': 'The Russian sentence is grammatically correct and sounds natural.',
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': 'The Finnish sentence is grammatically correct and sounds natural.',
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Finnish to Russian accurately conveys the same meaning.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The phrase 'в одно и то же время' is a valid form that matches the given Russian word 'в то же время, одновременно'.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The phrase 'samaan aikaan' is correctly used in the Finnish sentence.",
#   'suggestedFix': None}}

# %%
evaluate_flashcard(card7)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The Russian sentence is grammatically correct and natural. 'Вор пытался украсть ценное ювелирное изделие с витрины магазина.' is a well-formed and natural sentence in Russian.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The Finnish sentence is grammatically correct and natural. 'Varas yritti viedä arvokkaan korun näyteikkunasta.' is a well-formed and natural sentence in Finnish.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translation from Finnish to Russian is accurate. 'Varas yritti viedä arvokkaan korun näyteikkunasta.' correctly translates to 'Вор пытался украсть ценное ювелирное изделие с витрины магазина.'",
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
# ...

# %%
evaluate_flashcard(card8)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': 'The sentence is grammatically correct and sounds natural.',
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': 'The sentence is grammatically correct and sounds natural.',
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Finnish to Russian is accurate and maintains the original meaning.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'когда опять' appears in the sentence in the form 'когда моя сестра опять', which is acceptable.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The word 'kun taas' appears in the Finnish sentence in a natural form.",
#   'suggestedFix': None}}

# %%
card9 = WordPair("по-моему", "По-моему, чёрная рубашка отлично тебе идёт.", "musta (minusta)", "Minusta musta paita sopii hyvin sinulle.")
card10 = WordPair("популярный", "Этот ресторан популярен.", "suosittu", "Tämä ravintola on suosittu.")
card11 = WordPair("бесплатный", "Это бесплатно.", "ilmainen", "Tämä on ilmainen.")
card12 = WordPair("взломщик, грабитель", "Грабитель проник в дом через окно.", "murtovaras", "Murtovaras tunkeutui taloon ikkunan kautta.")
card13 = WordPair("объяснить, уточнить", "Мог бы ты уточнить, где ближайшая автобусная остановка?", "selvittää", "Voisitko selvittää, missä lähin bussipysäkki on?")

# %%
evaluate_flashcard(card9)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': 'The Russian sentence is grammatically correct and sounds natural.',
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': 'The Finnish sentence is grammatically correct and sounds natural.',
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Finnish to Russian is accurate.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'по-моему' appears in the Russian sentence in a correct form.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The word 'minusta' appears in the Finnish sentence in a correct form.",
#   'suggestedFix': None}}

# %%
evaluate_flashcard(card10)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Этот ресторан популярен.' is grammatically correct and sounds natural.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Tämä ravintola on suosittu.' is grammatically correct and sounds natural.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translation from Finnish ('Tämä ravintola on suosittu.') to Russian ('Этот ресторан популярен.') is accurate.",
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'популярный' occurs in the sentence in the form 'популярен', which is appropriate and natural in this context.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The word 'suosittu' appears in the sentence in the same form, which is appropriate and natural in this context.",
# ...

# %%
evaluate_flashcard(card11)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Это бесплатно.' is grammatically correct and natural in Russian.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Tämä on ilmainen.' is grammatically correct and natural in Finnish.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': "The translation from Finnish 'Tämä on ilmainen.' to Russian 'Это бесплатно.' is accurate.",
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': False,
#   'explanation': "The word 'бесплатный' (free) in Russian does not appear in the sentence in some form. The sentence uses 'бесплатно' which is an adverb.",
#   'suggestedFixSentence': 'Это бесплатно.',
#   'suggestedFixWord': 'бесплатный, бесплатный'},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The word 'ilmainen' (free) in Finnish appears in the sentence in some form.",
#   'suggestedFix': None}}

# %%
evaluate_flashcard(card12)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Грабитель проник в дом через окно.' is grammatically correct and sounds natural in Russian.",
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': "The sentence 'Murtovaras tunkeutui taloon ikkunan kautta.' is grammatically correct and natural in Finnish.",
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': "The Finnish sentence 'Murtovaras tunkeutui taloon ikkunan kautta.' is an accurate translation of the Russian sentence 'Грабитель проник в дом через окно.'",
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The word 'грабитель' appears in the sentence, which is a synonym of 'взломщик' and is appropriate in this context.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': 'взломщик, грабитель'},
#  'finnishWordUsage': {'isCorrect': True,
# ...

# %%
evaluate_flashcard(card13)
# Out:
# {'russianSentence': {'isCorrect': True,
#   'explanation': 'The Russian sentence is grammatically correct and natural.',
#   'suggestedFix': None},
#  'finnishSentence': {'isCorrect': True,
#   'explanation': 'The Finnish sentence is grammatically correct and natural.',
#   'suggestedFix': None},
#  'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation of the sentence from Finnish to Russian is accurate.',
#   'suggestedFix': None},
#  'russianWordUsage': {'isCorrect': True,
#   'explanation': "The Russian word 'уточнить' is used in the sentence, matching one of the given translations. No changes are necessary.",
#   'suggestedFixSentence': None,
#   'suggestedFixWord': None},
#  'finnishWordUsage': {'isCorrect': True,
#   'explanation': "The Finnish word 'selvittää' is used in the sentence. No changes are necessary.",
#   'suggestedFix': None}}

# %%
card14 = WordPair("Я не катался на лыжах, но много раз катался на коньках.", "", "En ole hiihtänyt, mutta olen luistellut monta kertaa.", "")
card15 = WordPair("Когда Педро пишет письмо на финском, он просит Ханну помочь.", "", "Kun Pedro kirjoittaa kirjettä suomeksi, hän pyytää Hannaa auttamaan.", "")

# %%
evaluate_flashcard(card14)
# Out:
# {'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translated phrase in Finnish accurately reflects the meaning of the Russian phrase, both pertaining to the activities of skiing and skating multiple times.'}}

# %%
evaluate_flashcard(card15)
# Out:
# {'translationAccuracy': {'isCorrect': True,
#   'explanation': 'The translation from Finnish to Russian is accurate and conveys the same meaning.'}}
