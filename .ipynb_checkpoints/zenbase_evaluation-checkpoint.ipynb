# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
import openai
import json
from tqdm.notebook import tqdm
import zenbase
import instructor
import random

os.environ["OPENAI_API_KEY"] = ""

# %%
from zenbase.adaptors.json.adaptor import JSONAdaptor
from zenbase.core.managers import ZenbaseTracer
from zenbase.optim.metric.labeled_few_shot import LabeledFewShot
from zenbase.types import LMDemo
from openai import OpenAI
from pydantic import BaseModel

# %% [markdown]
# # Environment Setup

# %%
openai_client = OpenAI()
instructor_client = instructor.from_openai(openai_client)
zenbase_tracer = ZenbaseTracer()

# %%
class InputModel(BaseModel): #define features of input data 
    russianWord: str
    russianSentence: str
    finnishWord: str
    finnishSentence: str
    id: int

class OutputModel(BaseModel): #define features of output data 
    if_corrected: str
    reasoning: str

# %%
user_prompt_word = """
You are given a flashcard containing a word and a sentence in Russian, along with its translation and a sentence in Finnish. Your task is to evaluate the correctness of the flashcard. Here’s what you need to check:

    1. Whether the sentence in Russian is grammatically correct and natural.
    2. Whether the sentence in Finnish is grammatically correct and natural.
    3. Whether the translation from Finnish to Russian is accurate.
    4. Whether the word in Russian occurs in some form in the Russian sentence.
    5. Whether the word in Finnish occurs in some form in the Finnish sentence.
    
If both sentence in Russian and Finnish are missing it is ok, just check the translation to Finnish. 
    
Check that the word in Russian appear in the sentence in some form, diregarding the case and form of the word, or the order of the words, if the words in russian consists of several words. For example if the word is 'в то же время' and in sentence it's 'в одно и то же время', it's ok. Or if 'когда опять' in the words and 'когда моя сестра опять' is in the sentence. If there are several synonyms in russian word field, then if one of them appears in the sentences in some form it's ok. For example if russian word is 'выносить, красть' and in sentence 'украсть' is used it's ok.
    
If the word doesn't appear in some form, suggest using synonyms or related terms in the translation to ensure the sentence remains natural and accurate. You can change either the sentence translation or the word translation. For example, if the word is "досуг," it can be translated as "досуг" or "свободное время". So if the word "свободное время" is in some form used in the sentence and it sounds natural, suggested fix can be to change the word translation to "досуг, свободное время", keeping the sentence intact
    
In the suggestedFix fields don't provide explanations or instructions, just provide the final corrected string. If it's better to fix word, not sentence, return null for suggestedFixSentence.

Provide a detailed evaluation for each point and suggest fixes where necessary.
    
If both sentence in Russian and Finnish are missing return only translationAccuracy block.

You need to evaluate if any corrections are required, and return True, if you need any corrections and False otherwise.
"""

# %% [markdown]
# # Dataset setup

# %%
df = pd.read_csv('../../data/russian-finnish/cards/all_cards_with_translator_comments.csv', index_col=0)
df
# Out:
#                       wordFirstLang                sentenceFirstLang  \
# 0                 приходить в гости  Мы рады, что вы пришли в гости.
# 1                               вот                    Вот ваш кофе.
# 2                           сувенир             Это для вас сувенир.
# 3                            свежий               Очень свежий хлеб.
# 4                             булка    Давайте выпьем кофе с булкой.
# ...                             ...                              ...
# 7965  Мы продолжим курсы в октябре.                              NaN
# 7967   Я оставлю зонт сегодня дома.                              NaN
# 7969        Стакан падает со стола.                              NaN
# 7971    Курс продолжится в октябре.                              NaN
# 7972     Зонт остался сегодня дома.                              NaN
#
#                               wordSecondLang  \
# 0                              käydä kylässä
# 1                               tässä (tämä)
# 2                                  tuliainen
# 3                                      tuore
# 4                                      pulla
# ...                                      ...
# 7965        Me jatkamme kursseja lokakuussa.
# 7967  Minä jätän sateenvarjon tänään kotiin.
# 7969                   Lasi putoaa pöydältä.
# 7971               Kurssi jatkuu lokakuussa.
# 7972          Sateenvarjo jäi tänään kotiin.
#
#                         sentenceSecondLang      id  if_corrected  \
# 0     Me iloitsimme, että kävitte kylässä.  2265.0         False
# 1                Tässä on teidän kahvinne.  2268.0         False
# 2              Tämä on teille tuliaiseksi.  2269.0         False
# 3                 Todella tuoretta leipää.  2270.0         False
# 4            Juoamme kahvia pullan kanssa.  2271.0          True
# ...                                    ...     ...           ...
# 7965                                   NaN  3573.0         False
# 7967                                   NaN  3575.0         False
# 7969                                   NaN  3577.0         False
# 7971                                   NaN  3579.0         False
# 7972                                   NaN  3580.0         False
#
#                                                new_card translator_comment
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4     wordFirstLang                                 ...  fixed centese fin
# ...                                                 ...                ...
# 7965                                                NaN                NaN
# 7967                                                NaN                NaN
# 7969                                                NaN                NaN
# 7971                                                NaN                NaN
# 7972                                                NaN                NaN
#
# [4625 rows x 8 columns]

# %%
data = df[df['sentenceFirstLang'].notnull()]
data = data.rename(columns={
    "wordFirstLang": "russianWord",
    "sentenceFirstLang": "russianSentence",
    "wordSecondLang": "finnishWord",
    "sentenceSecondLang": "finnishSentence",
})
data = data[["russianWord", "russianSentence", "finnishWord", "finnishSentence", "id", "if_corrected"]]
data = data.dropna()
data
# Out:
#             russianWord                        russianSentence    finnishWord  \
# 0     приходить в гости        Мы рады, что вы пришли в гости.  käydä kylässä
# 1                   вот                          Вот ваш кофе.   tässä (tämä)
# 2               сувенир                   Это для вас сувенир.      tuliainen
# 3                свежий                     Очень свежий хлеб.          tuore
# 4                 булка          Давайте выпьем кофе с булкой.          pulla
# ...                 ...                                    ...            ...
# 3357          ты бежишь                        Куда ты бежишь?   sinä pakenet
# 3358           он бежит               Он бежит в сторону леса.    hän pakenee
# 3359           мы бежим           Спешим, мы убегаем от дождя!   me pakenemme
# 3360        вы убегаете         Куда вы убежите во время бури?   te pakenette
# 3361          они бегут  Они бегут в лес, когда видят медведя.   he pakenevat
#
#                                 finnishSentence      id  if_corrected
# 0          Me iloitsimme, että kävitte kylässä.  2265.0         False
# 1                     Tässä on teidän kahvinne.  2268.0         False
# 2                   Tämä on teille tuliaiseksi.  2269.0         False
# 3                      Todella tuoretta leipää.  2270.0         False
# 4                 Juoamme kahvia pullan kanssa.  2271.0          True
# ...                                         ...     ...           ...
# 3357                        Mihin sinä pakenet?  3590.0          True
# 3358               Hän pakenee metsän suuntaan.  3591.0          True
# 3359       Kiirehditään, me pakenemme sateelta!  3592.0          True
# 3360         Mihin te pakenette myrskyn aikana?  3593.0          True
# 3361  He pakenevat metsään, kun näkevät karhun.  3594.0          True
#
# [3362 rows x 6 columns]

# %%
train_data = pd.concat([
    data[data["if_corrected"] == False].sample(15, random_state=42),
    data[data["if_corrected"] == True].sample(5, random_state=42)
], axis=0, ignore_index=True)

val_data = pd.concat([
    data[data["if_corrected"] == False].sample(5, random_state=21),
    data[data["if_corrected"] == True].sample(3, random_state=21)
], axis=0, ignore_index=True)

# %%
train_set = train_data.to_dict('records')
validation_set = val_data.to_dict('records')

# %% [markdown]
# # Train process

# %%
def process_data(data): # match data features and item parameter (data column)  
    return [
        LMDemo(inputs={
            "russianWord": item["russianWord"],
            "russianSentence": item["russianSentence"],
            "finnishWord": item["finnishWord"],
            "finnishSentence": item["finnishSentence"]
        }, 
               outputs={
                   "if_corrected": item["if_corrected"], 
                   "reasoning": ""
               })
        for item in data
    ]

training_set = process_data(train_set)
validation_set = process_data(validation_set)

# %%
@zenbase_tracer.trace_function
def sentiment_analyzer_function(request):
    messages = [
        {"role": "system", "content": user_prompt_word}, #give a prompt
    ]

    if request.zenbase.task_demos:
        for demo in request.zenbase.task_demos:
            messages.append({"role": "user", "content": str(demo.inputs)})
            messages.append({"role": "assistant", "content": str(demo.outputs)})

    messages.append({"role": "user", "content": str(request.inputs)}) #give data

    return instructor_client.chat.completions.create(
        model="gpt-4o-mini",
        response_model=OutputModel,
        messages=messages
    )

def custom_evaluator(output: OutputModel, ideal_output: dict) -> dict: #define criteria of successful answer
    return {"passed": True if output.if_corrected == ideal_output["if_corrected"] else False}

optimizer = LabeledFewShot(demoset=training_set, shots=3)

result = optimizer.perform(
    lmfn=sentiment_analyzer_function,
    evaluator=JSONAdaptor.metric_evaluator(
        data=validation_set,
        eval_function=custom_evaluator,
    ),
    samples=5,
)

card_analyzer = result.best_function

print("Evaluation of best candidate:", result.best_candidate_result.evals)
# Out:
# Evaluation of best candidate: {'score': 0.0}

# %% [markdown]
# # Results

# %%
card = {
    'russianWord': "тяжёлый",
    'russianSentence': "Эта неделя была действительно тяжёлой.",
    'finnishWord': "rankka",
    'finnishSentence': "Tämä viikko oli todella rankka.",
    'id': 6124
}

print("\nAnalyzing sample card:")
answer = card_analyzer(InputModel(
    russianWord=card["russianWord"],
    russianSentence=card["russianSentence"],
    finnishWord=card["finnishWord"], 
    finnishSentence=card["finnishSentence"],
    id=card["id"]
))
print(f"if_corrected: {answer.if_corrected}")
print(f"Reasoning: {answer.reasoning}")
# Out:
# Analyzing sample card:
# if_corrected: False
# Reasoning:

# %%
validation_dataset = val_data.to_dict('records')

for card in validation_dataset:
    print("\nAnalyzing sample card:")
    print(card)
    answer = card_analyzer(InputModel(
        russianWord=card["russianWord"],
        russianSentence=card["russianSentence"],
        finnishWord=card["finnishWord"], 
        finnishSentence=card["finnishSentence"],
        id=card["id"]
    ))
    print(f"if_corrected: {answer.if_corrected}")
    print(f"Reasoning: {answer.reasoning}")
    print()
# Out:
# Analyzing sample card:
# {'russianWord': 'точка', 'russianSentence': 'Поставь точку в конце предложения.', 'finnishWord': 'piste', 'finnishSentence': 'Laita piste lauseen loppuun.', 'id': 6173.0, 'if_corrected': False}
# if_corrected: False
# Reasoning:
#
#
# Analyzing sample card:
# {'russianWord': 'карьера', 'russianSentence': 'Он хочет преуспеть в своей карьере врача.', 'finnishWord': 'ura', 'finnishSentence': 'Hän haluaa menestyä urallaan lääkärinä.', 'id': 6311.0, 'if_corrected': False}
# if_corrected: False
# Reasoning:
#
#
# Analyzing sample card:
# {'russianWord': 'не говорим', 'russianSentence': 'Было бы лучше, если бы сегодня мы не говорили о политике.', 'finnishWord': 'ei puhuta', 'finnishSentence': 'Olisi parempi, jos ei puhuta politiikasta tänään.', 'id': 3158.0, 'if_corrected': False}
# if_corrected: True
# Reasoning: 1. The Russian sentence is grammatically correct and natural.
# 2. The Finnish sentence has a grammatical issue, as 'ei puhuta' is not correctly used in an indicative form; it should be conditional for the context. A more appropriate phrase would be 'ei puhuttaisi'.
# 3. The translation from Finnish to Russian is not accurate. 'ei puhuta' should translate more accurately as 'мы не будем говорить' or 'не говорим' in this conditional context.
# 4. The word 'не говорим' appears in the sentence in an appropriate form, relating to not talking.
# 5. The word 'ei puhuta' does not naturally appear in the sentence due to the grammatical issue.
# Suggested fixes are needed mainly for the Finnish sentence for correct contextual understanding.
#
#
# Analyzing sample card:
# {'russianWord': 'срок платежа', 'russianSentence': 'Срок оплаты счёта на следующей неделе.', 'finnishWord': 'eräpäivä', 'finnishSentence': 'Laskun eräpäivä on ensi viikolla.', 'id': 3981.0, 'if_corrected': False}
# if_corrected: True
# Reasoning: 1. The Russian sentence 'Срок оплаты счёта на следующей неделе.' is grammatically correct and natural.
# 2. The Finnish sentence 'Laskun eräpäivä on ensi viikolla.' is also grammatically correct and natural.
# 3. The translation from Finnish to Russian is not accurate; 'eräpäivä' translates to 'дата платежа' or 'срок оплаты', not 'срок платежа'.
# 4. The word 'срок платежа' does occur in the Russian sentence in an equivalent form 'срок оплаты'.
# 5. The word 'eräpäivä' is present in the Finnish sentence.
#
# Correction is needed for the translation accuracy and maintaining the context. Suggested fix is to change the Russian translation to better match the context: 'срок оплаты, дата платежа'.
#
#
# Analyzing sample card:
# {'russianWord': 'собирать грибы', 'russianSentence': 'Я собираю грибы в лесу.', 'finnishWord': 'poimia sieniä', 'finnishSentence': 'Minä poimin sieniä metsässä.', 'id': 3776.0, 'if_corrected': False}
# if_corrected: False
# Reasoning:
#
#
# Analyzing sample card:
# {'russianWord': 'уход, возвращение, туда-обратно', 'russianSentence': 'Билет в оба конца из Хельсинки в Тампере стоит примерно 40 евро.', 'finnishWord': 'meno, paluu, meno-paluu', 'finnishSentence': 'Meno-paluu lippu Helsingistä Tampereelle maksaa noin 40 euroa.', 'id': 3038.0, 'if_corrected': True}
# if_corrected: True
# Reasoning: The word 'уход, возвращение, туда-обратно' is relevant to the context but is not used directly in the Russian sentence. However, the Finnish words 'meno, paluu, meno-paluu' appear to be synonyms or related terms for the ticketing concept in travel. The Finnish sentence uses 'meno-paluu', which matches the sense of 'туда-обратно', but doesn't cover the other two words in the Russian sentence. A better match would ensure that 'уход' is replaced with 'поездка' or 'поездка туда-обратно' to match the transportation context better without altering the sentence's meaning.
#
#
# Analyzing sample card:
# {'russianWord': 'собирать', 'russianSentence': 'Можешь помочь мне собрать эту полку?', 'finnishWord': 'koota', 'finnishSentence': 'Voitko auttaa minua kokoamaan tämän hyllyn?', 'id': 5952.0, 'if_corrected': True}
# if_corrected: True
# Reasoning: The Russian sentence contains the verb 'собрать,' which is a synonym of the word 'собирать.' The Finnish sentence uses 'koota' which is also a synonym for 'собирать.' However, the relationship between the words does not imply a direct translation, so it would be more accurate to relate them synonymously.
#
#
# Analyzing sample card:
# {'russianWord': 'молоко', 'russianSentence': 'Молоко - отличный источник кальция.', 'finnishWord': 'maito', 'finnishSentence': 'Maito on erinomainen kalsiumin lähde.', 'id': 2574.0, 'if_corrected': True}
# if_corrected: False
# Reasoning:
